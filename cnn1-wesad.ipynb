# %%
# !pip install pyts
# Out:
# Collecting pyts
#   Downloading pyts-0.13.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.26.4)
# Requirement already satisfied: scipy>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.15.2)
# Requirement already satisfied: scikit-learn>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.4.2)
# Requirement already satisfied: numba>=0.55.2 in /usr/local/lib/python3.11/dist-packages (from pyts) (0.60.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.55.2->pyts) (0.43.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (2.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.2.0->pyts) (3.6.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.22.4->pyts) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.22.4->pyts) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.22.4->pyts) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.22.4->pyts) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.22.4->pyts) (2024.2.0)
# Downloading pyts-0.13.0-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 42.2 MB/s eta 0:00:0000:01
# Installing collected packages: pyts
# Successfully installed pyts-0.13.0

# %%
import os
import pickle
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from mpl_toolkits.axes_grid1 import ImageGrid
from pyts.image import GramianAngularField
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Conv2D, BatchNormalization, MaxPool2D, Flatten, Dense
from keras import backend as K
class ReadData:
    def __init__(self, path, subject):
        self.keys = ['label', 'subject', 'signal']
        self.signal_keys = ['wrist', 'chest']
        self.chest_sensor_keys = ['ACC', 'ECG', 'EDA', 'EMG', 'Resp', 'Temp']
        
        os.chdir(path)
        os.chdir(subject)
        with open(subject + '.pkl', 'rb') as file:
            data = pickle.load(file, encoding='latin1')
        self.data = data
        
    def get_labels(self):
        return self.data[self.keys[0]]
    def get_chest_data(self):
        return self.data[self.keys[2]][self.signal_keys[1]]

# %%
data_path = '/kaggle/input/tiles-05-05/WESAD'
subject = 'S17'
data_target = {subject: ReadData(data_path, subject)}
chest_data_dict = data_target[subject].get_chest_data()

acc_x = chest_data_dict['ACC'][:, 0]
acc_y = chest_data_dict['ACC'][:, 1]
acc_z = chest_data_dict['ACC'][:, 2]
emg_x = chest_data_dict['EMG'][:, 0]
eda_x = chest_data_dict['EDA'][:, 0]
ecg_x = chest_data_dict['ECG'][:, 0]
temp_x = chest_data_dict['Temp'][:, 0]
resp_x = chest_data_dict['Resp'][:, 0]
w_labels = data_target[subject].data['label']

# %%
def quantile_normalize(df):
    df_sorted = pd.DataFrame(np.sort(df.values, axis=0), index=df.index, columns=df.columns)
    df_mean = df_sorted.mean(axis=1)
    df_mean.index = np.arange(1, len(df_mean) + 1)
    df_qn = df.rank(method='min').stack().astype(int).map(df_mean).unstack()
    return df_qn
    
df_chest = pd.DataFrame({
    'ACC_X': acc_x,
    'ACC_Y': acc_y,
    'ACC_Z': acc_z,
    'EMG': emg_x,
    'EDA': eda_x,
    'ECG': ecg_x,
    'Temp': temp_x,
    'Resp': resp_x
})
df_chest['w_labels'] = w_labels  

if 'w_labels' in df_chest.columns:
    baseline_0 = df_chest[df_chest['w_labels'] == 0]  
    baseline = df_chest[df_chest['w_labels'] == 1]    
    stress = df_chest[df_chest['w_labels'] == 2]      
    amusement = df_chest[df_chest['w_labels'] == 3]   
else:
    raise KeyError("'w_labels' column not found in df_chest")

df_0 = baseline_0.tail(10000)
df_1 = baseline.tail(10000)
df_2 = stress.tail(10000)
df_3 = amusement.tail(10000)

df_chest = pd.concat([df_3, df_1, df_2, df_0], ignore_index=True)
print("before",df_chest.shape)
print("Before Normalization:")
print(df_chest.describe())

labels_wesad = df_chest.pop('w_labels').to_numpy()
df_chest = quantile_normalize(df_chest)
print("after",df_chest.shape)
print("After Normalization:")
print(df_chest.describe())
# Out:
# before (40000, 9)
# Before Normalization:
#               ACC_X         ACC_Y         ACC_Z           EMG           EDA  \
# count  40000.000000  40000.000000  40000.000000  40000.000000  40000.000000
# mean       0.693697     -0.003684     -0.516699     -0.004170      6.546550
# std        0.214727      0.052481      0.293308      0.016550      0.778822
# min        0.354600     -0.148600     -0.914400     -0.183975      5.482864
# 25%        0.523450     -0.047800     -0.810000     -0.012497      5.839729
# 50%        0.682000      0.006200     -0.519100     -0.003937      6.629562
# 75%        0.893000      0.043850     -0.210350      0.004257      7.321930
# max        1.257400      0.153400      0.082600      0.152618      7.411575
#
#                 ECG          Temp          Resp      w_labels
# count  40000.000000  40000.000000  40000.000000  40000.000000
# mean       0.000935     33.891136      0.004522      1.500000
# std        0.304003      0.409040      5.204628      1.118048
# min       -0.549454     33.435608    -17.668152      0.000000
# 25%       -0.116867     33.574677     -2.363586      0.750000
# 50%       -0.045273     33.764084     -0.367737      1.500000
# 75%        0.024582     34.114494      3.382874      2.250000
# max        1.499222     34.695465     12.091064      3.000000
# after (40000, 8)
# After Normalization:
#               ACC_X         ACC_Y         ACC_Z           EMG           EDA  \
# count  40000.000000  40000.000000  40000.000000  40000.000000  40000.000000
# mean       5.069479      5.070116      5.071703      5.074770      5.067471
# std        0.872955      0.868172      0.873510      0.867254      0.873757
# min        2.476061      2.476061      2.476061      2.476061      2.476061
# 25%        4.573369      4.521347      4.573388      4.516100      4.573388
# 50%        5.018225      4.916174      5.018225      4.919940      5.018225
# 75%        5.677986      5.694778      5.695512      5.678207      5.681315
# max        7.167918      7.167918      7.167918      7.167918      7.167918
#
#                 ECG          Temp          Resp
# count  40000.000000  40000.000000  40000.000000
# mean       5.076337      5.064553      5.076474
# std        0.867256      0.866327      0.867271
# min        2.476061      2.476061      2.476061
# 25%        4.525111      4.523536      4.522551
# 50%        4.922862      5.018090      4.924158
# 75%        5.679911      5.696830      5.680890
# max        7.141439      7.167918      7.167918

# %%
import tensorflow as tf
from tensorflow.keras import backend as K

def f1_m(y_true, y_pred):
    y_true = K.cast(y_true, dtype='float32')  
    y_pred = K.cast(y_pred, dtype='float32')  
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

def precision_m(y_true, y_pred):
    y_true = K.cast(y_true, dtype='float32')  
    y_pred = K.cast(y_pred, dtype='float32')  
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    return true_positives / (predicted_positives + K.epsilon())

def recall_m(y_true, y_pred):
    y_true = K.cast(y_true, dtype='float32')  
    y_pred = K.cast(y_pred, dtype='float32')  
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from pyts.image import GramianAngularField

gasf = GramianAngularField(method='summation')

X_train = df_chest.to_numpy()
X_train = gasf.fit_transform(X_train)

Y_train = labels_wesad.reshape(len(labels_wesad), 1)
X_train = X_train.reshape(X_train.shape[0], 8, 8, 1).astype('float32')
X_train /= np.amax(X_train)

Y_train = tf.keras.utils.to_categorical(Y_train, num_classes=4)

x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size=0.4, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, test_size=0.5, random_state=42)

print(f"x_train shape: {x_train.shape}, y_train shape: {y_train.shape}")
print(f"x_val shape: {x_val.shape}, y_val shape: {y_val.shape}")
print(f"x_test shape: {x_test.shape}, y_test shape: {y_test.shape}")
# Out:
# x_train shape: (24000, 8, 8, 1), y_train shape: (24000, 4)
# x_val shape: (8000, 8, 8, 1), y_val shape: (8000, 4)
# x_test shape: (8000, 8, 8, 1), y_test shape: (8000, 4)

# %%
import matplotlib.pyplot as plt

sample_idx = 0  

sample_gaf_image = x_train[sample_idx, :, :, 0]  

plt.figure(figsize=(4, 4))
plt.imshow(sample_gaf_image, cmap='viridis')  
plt.colorbar()
plt.title(f"Sample GAF Image (Index {sample_idx})")
plt.show()

# %%
import tensorflow as tf
from tensorflow.keras import layers, regularizers, callbacks

# Define the Model with Swish Activation
model_CNN = tf.keras.Sequential([
    layers.Conv2D(32, (3,3), padding="same", kernel_regularizer=regularizers.l2(1e-6), input_shape=(8, 8, 1)),
    layers.BatchNormalization(),
    layers.Activation('swish'),  
    layers.MaxPooling2D(2, 2),

    layers.Conv2D(64, (3,3), padding="same", kernel_regularizer=regularizers.l2(1e-6)),
    layers.BatchNormalization(),
    layers.Activation('swish'),  
    layers.MaxPooling2D(2, 2),

    layers.Conv2D(128, (3,3), padding="same", kernel_regularizer=regularizers.l2(1e-6)),  
    layers.BatchNormalization(),
    layers.Activation('swish'),  
    layers.MaxPooling2D(2, 2),

    layers.Flatten(),
    layers.Dense(64, activation='swish', kernel_regularizer=regularizers.l2(1e-6)), 
    layers.BatchNormalization(),

    layers.Dense(4, activation='softmax')
])
loss = tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1)

optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)

model_CNN.compile(optimizer=optimizer, 
                  loss=loss, 
                  metrics=['accuracy', f1_m, precision_m, recall_m])

# %%
model_checkpoint = callbacks.ModelCheckpoint("/kaggle/working/best_model.keras", save_best_only=True, monitor='val_loss', verbose=1)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1)

history = model_CNN.fit(
    x_train, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(x_val, y_val),
    callbacks=[ model_checkpoint, reduce_lr]
)
# Out:
# Epoch 1/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8092 - f1_m: 0.7955 - loss: 0.7259 - precision_m: 0.8430 - recall_m: 0.7555
# Epoch 1: val_loss improved from inf to 0.58885, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.8093 - f1_m: 0.7956 - loss: 0.7257 - precision_m: 0.8431 - recall_m: 0.7557 - val_accuracy: 0.8844 - val_f1_m: 0.8814 - val_loss: 0.5889 - val_precision_m: 0.9026 - val_recall_m: 0.8618 - learning_rate: 0.0010
# Epoch 2/100
# 743/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8958 - f1_m: 0.8926 - loss: 0.5543 - precision_m: 0.9180 - recall_m: 0.8693
# Epoch 2: val_loss improved from 0.58885 to 0.52916, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.8959 - f1_m: 0.8926 - loss: 0.5542 - precision_m: 0.9181 - recall_m: 0.8693 - val_accuracy: 0.9110 - val_f1_m: 0.9090 - val_loss: 0.5292 - val_precision_m: 0.9298 - val_recall_m: 0.8896 - learning_rate: 0.0010
# Epoch 3/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9170 - f1_m: 0.9135 - loss: 0.5185 - precision_m: 0.9330 - recall_m: 0.8955
# Epoch 3: val_loss improved from 0.52916 to 0.50981, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9170 - f1_m: 0.9135 - loss: 0.5185 - precision_m: 0.9330 - recall_m: 0.8955 - val_accuracy: 0.9190 - val_f1_m: 0.9179 - val_loss: 0.5098 - val_precision_m: 0.9336 - val_recall_m: 0.9032 - learning_rate: 0.0010
# Epoch 4/100
# 745/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9203 - f1_m: 0.9183 - loss: 0.5114 - precision_m: 0.9354 - recall_m: 0.9024
# Epoch 4: val_loss improved from 0.50981 to 0.50223, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9203 - f1_m: 0.9183 - loss: 0.5114 - precision_m: 0.9354 - recall_m: 0.9025 - val_accuracy: 0.9258 - val_f1_m: 0.9248 - val_loss: 0.5022 - val_precision_m: 0.9404 - val_recall_m: 0.9101 - learning_rate: 0.0010
# Epoch 5/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9320 - f1_m: 0.9294 - loss: 0.4924 - precision_m: 0.9444 - recall_m: 0.9154
# Epoch 5: val_loss improved from 0.50223 to 0.49886, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9320 - f1_m: 0.9294 - loss: 0.4924 - precision_m: 0.9444 - recall_m: 0.9154 - val_accuracy: 0.9262 - val_f1_m: 0.9227 - val_loss: 0.4989 - val_precision_m: 0.9371 - val_recall_m: 0.9090 - learning_rate: 0.0010
# Epoch 6/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9378 - f1_m: 0.9355 - loss: 0.4811 - precision_m: 0.9487 - recall_m: 0.9230
# Epoch 6: val_loss did not improve from 0.49886
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9378 - f1_m: 0.9355 - loss: 0.4811 - precision_m: 0.9487 - recall_m: 0.9230 - val_accuracy: 0.9112 - val_f1_m: 0.9102 - val_loss: 0.5197 - val_precision_m: 0.9232 - val_recall_m: 0.8979 - learning_rate: 0.0010
# Epoch 7/100
# 743/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9369 - f1_m: 0.9362 - loss: 0.4788 - precision_m: 0.9479 - recall_m: 0.9251
# Epoch 7: val_loss improved from 0.49886 to 0.48027, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9369 - f1_m: 0.9362 - loss: 0.4788 - precision_m: 0.9479 - recall_m: 0.9251 - val_accuracy: 0.9369 - val_f1_m: 0.9368 - val_loss: 0.4803 - val_precision_m: 0.9478 - val_recall_m: 0.9264 - learning_rate: 0.0010
# Epoch 8/100
# 743/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9434 - f1_m: 0.9414 - loss: 0.4690 - precision_m: 0.9518 - recall_m: 0.9315
# Epoch 8: val_loss did not improve from 0.48027
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9433 - f1_m: 0.9414 - loss: 0.4690 - precision_m: 0.9518 - recall_m: 0.9315 - val_accuracy: 0.9261 - val_f1_m: 0.9268 - val_loss: 0.4993 - val_precision_m: 0.9362 - val_recall_m: 0.9179 - learning_rate: 0.0010
# Epoch 9/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9484 - f1_m: 0.9461 - loss: 0.4629 - precision_m: 0.9559 - recall_m: 0.9368
# Epoch 9: val_loss did not improve from 0.48027
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9484 - f1_m: 0.9461 - loss: 0.4629 - precision_m: 0.9559 - recall_m: 0.9367 - val_accuracy: 0.9308 - val_f1_m: 0.9298 - val_loss: 0.4886 - val_precision_m: 0.9388 - val_recall_m: 0.9212 - learning_rate: 0.0010
# Epoch 10/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9494 - f1_m: 0.9494 - loss: 0.4544 - precision_m: 0.9591 - recall_m: 0.9401
# Epoch 10: val_loss improved from 0.48027 to 0.47744, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9494 - f1_m: 0.9494 - loss: 0.4544 - precision_m: 0.9591 - recall_m: 0.9401 - val_accuracy: 0.9354 - val_f1_m: 0.9342 - val_loss: 0.4774 - val_precision_m: 0.9426 - val_recall_m: 0.9261 - learning_rate: 0.0010
# Epoch 11/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9513 - f1_m: 0.9505 - loss: 0.4531 - precision_m: 0.9590 - recall_m: 0.9424
# Epoch 11: val_loss did not improve from 0.47744
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9513 - f1_m: 0.9505 - loss: 0.4532 - precision_m: 0.9590 - recall_m: 0.9424 - val_accuracy: 0.9336 - val_f1_m: 0.9325 - val_loss: 0.4854 - val_precision_m: 0.9417 - val_recall_m: 0.9239 - learning_rate: 0.0010
# Epoch 12/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9543 - f1_m: 0.9533 - loss: 0.4493 - precision_m: 0.9611 - recall_m: 0.9459
# Epoch 12: val_loss did not improve from 0.47744
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9543 - f1_m: 0.9533 - loss: 0.4493 - precision_m: 0.9611 - recall_m: 0.9459 - val_accuracy: 0.9367 - val_f1_m: 0.9347 - val_loss: 0.4815 - val_precision_m: 0.9443 - val_recall_m: 0.9256 - learning_rate: 0.0010
# Epoch 13/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9551 - f1_m: 0.9549 - loss: 0.4474 - precision_m: 0.9630 - recall_m: 0.9472
# Epoch 13: val_loss improved from 0.47744 to 0.47225, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9551 - f1_m: 0.9549 - loss: 0.4475 - precision_m: 0.9630 - recall_m: 0.9472 - val_accuracy: 0.9388 - val_f1_m: 0.9378 - val_loss: 0.4723 - val_precision_m: 0.9483 - val_recall_m: 0.9279 - learning_rate: 0.0010
# Epoch 14/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9581 - f1_m: 0.9579 - loss: 0.4408 - precision_m: 0.9651 - recall_m: 0.9510
# Epoch 14: val_loss did not improve from 0.47225
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9581 - f1_m: 0.9578 - loss: 0.4408 - precision_m: 0.9650 - recall_m: 0.9510 - val_accuracy: 0.9366 - val_f1_m: 0.9360 - val_loss: 0.4868 - val_precision_m: 0.9444 - val_recall_m: 0.9280 - learning_rate: 0.0010
# Epoch 15/100
# 743/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9594 - f1_m: 0.9596 - loss: 0.4365 - precision_m: 0.9667 - recall_m: 0.9529
# Epoch 15: val_loss did not improve from 0.47225
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9594 - f1_m: 0.9596 - loss: 0.4365 - precision_m: 0.9667 - recall_m: 0.9528 - val_accuracy: 0.9371 - val_f1_m: 0.9368 - val_loss: 0.4759 - val_precision_m: 0.9465 - val_recall_m: 0.9276 - learning_rate: 0.0010
# Epoch 16/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9633 - f1_m: 0.9629 - loss: 0.4338 - precision_m: 0.9700 - recall_m: 0.9561
# Epoch 16: val_loss improved from 0.47225 to 0.46935, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9633 - f1_m: 0.9629 - loss: 0.4338 - precision_m: 0.9700 - recall_m: 0.9561 - val_accuracy: 0.9404 - val_f1_m: 0.9405 - val_loss: 0.4693 - val_precision_m: 0.9461 - val_recall_m: 0.9351 - learning_rate: 0.0010
# Epoch 17/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9617 - f1_m: 0.9614 - loss: 0.4340 - precision_m: 0.9679 - recall_m: 0.9551
# Epoch 17: val_loss improved from 0.46935 to 0.46235, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9617 - f1_m: 0.9614 - loss: 0.4340 - precision_m: 0.9679 - recall_m: 0.9551 - val_accuracy: 0.9461 - val_f1_m: 0.9458 - val_loss: 0.4624 - val_precision_m: 0.9518 - val_recall_m: 0.9401 - learning_rate: 0.0010
# Epoch 18/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9663 - f1_m: 0.9658 - loss: 0.4272 - precision_m: 0.9718 - recall_m: 0.9600
# Epoch 18: val_loss did not improve from 0.46235
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9662 - f1_m: 0.9657 - loss: 0.4272 - precision_m: 0.9717 - recall_m: 0.9600 - val_accuracy: 0.9444 - val_f1_m: 0.9443 - val_loss: 0.4669 - val_precision_m: 0.9500 - val_recall_m: 0.9388 - learning_rate: 0.0010
# Epoch 19/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9650 - f1_m: 0.9636 - loss: 0.4270 - precision_m: 0.9701 - recall_m: 0.9575
# Epoch 19: val_loss did not improve from 0.46235
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9649 - f1_m: 0.9636 - loss: 0.4270 - precision_m: 0.9701 - recall_m: 0.9575 - val_accuracy: 0.9426 - val_f1_m: 0.9421 - val_loss: 0.4707 - val_precision_m: 0.9480 - val_recall_m: 0.9364 - learning_rate: 0.0010
# Epoch 20/100
# 744/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9630 - f1_m: 0.9627 - loss: 0.4301 - precision_m: 0.9687 - recall_m: 0.9570
# Epoch 20: val_loss did not improve from 0.46235
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9630 - f1_m: 0.9627 - loss: 0.4301 - precision_m: 0.9687 - recall_m: 0.9570 - val_accuracy: 0.9362 - val_f1_m: 0.9350 - val_loss: 0.4848 - val_precision_m: 0.9420 - val_recall_m: 0.9284 - learning_rate: 0.0010
# Epoch 21/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9726 - f1_m: 0.9723 - loss: 0.4113 - precision_m: 0.9769 - recall_m: 0.9680
# Epoch 21: val_loss improved from 0.46235 to 0.45282, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9726 - f1_m: 0.9723 - loss: 0.4113 - precision_m: 0.9769 - recall_m: 0.9680 - val_accuracy: 0.9511 - val_f1_m: 0.9501 - val_loss: 0.4528 - val_precision_m: 0.9554 - val_recall_m: 0.9450 - learning_rate: 5.0000e-04
# Epoch 22/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9755 - f1_m: 0.9758 - loss: 0.4060 - precision_m: 0.9801 - recall_m: 0.9717
# Epoch 22: val_loss did not improve from 0.45282
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9755 - f1_m: 0.9758 - loss: 0.4060 - precision_m: 0.9801 - recall_m: 0.9717 - val_accuracy: 0.9491 - val_f1_m: 0.9490 - val_loss: 0.4566 - val_precision_m: 0.9543 - val_recall_m: 0.9439 - learning_rate: 5.0000e-04
# Epoch 23/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9792 - f1_m: 0.9783 - loss: 0.4034 - precision_m: 0.9830 - recall_m: 0.9739
# Epoch 23: val_loss improved from 0.45282 to 0.45218, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9792 - f1_m: 0.9783 - loss: 0.4034 - precision_m: 0.9830 - recall_m: 0.9738 - val_accuracy: 0.9496 - val_f1_m: 0.9499 - val_loss: 0.4522 - val_precision_m: 0.9552 - val_recall_m: 0.9448 - learning_rate: 5.0000e-04
# Epoch 24/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9809 - f1_m: 0.9801 - loss: 0.4013 - precision_m: 0.9836 - recall_m: 0.9768
# Epoch 24: val_loss did not improve from 0.45218
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9809 - f1_m: 0.9801 - loss: 0.4013 - precision_m: 0.9836 - recall_m: 0.9768 - val_accuracy: 0.9503 - val_f1_m: 0.9509 - val_loss: 0.4538 - val_precision_m: 0.9562 - val_recall_m: 0.9457 - learning_rate: 5.0000e-04
# Epoch 25/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9815 - f1_m: 0.9809 - loss: 0.3992 - precision_m: 0.9842 - recall_m: 0.9777
# Epoch 25: val_loss did not improve from 0.45218
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9815 - f1_m: 0.9809 - loss: 0.3992 - precision_m: 0.9842 - recall_m: 0.9776 - val_accuracy: 0.9499 - val_f1_m: 0.9504 - val_loss: 0.4576 - val_precision_m: 0.9559 - val_recall_m: 0.9451 - learning_rate: 5.0000e-04
# Epoch 26/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9828 - f1_m: 0.9825 - loss: 0.3954 - precision_m: 0.9859 - recall_m: 0.9792
# Epoch 26: val_loss did not improve from 0.45218
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9828 - f1_m: 0.9825 - loss: 0.3955 - precision_m: 0.9859 - recall_m: 0.9792 - val_accuracy: 0.9500 - val_f1_m: 0.9493 - val_loss: 0.4543 - val_precision_m: 0.9546 - val_recall_m: 0.9442 - learning_rate: 5.0000e-04
# Epoch 27/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9862 - f1_m: 0.9857 - loss: 0.3908 - precision_m: 0.9887 - recall_m: 0.9829
# Epoch 27: val_loss did not improve from 0.45218
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9862 - f1_m: 0.9857 - loss: 0.3908 - precision_m: 0.9887 - recall_m: 0.9829 - val_accuracy: 0.9521 - val_f1_m: 0.9520 - val_loss: 0.4540 - val_precision_m: 0.9563 - val_recall_m: 0.9479 - learning_rate: 2.5000e-04
# Epoch 28/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9884 - f1_m: 0.9874 - loss: 0.3890 - precision_m: 0.9902 - recall_m: 0.9848
# Epoch 28: val_loss did not improve from 0.45218
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9884 - f1_m: 0.9874 - loss: 0.3890 - precision_m: 0.9902 - recall_m: 0.9848 - val_accuracy: 0.9491 - val_f1_m: 0.9497 - val_loss: 0.4550 - val_precision_m: 0.9550 - val_recall_m: 0.9446 - learning_rate: 2.5000e-04
# Epoch 29/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9898 - f1_m: 0.9894 - loss: 0.3852 - precision_m: 0.9918 - recall_m: 0.9872
# Epoch 29: val_loss did not improve from 0.45218
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9898 - f1_m: 0.9894 - loss: 0.3852 - precision_m: 0.9918 - recall_m: 0.9872 - val_accuracy: 0.9524 - val_f1_m: 0.9518 - val_loss: 0.4534 - val_precision_m: 0.9572 - val_recall_m: 0.9465 - learning_rate: 2.5000e-04
# Epoch 30/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9912 - f1_m: 0.9908 - loss: 0.3819 - precision_m: 0.9929 - recall_m: 0.9888
# Epoch 30: val_loss improved from 0.45218 to 0.45198, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9912 - f1_m: 0.9908 - loss: 0.3819 - precision_m: 0.9929 - recall_m: 0.9888 - val_accuracy: 0.9536 - val_f1_m: 0.9536 - val_loss: 0.4520 - val_precision_m: 0.9582 - val_recall_m: 0.9492 - learning_rate: 1.2500e-04
# Epoch 31/100
# 745/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9921 - f1_m: 0.9915 - loss: 0.3807 - precision_m: 0.9931 - recall_m: 0.9898
# Epoch 31: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9920 - f1_m: 0.9914 - loss: 0.3807 - precision_m: 0.9931 - recall_m: 0.9898 - val_accuracy: 0.9529 - val_f1_m: 0.9523 - val_loss: 0.4540 - val_precision_m: 0.9564 - val_recall_m: 0.9484 - learning_rate: 1.2500e-04
# Epoch 32/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9921 - f1_m: 0.9918 - loss: 0.3799 - precision_m: 0.9930 - recall_m: 0.9907
# Epoch 32: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9921 - f1_m: 0.9918 - loss: 0.3799 - precision_m: 0.9930 - recall_m: 0.9907 - val_accuracy: 0.9544 - val_f1_m: 0.9538 - val_loss: 0.4535 - val_precision_m: 0.9585 - val_recall_m: 0.9494 - learning_rate: 1.2500e-04
# Epoch 33/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9929 - f1_m: 0.9927 - loss: 0.3793 - precision_m: 0.9942 - recall_m: 0.9912
# Epoch 33: val_loss did not improve from 0.45198
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9929 - f1_m: 0.9927 - loss: 0.3793 - precision_m: 0.9942 - recall_m: 0.9912 - val_accuracy: 0.9526 - val_f1_m: 0.9523 - val_loss: 0.4533 - val_precision_m: 0.9571 - val_recall_m: 0.9476 - learning_rate: 1.2500e-04
# Epoch 34/100
# 744/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9938 - f1_m: 0.9940 - loss: 0.3768 - precision_m: 0.9955 - recall_m: 0.9926
# Epoch 34: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9938 - f1_m: 0.9940 - loss: 0.3768 - precision_m: 0.9955 - recall_m: 0.9925 - val_accuracy: 0.9531 - val_f1_m: 0.9524 - val_loss: 0.4537 - val_precision_m: 0.9573 - val_recall_m: 0.9477 - learning_rate: 6.2500e-05
# Epoch 35/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9930 - f1_m: 0.9932 - loss: 0.3785 - precision_m: 0.9948 - recall_m: 0.9917
# Epoch 35: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9930 - f1_m: 0.9932 - loss: 0.3785 - precision_m: 0.9948 - recall_m: 0.9917 - val_accuracy: 0.9532 - val_f1_m: 0.9526 - val_loss: 0.4555 - val_precision_m: 0.9567 - val_recall_m: 0.9488 - learning_rate: 6.2500e-05
# Epoch 36/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9948 - f1_m: 0.9943 - loss: 0.3766 - precision_m: 0.9956 - recall_m: 0.9931
# Epoch 36: val_loss did not improve from 0.45198
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9948 - f1_m: 0.9943 - loss: 0.3766 - precision_m: 0.9956 - recall_m: 0.9931 - val_accuracy: 0.9539 - val_f1_m: 0.9524 - val_loss: 0.4535 - val_precision_m: 0.9571 - val_recall_m: 0.9480 - learning_rate: 6.2500e-05
# Epoch 37/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9943 - f1_m: 0.9941 - loss: 0.3765 - precision_m: 0.9956 - recall_m: 0.9927
# Epoch 37: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9943 - f1_m: 0.9941 - loss: 0.3765 - precision_m: 0.9956 - recall_m: 0.9927 - val_accuracy: 0.9532 - val_f1_m: 0.9529 - val_loss: 0.4545 - val_precision_m: 0.9573 - val_recall_m: 0.9486 - learning_rate: 3.1250e-05
# Epoch 38/100
# 743/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9938 - f1_m: 0.9940 - loss: 0.3763 - precision_m: 0.9952 - recall_m: 0.9929
# Epoch 38: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9938 - f1_m: 0.9940 - loss: 0.3763 - precision_m: 0.9952 - recall_m: 0.9929 - val_accuracy: 0.9530 - val_f1_m: 0.9527 - val_loss: 0.4550 - val_precision_m: 0.9572 - val_recall_m: 0.9484 - learning_rate: 3.1250e-05
# Epoch 39/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9951 - f1_m: 0.9948 - loss: 0.3755 - precision_m: 0.9959 - recall_m: 0.9937
# Epoch 39: val_loss did not improve from 0.45198
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9951 - f1_m: 0.9948 - loss: 0.3755 - precision_m: 0.9959 - recall_m: 0.9937 - val_accuracy: 0.9538 - val_f1_m: 0.9529 - val_loss: 0.4551 - val_precision_m: 0.9573 - val_recall_m: 0.9488 - learning_rate: 3.1250e-05
# Epoch 40/100
# 744/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9950 - f1_m: 0.9949 - loss: 0.3753 - precision_m: 0.9960 - recall_m: 0.9939
# Epoch 40: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9950 - f1_m: 0.9949 - loss: 0.3753 - precision_m: 0.9960 - recall_m: 0.9939 - val_accuracy: 0.9536 - val_f1_m: 0.9529 - val_loss: 0.4545 - val_precision_m: 0.9572 - val_recall_m: 0.9488 - learning_rate: 1.5625e-05
# Epoch 41/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9949 - f1_m: 0.9947 - loss: 0.3751 - precision_m: 0.9960 - recall_m: 0.9934
# Epoch 41: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9949 - f1_m: 0.9947 - loss: 0.3751 - precision_m: 0.9960 - recall_m: 0.9934 - val_accuracy: 0.9538 - val_f1_m: 0.9527 - val_loss: 0.4551 - val_precision_m: 0.9570 - val_recall_m: 0.9485 - learning_rate: 1.5625e-05
# Epoch 42/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9951 - f1_m: 0.9947 - loss: 0.3751 - precision_m: 0.9958 - recall_m: 0.9936
# Epoch 42: val_loss did not improve from 0.45198
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9951 - f1_m: 0.9947 - loss: 0.3751 - precision_m: 0.9958 - recall_m: 0.9936 - val_accuracy: 0.9536 - val_f1_m: 0.9528 - val_loss: 0.4553 - val_precision_m: 0.9576 - val_recall_m: 0.9481 - learning_rate: 1.5625e-05
# Epoch 43/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9946 - f1_m: 0.9942 - loss: 0.3761 - precision_m: 0.9955 - recall_m: 0.9929
# Epoch 43: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9946 - f1_m: 0.9942 - loss: 0.3761 - precision_m: 0.9956 - recall_m: 0.9929 - val_accuracy: 0.9544 - val_f1_m: 0.9523 - val_loss: 0.4551 - val_precision_m: 0.9568 - val_recall_m: 0.9480 - learning_rate: 7.8125e-06
# Epoch 44/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9952 - f1_m: 0.9950 - loss: 0.3751 - precision_m: 0.9963 - recall_m: 0.9939
# Epoch 44: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9952 - f1_m: 0.9950 - loss: 0.3751 - precision_m: 0.9963 - recall_m: 0.9939 - val_accuracy: 0.9540 - val_f1_m: 0.9525 - val_loss: 0.4551 - val_precision_m: 0.9570 - val_recall_m: 0.9481 - learning_rate: 7.8125e-06
# Epoch 45/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9957 - f1_m: 0.9953 - loss: 0.3752 - precision_m: 0.9965 - recall_m: 0.9941
# Epoch 45: val_loss did not improve from 0.45198
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9957 - f1_m: 0.9953 - loss: 0.3752 - precision_m: 0.9965 - recall_m: 0.9941 - val_accuracy: 0.9538 - val_f1_m: 0.9525 - val_loss: 0.4556 - val_precision_m: 0.9575 - val_recall_m: 0.9476 - learning_rate: 7.8125e-06
# Epoch 46/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9954 - f1_m: 0.9950 - loss: 0.3745 - precision_m: 0.9963 - recall_m: 0.9937
# Epoch 46: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9954 - f1_m: 0.9950 - loss: 0.3745 - precision_m: 0.9963 - recall_m: 0.9937 - val_accuracy: 0.9540 - val_f1_m: 0.9528 - val_loss: 0.4553 - val_precision_m: 0.9572 - val_recall_m: 0.9485 - learning_rate: 3.9063e-06
# Epoch 47/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9951 - f1_m: 0.9946 - loss: 0.3750 - precision_m: 0.9956 - recall_m: 0.9936
# Epoch 47: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9951 - f1_m: 0.9946 - loss: 0.3750 - precision_m: 0.9956 - recall_m: 0.9936 - val_accuracy: 0.9538 - val_f1_m: 0.9525 - val_loss: 0.4551 - val_precision_m: 0.9571 - val_recall_m: 0.9481 - learning_rate: 3.9063e-06
# Epoch 48/100
# 745/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9947 - f1_m: 0.9944 - loss: 0.3750 - precision_m: 0.9960 - recall_m: 0.9929
# Epoch 48: val_loss did not improve from 0.45198
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9947 - f1_m: 0.9944 - loss: 0.3750 - precision_m: 0.9960 - recall_m: 0.9930 - val_accuracy: 0.9536 - val_f1_m: 0.9524 - val_loss: 0.4552 - val_precision_m: 0.9571 - val_recall_m: 0.9479 - learning_rate: 3.9063e-06
# Epoch 49/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9946 - f1_m: 0.9950 - loss: 0.3748 - precision_m: 0.9962 - recall_m: 0.9937
# Epoch 49: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9946 - f1_m: 0.9950 - loss: 0.3748 - precision_m: 0.9962 - recall_m: 0.9937 - val_accuracy: 0.9535 - val_f1_m: 0.9526 - val_loss: 0.4551 - val_precision_m: 0.9569 - val_recall_m: 0.9485 - learning_rate: 1.9531e-06
# Epoch 50/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9951 - f1_m: 0.9949 - loss: 0.3751 - precision_m: 0.9961 - recall_m: 0.9937
# Epoch 50: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9951 - f1_m: 0.9949 - loss: 0.3751 - precision_m: 0.9961 - recall_m: 0.9937 - val_accuracy: 0.9535 - val_f1_m: 0.9526 - val_loss: 0.4552 - val_precision_m: 0.9568 - val_recall_m: 0.9486 - learning_rate: 1.9531e-06
# Epoch 51/100
# 745/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9959 - f1_m: 0.9957 - loss: 0.3732 - precision_m: 0.9970 - recall_m: 0.9944
# Epoch 51: val_loss did not improve from 0.45198
#
# Epoch 51: ReduceLROnPlateau reducing learning rate to 1e-06.
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9959 - f1_m: 0.9957 - loss: 0.3732 - precision_m: 0.9970 - recall_m: 0.9944 - val_accuracy: 0.9535 - val_f1_m: 0.9526 - val_loss: 0.4551 - val_precision_m: 0.9567 - val_recall_m: 0.9486 - learning_rate: 1.9531e-06
# Epoch 52/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9963 - f1_m: 0.9956 - loss: 0.3744 - precision_m: 0.9969 - recall_m: 0.9945
# Epoch 52: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9963 - f1_m: 0.9956 - loss: 0.3744 - precision_m: 0.9969 - recall_m: 0.9945 - val_accuracy: 0.9531 - val_f1_m: 0.9522 - val_loss: 0.4551 - val_precision_m: 0.9567 - val_recall_m: 0.9479 - learning_rate: 1.0000e-06
# Epoch 53/100
# 744/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9957 - f1_m: 0.9952 - loss: 0.3746 - precision_m: 0.9962 - recall_m: 0.9943
# Epoch 53: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9957 - f1_m: 0.9952 - loss: 0.3746 - precision_m: 0.9962 - recall_m: 0.9943 - val_accuracy: 0.9534 - val_f1_m: 0.9528 - val_loss: 0.4557 - val_precision_m: 0.9571 - val_recall_m: 0.9486 - learning_rate: 1.0000e-06
# Epoch 54/100
# 744/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9960 - f1_m: 0.9955 - loss: 0.3747 - precision_m: 0.9968 - recall_m: 0.9942
# Epoch 54: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9960 - f1_m: 0.9955 - loss: 0.3747 - precision_m: 0.9968 - recall_m: 0.9942 - val_accuracy: 0.9532 - val_f1_m: 0.9524 - val_loss: 0.4552 - val_precision_m: 0.9569 - val_recall_m: 0.9481 - learning_rate: 1.0000e-06
# Epoch 55/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9947 - f1_m: 0.9946 - loss: 0.3759 - precision_m: 0.9960 - recall_m: 0.9933
# Epoch 55: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9947 - f1_m: 0.9946 - loss: 0.3759 - precision_m: 0.9960 - recall_m: 0.9933 - val_accuracy: 0.9529 - val_f1_m: 0.9523 - val_loss: 0.4554 - val_precision_m: 0.9568 - val_recall_m: 0.9480 - learning_rate: 1.0000e-06
# Epoch 56/100
# 744/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9942 - f1_m: 0.9942 - loss: 0.3750 - precision_m: 0.9957 - recall_m: 0.9927
# Epoch 56: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9942 - f1_m: 0.9942 - loss: 0.3750 - precision_m: 0.9957 - recall_m: 0.9927 - val_accuracy: 0.9538 - val_f1_m: 0.9526 - val_loss: 0.4547 - val_precision_m: 0.9567 - val_recall_m: 0.9486 - learning_rate: 1.0000e-06
# Epoch 57/100
# 741/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9958 - f1_m: 0.9951 - loss: 0.3751 - precision_m: 0.9965 - recall_m: 0.9937
# Epoch 57: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9958 - f1_m: 0.9951 - loss: 0.3751 - precision_m: 0.9965 - recall_m: 0.9937 - val_accuracy: 0.9535 - val_f1_m: 0.9526 - val_loss: 0.4547 - val_precision_m: 0.9571 - val_recall_m: 0.9482 - learning_rate: 1.0000e-06
# Epoch 58/100
# 745/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9960 - f1_m: 0.9959 - loss: 0.3741 - precision_m: 0.9970 - recall_m: 0.9947
# Epoch 58: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9960 - f1_m: 0.9959 - loss: 0.3741 - precision_m: 0.9970 - recall_m: 0.9947 - val_accuracy: 0.9540 - val_f1_m: 0.9526 - val_loss: 0.4551 - val_precision_m: 0.9569 - val_recall_m: 0.9485 - learning_rate: 1.0000e-06
# Epoch 59/100
# 743/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9946 - f1_m: 0.9942 - loss: 0.3748 - precision_m: 0.9952 - recall_m: 0.9931
# Epoch 59: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9946 - f1_m: 0.9942 - loss: 0.3748 - precision_m: 0.9953 - recall_m: 0.9931 - val_accuracy: 0.9532 - val_f1_m: 0.9524 - val_loss: 0.4551 - val_precision_m: 0.9568 - val_recall_m: 0.9481 - learning_rate: 1.0000e-06
# Epoch 60/100
# 743/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9958 - f1_m: 0.9953 - loss: 0.3745 - precision_m: 0.9967 - recall_m: 0.9940
# Epoch 60: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9958 - f1_m: 0.9953 - loss: 0.3745 - precision_m: 0.9967 - recall_m: 0.9940 - val_accuracy: 0.9536 - val_f1_m: 0.9525 - val_loss: 0.4548 - val_precision_m: 0.9572 - val_recall_m: 0.9481 - learning_rate: 1.0000e-06
# Epoch 61/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9946 - f1_m: 0.9947 - loss: 0.3747 - precision_m: 0.9963 - recall_m: 0.9932
# Epoch 61: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9946 - f1_m: 0.9947 - loss: 0.3747 - precision_m: 0.9963 - recall_m: 0.9932 - val_accuracy: 0.9534 - val_f1_m: 0.9523 - val_loss: 0.4549 - val_precision_m: 0.9567 - val_recall_m: 0.9480 - learning_rate: 1.0000e-06
# Epoch 62/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9950 - f1_m: 0.9946 - loss: 0.3756 - precision_m: 0.9957 - recall_m: 0.9935
# Epoch 62: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9950 - f1_m: 0.9946 - loss: 0.3756 - precision_m: 0.9957 - recall_m: 0.9935 - val_accuracy: 0.9534 - val_f1_m: 0.9524 - val_loss: 0.4551 - val_precision_m: 0.9567 - val_recall_m: 0.9482 - learning_rate: 1.0000e-06
# Epoch 63/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9957 - f1_m: 0.9959 - loss: 0.3754 - precision_m: 0.9969 - recall_m: 0.9949
# Epoch 63: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9957 - f1_m: 0.9959 - loss: 0.3754 - precision_m: 0.9969 - recall_m: 0.9949 - val_accuracy: 0.9535 - val_f1_m: 0.9525 - val_loss: 0.4549 - val_precision_m: 0.9568 - val_recall_m: 0.9484 - learning_rate: 1.0000e-06
# Epoch 64/100
# 745/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9953 - f1_m: 0.9950 - loss: 0.3757 - precision_m: 0.9966 - recall_m: 0.9936
# Epoch 64: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9953 - f1_m: 0.9950 - loss: 0.3757 - precision_m: 0.9966 - recall_m: 0.9936 - val_accuracy: 0.9539 - val_f1_m: 0.9525 - val_loss: 0.4551 - val_precision_m: 0.9570 - val_recall_m: 0.9481 - learning_rate: 1.0000e-06
# Epoch 65/100
# 743/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9944 - f1_m: 0.9939 - loss: 0.3763 - precision_m: 0.9953 - recall_m: 0.9925
# Epoch 65: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9944 - f1_m: 0.9939 - loss: 0.3763 - precision_m: 0.9953 - recall_m: 0.9925 - val_accuracy: 0.9532 - val_f1_m: 0.9526 - val_loss: 0.4554 - val_precision_m: 0.9571 - val_recall_m: 0.9484 - learning_rate: 1.0000e-06
# Epoch 66/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9953 - f1_m: 0.9950 - loss: 0.3753 - precision_m: 0.9964 - recall_m: 0.9937
# Epoch 66: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9953 - f1_m: 0.9950 - loss: 0.3753 - precision_m: 0.9964 - recall_m: 0.9937 - val_accuracy: 0.9535 - val_f1_m: 0.9526 - val_loss: 0.4553 - val_precision_m: 0.9569 - val_recall_m: 0.9484 - learning_rate: 1.0000e-06
# Epoch 67/100
# 745/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9946 - f1_m: 0.9944 - loss: 0.3752 - precision_m: 0.9957 - recall_m: 0.9933
# Epoch 67: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9946 - f1_m: 0.9944 - loss: 0.3752 - precision_m: 0.9957 - recall_m: 0.9933 - val_accuracy: 0.9532 - val_f1_m: 0.9526 - val_loss: 0.4555 - val_precision_m: 0.9569 - val_recall_m: 0.9485 - learning_rate: 1.0000e-06
# Epoch 68/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9952 - f1_m: 0.9947 - loss: 0.3753 - precision_m: 0.9961 - recall_m: 0.9934
# Epoch 68: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9952 - f1_m: 0.9947 - loss: 0.3753 - precision_m: 0.9961 - recall_m: 0.9934 - val_accuracy: 0.9535 - val_f1_m: 0.9523 - val_loss: 0.4552 - val_precision_m: 0.9566 - val_recall_m: 0.9482 - learning_rate: 1.0000e-06
# Epoch 69/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9957 - f1_m: 0.9958 - loss: 0.3736 - precision_m: 0.9967 - recall_m: 0.9949
# Epoch 69: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9957 - f1_m: 0.9958 - loss: 0.3736 - precision_m: 0.9967 - recall_m: 0.9949 - val_accuracy: 0.9534 - val_f1_m: 0.9525 - val_loss: 0.4549 - val_precision_m: 0.9570 - val_recall_m: 0.9481 - learning_rate: 1.0000e-06
# Epoch 70/100
# 744/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9953 - f1_m: 0.9953 - loss: 0.3743 - precision_m: 0.9968 - recall_m: 0.9939
# Epoch 70: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9953 - f1_m: 0.9953 - loss: 0.3743 - precision_m: 0.9968 - recall_m: 0.9939 - val_accuracy: 0.9534 - val_f1_m: 0.9524 - val_loss: 0.4549 - val_precision_m: 0.9568 - val_recall_m: 0.9482 - learning_rate: 1.0000e-06
# Epoch 71/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9961 - f1_m: 0.9958 - loss: 0.3736 - precision_m: 0.9969 - recall_m: 0.9946
# Epoch 71: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9961 - f1_m: 0.9958 - loss: 0.3736 - precision_m: 0.9969 - recall_m: 0.9946 - val_accuracy: 0.9534 - val_f1_m: 0.9526 - val_loss: 0.4553 - val_precision_m: 0.9568 - val_recall_m: 0.9485 - learning_rate: 1.0000e-06
# Epoch 72/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9947 - f1_m: 0.9946 - loss: 0.3756 - precision_m: 0.9961 - recall_m: 0.9931
# Epoch 72: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9947 - f1_m: 0.9946 - loss: 0.3756 - precision_m: 0.9961 - recall_m: 0.9931 - val_accuracy: 0.9534 - val_f1_m: 0.9525 - val_loss: 0.4556 - val_precision_m: 0.9570 - val_recall_m: 0.9481 - learning_rate: 1.0000e-06
# Epoch 73/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9958 - f1_m: 0.9954 - loss: 0.3750 - precision_m: 0.9965 - recall_m: 0.9944
# Epoch 73: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9958 - f1_m: 0.9954 - loss: 0.3750 - precision_m: 0.9965 - recall_m: 0.9944 - val_accuracy: 0.9529 - val_f1_m: 0.9524 - val_loss: 0.4551 - val_precision_m: 0.9567 - val_recall_m: 0.9484 - learning_rate: 1.0000e-06
# Epoch 74/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9959 - f1_m: 0.9960 - loss: 0.3746 - precision_m: 0.9971 - recall_m: 0.9948
# Epoch 74: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9959 - f1_m: 0.9960 - loss: 0.3746 - precision_m: 0.9971 - recall_m: 0.9948 - val_accuracy: 0.9535 - val_f1_m: 0.9526 - val_loss: 0.4559 - val_precision_m: 0.9572 - val_recall_m: 0.9482 - learning_rate: 1.0000e-06
# Epoch 75/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9952 - f1_m: 0.9947 - loss: 0.3751 - precision_m: 0.9962 - recall_m: 0.9933
# Epoch 75: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9952 - f1_m: 0.9947 - loss: 0.3751 - precision_m: 0.9962 - recall_m: 0.9933 - val_accuracy: 0.9536 - val_f1_m: 0.9524 - val_loss: 0.4552 - val_precision_m: 0.9567 - val_recall_m: 0.9482 - learning_rate: 1.0000e-06
# Epoch 76/100
# 743/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9955 - f1_m: 0.9953 - loss: 0.3754 - precision_m: 0.9964 - recall_m: 0.9941
# Epoch 76: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9955 - f1_m: 0.9953 - loss: 0.3754 - precision_m: 0.9964 - recall_m: 0.9941 - val_accuracy: 0.9531 - val_f1_m: 0.9524 - val_loss: 0.4561 - val_precision_m: 0.9570 - val_recall_m: 0.9481 - learning_rate: 1.0000e-06
# Epoch 77/100
# 745/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9957 - f1_m: 0.9951 - loss: 0.3752 - precision_m: 0.9962 - recall_m: 0.9941
# Epoch 77: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9957 - f1_m: 0.9951 - loss: 0.3752 - precision_m: 0.9962 - recall_m: 0.9941 - val_accuracy: 0.9534 - val_f1_m: 0.9526 - val_loss: 0.4554 - val_precision_m: 0.9568 - val_recall_m: 0.9485 - learning_rate: 1.0000e-06
# Epoch 78/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9955 - f1_m: 0.9955 - loss: 0.3747 - precision_m: 0.9968 - recall_m: 0.9943
# Epoch 78: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9955 - f1_m: 0.9955 - loss: 0.3747 - precision_m: 0.9968 - recall_m: 0.9943 - val_accuracy: 0.9532 - val_f1_m: 0.9525 - val_loss: 0.4551 - val_precision_m: 0.9568 - val_recall_m: 0.9484 - learning_rate: 1.0000e-06
# Epoch 79/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9961 - f1_m: 0.9958 - loss: 0.3743 - precision_m: 0.9970 - recall_m: 0.9946
# Epoch 79: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9961 - f1_m: 0.9958 - loss: 0.3743 - precision_m: 0.9970 - recall_m: 0.9946 - val_accuracy: 0.9535 - val_f1_m: 0.9526 - val_loss: 0.4554 - val_precision_m: 0.9569 - val_recall_m: 0.9485 - learning_rate: 1.0000e-06
# Epoch 80/100
# 745/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9958 - f1_m: 0.9955 - loss: 0.3737 - precision_m: 0.9966 - recall_m: 0.9943
# Epoch 80: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9958 - f1_m: 0.9955 - loss: 0.3737 - precision_m: 0.9966 - recall_m: 0.9943 - val_accuracy: 0.9531 - val_f1_m: 0.9523 - val_loss: 0.4553 - val_precision_m: 0.9566 - val_recall_m: 0.9482 - learning_rate: 1.0000e-06
# Epoch 81/100
# 745/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9958 - f1_m: 0.9959 - loss: 0.3743 - precision_m: 0.9969 - recall_m: 0.9950
# Epoch 81: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9958 - f1_m: 0.9959 - loss: 0.3743 - precision_m: 0.9969 - recall_m: 0.9949 - val_accuracy: 0.9535 - val_f1_m: 0.9522 - val_loss: 0.4553 - val_precision_m: 0.9567 - val_recall_m: 0.9479 - learning_rate: 1.0000e-06
# Epoch 82/100
# 745/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9942 - f1_m: 0.9940 - loss: 0.3758 - precision_m: 0.9953 - recall_m: 0.9928
# Epoch 82: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9942 - f1_m: 0.9940 - loss: 0.3758 - precision_m: 0.9953 - recall_m: 0.9928 - val_accuracy: 0.9534 - val_f1_m: 0.9522 - val_loss: 0.4556 - val_precision_m: 0.9566 - val_recall_m: 0.9480 - learning_rate: 1.0000e-06
# Epoch 83/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9953 - f1_m: 0.9954 - loss: 0.3746 - precision_m: 0.9965 - recall_m: 0.9943
# Epoch 83: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9953 - f1_m: 0.9954 - loss: 0.3746 - precision_m: 0.9965 - recall_m: 0.9943 - val_accuracy: 0.9532 - val_f1_m: 0.9523 - val_loss: 0.4556 - val_precision_m: 0.9568 - val_recall_m: 0.9480 - learning_rate: 1.0000e-06
# Epoch 84/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9953 - f1_m: 0.9952 - loss: 0.3742 - precision_m: 0.9963 - recall_m: 0.9942
# Epoch 84: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9953 - f1_m: 0.9952 - loss: 0.3742 - precision_m: 0.9963 - recall_m: 0.9942 - val_accuracy: 0.9535 - val_f1_m: 0.9524 - val_loss: 0.4549 - val_precision_m: 0.9568 - val_recall_m: 0.9481 - learning_rate: 1.0000e-06
# Epoch 85/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9958 - f1_m: 0.9952 - loss: 0.3742 - precision_m: 0.9965 - recall_m: 0.9939
# Epoch 85: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9958 - f1_m: 0.9952 - loss: 0.3742 - precision_m: 0.9965 - recall_m: 0.9939 - val_accuracy: 0.9534 - val_f1_m: 0.9522 - val_loss: 0.4552 - val_precision_m: 0.9568 - val_recall_m: 0.9477 - learning_rate: 1.0000e-06
# Epoch 86/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9953 - f1_m: 0.9950 - loss: 0.3747 - precision_m: 0.9962 - recall_m: 0.9939
# Epoch 86: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9953 - f1_m: 0.9950 - loss: 0.3747 - precision_m: 0.9962 - recall_m: 0.9939 - val_accuracy: 0.9531 - val_f1_m: 0.9527 - val_loss: 0.4554 - val_precision_m: 0.9567 - val_recall_m: 0.9489 - learning_rate: 1.0000e-06
# Epoch 87/100
# 743/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9945 - f1_m: 0.9942 - loss: 0.3761 - precision_m: 0.9956 - recall_m: 0.9929
# Epoch 87: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9945 - f1_m: 0.9942 - loss: 0.3761 - precision_m: 0.9956 - recall_m: 0.9929 - val_accuracy: 0.9531 - val_f1_m: 0.9521 - val_loss: 0.4551 - val_precision_m: 0.9564 - val_recall_m: 0.9480 - learning_rate: 1.0000e-06
# Epoch 88/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9957 - f1_m: 0.9956 - loss: 0.3747 - precision_m: 0.9970 - recall_m: 0.9943
# Epoch 88: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9957 - f1_m: 0.9956 - loss: 0.3747 - precision_m: 0.9970 - recall_m: 0.9943 - val_accuracy: 0.9531 - val_f1_m: 0.9523 - val_loss: 0.4552 - val_precision_m: 0.9567 - val_recall_m: 0.9481 - learning_rate: 1.0000e-06
# Epoch 89/100
# 744/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9959 - f1_m: 0.9958 - loss: 0.3734 - precision_m: 0.9970 - recall_m: 0.9947
# Epoch 89: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9959 - f1_m: 0.9958 - loss: 0.3734 - precision_m: 0.9970 - recall_m: 0.9947 - val_accuracy: 0.9531 - val_f1_m: 0.9522 - val_loss: 0.4551 - val_precision_m: 0.9566 - val_recall_m: 0.9480 - learning_rate: 1.0000e-06
# Epoch 90/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9951 - f1_m: 0.9949 - loss: 0.3745 - precision_m: 0.9961 - recall_m: 0.9937
# Epoch 90: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9951 - f1_m: 0.9949 - loss: 0.3745 - precision_m: 0.9961 - recall_m: 0.9937 - val_accuracy: 0.9530 - val_f1_m: 0.9524 - val_loss: 0.4560 - val_precision_m: 0.9568 - val_recall_m: 0.9482 - learning_rate: 1.0000e-06
# Epoch 91/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9952 - f1_m: 0.9946 - loss: 0.3751 - precision_m: 0.9958 - recall_m: 0.9935
# Epoch 91: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9952 - f1_m: 0.9946 - loss: 0.3751 - precision_m: 0.9958 - recall_m: 0.9935 - val_accuracy: 0.9531 - val_f1_m: 0.9522 - val_loss: 0.4551 - val_precision_m: 0.9567 - val_recall_m: 0.9480 - learning_rate: 1.0000e-06
# Epoch 92/100
# 745/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9957 - f1_m: 0.9956 - loss: 0.3737 - precision_m: 0.9968 - recall_m: 0.9944
# Epoch 92: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9957 - f1_m: 0.9956 - loss: 0.3737 - precision_m: 0.9968 - recall_m: 0.9944 - val_accuracy: 0.9534 - val_f1_m: 0.9521 - val_loss: 0.4554 - val_precision_m: 0.9565 - val_recall_m: 0.9480 - learning_rate: 1.0000e-06
# Epoch 93/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9950 - f1_m: 0.9946 - loss: 0.3757 - precision_m: 0.9961 - recall_m: 0.9932
# Epoch 93: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9951 - f1_m: 0.9946 - loss: 0.3757 - precision_m: 0.9961 - recall_m: 0.9932 - val_accuracy: 0.9534 - val_f1_m: 0.9521 - val_loss: 0.4555 - val_precision_m: 0.9567 - val_recall_m: 0.9476 - learning_rate: 1.0000e-06
# Epoch 94/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9955 - f1_m: 0.9952 - loss: 0.3745 - precision_m: 0.9966 - recall_m: 0.9938
# Epoch 94: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9955 - f1_m: 0.9952 - loss: 0.3745 - precision_m: 0.9966 - recall_m: 0.9938 - val_accuracy: 0.9530 - val_f1_m: 0.9524 - val_loss: 0.4554 - val_precision_m: 0.9567 - val_recall_m: 0.9482 - learning_rate: 1.0000e-06
# Epoch 95/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9947 - f1_m: 0.9947 - loss: 0.3745 - precision_m: 0.9961 - recall_m: 0.9932
# Epoch 95: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9947 - f1_m: 0.9947 - loss: 0.3745 - precision_m: 0.9961 - recall_m: 0.9932 - val_accuracy: 0.9529 - val_f1_m: 0.9523 - val_loss: 0.4557 - val_precision_m: 0.9567 - val_recall_m: 0.9481 - learning_rate: 1.0000e-06
# Epoch 96/100
# 744/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9953 - f1_m: 0.9953 - loss: 0.3747 - precision_m: 0.9968 - recall_m: 0.9939
# Epoch 96: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9953 - f1_m: 0.9953 - loss: 0.3747 - precision_m: 0.9968 - recall_m: 0.9939 - val_accuracy: 0.9530 - val_f1_m: 0.9520 - val_loss: 0.4552 - val_precision_m: 0.9567 - val_recall_m: 0.9476 - learning_rate: 1.0000e-06
# Epoch 97/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9945 - f1_m: 0.9947 - loss: 0.3753 - precision_m: 0.9956 - recall_m: 0.9938
# Epoch 97: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9945 - f1_m: 0.9947 - loss: 0.3753 - precision_m: 0.9956 - recall_m: 0.9938 - val_accuracy: 0.9532 - val_f1_m: 0.9524 - val_loss: 0.4555 - val_precision_m: 0.9568 - val_recall_m: 0.9482 - learning_rate: 1.0000e-06
# Epoch 98/100
# 745/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9963 - f1_m: 0.9961 - loss: 0.3735 - precision_m: 0.9974 - recall_m: 0.9948
# Epoch 98: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9963 - f1_m: 0.9961 - loss: 0.3735 - precision_m: 0.9974 - recall_m: 0.9948 - val_accuracy: 0.9532 - val_f1_m: 0.9523 - val_loss: 0.4558 - val_precision_m: 0.9570 - val_recall_m: 0.9477 - learning_rate: 1.0000e-06
# Epoch 99/100
# 744/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9958 - f1_m: 0.9954 - loss: 0.3742 - precision_m: 0.9966 - recall_m: 0.9943
# Epoch 99: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9958 - f1_m: 0.9954 - loss: 0.3742 - precision_m: 0.9966 - recall_m: 0.9943 - val_accuracy: 0.9532 - val_f1_m: 0.9523 - val_loss: 0.4555 - val_precision_m: 0.9568 - val_recall_m: 0.9480 - learning_rate: 1.0000e-06
# Epoch 100/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9955 - f1_m: 0.9955 - loss: 0.3741 - precision_m: 0.9965 - recall_m: 0.9945
# Epoch 100: val_loss did not improve from 0.45198
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9955 - f1_m: 0.9955 - loss: 0.3741 - precision_m: 0.9965 - recall_m: 0.9945 - val_accuracy: 0.9534 - val_f1_m: 0.9524 - val_loss: 0.4554 - val_precision_m: 0.9568 - val_recall_m: 0.9482 - learning_rate: 1.0000e-06

# %%
loss, accuracy, f1_score, precision, recall = model_CNN.evaluate(x_test, y_test, verbose=0)
print(f"Validation Loss: {loss}")
print(f"Accuracy: {accuracy}")
print(f"F1 Score: {f1_score}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
# Out:
# Validation Loss: 0.4494066536426544
# Accuracy: 0.9559999704360962
# F1 Score: 0.9549255967140198
# Precision: 0.9590020179748535
# Recall: 0.9509999752044678

# %% [markdown]
# **Visualizations**

# %%
import matplotlib.pyplot as plt

def plot_accuracy_loss(history):
    fig, axs = plt.subplots(1, 2, figsize=(12, 4))

    axs[0].plot(history.history['accuracy'], label='Train Accuracy')
    axs[0].plot(history.history['val_accuracy'], label='Validation Accuracy')
    axs[0].set_title('Model Accuracy')
    axs[0].set_xlabel('Epochs')
    axs[0].set_ylabel('Accuracy')
    axs[0].legend()

    axs[1].plot(history.history['loss'], label='Train Loss')
    axs[1].plot(history.history['val_loss'], label='Validation Loss')
    axs[1].set_title('Model Loss')
    axs[1].set_xlabel('Epochs')
    axs[1].set_ylabel('Loss')
    axs[1].legend()

    plt.show()

plot_accuracy_loss(history)

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
import numpy as np

def plot_confusion_matrix(model, x_test, y_test):
    y_pred = np.argmax(model.predict(x_test), axis=1)
    y_true = np.argmax(y_test, axis=1)

    cm = confusion_matrix(y_true, y_pred)
    class_names = [f'Class {i}' for i in range(y_test.shape[1])]
    
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names,
                yticklabels=class_names)
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.show()

plot_confusion_matrix(model_CNN, x_test, y_test)
# Out:
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
from sklearn.metrics import roc_curve, auc, roc_auc_score
from itertools import cycle
import matplotlib.pyplot as plt

def plot_roc_curve(model, x_test, y_test):
    y_pred = model.predict(x_test)
    n_classes = y_test.shape[1]

    fpr, tpr, roc_auc = {}, {}, {}
    plt.figure(figsize=(8, 6))
    colors = cycle(['blue', 'red', 'green', 'purple', 'orange'])

    for i, color in zip(range(n_classes), colors):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
        plt.plot(fpr[i], tpr[i], color=color, lw=2,
                 label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

    fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_pred.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
    plt.plot(fpr["micro"], tpr["micro"],
             label=f'Micro-average ROC (AUC = {roc_auc["micro"]:.2f})',
             color='black', linestyle='--', linewidth=2)

    plt.plot([0, 1], [0, 1], 'k--', lw=1)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Multi-class ROC Curve')
    plt.legend(loc="lower right")
    plt.tight_layout()
    plt.show()
plot_roc_curve(model_CNN, x_test, y_test)
# Out:
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

def permutation_importance_gaf(model, X, y_true, feature_names, base_score_fn=accuracy_score):
    """
    Computes permutation importance for GAF input of shape (N, 8, 8, 1).
    Each original feature is encoded as a GAF image row/column.
    """
    base_preds = np.argmax(model.predict(X), axis=1)
    if len(y_true.shape) > 1:
        y_true = np.argmax(y_true, axis=1)

    base_score = base_score_fn(y_true, base_preds)
    feature_importance = []

    for i in range(8):  
        X_permuted = np.copy(X)

        for j in range(X.shape[0]):
            row_perm = np.random.permutation(8)
            col_perm = np.random.permutation(8)

            X_permuted[j, i, :, 0] = X[j, i, col_perm, 0]  
            X_permuted[j, :, i, 0] = X[j, row_perm, i, 0]  

        preds = np.argmax(model.predict(X_permuted), axis=1)
        score = base_score_fn(y_true, preds)
        importance = base_score - score
        feature_importance.append(importance)

    return feature_importance
feature_names = ["ACC_X", "ACC_Y", "ACC_Z", "EMG", "EDA", "ECG", "Temp", "Resp"]
importances = permutation_importance_gaf(model_CNN, x_test, y_test, feature_names)

importances = np.array(importances)
importances /= importances.max()

plt.figure(figsize=(10, 5))
plt.bar(range(8), importances, color='teal')
plt.xticks(range(8), feature_names, rotation=45)
plt.ylabel("Feature Importance")
plt.title("Permutation Feature Importance (GAF-CNN)")
plt.tight_layout()
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()
# Out:
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
