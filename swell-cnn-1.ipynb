# %%
# !pip install pyts
# Out:
# Collecting pyts
#   Downloading pyts-0.13.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.26.4)
# Requirement already satisfied: scipy>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.15.2)
# Requirement already satisfied: scikit-learn>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.4.2)
# Requirement already satisfied: numba>=0.55.2 in /usr/local/lib/python3.11/dist-packages (from pyts) (0.60.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.55.2->pyts) (0.43.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (2.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.2.0->pyts) (3.6.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.22.4->pyts) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.22.4->pyts) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.22.4->pyts) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.22.4->pyts) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.22.4->pyts) (2024.2.0)
# Downloading pyts-0.13.0-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 32.8 MB/s eta 0:00:0000:0100:01
# Installing collected packages: pyts
# Successfully installed pyts-0.13.0

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt

from mpl_toolkits.axes_grid1 import ImageGrid
from pyts.image import GramianAngularField
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

def root_directory():
    """Returns the root directory of the project."""
    return "/kaggle/input/swell-heart-rate-variability-hrv/hrv dataset"

def data_directory():
    """Returns the data directory path."""
    return os.path.join(root_directory(), "data")
    
def load_train_set():
    """Loads training dataset as a Pandas DataFrame."""
    train_file = os.path.join(data_directory(), "final", "train.csv")
    return pd.read_csv(train_file)

def load_test_set():
    """Loads test dataset as a Pandas DataFrame."""
    test_file = os.path.join(data_directory(), "final", "test.csv")
    return pd.read_csv(test_file)

train = load_train_set()
test = load_test_set()

target = "condition"

hrv_features = [col for col in train.columns if col != target]

label_map = {"no stress": 0, "interruption":1, "time pressure": 2}
train[target] = train[target].map(label_map)
test[target] = test[target].map(label_map)


def sample_data(df, label_col, n_samples):
    """Safely sample n_samples per class without errors."""
    sampled_df = []
    for label in df[label_col].unique():
        class_data = df[df[label_col] == label]
        sample_size = min(n_samples, len(class_data))  
        sampled_df.append(class_data.sample(n=sample_size, random_state=42))
    return pd.concat(sampled_df).reset_index(drop=True)

train_balanced = sample_data(train, target, 10000)
test_balanced = sample_data(test, target, 3000)  

X_train = train_balanced[hrv_features]
y_train = train_balanced[target]

if "datasetId" in X_train.columns:
    X_train = X_train.drop(columns="datasetId")

X_test = test_balanced[hrv_features]
y_test = test_balanced[target]

if "datasetId" in X_test.columns:
    X_test = X_test.drop(columns="datasetId")

print(f"Train Set Shape: {X_train.shape}, Labels Shape: {y_train.shape}")
print(f"Test Set Shape: {X_test.shape}, Labels Shape: {y_test.shape}")

display(X_train.head())
display(y_train.head())
# Out:
# Train Set Shape: (30000, 34), Labels Shape: (30000,)
# Test Set Shape: (9000, 34), Labels Shape: (9000,)
#       MEAN_RR   MEDIAN_RR        SDRR      RMSSD       SDSD  SDRR_RMSSD  \
# 0  896.720876  880.459590  106.101117  13.924951  13.924949    7.619497
# 1  903.325242  905.495460   72.285411  12.387407  12.386563    5.835395
# 2  934.870026  916.307545  128.556268  16.728592  16.728579    7.684823
# 3  726.048217  726.396200   58.167902   9.760850   9.760850    5.959307
# 4  903.212333  918.237180  108.998652  16.905228  16.905228    6.447630
#
#           HR      pNN25     pNN50        SD1  ...     LF_PCT      LF_NU  \
# 0  67.818401   7.733333  0.466667   9.849712  ...  28.035932  98.809256
# 1  66.855229   4.466667  0.133333   8.761546  ...  23.244445  99.726832
# 2  65.364253  13.200000  1.066667  11.832839  ...  28.280122  99.507931
# 3  83.181060   1.400000  0.000000   6.904267  ...  22.022647  93.990424
# 4  67.479959  12.400000  1.333333  11.957790  ...  23.825552  98.769012
#
#           HF    HF_PCT     HF_NU           TP       LF_HF     HF_LF    sampen  \
# 0   9.922258  0.337859  1.190744  2936.803667   82.981135  0.012051  2.127076
# 1   1.783522  0.063670  0.273168  2801.178306  365.074431  0.002739  2.192351
# 2   6.164162  0.139846  0.492069  4407.828115  202.223606  0.004945  2.160318
# 3  26.015607  1.408088  6.009576  1847.584044   15.640109  0.063938  2.157452
# 4  13.625402  0.296945  1.230988  4588.526989   80.235569  0.012463  2.179244
#
#      higuci
# 0  1.134921
# 1  1.069071
# 2  1.126186
# 3  1.152640
# 4  1.177820
#
# [5 rows x 34 columns]
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: condition, dtype: int64

# %%
def quantile_normalize(df):
    """Applies quantile normalization to the DataFrame."""
    df_sorted = pd.DataFrame(np.sort(df.values, axis=0), index=df.index, columns=df.columns)
    df_mean = df_sorted.mean(axis=1)
    df_mean.index = np.arange(1, len(df_mean) + 1)
    df_qn = df.rank(method="min").stack().astype(int).map(df_mean).unstack()
    return df_qn

x_train_swell = quantile_normalize(X_train)
x_test_swell = quantile_normalize(X_test)

display(x_train_swell.head())
display(x_test_swell.head())
print(x_train_swell.describe())
print(x_test_swell.describe())
# Out:
#       MEAN_RR   MEDIAN_RR        SDRR       RMSSD        SDSD  SDRR_RMSSD  \
# 0  276.697101  261.548330  281.634094  201.939225  201.948873  306.099269
# 1  283.060633  290.437894  183.073989  167.021640  166.952993  215.238532
# 2  312.856441  298.311570  333.659979  277.912510  277.935225  309.649467
# 3  118.124366  124.548167  136.809099  117.415260  117.430190  221.768654
# 4  282.869530  300.263695  289.169845  283.041251  283.046942  248.500700
#
#            HR       pNN25       pNN50         SD1  ...      LF_PCT  \
# 0  186.792253  220.098299  219.751609  201.948873  ...  209.281585
# 1  178.099179  165.854182  166.058400  166.952993  ...  175.512435
# 2  167.908511  315.431057  277.893149  277.935225  ...  211.163474
# 3  463.050505  112.676927   57.594885  117.430190  ...  165.622387
# 4  183.634928  300.234227  309.342415  283.046942  ...  179.713401
#
#         LF_NU          HF      HF_PCT       HF_NU          TP       LF_HF  \
# 0  309.383929  166.989622  170.844721  172.502720  229.176610  309.383929
# 1  527.319177  104.591577  111.702021  111.394438  220.181001  527.319177
# 2  434.164037  141.753598  139.078646  129.723889  339.437487  434.164037
# 3  158.516499  250.212396  280.129440  339.707893  158.679659  158.516499
# 4  305.818680  184.847490  165.565337  174.383861  355.878824  305.818680
#
#         HF_LF      sampen      higuci
# 0  172.502720  220.280335  160.774105
# 1  111.394438  390.664047   91.473882
# 2  129.723889  264.643133  147.015168
# 3  339.707893  259.802904  193.893174
# 4  174.383861  315.449174  240.393451
#
# [5 rows x 34 columns]
#       MEAN_RR   MEDIAN_RR        SDRR       RMSSD        SDSD  SDRR_RMSSD  \
# 0  154.981903  130.948799  357.917964  218.603896  218.603896  399.488499
# 1  206.332670  212.064032  158.559158  158.894224  158.894224  188.846044
# 2  108.774609  110.761248  174.510012  123.887169  123.887169  272.919928
# 3  184.635339  206.397936  343.041840  204.879360  204.879360  387.853716
# 4  173.729083  170.568761  115.378578  158.499353  158.499353  143.334814
#
#            HR       pNN25       pNN50         SD1  ...      LF_PCT  \
# 0  376.844594  226.243094  239.203434  218.603896  ...  181.232421
# 1  240.684831  152.445046   58.596835  158.894224  ...  190.435567
# 2  513.057777  134.679136   58.596835  123.887169  ...  207.303791
# 3  305.771471  206.484818  278.290686  204.879360  ...  166.258531
# 4  289.746416  143.353928   58.596835  158.499353  ...  522.481666
#
#         LF_NU          HF      HF_PCT       HF_NU          TP       LF_HF  \
# 0  142.039242  396.002894  311.944479  386.663115  242.885987  142.039242
# 1  171.716120  259.323638  280.144485  306.319210  163.331167  171.716120
# 2  223.802244  209.252014  228.533895  232.983896  175.664416  223.802244
# 3  211.404028  272.407888  219.344145  244.743676  281.113670  211.404028
# 4  276.389324  196.987243  244.559104  188.324377  140.363456  276.389324
#
#         HF_LF      sampen      higuci
# 0  386.663115   94.875043  272.298257
# 1  306.319210  250.749993  301.416603
# 2  232.983896  297.822034  161.413623
# 3  244.743676  194.813778  174.500443
# 4  188.324377  267.048739  166.388660
#
# [5 rows x 34 columns]
#             MEAN_RR     MEDIAN_RR          SDRR         RMSSD          SDSD  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean     272.534334    272.434753    272.534334    272.534334    272.534334
# std      161.064480    160.681748    161.064480    161.064480    161.064480
# min       57.594885     57.594885     57.594885     57.594885     57.594885
# 25%      161.769849    161.769849    161.769849    161.769849    161.769849
# 50%      229.496375    229.489324    229.496375    229.496375    229.496375
# 75%      332.274137    332.242212    332.274137    332.274137    332.274137
# max     1242.394745   1144.375092   1242.394745   1242.394745   1242.394745
#
#          SDRR_RMSSD            HR         pNN25         pNN50           SD1  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean     272.534334    272.534334    271.779447    253.502644    272.534334
# std      161.064480    161.064480    160.934737    173.991796    161.064480
# min       57.594885     57.594885     57.594885     57.594885     57.594885
# 25%      161.769849    161.769849    161.525190    157.635702    161.769849
# 50%      229.496375    229.496375    228.712355    224.236676    229.496375
# 75%      332.274137    332.274137    331.051105    332.262775    332.274137
# max     1242.394745   1242.394745   1242.394745   1242.394745   1242.394745
#
#        ...        LF_PCT         LF_NU            HF        HF_PCT  \
# count  ...  30000.000000  30000.000000  30000.000000  30000.000000
# mean   ...    272.534334    272.534334    272.534334    272.534334
# std    ...    161.064480    161.064480    161.064480    161.064480
# min    ...     57.594885     57.594885     57.594885     57.594885
# 25%    ...    161.769849    161.769849    161.769849    161.769849
# 50%    ...    229.496375    229.496375    229.496375    229.496375
# 75%    ...    332.274137    332.274137    332.274137    332.274137
# max    ...   1242.394745   1242.394745   1242.394745   1242.394745
#
#               HF_NU            TP         LF_HF         HF_LF        sampen  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean     272.534334    272.534334    272.534334    272.534334    272.518826
# std      161.064480    161.064480    161.064480    161.064480    161.039607
# min       57.594885     57.594885     57.594885     57.594885     57.594885
# 25%      161.769849    161.769849    161.769849    161.769849    161.768069
# 50%      229.496375    229.496375    229.496375    229.496375    229.496375
# 75%      332.274137    332.274137    332.274137    332.274137    332.262775
# max     1242.394745   1242.394745   1242.394745   1242.394745   1242.394745
#
#              higuci
# count  30000.000000
# mean     272.534334
# std      161.064480
# min       57.594885
# 25%      161.769849
# 50%      229.496375
# 75%      332.274137
# max     1242.394745
#
# [8 rows x 34 columns]
#            MEAN_RR    MEDIAN_RR         SDRR        RMSSD         SDSD  \
# count  9000.000000  9000.000000  9000.000000  9000.000000  9000.000000
# mean    270.802541   270.717383   270.802541   270.802541   270.802541
# std     160.659658   160.343754   160.659658   160.659658   160.659658
# min      58.596835    58.596835    58.596835    58.596835    58.596835
# 25%     160.556477   160.556477   160.556477   160.556477   160.556477
# 50%     228.452560   228.452560   228.452560   228.452560   228.452560
# 75%     330.168948   330.168948   330.168948   330.168948   330.168948
# max    1234.324066  1167.337049  1234.324066  1234.324066  1234.324066
#
#         SDRR_RMSSD           HR        pNN25        pNN50          SD1  ...  \
# count  9000.000000  9000.000000  9000.000000  9000.000000  9000.000000  ...
# mean    270.802541   270.802541   270.047725   252.342726   270.802541  ...
# std     160.659658   160.659658   160.541381   173.061263   160.659658  ...
# min      58.596835    58.596835    58.596835    58.596835    58.596835  ...
# 25%     160.556477   160.556477   160.241940   156.411510   160.556477  ...
# 50%     228.452560   228.452560   227.704178   223.068524   228.452560  ...
# 75%     330.168948   330.168948   329.177168   327.284772   330.168948  ...
# max    1234.324066  1234.324066  1234.324066  1234.324066  1234.324066  ...
#
#             LF_PCT        LF_NU           HF       HF_PCT        HF_NU  \
# count  9000.000000  9000.000000  9000.000000  9000.000000  9000.000000
# mean    270.802541   270.802541   270.802541   270.802541   270.802541
# std     160.659658   160.659658   160.659658   160.659658   160.659658
# min      58.596835    58.596835    58.596835    58.596835    58.596835
# 25%     160.556477   160.556477   160.556477   160.556477   160.556477
# 50%     228.452560   228.452560   228.452560   228.452560   228.452560
# 75%     330.168948   330.168948   330.168948   330.168948   330.168948
# max    1234.324066  1234.324066  1234.324066  1234.324066  1234.324066
#
#                 TP        LF_HF        HF_LF       sampen       higuci
# count  9000.000000  9000.000000  9000.000000  9000.000000  9000.000000
# mean    270.802541   270.802541   270.802541   270.783826   270.802541
# std     160.659658   160.659658   160.659658   160.619619   160.659658
# min      58.596835    58.596835    58.596835    58.596835    58.596835
# 25%     160.556477   160.556477   160.556477   160.535503   160.556477
# 50%     228.452560   228.452560   228.452560   228.452560   228.452560
# 75%     330.168948   330.168948   330.168948   330.120840   330.168948
# max    1234.324066  1234.324066  1234.324066  1234.324066  1234.324066
#
# [8 rows x 34 columns]

# %%
gaf = GramianAngularField()

X_train_gaf = gaf.fit_transform(X_train.to_numpy())
X_test_gaf = gaf.fit_transform(X_test.to_numpy())

X_train_gaf = X_train_gaf.reshape(X_train_gaf.shape[0], 34, 34, 1)
X_test_gaf = X_test_gaf.reshape(X_test_gaf.shape[0], 34, 34, 1)

X_train_gaf /= np.max(X_train_gaf, axis=(1, 2, 3), keepdims=True)
X_test_gaf /= np.max(X_test_gaf, axis=(1, 2, 3), keepdims=True)

y_train = tf.keras.utils.to_categorical(y_train, num_classes=3)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=3)
print(X_train_gaf.shape)
print(X_test_gaf.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (30000, 34, 34, 1)
# (9000, 34, 34, 1)
# (30000, 3)
# (9000, 3)

# %%
import matplotlib.pyplot as plt

sample_idx = 0  

sample_gaf_image = X_train_gaf[sample_idx, :, :, 0]  

plt.figure(figsize=(4, 4))
plt.imshow(sample_gaf_image, cmap='viridis')  
plt.colorbar()
plt.title(f"Sample GAF Image (Index {sample_idx})")
plt.show()

# %%
import tensorflow as tf
from tensorflow.keras import backend as K
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    return true_positives / (predicted_positives + K.epsilon())

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

# %%
import tensorflow as tf
from tensorflow.keras import layers, regularizers, callbacks

# Define the Model with Swish Activation
model_CNN = tf.keras.Sequential([
    layers.Conv2D(32, (3,3), padding="same", kernel_regularizer=regularizers.l2(1e-6), input_shape=(34, 34, 1)),
    layers.BatchNormalization(),
    layers.Activation('swish'),  
    layers.MaxPooling2D(2, 2),

    layers.Conv2D(64, (3,3), padding="same", kernel_regularizer=regularizers.l2(1e-6)),
    layers.BatchNormalization(),
    layers.Activation('swish'),  
    layers.MaxPooling2D(2, 2),

    layers.Conv2D(128, (3,3), padding="same", kernel_regularizer=regularizers.l2(1e-6)),  
    layers.BatchNormalization(),
    layers.Activation('swish'),  
    layers.MaxPooling2D(2, 2),

    layers.Flatten(),
    layers.Dense(64, activation='swish', kernel_regularizer=regularizers.l2(1e-6)), 
    layers.BatchNormalization(),

    layers.Dense(3, activation='softmax')
])

loss = tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1)

optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)

model_CNN.compile(optimizer=optimizer, 
                  loss=loss, 
                  metrics=['accuracy', f1_m, precision_m, recall_m])
model_CNN.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)                    │ (None, 34, 34, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 34, 34, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_3 (Activation)            │ (None, 34, 34, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 17, 17, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 17, 17, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 17, 17, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_4 (Activation)            │ (None, 17, 17, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 8, 8, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 8, 8, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_5 (Activation)            │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 64)                  │         131,136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_7                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 3)                   │             195 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 225,155 (879.51 KB)
#  Trainable params: 224,579 (877.26 KB)
#  Non-trainable params: 576 (2.25 KB)

# %%
model_checkpoint = callbacks.ModelCheckpoint("best_model.keras", save_best_only=True, monitor='val_loss', verbose=1)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1)

history = model_CNN.fit(
    X_train_gaf, y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_test_gaf, y_test),
    callbacks=[ model_checkpoint, reduce_lr]
)
# Out:
# Epoch 1/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5105 - f1_m: 0.3915 - loss: 1.0249 - precision_m: 0.6055 - recall_m: 0.2995
# Epoch 1: val_loss improved from inf to 1.03269, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 75s 72ms/step - accuracy: 0.5106 - f1_m: 0.3916 - loss: 1.0248 - precision_m: 0.6056 - recall_m: 0.2997 - val_accuracy: 0.5396 - val_f1_m: 0.5001 - val_loss: 1.0327 - val_precision_m: 0.5451 - val_recall_m: 0.4705 - learning_rate: 0.0010
# Epoch 2/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6535 - f1_m: 0.6062 - loss: 0.8421 - precision_m: 0.7251 - recall_m: 0.5244
# Epoch 2: val_loss improved from 1.03269 to 0.91289, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 70s 74ms/step - accuracy: 0.6536 - f1_m: 0.6063 - loss: 0.8421 - precision_m: 0.7251 - recall_m: 0.5245 - val_accuracy: 0.6359 - val_f1_m: 0.5887 - val_loss: 0.9129 - val_precision_m: 0.6518 - val_recall_m: 0.5423 - learning_rate: 0.0010
# Epoch 3/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7029 - f1_m: 0.6758 - loss: 0.7807 - precision_m: 0.7645 - recall_m: 0.6082
# Epoch 3: val_loss did not improve from 0.91289
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 72s 77ms/step - accuracy: 0.7029 - f1_m: 0.6759 - loss: 0.7807 - precision_m: 0.7645 - recall_m: 0.6083 - val_accuracy: 0.5454 - val_f1_m: 0.5367 - val_loss: 1.0962 - val_precision_m: 0.5499 - val_recall_m: 0.5252 - learning_rate: 0.0010
# Epoch 4/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7448 - f1_m: 0.7244 - loss: 0.7250 - precision_m: 0.7955 - recall_m: 0.6670
# Epoch 4: val_loss improved from 0.91289 to 0.69090, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 70s 75ms/step - accuracy: 0.7448 - f1_m: 0.7244 - loss: 0.7250 - precision_m: 0.7956 - recall_m: 0.6670 - val_accuracy: 0.7588 - val_f1_m: 0.7409 - val_loss: 0.6909 - val_precision_m: 0.8005 - val_recall_m: 0.6920 - learning_rate: 0.0010
# Epoch 5/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7724 - f1_m: 0.7592 - loss: 0.6850 - precision_m: 0.8168 - recall_m: 0.7112
# Epoch 5: val_loss improved from 0.69090 to 0.67017, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 70s 74ms/step - accuracy: 0.7724 - f1_m: 0.7592 - loss: 0.6850 - precision_m: 0.8168 - recall_m: 0.7113 - val_accuracy: 0.7931 - val_f1_m: 0.7775 - val_loss: 0.6702 - val_precision_m: 0.8103 - val_recall_m: 0.7483 - learning_rate: 0.0010
# Epoch 6/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7983 - f1_m: 0.7863 - loss: 0.6524 - precision_m: 0.8353 - recall_m: 0.7441
# Epoch 6: val_loss did not improve from 0.67017
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 77s 82ms/step - accuracy: 0.7983 - f1_m: 0.7863 - loss: 0.6524 - precision_m: 0.8353 - recall_m: 0.7442 - val_accuracy: 0.6091 - val_f1_m: 0.5995 - val_loss: 1.0126 - val_precision_m: 0.6090 - val_recall_m: 0.5911 - learning_rate: 0.0010
# Epoch 7/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8164 - f1_m: 0.8054 - loss: 0.6236 - precision_m: 0.8473 - recall_m: 0.7688
# Epoch 7: val_loss did not improve from 0.67017
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 70s 74ms/step - accuracy: 0.8164 - f1_m: 0.8054 - loss: 0.6236 - precision_m: 0.8473 - recall_m: 0.7688 - val_accuracy: 0.7993 - val_f1_m: 0.7906 - val_loss: 0.7292 - val_precision_m: 0.8112 - val_recall_m: 0.7727 - learning_rate: 0.0010
# Epoch 8/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8302 - f1_m: 0.8188 - loss: 0.6054 - precision_m: 0.8587 - recall_m: 0.7835
# Epoch 8: val_loss improved from 0.67017 to 0.61400, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 75s 80ms/step - accuracy: 0.8302 - f1_m: 0.8188 - loss: 0.6054 - precision_m: 0.8588 - recall_m: 0.7835 - val_accuracy: 0.8354 - val_f1_m: 0.8265 - val_loss: 0.6140 - val_precision_m: 0.8528 - val_recall_m: 0.8033 - learning_rate: 0.0010
# Epoch 9/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8538 - f1_m: 0.8481 - loss: 0.5658 - precision_m: 0.8828 - recall_m: 0.8171
# Epoch 9: val_loss did not improve from 0.61400
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 80s 86ms/step - accuracy: 0.8538 - f1_m: 0.8481 - loss: 0.5658 - precision_m: 0.8828 - recall_m: 0.8171 - val_accuracy: 0.6441 - val_f1_m: 0.6331 - val_loss: 1.0020 - val_precision_m: 0.6408 - val_recall_m: 0.6262 - learning_rate: 0.0010
# Epoch 10/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8702 - f1_m: 0.8645 - loss: 0.5467 - precision_m: 0.8937 - recall_m: 0.8380
# Epoch 10: val_loss did not improve from 0.61400
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 70s 75ms/step - accuracy: 0.8703 - f1_m: 0.8645 - loss: 0.5467 - precision_m: 0.8937 - recall_m: 0.8380 - val_accuracy: 0.7739 - val_f1_m: 0.7555 - val_loss: 0.6846 - val_precision_m: 0.7925 - val_recall_m: 0.7267 - learning_rate: 0.0010
# Epoch 11/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8831 - f1_m: 0.8782 - loss: 0.5282 - precision_m: 0.9064 - recall_m: 0.8527
# Epoch 11: val_loss did not improve from 0.61400
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 71s 75ms/step - accuracy: 0.8831 - f1_m: 0.8783 - loss: 0.5282 - precision_m: 0.9064 - recall_m: 0.8527 - val_accuracy: 0.7719 - val_f1_m: 0.7621 - val_loss: 0.7835 - val_precision_m: 0.7808 - val_recall_m: 0.7456 - learning_rate: 0.0010
# Epoch 12/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9199 - f1_m: 0.9169 - loss: 0.4729 - precision_m: 0.9378 - recall_m: 0.8975
# Epoch 12: val_loss improved from 0.61400 to 0.51753, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 69s 74ms/step - accuracy: 0.9199 - f1_m: 0.9169 - loss: 0.4728 - precision_m: 0.9378 - recall_m: 0.8975 - val_accuracy: 0.8936 - val_f1_m: 0.8910 - val_loss: 0.5175 - val_precision_m: 0.9056 - val_recall_m: 0.8774 - learning_rate: 5.0000e-04
# Epoch 13/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9304 - f1_m: 0.9271 - loss: 0.4558 - precision_m: 0.9447 - recall_m: 0.9107
# Epoch 13: val_loss did not improve from 0.51753
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 67s 71ms/step - accuracy: 0.9304 - f1_m: 0.9271 - loss: 0.4558 - precision_m: 0.9447 - recall_m: 0.9107 - val_accuracy: 0.6507 - val_f1_m: 0.6383 - val_loss: 1.1177 - val_precision_m: 0.6422 - val_recall_m: 0.6349 - learning_rate: 5.0000e-04
# Epoch 14/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9387 - f1_m: 0.9363 - loss: 0.4452 - precision_m: 0.9533 - recall_m: 0.9203
# Epoch 14: val_loss improved from 0.51753 to 0.45168, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 66s 71ms/step - accuracy: 0.9387 - f1_m: 0.9363 - loss: 0.4452 - precision_m: 0.9533 - recall_m: 0.9203 - val_accuracy: 0.9348 - val_f1_m: 0.9314 - val_loss: 0.4517 - val_precision_m: 0.9461 - val_recall_m: 0.9181 - learning_rate: 5.0000e-04
# Epoch 15/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9448 - f1_m: 0.9410 - loss: 0.4355 - precision_m: 0.9566 - recall_m: 0.9265
# Epoch 15: val_loss did not improve from 0.45168
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 66s 71ms/step - accuracy: 0.9448 - f1_m: 0.9411 - loss: 0.4354 - precision_m: 0.9566 - recall_m: 0.9265 - val_accuracy: 0.8033 - val_f1_m: 0.7957 - val_loss: 0.7077 - val_precision_m: 0.8093 - val_recall_m: 0.7847 - learning_rate: 5.0000e-04
# Epoch 16/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9450 - f1_m: 0.9437 - loss: 0.4292 - precision_m: 0.9580 - recall_m: 0.9303
# Epoch 16: val_loss did not improve from 0.45168
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 69s 73ms/step - accuracy: 0.9450 - f1_m: 0.9437 - loss: 0.4292 - precision_m: 0.9580 - recall_m: 0.9303 - val_accuracy: 0.9309 - val_f1_m: 0.9259 - val_loss: 0.4604 - val_precision_m: 0.9389 - val_recall_m: 0.9138 - learning_rate: 5.0000e-04
# Epoch 17/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9529 - f1_m: 0.9523 - loss: 0.4186 - precision_m: 0.9647 - recall_m: 0.9407
# Epoch 17: val_loss did not improve from 0.45168
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 67s 72ms/step - accuracy: 0.9529 - f1_m: 0.9523 - loss: 0.4186 - precision_m: 0.9647 - recall_m: 0.9407 - val_accuracy: 0.9396 - val_f1_m: 0.9337 - val_loss: 0.4535 - val_precision_m: 0.9498 - val_recall_m: 0.9193 - learning_rate: 5.0000e-04
# Epoch 18/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9686 - f1_m: 0.9667 - loss: 0.3922 - precision_m: 0.9761 - recall_m: 0.9578
# Epoch 18: val_loss improved from 0.45168 to 0.40683, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 67s 72ms/step - accuracy: 0.9686 - f1_m: 0.9667 - loss: 0.3921 - precision_m: 0.9761 - recall_m: 0.9578 - val_accuracy: 0.9622 - val_f1_m: 0.9600 - val_loss: 0.4068 - val_precision_m: 0.9721 - val_recall_m: 0.9488 - learning_rate: 2.5000e-04
# Epoch 19/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9719 - f1_m: 0.9697 - loss: 0.3877 - precision_m: 0.9779 - recall_m: 0.9619
# Epoch 19: val_loss improved from 0.40683 to 0.37728, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 67s 71ms/step - accuracy: 0.9719 - f1_m: 0.9697 - loss: 0.3877 - precision_m: 0.9779 - recall_m: 0.9619 - val_accuracy: 0.9780 - val_f1_m: 0.9755 - val_loss: 0.3773 - val_precision_m: 0.9816 - val_recall_m: 0.9697 - learning_rate: 2.5000e-04
# Epoch 20/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9722 - f1_m: 0.9709 - loss: 0.3834 - precision_m: 0.9789 - recall_m: 0.9632
# Epoch 20: val_loss did not improve from 0.37728
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 67s 72ms/step - accuracy: 0.9722 - f1_m: 0.9709 - loss: 0.3834 - precision_m: 0.9789 - recall_m: 0.9632 - val_accuracy: 0.9809 - val_f1_m: 0.9774 - val_loss: 0.3835 - val_precision_m: 0.9847 - val_recall_m: 0.9704 - learning_rate: 2.5000e-04
# Epoch 21/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9753 - f1_m: 0.9739 - loss: 0.3787 - precision_m: 0.9810 - recall_m: 0.9671
# Epoch 21: val_loss did not improve from 0.37728
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 70s 74ms/step - accuracy: 0.9753 - f1_m: 0.9739 - loss: 0.3787 - precision_m: 0.9810 - recall_m: 0.9671 - val_accuracy: 0.9760 - val_f1_m: 0.9742 - val_loss: 0.3822 - val_precision_m: 0.9798 - val_recall_m: 0.9689 - learning_rate: 2.5000e-04
# Epoch 22/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9749 - f1_m: 0.9740 - loss: 0.3779 - precision_m: 0.9804 - recall_m: 0.9678
# Epoch 22: val_loss did not improve from 0.37728
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 71s 76ms/step - accuracy: 0.9749 - f1_m: 0.9740 - loss: 0.3779 - precision_m: 0.9804 - recall_m: 0.9678 - val_accuracy: 0.9611 - val_f1_m: 0.9573 - val_loss: 0.4137 - val_precision_m: 0.9678 - val_recall_m: 0.9475 - learning_rate: 2.5000e-04
# Epoch 23/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9841 - f1_m: 0.9832 - loss: 0.3602 - precision_m: 0.9880 - recall_m: 0.9786
# Epoch 23: val_loss improved from 0.37728 to 0.36377, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 75ms/step - accuracy: 0.9841 - f1_m: 0.9832 - loss: 0.3602 - precision_m: 0.9880 - recall_m: 0.9786 - val_accuracy: 0.9844 - val_f1_m: 0.9839 - val_loss: 0.3638 - val_precision_m: 0.9880 - val_recall_m: 0.9799 - learning_rate: 1.2500e-04
# Epoch 24/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9846 - f1_m: 0.9836 - loss: 0.3598 - precision_m: 0.9887 - recall_m: 0.9787
# Epoch 24: val_loss improved from 0.36377 to 0.35176, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 71s 75ms/step - accuracy: 0.9846 - f1_m: 0.9836 - loss: 0.3598 - precision_m: 0.9887 - recall_m: 0.9787 - val_accuracy: 0.9909 - val_f1_m: 0.9903 - val_loss: 0.3518 - val_precision_m: 0.9932 - val_recall_m: 0.9876 - learning_rate: 1.2500e-04
# Epoch 25/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9866 - f1_m: 0.9859 - loss: 0.3564 - precision_m: 0.9900 - recall_m: 0.9820
# Epoch 25: val_loss did not improve from 0.35176
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 71s 76ms/step - accuracy: 0.9866 - f1_m: 0.9859 - loss: 0.3564 - precision_m: 0.9900 - recall_m: 0.9820 - val_accuracy: 0.9572 - val_f1_m: 0.9551 - val_loss: 0.4252 - val_precision_m: 0.9628 - val_recall_m: 0.9480 - learning_rate: 1.2500e-04
# Epoch 26/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9870 - f1_m: 0.9854 - loss: 0.3564 - precision_m: 0.9900 - recall_m: 0.9809
# Epoch 26: val_loss did not improve from 0.35176
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 71s 76ms/step - accuracy: 0.9870 - f1_m: 0.9854 - loss: 0.3564 - precision_m: 0.9900 - recall_m: 0.9809 - val_accuracy: 0.9838 - val_f1_m: 0.9817 - val_loss: 0.3695 - val_precision_m: 0.9873 - val_recall_m: 0.9763 - learning_rate: 1.2500e-04
# Epoch 27/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9872 - f1_m: 0.9861 - loss: 0.3543 - precision_m: 0.9900 - recall_m: 0.9824
# Epoch 27: val_loss did not improve from 0.35176
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 70s 75ms/step - accuracy: 0.9872 - f1_m: 0.9861 - loss: 0.3543 - precision_m: 0.9900 - recall_m: 0.9824 - val_accuracy: 0.9768 - val_f1_m: 0.9742 - val_loss: 0.3946 - val_precision_m: 0.9818 - val_recall_m: 0.9671 - learning_rate: 1.2500e-04
# Epoch 28/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9908 - f1_m: 0.9900 - loss: 0.3468 - precision_m: 0.9932 - recall_m: 0.9868
# Epoch 28: val_loss improved from 0.35176 to 0.34447, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 68s 73ms/step - accuracy: 0.9908 - f1_m: 0.9900 - loss: 0.3469 - precision_m: 0.9932 - recall_m: 0.9868 - val_accuracy: 0.9877 - val_f1_m: 0.9874 - val_loss: 0.3445 - val_precision_m: 0.9910 - val_recall_m: 0.9839 - learning_rate: 6.2500e-05
# Epoch 29/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9916 - f1_m: 0.9901 - loss: 0.3450 - precision_m: 0.9932 - recall_m: 0.9872
# Epoch 29: val_loss improved from 0.34447 to 0.33936, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 73s 78ms/step - accuracy: 0.9916 - f1_m: 0.9901 - loss: 0.3450 - precision_m: 0.9932 - recall_m: 0.9872 - val_accuracy: 0.9898 - val_f1_m: 0.9901 - val_loss: 0.3394 - val_precision_m: 0.9921 - val_recall_m: 0.9883 - learning_rate: 6.2500e-05
# Epoch 30/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.9910 - f1_m: 0.9904 - loss: 0.3463 - precision_m: 0.9934 - recall_m: 0.9875
# Epoch 30: val_loss improved from 0.33936 to 0.33628, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 72s 76ms/step - accuracy: 0.9910 - f1_m: 0.9904 - loss: 0.3463 - precision_m: 0.9934 - recall_m: 0.9875 - val_accuracy: 0.9928 - val_f1_m: 0.9926 - val_loss: 0.3363 - val_precision_m: 0.9940 - val_recall_m: 0.9912 - learning_rate: 6.2500e-05
# Epoch 31/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9917 - f1_m: 0.9906 - loss: 0.3443 - precision_m: 0.9931 - recall_m: 0.9883
# Epoch 31: val_loss did not improve from 0.33628
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 68s 73ms/step - accuracy: 0.9917 - f1_m: 0.9906 - loss: 0.3443 - precision_m: 0.9931 - recall_m: 0.9883 - val_accuracy: 0.9914 - val_f1_m: 0.9909 - val_loss: 0.3438 - val_precision_m: 0.9936 - val_recall_m: 0.9884 - learning_rate: 6.2500e-05
# Epoch 32/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9917 - f1_m: 0.9911 - loss: 0.3436 - precision_m: 0.9938 - recall_m: 0.9886
# Epoch 32: val_loss improved from 0.33628 to 0.33436, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 68s 72ms/step - accuracy: 0.9917 - f1_m: 0.9911 - loss: 0.3436 - precision_m: 0.9938 - recall_m: 0.9886 - val_accuracy: 0.9922 - val_f1_m: 0.9920 - val_loss: 0.3344 - val_precision_m: 0.9940 - val_recall_m: 0.9900 - learning_rate: 6.2500e-05
# Epoch 33/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9919 - f1_m: 0.9909 - loss: 0.3431 - precision_m: 0.9937 - recall_m: 0.9883
# Epoch 33: val_loss did not improve from 0.33436
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 68s 73ms/step - accuracy: 0.9919 - f1_m: 0.9909 - loss: 0.3431 - precision_m: 0.9937 - recall_m: 0.9883 - val_accuracy: 0.9836 - val_f1_m: 0.9824 - val_loss: 0.3532 - val_precision_m: 0.9855 - val_recall_m: 0.9795 - learning_rate: 6.2500e-05
# Epoch 34/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9927 - f1_m: 0.9923 - loss: 0.3416 - precision_m: 0.9946 - recall_m: 0.9900
# Epoch 34: val_loss did not improve from 0.33436
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 68s 72ms/step - accuracy: 0.9927 - f1_m: 0.9922 - loss: 0.3416 - precision_m: 0.9946 - recall_m: 0.9900 - val_accuracy: 0.9934 - val_f1_m: 0.9931 - val_loss: 0.3362 - val_precision_m: 0.9950 - val_recall_m: 0.9912 - learning_rate: 6.2500e-05
# Epoch 35/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9927 - f1_m: 0.9920 - loss: 0.3412 - precision_m: 0.9943 - recall_m: 0.9898
# Epoch 35: val_loss did not improve from 0.33436
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 70s 75ms/step - accuracy: 0.9927 - f1_m: 0.9920 - loss: 0.3412 - precision_m: 0.9943 - recall_m: 0.9898 - val_accuracy: 0.9899 - val_f1_m: 0.9896 - val_loss: 0.3513 - val_precision_m: 0.9919 - val_recall_m: 0.9875 - learning_rate: 6.2500e-05
# Epoch 36/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9937 - f1_m: 0.9933 - loss: 0.3385 - precision_m: 0.9952 - recall_m: 0.9915
# Epoch 36: val_loss improved from 0.33436 to 0.33085, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 67s 71ms/step - accuracy: 0.9937 - f1_m: 0.9933 - loss: 0.3385 - precision_m: 0.9952 - recall_m: 0.9915 - val_accuracy: 0.9930 - val_f1_m: 0.9922 - val_loss: 0.3308 - val_precision_m: 0.9940 - val_recall_m: 0.9905 - learning_rate: 3.1250e-05
# Epoch 37/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9934 - f1_m: 0.9930 - loss: 0.3374 - precision_m: 0.9951 - recall_m: 0.9909
# Epoch 37: val_loss did not improve from 0.33085
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 66s 71ms/step - accuracy: 0.9934 - f1_m: 0.9930 - loss: 0.3374 - precision_m: 0.9951 - recall_m: 0.9909 - val_accuracy: 0.9929 - val_f1_m: 0.9928 - val_loss: 0.3324 - val_precision_m: 0.9938 - val_recall_m: 0.9919 - learning_rate: 3.1250e-05
# Epoch 38/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9938 - f1_m: 0.9935 - loss: 0.3372 - precision_m: 0.9953 - recall_m: 0.9916
# Epoch 38: val_loss did not improve from 0.33085
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 66s 71ms/step - accuracy: 0.9938 - f1_m: 0.9935 - loss: 0.3372 - precision_m: 0.9953 - recall_m: 0.9916 - val_accuracy: 0.9940 - val_f1_m: 0.9936 - val_loss: 0.3355 - val_precision_m: 0.9951 - val_recall_m: 0.9921 - learning_rate: 3.1250e-05
# Epoch 39/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9940 - f1_m: 0.9934 - loss: 0.3376 - precision_m: 0.9951 - recall_m: 0.9918
# Epoch 39: val_loss improved from 0.33085 to 0.32998, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 67s 71ms/step - accuracy: 0.9940 - f1_m: 0.9934 - loss: 0.3376 - precision_m: 0.9951 - recall_m: 0.9918 - val_accuracy: 0.9937 - val_f1_m: 0.9937 - val_loss: 0.3300 - val_precision_m: 0.9949 - val_recall_m: 0.9926 - learning_rate: 3.1250e-05
# Epoch 40/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9946 - f1_m: 0.9940 - loss: 0.3359 - precision_m: 0.9957 - recall_m: 0.9923
# Epoch 40: val_loss improved from 0.32998 to 0.32893, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 67s 72ms/step - accuracy: 0.9946 - f1_m: 0.9940 - loss: 0.3359 - precision_m: 0.9957 - recall_m: 0.9923 - val_accuracy: 0.9948 - val_f1_m: 0.9943 - val_loss: 0.3289 - val_precision_m: 0.9957 - val_recall_m: 0.9929 - learning_rate: 3.1250e-05
# Epoch 41/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9940 - f1_m: 0.9934 - loss: 0.3357 - precision_m: 0.9953 - recall_m: 0.9916
# Epoch 41: val_loss did not improve from 0.32893
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 67s 71ms/step - accuracy: 0.9940 - f1_m: 0.9934 - loss: 0.3357 - precision_m: 0.9953 - recall_m: 0.9916 - val_accuracy: 0.9928 - val_f1_m: 0.9930 - val_loss: 0.3312 - val_precision_m: 0.9945 - val_recall_m: 0.9915 - learning_rate: 3.1250e-05
# Epoch 42/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9943 - f1_m: 0.9937 - loss: 0.3369 - precision_m: 0.9955 - recall_m: 0.9920
# Epoch 42: val_loss did not improve from 0.32893
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 69s 74ms/step - accuracy: 0.9943 - f1_m: 0.9937 - loss: 0.3369 - precision_m: 0.9955 - recall_m: 0.9920 - val_accuracy: 0.9942 - val_f1_m: 0.9936 - val_loss: 0.3326 - val_precision_m: 0.9951 - val_recall_m: 0.9922 - learning_rate: 3.1250e-05
# Epoch 43/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9945 - f1_m: 0.9940 - loss: 0.3360 - precision_m: 0.9961 - recall_m: 0.9919
# Epoch 43: val_loss did not improve from 0.32893
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 68s 72ms/step - accuracy: 0.9945 - f1_m: 0.9940 - loss: 0.3360 - precision_m: 0.9961 - recall_m: 0.9920 - val_accuracy: 0.9932 - val_f1_m: 0.9927 - val_loss: 0.3297 - val_precision_m: 0.9939 - val_recall_m: 0.9916 - learning_rate: 3.1250e-05
# Epoch 44/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9947 - f1_m: 0.9945 - loss: 0.3338 - precision_m: 0.9960 - recall_m: 0.9930
# Epoch 44: val_loss improved from 0.32893 to 0.32738, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 67s 71ms/step - accuracy: 0.9947 - f1_m: 0.9945 - loss: 0.3338 - precision_m: 0.9960 - recall_m: 0.9930 - val_accuracy: 0.9939 - val_f1_m: 0.9936 - val_loss: 0.3274 - val_precision_m: 0.9951 - val_recall_m: 0.9921 - learning_rate: 1.5625e-05
# Epoch 45/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9939 - f1_m: 0.9934 - loss: 0.3341 - precision_m: 0.9956 - recall_m: 0.9914
# Epoch 45: val_loss improved from 0.32738 to 0.32658, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 66s 71ms/step - accuracy: 0.9939 - f1_m: 0.9934 - loss: 0.3341 - precision_m: 0.9956 - recall_m: 0.9914 - val_accuracy: 0.9947 - val_f1_m: 0.9945 - val_loss: 0.3266 - val_precision_m: 0.9960 - val_recall_m: 0.9931 - learning_rate: 1.5625e-05
# Epoch 46/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9952 - f1_m: 0.9948 - loss: 0.3334 - precision_m: 0.9963 - recall_m: 0.9933
# Epoch 46: val_loss improved from 0.32658 to 0.32648, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 67s 71ms/step - accuracy: 0.9952 - f1_m: 0.9948 - loss: 0.3334 - precision_m: 0.9963 - recall_m: 0.9933 - val_accuracy: 0.9942 - val_f1_m: 0.9945 - val_loss: 0.3265 - val_precision_m: 0.9961 - val_recall_m: 0.9929 - learning_rate: 1.5625e-05
# Epoch 47/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9949 - f1_m: 0.9949 - loss: 0.3334 - precision_m: 0.9963 - recall_m: 0.9936
# Epoch 47: val_loss did not improve from 0.32648
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 68s 72ms/step - accuracy: 0.9949 - f1_m: 0.9949 - loss: 0.3334 - precision_m: 0.9963 - recall_m: 0.9936 - val_accuracy: 0.9917 - val_f1_m: 0.9914 - val_loss: 0.3336 - val_precision_m: 0.9931 - val_recall_m: 0.9897 - learning_rate: 1.5625e-05
# Epoch 48/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9944 - f1_m: 0.9940 - loss: 0.3340 - precision_m: 0.9958 - recall_m: 0.9924
# Epoch 48: val_loss did not improve from 0.32648
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 81s 71ms/step - accuracy: 0.9944 - f1_m: 0.9940 - loss: 0.3340 - precision_m: 0.9958 - recall_m: 0.9924 - val_accuracy: 0.9927 - val_f1_m: 0.9926 - val_loss: 0.3297 - val_precision_m: 0.9942 - val_recall_m: 0.9910 - learning_rate: 1.5625e-05
# Epoch 49/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9953 - f1_m: 0.9947 - loss: 0.3329 - precision_m: 0.9962 - recall_m: 0.9932
# Epoch 49: val_loss did not improve from 0.32648
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 68s 72ms/step - accuracy: 0.9953 - f1_m: 0.9947 - loss: 0.3329 - precision_m: 0.9962 - recall_m: 0.9932 - val_accuracy: 0.9953 - val_f1_m: 0.9955 - val_loss: 0.3299 - val_precision_m: 0.9967 - val_recall_m: 0.9943 - learning_rate: 1.5625e-05
# Epoch 50/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9946 - f1_m: 0.9941 - loss: 0.3330 - precision_m: 0.9957 - recall_m: 0.9924
# Epoch 50: val_loss improved from 0.32648 to 0.32627, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 68s 72ms/step - accuracy: 0.9946 - f1_m: 0.9941 - loss: 0.3330 - precision_m: 0.9957 - recall_m: 0.9924 - val_accuracy: 0.9947 - val_f1_m: 0.9944 - val_loss: 0.3263 - val_precision_m: 0.9957 - val_recall_m: 0.9932 - learning_rate: 7.8125e-06

# %%
loss, accuracy, f1_score, precision, recall = model_CNN.evaluate(X_test_gaf, y_test, verbose=0)
print(f"Validation Loss: {loss}")
print(f"Accuracy: {accuracy}")
print(f"F1 Score: {f1_score}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
# Out:
# Validation Loss: 0.32627126574516296
# Accuracy: 0.9946666955947876
# F1 Score: 0.9944291114807129
# Precision: 0.9956637024879456
# Recall: 0.993240237236023

# %% [markdown]
# **Visualizations**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, roc_curve, auc, accuracy_score
import numpy as np
from itertools import cycle

def plot_accuracy_loss(history):
    fig, axs = plt.subplots(1, 2, figsize=(12, 4))

    axs[0].plot(history.history['accuracy'], label='Train Accuracy')
    axs[0].plot(history.history['val_accuracy'], label='Validation Accuracy')
    axs[0].set_title('Model Accuracy')
    axs[0].set_xlabel('Epochs')
    axs[0].set_ylabel('Accuracy')
    axs[0].legend()

    axs[1].plot(history.history['loss'], label='Train Loss')
    axs[1].plot(history.history['val_loss'], label='Validation Loss')
    axs[1].set_title('Model Loss')
    axs[1].set_xlabel('Epochs')
    axs[1].set_ylabel('Loss')
    axs[1].legend()
    plt.show()
    
plot_accuracy_loss(history)

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
import numpy as np

def plot_confusion_matrix(model, x_test, y_test):
    y_pred = np.argmax(model.predict(x_test), axis=1)
    y_true = np.argmax(y_test, axis=1)

    cm = confusion_matrix(y_true, y_pred)
    class_names = [f'Class {i}' for i in range(y_test.shape[1])]
    
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names,
                yticklabels=class_names)
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.show()

plot_confusion_matrix(model_CNN, X_test_gaf, y_test)
# Out:
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step

# %%
from sklearn.metrics import roc_curve, auc, roc_auc_score
from itertools import cycle
import matplotlib.pyplot as plt

def plot_roc_curve(model, x_test, y_test):
    y_pred = model.predict(x_test)
    n_classes = y_test.shape[1]

    fpr, tpr, roc_auc = {}, {}, {}
    plt.figure(figsize=(8, 6))
    colors = cycle(['blue', 'red', 'green', 'purple', 'orange'])

    for i, color in zip(range(n_classes), colors):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
        plt.plot(fpr[i], tpr[i], color=color, lw=2,
                 label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

    fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_pred.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
    plt.plot(fpr["micro"], tpr["micro"],
             label=f'Micro-average ROC (AUC = {roc_auc["micro"]:.2f})',
             color='black', linestyle='--', linewidth=2)

    plt.plot([0, 1], [0, 1], 'k--', lw=1)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Multi-class ROC Curve')
    plt.legend(loc="lower right")
    plt.tight_layout()
    plt.show()
    
plot_roc_curve(model_CNN, X_test_gaf, y_test)
# Out:
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

def permutation_importance_gaf(model, X, y_true, base_score_fn=accuracy_score):
    """
    Computes permutation importance for GAF input of shape (N, 34, 34).
    Permutes both row and column i for each of the 34 original features.
    """
    base_preds = np.argmax(model.predict(X), axis=1)
    if len(y_true.shape) > 1:
        y_true = np.argmax(y_true, axis=1)

    base_score = base_score_fn(y_true, base_preds)
    feature_importance = []

    for i in range(34):  
        X_permuted = np.copy(X)

        for j in range(X.shape[0]):  
            perm = np.random.permutation(X.shape[1])
            X_permuted[j, i, :] = X_permuted[j, i, perm]  
            X_permuted[j, :, i] = X_permuted[j, perm, i]  

        preds = np.argmax(model.predict(X_permuted), axis=1)
        score = base_score_fn(y_true, preds)
        importance = base_score - score
        feature_importance.append(importance)

    return feature_importance                                                                                                                                                                                                                                      # Feature names (ensure this matches your original 34 features)
feature_names = [
    "MEAN_RR", "MEDIAN_RR", "SDRR", "RMSSD", "SDSD", "SDRR_RMSSD", "HR", 
    "pNN25", "pNN50", "SD1", "SD2", "SD2_SD1", "KURT", "SKEW", "IQR", 
    "HF_PEAK", "HF_MEAN", "HF_MED", "HF_VAR", "LF", "LF_PEAK", "LF_MEAN", 
    "LF_MED", "LF_VAR", "LF_PCT", "LF_NU", "HF", "HF_PCT", "HF_NU", "TP", 
    "LF_HF", "HF_LF", "sampen", "higuci"
]

importance_per_feature = permutation_importance_gaf(model_CNN, X_test_gaf, y_test)
importance_per_feature = np.array(importance_per_feature)
importance_per_feature /= importance_per_feature.max()
plt.figure(figsize=(16, 6))
plt.bar(range(34), importance_per_feature, color='skyblue')
plt.xticks(range(34), feature_names, rotation=90)
plt.ylabel("Feature Importance")
plt.title("Permutation Feature Importance per Original Feature")
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 6s 22ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step
