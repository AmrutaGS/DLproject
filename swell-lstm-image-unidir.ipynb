# %%
# !pip install pyts
# Out:
# Collecting pyts
#   Downloading pyts-0.13.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pyts) (1.26.4)
# Requirement already satisfied: scipy>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from pyts) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from pyts) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from pyts) (1.4.2)
# Requirement already satisfied: numba>=0.55.2 in /usr/local/lib/python3.10/dist-packages (from pyts) (0.60.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.55.2->pyts) (0.43.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.22.4->pyts) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.22.4->pyts) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.22.4->pyts) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.22.4->pyts) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.22.4->pyts) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.22.4->pyts) (2.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.2.0->pyts) (3.5.0)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.22.4->pyts) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.22.4->pyts) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.22.4->pyts) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.22.4->pyts) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.22.4->pyts) (2024.2.0)
# Downloading pyts-0.13.0-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 26.1 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pyts
# Successfully installed pyts-0.13.0

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt

from mpl_toolkits.axes_grid1 import ImageGrid
from pyts.image import GramianAngularField
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

def root_directory():
    """Returns the root directory of the project."""
    return "/kaggle/input/swell-heart-rate-variability-hrv/hrv dataset"

def data_directory():
    """Returns the data directory path."""
    return os.path.join(root_directory(), "data") 
def load_train_set():
    """Loads training dataset as a Pandas DataFrame."""
    train_file = os.path.join(data_directory(), "final", "train.csv")
    return pd.read_csv(train_file)

def load_test_set():
    """Loads test dataset as a Pandas DataFrame."""
    test_file = os.path.join(data_directory(), "final", "test.csv")
    return pd.read_csv(test_file)

train = load_train_set()
test = load_test_set()

target = "condition"

hrv_features = [col for col in train.columns if col != target]

label_map = {"no stress": 0, "interruption": 1, "time pressure": 2}
train[target] = train[target].map(label_map)
test[target] = test[target].map(label_map)


def sample_data(df, label_col, n_samples):
    """Safely sample n_samples per class without errors."""
    sampled_df = []
    for label in df[label_col].unique():
        class_data = df[df[label_col] == label]
        sample_size = min(n_samples, len(class_data))  
        sampled_df.append(class_data.sample(n=sample_size, random_state=42))
    return pd.concat(sampled_df).reset_index(drop=True)

train_balanced = sample_data(train, target, 10000)
test_balanced = sample_data(test, target, 3000)  

X_train = train_balanced[hrv_features]
y_train = train_balanced[target]

if "datasetId" in X_train.columns:
    X_train = X_train.drop(columns="datasetId")

X_test = test_balanced[hrv_features]
y_test = test_balanced[target]

if "datasetId" in X_test.columns:
    X_test = X_test.drop(columns="datasetId")

print(f"Train Set Shape: {X_train.shape}, Labels Shape: {y_train.shape}")
print(f"Test Set Shape: {X_test.shape}, Labels Shape: {y_test.shape}")

display(X_train.head())
display(y_train.head())
# Out:
# Train Set Shape: (30000, 34), Labels Shape: (30000,)
# Test Set Shape: (9000, 34), Labels Shape: (9000,)
#       MEAN_RR   MEDIAN_RR        SDRR      RMSSD       SDSD  SDRR_RMSSD  \
# 0  896.720876  880.459590  106.101117  13.924951  13.924949    7.619497
# 1  903.325242  905.495460   72.285411  12.387407  12.386563    5.835395
# 2  934.870026  916.307545  128.556268  16.728592  16.728579    7.684823
# 3  726.048217  726.396200   58.167902   9.760850   9.760850    5.959307
# 4  903.212333  918.237180  108.998652  16.905228  16.905228    6.447630
#
#           HR      pNN25     pNN50        SD1  ...     LF_PCT      LF_NU  \
# 0  67.818401   7.733333  0.466667   9.849712  ...  28.035932  98.809256
# 1  66.855229   4.466667  0.133333   8.761546  ...  23.244445  99.726832
# 2  65.364253  13.200000  1.066667  11.832839  ...  28.280122  99.507931
# 3  83.181060   1.400000  0.000000   6.904267  ...  22.022647  93.990424
# 4  67.479959  12.400000  1.333333  11.957790  ...  23.825552  98.769012
#
#           HF    HF_PCT     HF_NU           TP       LF_HF     HF_LF    sampen  \
# 0   9.922258  0.337859  1.190744  2936.803667   82.981135  0.012051  2.127076
# 1   1.783522  0.063670  0.273168  2801.178306  365.074431  0.002739  2.192351
# 2   6.164162  0.139846  0.492069  4407.828115  202.223606  0.004945  2.160318
# 3  26.015607  1.408088  6.009576  1847.584044   15.640109  0.063938  2.157452
# 4  13.625402  0.296945  1.230988  4588.526989   80.235569  0.012463  2.179244
#
#      higuci
# 0  1.134921
# 1  1.069071
# 2  1.126186
# 3  1.152640
# 4  1.177820
#
# [5 rows x 34 columns]
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: condition, dtype: int64

# %%
def quantile_normalize(df):
    """Applies quantile normalization to the DataFrame."""
    df_sorted = pd.DataFrame(np.sort(df.values, axis=0), index=df.index, columns=df.columns)
    df_mean = df_sorted.mean(axis=1)
    df_mean.index = np.arange(1, len(df_mean) + 1)
    df_qn = df.rank(method="min").stack().astype(int).map(df_mean).unstack()
    return df_qn


x_train_swell = quantile_normalize(X_train)
x_test_swell = quantile_normalize(X_test)

display(x_train_swell.head())
display(x_test_swell.head())
print(x_train_swell.describe())
print(x_test_swell.describe())
# Out:
#       MEAN_RR   MEDIAN_RR        SDRR       RMSSD        SDSD  SDRR_RMSSD  \
# 0  276.697101  261.548330  281.634094  201.939225  201.948873  306.099269
# 1  283.060633  290.437894  183.073989  167.021640  166.952993  215.238532
# 2  312.856441  298.311570  333.659979  277.912510  277.935225  309.649467
# 3  118.124366  124.548167  136.809099  117.415260  117.430190  221.768654
# 4  282.869530  300.263695  289.169845  283.041251  283.046942  248.500700
#
#            HR       pNN25       pNN50         SD1  ...      LF_PCT  \
# 0  186.792253  220.098299  219.751609  201.948873  ...  209.281585
# 1  178.099179  165.854182  166.058400  166.952993  ...  175.512435
# 2  167.908511  315.431057  277.893149  277.935225  ...  211.163474
# 3  463.050505  112.676927   57.594885  117.430190  ...  165.622387
# 4  183.634928  300.234227  309.342415  283.046942  ...  179.713401
#
#         LF_NU          HF      HF_PCT       HF_NU          TP       LF_HF  \
# 0  309.383929  166.989622  170.844721  172.502720  229.176610  309.383929
# 1  527.319177  104.591577  111.702021  111.394438  220.181001  527.319177
# 2  434.164037  141.753598  139.078646  129.723889  339.437487  434.164037
# 3  158.516499  250.212396  280.129440  339.707893  158.679659  158.516499
# 4  305.818680  184.847490  165.565337  174.383861  355.878824  305.818680
#
#         HF_LF      sampen      higuci
# 0  172.502720  220.280335  160.774105
# 1  111.394438  390.664047   91.473882
# 2  129.723889  264.643133  147.015168
# 3  339.707893  259.802904  193.893174
# 4  174.383861  315.449174  240.393451
#
# [5 rows x 34 columns]
#       MEAN_RR   MEDIAN_RR        SDRR       RMSSD        SDSD  SDRR_RMSSD  \
# 0  154.981903  130.948799  357.917964  218.603896  218.603896  399.488499
# 1  206.332670  212.064032  158.559158  158.894224  158.894224  188.846044
# 2  108.774609  110.761248  174.510012  123.887169  123.887169  272.919928
# 3  184.635339  206.397936  343.041840  204.879360  204.879360  387.853716
# 4  173.729083  170.568761  115.378578  158.499353  158.499353  143.334814
#
#            HR       pNN25       pNN50         SD1  ...      LF_PCT  \
# 0  376.844594  226.243094  239.203434  218.603896  ...  181.232421
# 1  240.684831  152.445046   58.596835  158.894224  ...  190.435567
# 2  513.057777  134.679136   58.596835  123.887169  ...  207.303791
# 3  305.771471  206.484818  278.290686  204.879360  ...  166.258531
# 4  289.746416  143.353928   58.596835  158.499353  ...  522.481666
#
#         LF_NU          HF      HF_PCT       HF_NU          TP       LF_HF  \
# 0  142.039242  396.002894  311.944479  386.663115  242.885987  142.039242
# 1  171.716120  259.323638  280.144485  306.319210  163.331167  171.716120
# 2  223.802244  209.252014  228.533895  232.983896  175.664416  223.802244
# 3  211.404028  272.407888  219.344145  244.743676  281.113670  211.404028
# 4  276.389324  196.987243  244.559104  188.324377  140.363456  276.389324
#
#         HF_LF      sampen      higuci
# 0  386.663115   94.875043  272.298257
# 1  306.319210  250.749993  301.416603
# 2  232.983896  297.822034  161.413623
# 3  244.743676  194.813778  174.500443
# 4  188.324377  267.048739  166.388660
#
# [5 rows x 34 columns]
#             MEAN_RR     MEDIAN_RR          SDRR         RMSSD          SDSD  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean     272.534334    272.434753    272.534334    272.534334    272.534334
# std      161.064480    160.681748    161.064480    161.064480    161.064480
# min       57.594885     57.594885     57.594885     57.594885     57.594885
# 25%      161.769849    161.769849    161.769849    161.769849    161.769849
# 50%      229.496375    229.489324    229.496375    229.496375    229.496375
# 75%      332.274137    332.242212    332.274137    332.274137    332.274137
# max     1242.394745   1144.375092   1242.394745   1242.394745   1242.394745
#
#          SDRR_RMSSD            HR         pNN25         pNN50           SD1  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean     272.534334    272.534334    271.779447    253.502644    272.534334
# std      161.064480    161.064480    160.934737    173.991796    161.064480
# min       57.594885     57.594885     57.594885     57.594885     57.594885
# 25%      161.769849    161.769849    161.525190    157.635702    161.769849
# 50%      229.496375    229.496375    228.712355    224.236676    229.496375
# 75%      332.274137    332.274137    331.051105    332.262775    332.274137
# max     1242.394745   1242.394745   1242.394745   1242.394745   1242.394745
#
#        ...        LF_PCT         LF_NU            HF        HF_PCT  \
# count  ...  30000.000000  30000.000000  30000.000000  30000.000000
# mean   ...    272.534334    272.534334    272.534334    272.534334
# std    ...    161.064480    161.064480    161.064480    161.064480
# min    ...     57.594885     57.594885     57.594885     57.594885
# 25%    ...    161.769849    161.769849    161.769849    161.769849
# 50%    ...    229.496375    229.496375    229.496375    229.496375
# 75%    ...    332.274137    332.274137    332.274137    332.274137
# max    ...   1242.394745   1242.394745   1242.394745   1242.394745
#
#               HF_NU            TP         LF_HF         HF_LF        sampen  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean     272.534334    272.534334    272.534334    272.534334    272.518826
# std      161.064480    161.064480    161.064480    161.064480    161.039607
# min       57.594885     57.594885     57.594885     57.594885     57.594885
# 25%      161.769849    161.769849    161.769849    161.769849    161.768069
# 50%      229.496375    229.496375    229.496375    229.496375    229.496375
# 75%      332.274137    332.274137    332.274137    332.274137    332.262775
# max     1242.394745   1242.394745   1242.394745   1242.394745   1242.394745
#
#              higuci
# count  30000.000000
# mean     272.534334
# std      161.064480
# min       57.594885
# 25%      161.769849
# 50%      229.496375
# 75%      332.274137
# max     1242.394745
#
# [8 rows x 34 columns]
#            MEAN_RR    MEDIAN_RR         SDRR        RMSSD         SDSD  \
# count  9000.000000  9000.000000  9000.000000  9000.000000  9000.000000
# mean    270.802541   270.717383   270.802541   270.802541   270.802541
# std     160.659658   160.343754   160.659658   160.659658   160.659658
# min      58.596835    58.596835    58.596835    58.596835    58.596835
# 25%     160.556477   160.556477   160.556477   160.556477   160.556477
# 50%     228.452560   228.452560   228.452560   228.452560   228.452560
# 75%     330.168948   330.168948   330.168948   330.168948   330.168948
# max    1234.324066  1167.337049  1234.324066  1234.324066  1234.324066
#
#         SDRR_RMSSD           HR        pNN25        pNN50          SD1  ...  \
# count  9000.000000  9000.000000  9000.000000  9000.000000  9000.000000  ...
# mean    270.802541   270.802541   270.047725   252.342726   270.802541  ...
# std     160.659658   160.659658   160.541381   173.061263   160.659658  ...
# min      58.596835    58.596835    58.596835    58.596835    58.596835  ...
# 25%     160.556477   160.556477   160.241940   156.411510   160.556477  ...
# 50%     228.452560   228.452560   227.704178   223.068524   228.452560  ...
# 75%     330.168948   330.168948   329.177168   327.284772   330.168948  ...
# max    1234.324066  1234.324066  1234.324066  1234.324066  1234.324066  ...
#
#             LF_PCT        LF_NU           HF       HF_PCT        HF_NU  \
# count  9000.000000  9000.000000  9000.000000  9000.000000  9000.000000
# mean    270.802541   270.802541   270.802541   270.802541   270.802541
# std     160.659658   160.659658   160.659658   160.659658   160.659658
# min      58.596835    58.596835    58.596835    58.596835    58.596835
# 25%     160.556477   160.556477   160.556477   160.556477   160.556477
# 50%     228.452560   228.452560   228.452560   228.452560   228.452560
# 75%     330.168948   330.168948   330.168948   330.168948   330.168948
# max    1234.324066  1234.324066  1234.324066  1234.324066  1234.324066
#
#                 TP        LF_HF        HF_LF       sampen       higuci
# count  9000.000000  9000.000000  9000.000000  9000.000000  9000.000000
# mean    270.802541   270.802541   270.802541   270.783826   270.802541
# std     160.659658   160.659658   160.659658   160.619619   160.659658
# min      58.596835    58.596835    58.596835    58.596835    58.596835
# 25%     160.556477   160.556477   160.556477   160.535503   160.556477
# 50%     228.452560   228.452560   228.452560   228.452560   228.452560
# 75%     330.168948   330.168948   330.168948   330.120840   330.168948
# max    1234.324066  1234.324066  1234.324066  1234.324066  1234.324066
#
# [8 rows x 34 columns]

# %%
gaf = GramianAngularField()

X_train_gaf = gaf.fit_transform(X_train.to_numpy())
X_test_gaf = gaf.fit_transform(X_test.to_numpy())

X_train_gaf = X_train_gaf.reshape(X_train_gaf.shape[0], 34, 34, 1)
X_test_gaf = X_test_gaf.reshape(X_test_gaf.shape[0], 34, 34, 1)

X_train_gaf /= np.max(X_train_gaf, axis=(1, 2, 3), keepdims=True)
X_test_gaf /= np.max(X_test_gaf, axis=(1, 2, 3), keepdims=True)

y_train = tf.keras.utils.to_categorical(y_train, num_classes=3)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=3)
print(X_train_gaf.shape)
print(X_test_gaf.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (30000, 34, 34, 1)
# (9000, 34, 34, 1)
# (30000, 3)
# (9000, 3)

# %%
x_train_lstm = X_train_gaf.reshape(-1, 34, 34)
x_test_lstm = X_test_gaf.reshape(-1, 34, 34)

# %%
print("Train set:", x_train_lstm.shape, y_train.shape)   
print("Test set:", x_test_lstm.shape, y_test.shape)
# Out:
# Train set: (30000, 34, 34) (30000, 3)
# Test set: (9000, 34, 34) (9000, 3)

# %%
import tensorflow as tf
from tensorflow.keras import backend as K

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    return true_positives / (predicted_positives + K.epsilon())

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

# %%
import tensorflow as tf
from tensorflow.keras import layers, regularizers, callbacks
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, BatchNormalization, Dense
from tensorflow.keras.optimizers import Adam

def model_LSTM():
    model = Sequential()
    model.add(LSTM(64, return_sequences=True, input_shape=(34, 34), activation='tanh'))
    model.add(BatchNormalization())
    model.add(LSTM(64, return_sequences=True, activation='tanh'))
    model.add(BatchNormalization())
    model.add(LSTM(64, activation='tanh'))
    model.add(BatchNormalization())
    model.add(Dense(6)) 
    model.add(Dense(3, activation='softmax'))  
    model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy', f1_m, precision_m, recall_m])
    return model
    
model=model_LSTM()

loss = tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1)

optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)

model.compile(
    optimizer=optimizer,
    loss=loss,
    metrics=['accuracy', f1_m, precision_m, recall_m]
)
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 34, 64)              │          25,344 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 34, 64)              │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 34, 64)              │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 34, 64)              │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_2 (LSTM)                        │ (None, 64)                  │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 6)                   │             390 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3)                   │              21 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 92,571 (361.61 KB)
#  Trainable params: 92,187 (360.11 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
model=model_LSTM()
model_checkpoint = callbacks.ModelCheckpoint("best_model.keras", save_best_only=True, monitor='val_loss', verbose=1)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1)
history = model.fit(x_train_lstm, y_train, epochs=50, batch_size=32,
                    validation_data=(x_test_lstm, y_test),
                    callbacks=[model_checkpoint,reduce_lr])
# Out:
# Epoch 1/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5426 - f1_m: 0.4812 - loss: 0.9635 - precision_m: 0.6152 - recall_m: 0.4012
# Epoch 1: val_loss improved from inf to 2.17947, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 48s 46ms/step - accuracy: 0.5427 - f1_m: 0.4813 - loss: 0.9634 - precision_m: 0.6153 - recall_m: 0.4013 - val_accuracy: 0.3607 - val_f1_m: 0.3510 - val_loss: 2.1795 - val_precision_m: 0.3557 - val_recall_m: 0.3466 - learning_rate: 0.0010
# Epoch 2/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7130 - f1_m: 0.7023 - loss: 0.6569 - precision_m: 0.7505 - recall_m: 0.6615
# Epoch 2: val_loss improved from 2.17947 to 1.26725, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 42s 44ms/step - accuracy: 0.7130 - f1_m: 0.7024 - loss: 0.6569 - precision_m: 0.7505 - recall_m: 0.6615 - val_accuracy: 0.5116 - val_f1_m: 0.4980 - val_loss: 1.2673 - val_precision_m: 0.5113 - val_recall_m: 0.4858 - learning_rate: 0.0010
# Epoch 3/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7798 - f1_m: 0.7739 - loss: 0.5321 - precision_m: 0.8026 - recall_m: 0.7481
# Epoch 3: val_loss did not improve from 1.26725
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 44ms/step - accuracy: 0.7798 - f1_m: 0.7739 - loss: 0.5321 - precision_m: 0.8027 - recall_m: 0.7481 - val_accuracy: 0.4631 - val_f1_m: 0.4584 - val_loss: 1.7949 - val_precision_m: 0.4634 - val_recall_m: 0.4537 - learning_rate: 0.0010
# Epoch 4/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8148 - f1_m: 0.8120 - loss: 0.4520 - precision_m: 0.8335 - recall_m: 0.7922
# Epoch 4: val_loss did not improve from 1.26725
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 44ms/step - accuracy: 0.8148 - f1_m: 0.8120 - loss: 0.4520 - precision_m: 0.8335 - recall_m: 0.7922 - val_accuracy: 0.4560 - val_f1_m: 0.4515 - val_loss: 1.6959 - val_precision_m: 0.4759 - val_recall_m: 0.4305 - learning_rate: 0.0010
# Epoch 5/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8407 - f1_m: 0.8387 - loss: 0.3900 - precision_m: 0.8546 - recall_m: 0.8239
# Epoch 5: val_loss improved from 1.26725 to 1.22315, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 44ms/step - accuracy: 0.8407 - f1_m: 0.8387 - loss: 0.3900 - precision_m: 0.8546 - recall_m: 0.8239 - val_accuracy: 0.6200 - val_f1_m: 0.6175 - val_loss: 1.2231 - val_precision_m: 0.6337 - val_recall_m: 0.6026 - learning_rate: 0.0010
# Epoch 6/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8659 - f1_m: 0.8653 - loss: 0.3343 - precision_m: 0.8780 - recall_m: 0.8533
# Epoch 6: val_loss did not improve from 1.22315
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 44ms/step - accuracy: 0.8659 - f1_m: 0.8653 - loss: 0.3343 - precision_m: 0.8780 - recall_m: 0.8533 - val_accuracy: 0.5074 - val_f1_m: 0.5019 - val_loss: 1.6829 - val_precision_m: 0.5126 - val_recall_m: 0.4920 - learning_rate: 0.0010
# Epoch 7/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8884 - f1_m: 0.8883 - loss: 0.2866 - precision_m: 0.8968 - recall_m: 0.8803
# Epoch 7: val_loss did not improve from 1.22315
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 42s 44ms/step - accuracy: 0.8884 - f1_m: 0.8883 - loss: 0.2866 - precision_m: 0.8968 - recall_m: 0.8803 - val_accuracy: 0.4890 - val_f1_m: 0.4801 - val_loss: 1.5234 - val_precision_m: 0.4962 - val_recall_m: 0.4654 - learning_rate: 0.0010
# Epoch 8/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9017 - f1_m: 0.9022 - loss: 0.2515 - precision_m: 0.9085 - recall_m: 0.8963
# Epoch 8: val_loss did not improve from 1.22315
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 44ms/step - accuracy: 0.9017 - f1_m: 0.9023 - loss: 0.2515 - precision_m: 0.9085 - recall_m: 0.8963 - val_accuracy: 0.6169 - val_f1_m: 0.6138 - val_loss: 1.2590 - val_precision_m: 0.6202 - val_recall_m: 0.6077 - learning_rate: 0.0010
# Epoch 9/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9319 - f1_m: 0.9315 - loss: 0.1775 - precision_m: 0.9353 - recall_m: 0.9279
# Epoch 9: val_loss improved from 1.22315 to 0.35738, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 42s 45ms/step - accuracy: 0.9319 - f1_m: 0.9315 - loss: 0.1775 - precision_m: 0.9353 - recall_m: 0.9279 - val_accuracy: 0.8769 - val_f1_m: 0.8777 - val_loss: 0.3574 - val_precision_m: 0.8823 - val_recall_m: 0.8732 - learning_rate: 5.0000e-04
# Epoch 10/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9421 - f1_m: 0.9422 - loss: 0.1556 - precision_m: 0.9448 - recall_m: 0.9397
# Epoch 10: val_loss did not improve from 0.35738
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 42s 44ms/step - accuracy: 0.9421 - f1_m: 0.9422 - loss: 0.1556 - precision_m: 0.9448 - recall_m: 0.9397 - val_accuracy: 0.5500 - val_f1_m: 0.5480 - val_loss: 1.9167 - val_precision_m: 0.5550 - val_recall_m: 0.5414 - learning_rate: 5.0000e-04
# Epoch 11/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9477 - f1_m: 0.9477 - loss: 0.1421 - precision_m: 0.9499 - recall_m: 0.9456
# Epoch 11: val_loss did not improve from 0.35738
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 42s 44ms/step - accuracy: 0.9477 - f1_m: 0.9477 - loss: 0.1421 - precision_m: 0.9499 - recall_m: 0.9456 - val_accuracy: 0.6663 - val_f1_m: 0.6638 - val_loss: 1.1416 - val_precision_m: 0.6679 - val_recall_m: 0.6599 - learning_rate: 5.0000e-04
# Epoch 12/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9552 - f1_m: 0.9552 - loss: 0.1250 - precision_m: 0.9568 - recall_m: 0.9536
# Epoch 12: val_loss did not improve from 0.35738
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 44ms/step - accuracy: 0.9552 - f1_m: 0.9552 - loss: 0.1250 - precision_m: 0.9568 - recall_m: 0.9536 - val_accuracy: 0.5528 - val_f1_m: 0.5505 - val_loss: 1.9328 - val_precision_m: 0.5540 - val_recall_m: 0.5471 - learning_rate: 5.0000e-04
# Epoch 13/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9636 - f1_m: 0.9636 - loss: 0.0963 - precision_m: 0.9652 - recall_m: 0.9621
# Epoch 13: val_loss did not improve from 0.35738
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 42s 44ms/step - accuracy: 0.9636 - f1_m: 0.9636 - loss: 0.0962 - precision_m: 0.9652 - recall_m: 0.9621 - val_accuracy: 0.8456 - val_f1_m: 0.8451 - val_loss: 0.4589 - val_precision_m: 0.8483 - val_recall_m: 0.8421 - learning_rate: 2.5000e-04
# Epoch 14/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9690 - f1_m: 0.9689 - loss: 0.0864 - precision_m: 0.9697 - recall_m: 0.9681
# Epoch 14: val_loss improved from 0.35738 to 0.14956, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 42s 45ms/step - accuracy: 0.9690 - f1_m: 0.9689 - loss: 0.0864 - precision_m: 0.9697 - recall_m: 0.9681 - val_accuracy: 0.9432 - val_f1_m: 0.9429 - val_loss: 0.1496 - val_precision_m: 0.9440 - val_recall_m: 0.9418 - learning_rate: 2.5000e-04
# Epoch 15/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9681 - f1_m: 0.9685 - loss: 0.0842 - precision_m: 0.9698 - recall_m: 0.9672
# Epoch 15: val_loss did not improve from 0.14956
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 44ms/step - accuracy: 0.9681 - f1_m: 0.9685 - loss: 0.0842 - precision_m: 0.9698 - recall_m: 0.9672 - val_accuracy: 0.6554 - val_f1_m: 0.6546 - val_loss: 1.4600 - val_precision_m: 0.6564 - val_recall_m: 0.6529 - learning_rate: 2.5000e-04
# Epoch 16/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9710 - f1_m: 0.9709 - loss: 0.0778 - precision_m: 0.9715 - recall_m: 0.9704
# Epoch 16: val_loss did not improve from 0.14956
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 42s 45ms/step - accuracy: 0.9710 - f1_m: 0.9709 - loss: 0.0778 - precision_m: 0.9715 - recall_m: 0.9704 - val_accuracy: 0.9140 - val_f1_m: 0.9136 - val_loss: 0.2464 - val_precision_m: 0.9157 - val_recall_m: 0.9117 - learning_rate: 2.5000e-04
# Epoch 17/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9732 - f1_m: 0.9732 - loss: 0.0736 - precision_m: 0.9740 - recall_m: 0.9725
# Epoch 17: val_loss did not improve from 0.14956
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 42s 45ms/step - accuracy: 0.9732 - f1_m: 0.9732 - loss: 0.0736 - precision_m: 0.9740 - recall_m: 0.9725 - val_accuracy: 0.7282 - val_f1_m: 0.7266 - val_loss: 1.1318 - val_precision_m: 0.7306 - val_recall_m: 0.7227 - learning_rate: 2.5000e-04
# Epoch 18/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9791 - f1_m: 0.9792 - loss: 0.0597 - precision_m: 0.9797 - recall_m: 0.9787
# Epoch 18: val_loss did not improve from 0.14956
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 43s 46ms/step - accuracy: 0.9791 - f1_m: 0.9792 - loss: 0.0597 - precision_m: 0.9797 - recall_m: 0.9787 - val_accuracy: 0.9323 - val_f1_m: 0.9326 - val_loss: 0.1807 - val_precision_m: 0.9339 - val_recall_m: 0.9314 - learning_rate: 1.2500e-04
# Epoch 19/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9813 - f1_m: 0.9814 - loss: 0.0560 - precision_m: 0.9819 - recall_m: 0.9809
# Epoch 19: val_loss did not improve from 0.14956
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 42s 45ms/step - accuracy: 0.9813 - f1_m: 0.9814 - loss: 0.0560 - precision_m: 0.9819 - recall_m: 0.9809 - val_accuracy: 0.9434 - val_f1_m: 0.9439 - val_loss: 0.1711 - val_precision_m: 0.9455 - val_recall_m: 0.9424 - learning_rate: 1.2500e-04
# Epoch 20/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9809 - f1_m: 0.9811 - loss: 0.0549 - precision_m: 0.9815 - recall_m: 0.9808
# Epoch 20: val_loss improved from 0.14956 to 0.02452, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 42s 45ms/step - accuracy: 0.9809 - f1_m: 0.9811 - loss: 0.0549 - precision_m: 0.9815 - recall_m: 0.9808 - val_accuracy: 0.9912 - val_f1_m: 0.9912 - val_loss: 0.0245 - val_precision_m: 0.9914 - val_recall_m: 0.9911 - learning_rate: 1.2500e-04
# Epoch 21/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9841 - f1_m: 0.9841 - loss: 0.0485 - precision_m: 0.9843 - recall_m: 0.9839
# Epoch 21: val_loss did not improve from 0.02452
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 42s 45ms/step - accuracy: 0.9841 - f1_m: 0.9841 - loss: 0.0485 - precision_m: 0.9843 - recall_m: 0.9839 - val_accuracy: 0.9416 - val_f1_m: 0.9415 - val_loss: 0.1821 - val_precision_m: 0.9423 - val_recall_m: 0.9408 - learning_rate: 1.2500e-04
# Epoch 22/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9807 - f1_m: 0.9806 - loss: 0.0511 - precision_m: 0.9809 - recall_m: 0.9802
# Epoch 22: val_loss did not improve from 0.02452
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 42s 45ms/step - accuracy: 0.9807 - f1_m: 0.9806 - loss: 0.0511 - precision_m: 0.9809 - recall_m: 0.9802 - val_accuracy: 0.8223 - val_f1_m: 0.8221 - val_loss: 0.6364 - val_precision_m: 0.8261 - val_recall_m: 0.8184 - learning_rate: 1.2500e-04
# Epoch 23/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9843 - f1_m: 0.9842 - loss: 0.0469 - precision_m: 0.9844 - recall_m: 0.9839
# Epoch 23: val_loss did not improve from 0.02452
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 42s 44ms/step - accuracy: 0.9843 - f1_m: 0.9842 - loss: 0.0469 - precision_m: 0.9844 - recall_m: 0.9839 - val_accuracy: 0.9757 - val_f1_m: 0.9757 - val_loss: 0.0623 - val_precision_m: 0.9759 - val_recall_m: 0.9755 - learning_rate: 1.2500e-04
# Epoch 24/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9856 - f1_m: 0.9855 - loss: 0.0388 - precision_m: 0.9857 - recall_m: 0.9854
# Epoch 24: val_loss improved from 0.02452 to 0.02443, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 42s 44ms/step - accuracy: 0.9856 - f1_m: 0.9855 - loss: 0.0388 - precision_m: 0.9857 - recall_m: 0.9854 - val_accuracy: 0.9917 - val_f1_m: 0.9916 - val_loss: 0.0244 - val_precision_m: 0.9918 - val_recall_m: 0.9915 - learning_rate: 6.2500e-05
# Epoch 25/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9852 - f1_m: 0.9852 - loss: 0.0424 - precision_m: 0.9853 - recall_m: 0.9851
# Epoch 25: val_loss improved from 0.02443 to 0.02321, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 44ms/step - accuracy: 0.9852 - f1_m: 0.9852 - loss: 0.0424 - precision_m: 0.9853 - recall_m: 0.9851 - val_accuracy: 0.9923 - val_f1_m: 0.9924 - val_loss: 0.0232 - val_precision_m: 0.9925 - val_recall_m: 0.9924 - learning_rate: 6.2500e-05
# Epoch 26/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9885 - f1_m: 0.9886 - loss: 0.0350 - precision_m: 0.9888 - recall_m: 0.9883
# Epoch 26: val_loss improved from 0.02321 to 0.02132, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 44ms/step - accuracy: 0.9885 - f1_m: 0.9886 - loss: 0.0350 - precision_m: 0.9888 - recall_m: 0.9883 - val_accuracy: 0.9922 - val_f1_m: 0.9923 - val_loss: 0.0213 - val_precision_m: 0.9924 - val_recall_m: 0.9922 - learning_rate: 6.2500e-05
# Epoch 27/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9867 - f1_m: 0.9868 - loss: 0.0375 - precision_m: 0.9870 - recall_m: 0.9866
# Epoch 27: val_loss improved from 0.02132 to 0.02062, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 44ms/step - accuracy: 0.9867 - f1_m: 0.9868 - loss: 0.0375 - precision_m: 0.9870 - recall_m: 0.9866 - val_accuracy: 0.9933 - val_f1_m: 0.9934 - val_loss: 0.0206 - val_precision_m: 0.9934 - val_recall_m: 0.9934 - learning_rate: 6.2500e-05
# Epoch 28/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9884 - f1_m: 0.9881 - loss: 0.0354 - precision_m: 0.9884 - recall_m: 0.9879
# Epoch 28: val_loss did not improve from 0.02062
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 42s 45ms/step - accuracy: 0.9884 - f1_m: 0.9881 - loss: 0.0354 - precision_m: 0.9884 - recall_m: 0.9879 - val_accuracy: 0.9910 - val_f1_m: 0.9906 - val_loss: 0.0275 - val_precision_m: 0.9908 - val_recall_m: 0.9905 - learning_rate: 6.2500e-05
# Epoch 29/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9867 - f1_m: 0.9868 - loss: 0.0378 - precision_m: 0.9870 - recall_m: 0.9866
# Epoch 29: val_loss did not improve from 0.02062
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 42s 45ms/step - accuracy: 0.9867 - f1_m: 0.9868 - loss: 0.0378 - precision_m: 0.9870 - recall_m: 0.9866 - val_accuracy: 0.9790 - val_f1_m: 0.9792 - val_loss: 0.0587 - val_precision_m: 0.9795 - val_recall_m: 0.9788 - learning_rate: 6.2500e-05
# Epoch 30/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9888 - f1_m: 0.9888 - loss: 0.0322 - precision_m: 0.9889 - recall_m: 0.9886
# Epoch 30: val_loss did not improve from 0.02062
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 44ms/step - accuracy: 0.9888 - f1_m: 0.9888 - loss: 0.0322 - precision_m: 0.9889 - recall_m: 0.9886 - val_accuracy: 0.9644 - val_f1_m: 0.9642 - val_loss: 0.0983 - val_precision_m: 0.9645 - val_recall_m: 0.9639 - learning_rate: 6.2500e-05
# Epoch 31/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9899 - f1_m: 0.9902 - loss: 0.0299 - precision_m: 0.9905 - recall_m: 0.9898
# Epoch 31: val_loss improved from 0.02062 to 0.01387, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 42s 45ms/step - accuracy: 0.9899 - f1_m: 0.9901 - loss: 0.0299 - precision_m: 0.9905 - recall_m: 0.9898 - val_accuracy: 0.9958 - val_f1_m: 0.9958 - val_loss: 0.0139 - val_precision_m: 0.9959 - val_recall_m: 0.9957 - learning_rate: 3.1250e-05
# Epoch 32/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9884 - f1_m: 0.9884 - loss: 0.0324 - precision_m: 0.9885 - recall_m: 0.9883
# Epoch 32: val_loss did not improve from 0.01387
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 44ms/step - accuracy: 0.9884 - f1_m: 0.9884 - loss: 0.0324 - precision_m: 0.9885 - recall_m: 0.9883 - val_accuracy: 0.9938 - val_f1_m: 0.9938 - val_loss: 0.0167 - val_precision_m: 0.9938 - val_recall_m: 0.9938 - learning_rate: 3.1250e-05
# Epoch 33/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9881 - f1_m: 0.9881 - loss: 0.0325 - precision_m: 0.9882 - recall_m: 0.9880
# Epoch 33: val_loss did not improve from 0.01387
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 43ms/step - accuracy: 0.9881 - f1_m: 0.9881 - loss: 0.0325 - precision_m: 0.9882 - recall_m: 0.9880 - val_accuracy: 0.9948 - val_f1_m: 0.9948 - val_loss: 0.0157 - val_precision_m: 0.9948 - val_recall_m: 0.9948 - learning_rate: 3.1250e-05
# Epoch 34/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9890 - f1_m: 0.9890 - loss: 0.0294 - precision_m: 0.9893 - recall_m: 0.9888
# Epoch 34: val_loss did not improve from 0.01387
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 43ms/step - accuracy: 0.9890 - f1_m: 0.9890 - loss: 0.0294 - precision_m: 0.9893 - recall_m: 0.9888 - val_accuracy: 0.9929 - val_f1_m: 0.9930 - val_loss: 0.0199 - val_precision_m: 0.9931 - val_recall_m: 0.9928 - learning_rate: 3.1250e-05
# Epoch 35/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9900 - f1_m: 0.9901 - loss: 0.0261 - precision_m: 0.9902 - recall_m: 0.9900
# Epoch 35: val_loss improved from 0.01387 to 0.01357, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 43ms/step - accuracy: 0.9900 - f1_m: 0.9901 - loss: 0.0261 - precision_m: 0.9902 - recall_m: 0.9900 - val_accuracy: 0.9953 - val_f1_m: 0.9953 - val_loss: 0.0136 - val_precision_m: 0.9953 - val_recall_m: 0.9953 - learning_rate: 1.5625e-05
# Epoch 36/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9914 - f1_m: 0.9913 - loss: 0.0239 - precision_m: 0.9914 - recall_m: 0.9912
# Epoch 36: val_loss improved from 0.01357 to 0.01196, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 43ms/step - accuracy: 0.9914 - f1_m: 0.9913 - loss: 0.0239 - precision_m: 0.9914 - recall_m: 0.9912 - val_accuracy: 0.9959 - val_f1_m: 0.9959 - val_loss: 0.0120 - val_precision_m: 0.9959 - val_recall_m: 0.9959 - learning_rate: 1.5625e-05
# Epoch 37/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9891 - f1_m: 0.9892 - loss: 0.0295 - precision_m: 0.9893 - recall_m: 0.9890
# Epoch 37: val_loss did not improve from 0.01196
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 43ms/step - accuracy: 0.9891 - f1_m: 0.9892 - loss: 0.0295 - precision_m: 0.9893 - recall_m: 0.9890 - val_accuracy: 0.9922 - val_f1_m: 0.9922 - val_loss: 0.0216 - val_precision_m: 0.9924 - val_recall_m: 0.9921 - learning_rate: 1.5625e-05
# Epoch 38/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9916 - f1_m: 0.9916 - loss: 0.0257 - precision_m: 0.9917 - recall_m: 0.9915
# Epoch 38: val_loss did not improve from 0.01196
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 43ms/step - accuracy: 0.9916 - f1_m: 0.9916 - loss: 0.0257 - precision_m: 0.9917 - recall_m: 0.9915 - val_accuracy: 0.9950 - val_f1_m: 0.9951 - val_loss: 0.0157 - val_precision_m: 0.9951 - val_recall_m: 0.9950 - learning_rate: 1.5625e-05
# Epoch 39/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9902 - f1_m: 0.9903 - loss: 0.0270 - precision_m: 0.9906 - recall_m: 0.9901
# Epoch 39: val_loss improved from 0.01196 to 0.01115, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 44ms/step - accuracy: 0.9902 - f1_m: 0.9903 - loss: 0.0270 - precision_m: 0.9906 - recall_m: 0.9901 - val_accuracy: 0.9962 - val_f1_m: 0.9963 - val_loss: 0.0112 - val_precision_m: 0.9963 - val_recall_m: 0.9962 - learning_rate: 1.5625e-05
# Epoch 40/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9901 - f1_m: 0.9901 - loss: 0.0273 - precision_m: 0.9902 - recall_m: 0.9900
# Epoch 40: val_loss did not improve from 0.01115
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 43ms/step - accuracy: 0.9901 - f1_m: 0.9901 - loss: 0.0273 - precision_m: 0.9902 - recall_m: 0.9900 - val_accuracy: 0.9957 - val_f1_m: 0.9957 - val_loss: 0.0136 - val_precision_m: 0.9957 - val_recall_m: 0.9957 - learning_rate: 1.5625e-05
# Epoch 41/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9909 - f1_m: 0.9909 - loss: 0.0257 - precision_m: 0.9910 - recall_m: 0.9908
# Epoch 41: val_loss improved from 0.01115 to 0.01063, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 43ms/step - accuracy: 0.9909 - f1_m: 0.9909 - loss: 0.0257 - precision_m: 0.9910 - recall_m: 0.9908 - val_accuracy: 0.9960 - val_f1_m: 0.9961 - val_loss: 0.0106 - val_precision_m: 0.9962 - val_recall_m: 0.9959 - learning_rate: 1.5625e-05
# Epoch 42/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9912 - f1_m: 0.9912 - loss: 0.0256 - precision_m: 0.9913 - recall_m: 0.9911
# Epoch 42: val_loss did not improve from 0.01063
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 43ms/step - accuracy: 0.9912 - f1_m: 0.9912 - loss: 0.0256 - precision_m: 0.9913 - recall_m: 0.9911 - val_accuracy: 0.9946 - val_f1_m: 0.9946 - val_loss: 0.0173 - val_precision_m: 0.9946 - val_recall_m: 0.9946 - learning_rate: 1.5625e-05
# Epoch 43/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9911 - f1_m: 0.9912 - loss: 0.0263 - precision_m: 0.9913 - recall_m: 0.9910
# Epoch 43: val_loss did not improve from 0.01063
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 43ms/step - accuracy: 0.9911 - f1_m: 0.9912 - loss: 0.0263 - precision_m: 0.9913 - recall_m: 0.9910 - val_accuracy: 0.9948 - val_f1_m: 0.9948 - val_loss: 0.0173 - val_precision_m: 0.9948 - val_recall_m: 0.9948 - learning_rate: 1.5625e-05
# Epoch 44/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9904 - f1_m: 0.9905 - loss: 0.0274 - precision_m: 0.9906 - recall_m: 0.9904
# Epoch 44: val_loss did not improve from 0.01063
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 43ms/step - accuracy: 0.9904 - f1_m: 0.9905 - loss: 0.0274 - precision_m: 0.9906 - recall_m: 0.9904 - val_accuracy: 0.9948 - val_f1_m: 0.9948 - val_loss: 0.0150 - val_precision_m: 0.9948 - val_recall_m: 0.9948 - learning_rate: 1.5625e-05
# Epoch 45/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9911 - f1_m: 0.9912 - loss: 0.0269 - precision_m: 0.9913 - recall_m: 0.9910
# Epoch 45: val_loss improved from 0.01063 to 0.00937, saving model to best_model.keras
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 43ms/step - accuracy: 0.9911 - f1_m: 0.9912 - loss: 0.0269 - precision_m: 0.9913 - recall_m: 0.9910 - val_accuracy: 0.9966 - val_f1_m: 0.9967 - val_loss: 0.0094 - val_precision_m: 0.9968 - val_recall_m: 0.9966 - learning_rate: 7.8125e-06
# Epoch 46/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9919 - f1_m: 0.9920 - loss: 0.0239 - precision_m: 0.9922 - recall_m: 0.9918
# Epoch 46: val_loss did not improve from 0.00937
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 43ms/step - accuracy: 0.9919 - f1_m: 0.9920 - loss: 0.0239 - precision_m: 0.9922 - recall_m: 0.9918 - val_accuracy: 0.9966 - val_f1_m: 0.9967 - val_loss: 0.0100 - val_precision_m: 0.9968 - val_recall_m: 0.9966 - learning_rate: 7.8125e-06
# Epoch 47/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9911 - f1_m: 0.9913 - loss: 0.0252 - precision_m: 0.9914 - recall_m: 0.9911
# Epoch 47: val_loss did not improve from 0.00937
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 43ms/step - accuracy: 0.9911 - f1_m: 0.9913 - loss: 0.0252 - precision_m: 0.9914 - recall_m: 0.9911 - val_accuracy: 0.9966 - val_f1_m: 0.9966 - val_loss: 0.0098 - val_precision_m: 0.9966 - val_recall_m: 0.9966 - learning_rate: 7.8125e-06
# Epoch 48/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9914 - f1_m: 0.9915 - loss: 0.0239 - precision_m: 0.9917 - recall_m: 0.9913
# Epoch 48: val_loss did not improve from 0.00937
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 43ms/step - accuracy: 0.9914 - f1_m: 0.9915 - loss: 0.0239 - precision_m: 0.9917 - recall_m: 0.9913 - val_accuracy: 0.9963 - val_f1_m: 0.9963 - val_loss: 0.0113 - val_precision_m: 0.9963 - val_recall_m: 0.9963 - learning_rate: 7.8125e-06
# Epoch 49/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9918 - f1_m: 0.9918 - loss: 0.0225 - precision_m: 0.9919 - recall_m: 0.9917
# Epoch 49: val_loss did not improve from 0.00937
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 43ms/step - accuracy: 0.9918 - f1_m: 0.9918 - loss: 0.0225 - precision_m: 0.9919 - recall_m: 0.9917 - val_accuracy: 0.9967 - val_f1_m: 0.9968 - val_loss: 0.0097 - val_precision_m: 0.9969 - val_recall_m: 0.9967 - learning_rate: 3.9063e-06
# Epoch 50/50
# 937/938 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9896 - f1_m: 0.9895 - loss: 0.0295 - precision_m: 0.9896 - recall_m: 0.9895
# Epoch 50: val_loss did not improve from 0.00937
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 43ms/step - accuracy: 0.9896 - f1_m: 0.9895 - loss: 0.0295 - precision_m: 0.9896 - recall_m: 0.9895 - val_accuracy: 0.9966 - val_f1_m: 0.9966 - val_loss: 0.0105 - val_precision_m: 0.9966 - val_recall_m: 0.9966 - learning_rate: 3.9063e-06

# %%
loss, accuracy, f1_score, precision, recall = model.evaluate(x_test_lstm, y_test, verbose=0)
print(f"Validation Loss: {loss}")
print(f"Accuracy: {accuracy}")
print(f"F1 Score: {f1_score}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
# Out:
# Validation Loss: 0.010487928055226803
# Accuracy: 0.9965555667877197
# F1 Score: 0.9965647459030151
# Precision: 0.9965647459030151
# Recall: 0.9965647459030151

# %% [markdown]
# **Visualizations**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, roc_curve, auc, accuracy_score
import numpy as np
from itertools import cycle

def plot_accuracy_loss(history):
    fig, axs = plt.subplots(1, 2, figsize=(12, 4))

    axs[0].plot(history.history['accuracy'], label='Train Accuracy')
    axs[0].plot(history.history['val_accuracy'], label='Validation Accuracy')
    axs[0].set_title('Model Accuracy')
    axs[0].set_xlabel('Epochs')
    axs[0].set_ylabel('Accuracy')
    axs[0].legend()

    axs[1].plot(history.history['loss'], label='Train Loss')
    axs[1].plot(history.history['val_loss'], label='Validation Loss')
    axs[1].set_title('Model Loss')
    axs[1].set_xlabel('Epochs')
    axs[1].set_ylabel('Loss')
    axs[1].legend()
    plt.show()
    
plot_accuracy_loss(history)

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
import numpy as np

def plot_confusion_matrix(model, x_test, y_test):
    y_pred = np.argmax(model.predict(x_test), axis=1)
    y_true = np.argmax(y_test, axis=1)

    cm = confusion_matrix(y_true, y_pred)
    class_names = [f'Class {i}' for i in range(y_test.shape[1])]
    
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names,
                yticklabels=class_names)
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.show()

plot_confusion_matrix(model, x_test_lstm, y_test)
# Out:
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step

# %%
from sklearn.metrics import roc_curve, auc, roc_auc_score
from itertools import cycle
import matplotlib.pyplot as plt

def plot_roc_curve(model, x_test, y_test):
    y_pred = model.predict(x_test)
    n_classes = y_test.shape[1]

    fpr, tpr, roc_auc = {}, {}, {}
    plt.figure(figsize=(8, 6))
    colors = cycle(['blue', 'red', 'green', 'purple', 'orange'])

    for i, color in zip(range(n_classes), colors):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
        plt.plot(fpr[i], tpr[i], color=color, lw=2,
                 label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

    fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_pred.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
    plt.plot(fpr["micro"], tpr["micro"],
             label=f'Micro-average ROC (AUC = {roc_auc["micro"]:.2f})',
             color='black', linestyle='--', linewidth=2)

    plt.plot([0, 1], [0, 1], 'k--', lw=1)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Multi-class ROC Curve')
    plt.legend(loc="lower right")
    plt.tight_layout()
    plt.show()
    
plot_roc_curve(model, x_test_lstm, y_test)
# Out:
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

def permutation_importance_gaf(model, X, y_true, base_score_fn=accuracy_score):
    """
    Computes permutation importance for GAF input of shape (N, 34, 34).
    Permutes both row and column i for each of the 34 original features.
    """
    base_preds = np.argmax(model.predict(X), axis=1)
    if len(y_true.shape) > 1:
        y_true = np.argmax(y_true, axis=1)

    base_score = base_score_fn(y_true, base_preds)
    feature_importance = []

    for i in range(34):  
        X_permuted = np.copy(X)

        for j in range(X.shape[0]):  
            perm = np.random.permutation(X.shape[1])
            X_permuted[j, i, :] = X_permuted[j, i, perm]  
            X_permuted[j, :, i] = X_permuted[j, perm, i]  

        preds = np.argmax(model.predict(X_permuted), axis=1)
        score = base_score_fn(y_true, preds)
        importance = base_score - score
        feature_importance.append(importance)

    return feature_importance       
feature_names = [
    "MEAN_RR", "MEDIAN_RR", "SDRR", "RMSSD", "SDSD", "SDRR_RMSSD", "HR", 
    "pNN25", "pNN50", "SD1", "SD2", "SD2_SD1", "KURT", "SKEW", "IQR", 
    "HF_PEAK", "HF_MEAN", "HF_MED", "HF_VAR", "LF", "LF_PEAK", "LF_MEAN", 
    "LF_MED", "LF_VAR", "LF_PCT", "LF_NU", "HF", "HF_PCT", "HF_NU", "TP", 
    "LF_HF", "HF_LF", "sampen", "higuci"
]
importance_per_feature = permutation_importance_gaf(model, x_test_lstm, y_test)
importance_per_feature = np.array(importance_per_feature)
importance_per_feature /= importance_per_feature.max()
plt.figure(figsize=(16, 6))
plt.bar(range(34), importance_per_feature, color='skyblue')
plt.xticks(range(34), feature_names, rotation=90)
plt.ylabel("Feature Importance")
plt.title("Permutation Feature Importance per Original Feature")
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step
