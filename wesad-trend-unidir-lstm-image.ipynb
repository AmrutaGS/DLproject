# %%
# !pip install pyts
# Out:
# Collecting pyts
#   Downloading pyts-0.13.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.26.4)
# Requirement already satisfied: scipy>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.15.2)
# Requirement already satisfied: scikit-learn>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.4.2)
# Requirement already satisfied: numba>=0.55.2 in /usr/local/lib/python3.11/dist-packages (from pyts) (0.60.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.55.2->pyts) (0.43.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (2.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.2.0->pyts) (3.6.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.22.4->pyts) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.22.4->pyts) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.22.4->pyts) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.22.4->pyts) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.22.4->pyts) (2024.2.0)
# Downloading pyts-0.13.0-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 25.5 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pyts
# Successfully installed pyts-0.13.0

# %%
import os
import pickle
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from mpl_toolkits.axes_grid1 import ImageGrid
from pyts.image import GramianAngularField
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Conv2D, BatchNormalization, MaxPool2D, Flatten, Dense
from keras import backend as K
class ReadData:
    def __init__(self, path, subject):
        self.keys = ['label', 'subject', 'signal']
        self.signal_keys = ['wrist', 'chest']
        self.chest_sensor_keys = ['ACC', 'ECG', 'EDA', 'EMG', 'Resp', 'Temp']
        
        os.chdir(path)
        os.chdir(subject)
        with open(subject + '.pkl', 'rb') as file:
            data = pickle.load(file, encoding='latin1')
        self.data = data
        
    def get_labels(self):
        return self.data[self.keys[0]]
    def get_chest_data(self):
        return self.data[self.keys[2]][self.signal_keys[1]]

# %%
data_path = '/kaggle/input/tiles-05-05/WESAD'
subject = 'S17'
data_target = {subject: ReadData(data_path, subject)}
chest_data_dict = data_target[subject].get_chest_data()

acc_x = chest_data_dict['ACC'][:, 0]
acc_y = chest_data_dict['ACC'][:, 1]
acc_z = chest_data_dict['ACC'][:, 2]
emg_x = chest_data_dict['EMG'][:, 0]
eda_x = chest_data_dict['EDA'][:, 0]
ecg_x = chest_data_dict['ECG'][:, 0]
temp_x = chest_data_dict['Temp'][:, 0]
resp_x = chest_data_dict['Resp'][:, 0]
w_labels = data_target[subject].data['label']

# %%
def quantile_normalize(df):
    df_sorted = pd.DataFrame(np.sort(df.values, axis=0), index=df.index, columns=df.columns)
    df_mean = df_sorted.mean(axis=1)
    df_mean.index = np.arange(1, len(df_mean) + 1)
    df_qn = df.rank(method='min').stack().astype(int).map(df_mean).unstack()
    return df_qn
    
df_chest = pd.DataFrame({
    'ACC_X': acc_x,
    'ACC_Y': acc_y,
    'ACC_Z': acc_z,
    'EMG': emg_x,
    'EDA': eda_x,
    'ECG': ecg_x,
    'Temp': temp_x,
    'Resp': resp_x
})
df_chest['w_labels'] = w_labels  
if 'w_labels' in df_chest.columns:
    baseline_0 = df_chest[df_chest['w_labels'] == 0]  
    baseline = df_chest[df_chest['w_labels'] == 1]    
    stress = df_chest[df_chest['w_labels'] == 2]      
    amusement = df_chest[df_chest['w_labels'] == 3]   
else:
    raise KeyError("'w_labels' column not found in df_chest")

df_0 = baseline_0.tail(10000)
df_1 = baseline.tail(10000)
df_2 = stress.tail(10000)
df_3 = amusement.tail(10000)

df_chest = pd.concat([df_3, df_1, df_2, df_0], ignore_index=True)
print("before",df_chest.shape)
print("Before Normalization:")
print(df_chest.describe())

labels_wesad = df_chest.pop('w_labels').to_numpy()
df_chest = quantile_normalize(df_chest)
print("after",df_chest.shape)
print("After Normalization:")
print(df_chest.describe())
# Out:
# before (40000, 9)
# Before Normalization:
#               ACC_X         ACC_Y         ACC_Z           EMG           EDA  \
# count  40000.000000  40000.000000  40000.000000  40000.000000  40000.000000
# mean       0.693697     -0.003684     -0.516699     -0.004170      6.546550
# std        0.214727      0.052481      0.293308      0.016550      0.778822
# min        0.354600     -0.148600     -0.914400     -0.183975      5.482864
# 25%        0.523450     -0.047800     -0.810000     -0.012497      5.839729
# 50%        0.682000      0.006200     -0.519100     -0.003937      6.629562
# 75%        0.893000      0.043850     -0.210350      0.004257      7.321930
# max        1.257400      0.153400      0.082600      0.152618      7.411575
#
#                 ECG          Temp          Resp      w_labels
# count  40000.000000  40000.000000  40000.000000  40000.000000
# mean       0.000935     33.891136      0.004522      1.500000
# std        0.304003      0.409040      5.204628      1.118048
# min       -0.549454     33.435608    -17.668152      0.000000
# 25%       -0.116867     33.574677     -2.363586      0.750000
# 50%       -0.045273     33.764084     -0.367737      1.500000
# 75%        0.024582     34.114494      3.382874      2.250000
# max        1.499222     34.695465     12.091064      3.000000
# after (40000, 8)
# After Normalization:
#               ACC_X         ACC_Y         ACC_Z           EMG           EDA  \
# count  40000.000000  40000.000000  40000.000000  40000.000000  40000.000000
# mean       5.069479      5.070116      5.071703      5.074770      5.067471
# std        0.872955      0.868172      0.873510      0.867254      0.873757
# min        2.476061      2.476061      2.476061      2.476061      2.476061
# 25%        4.573369      4.521347      4.573388      4.516100      4.573388
# 50%        5.018225      4.916174      5.018225      4.919940      5.018225
# 75%        5.677986      5.694778      5.695512      5.678207      5.681315
# max        7.167918      7.167918      7.167918      7.167918      7.167918
#
#                 ECG          Temp          Resp
# count  40000.000000  40000.000000  40000.000000
# mean       5.076337      5.064553      5.076474
# std        0.867256      0.866327      0.867271
# min        2.476061      2.476061      2.476061
# 25%        4.525111      4.523536      4.522551
# 50%        4.922862      5.018090      4.924158
# 75%        5.679911      5.696830      5.680890
# max        7.141439      7.167918      7.167918

# %%
import tensorflow as tf
from tensorflow.keras import backend as K

def f1_m(y_true, y_pred):
    y_true = K.cast(y_true, dtype='float32')  
    y_pred = K.cast(y_pred, dtype='float32')  
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

def precision_m(y_true, y_pred):
    y_true = K.cast(y_true, dtype='float32')  
    y_pred = K.cast(y_pred, dtype='float32')  
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    return true_positives / (predicted_positives + K.epsilon())

def recall_m(y_true, y_pred):
    y_true = K.cast(y_true, dtype='float32')  
    y_pred = K.cast(y_pred, dtype='float32')  
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from pyts.image import GramianAngularField

gasf = GramianAngularField(method='summation')

X_train = df_chest.to_numpy()
X_train = gasf.fit_transform(X_train)

Y_train = labels_wesad.reshape(len(labels_wesad), 1)
X_train = X_train.reshape(X_train.shape[0], 8, 8, 1).astype('float32')
X_train /= np.amax(X_train)

Y_train = tf.keras.utils.to_categorical(Y_train, num_classes=4)

x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size=0.4, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, test_size=0.5, random_state=42)

print(f"x_train shape: {x_train.shape}, y_train shape: {y_train.shape}")
print(f"x_val shape: {x_val.shape}, y_val shape: {y_val.shape}")
print(f"x_test shape: {x_test.shape}, y_test shape: {y_test.shape}")

plt.imshow(x_train[0, :, :, 0], cmap='gray') 
plt.title(f"Class: {np.argmax(y_train[0])}")
plt.show()
# Out:
# x_train shape: (24000, 8, 8, 1), y_train shape: (24000, 4)
# x_val shape: (8000, 8, 8, 1), y_val shape: (8000, 4)
# x_test shape: (8000, 8, 8, 1), y_test shape: (8000, 4)

# %%
import tensorflow as tf
from tensorflow.keras import backend as K

# Mean Absolute Error (MAE)
def mae_m(y_true, y_pred):
    y_true = K.cast(y_true, dtype='float32')  
    y_pred = K.cast(y_pred, dtype='float32')  
    return K.mean(K.abs(y_true - y_pred))

def mape_m(y_true, y_pred):
    y_true = K.cast(y_true, dtype='float32')
    y_pred = K.cast(y_pred, dtype='float32')
    diff = K.abs(y_true - y_pred)
    denom = K.maximum(K.abs(y_true), 1.0)  # Use 1.0 instead of tiny epsilon
    return 100.0 * K.mean(diff / denom)

# Root Mean Squared Error (RMSE)
def rmse_m(y_true, y_pred):
    y_true = K.cast(y_true, dtype='float32')
    y_pred = K.cast(y_pred, dtype='float32')
    return K.sqrt(K.mean(K.square(y_true - y_pred)))

# %%
x_train_lstm = x_train.reshape(-1, 8, 8)
x_val_lstm = x_val.reshape(-1, 8, 8)
x_test_lstm = x_test.reshape(-1, 8, 8)

# %%
from tensorflow.keras import layers, regularizers, callbacks
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, BatchNormalization, Dense
from tensorflow.keras.optimizers import Adam

def model_LSTM():
    model = Sequential()
    model.add(LSTM(64, return_sequences=True, input_shape=(8,8), activation='tanh'))
    model.add(BatchNormalization())
    model.add(LSTM(64, return_sequences=True, activation='tanh'))
    model.add(BatchNormalization())
    model.add(LSTM(64, activation='tanh'))
    model.add(BatchNormalization())
    model.add(Dense(6)) 
    model.add(Dense(4, activation='softmax'))  
    model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy', f1_m, precision_m, recall_m,mae_m, mape_m, rmse_m])
    return model
    
model=model_LSTM()

loss = tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1)

optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)

model.compile(
    optimizer=optimizer,
    loss=loss,
    metrics=['accuracy', f1_m, precision_m, recall_m,mae_m, mape_m, rmse_m]
)

# %%
model_checkpoint = callbacks.ModelCheckpoint("/kaggle/working/best_model.keras", save_best_only=True, monitor='val_loss', verbose=1)
history = model.fit(x_train_lstm, y_train, batch_size=32, epochs=100, validation_data=(x_val_lstm, y_val),callbacks=[model_checkpoint])
# Out:
# Epoch 1/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7583 - f1_m: 0.7313 - loss: 0.8123 - mae_m: 0.1870 - mape_m: 18.6990 - precision_m: 0.8035 - recall_m: 0.6769 - rmse_m: 0.2857
# Epoch 1: val_loss improved from inf to 0.54292, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 22s 16ms/step - accuracy: 0.7586 - f1_m: 0.7316 - loss: 0.8118 - mae_m: 0.1868 - mape_m: 18.6840 - precision_m: 0.8037 - recall_m: 0.6774 - rmse_m: 0.2855 - val_accuracy: 0.8971 - val_f1_m: 0.8958 - val_loss: 0.5429 - val_mae_m: 0.1066 - val_mape_m: 10.6582 - val_precision_m: 0.9186 - val_recall_m: 0.8748 - val_rmse_m: 0.1941
# Epoch 2/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8818 - f1_m: 0.8802 - loss: 0.5670 - mae_m: 0.1143 - mape_m: 11.4336 - precision_m: 0.9027 - recall_m: 0.8594 - rmse_m: 0.2051
# Epoch 2: val_loss improved from 0.54292 to 0.51391, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.8818 - f1_m: 0.8802 - loss: 0.5670 - mae_m: 0.1143 - mape_m: 11.4331 - precision_m: 0.9027 - recall_m: 0.8594 - rmse_m: 0.2051 - val_accuracy: 0.9109 - val_f1_m: 0.9100 - val_loss: 0.5139 - val_mae_m: 0.0947 - val_mape_m: 9.4687 - val_precision_m: 0.9300 - val_recall_m: 0.8914 - val_rmse_m: 0.1802
# Epoch 3/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9078 - f1_m: 0.9069 - loss: 0.5279 - mae_m: 0.1011 - mape_m: 10.1149 - precision_m: 0.9251 - recall_m: 0.8898 - rmse_m: 0.1862
# Epoch 3: val_loss improved from 0.51391 to 0.51380, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9078 - f1_m: 0.9069 - loss: 0.5279 - mae_m: 0.1011 - mape_m: 10.1142 - precision_m: 0.9251 - recall_m: 0.8899 - rmse_m: 0.1862 - val_accuracy: 0.9171 - val_f1_m: 0.9160 - val_loss: 0.5138 - val_mae_m: 0.0892 - val_mape_m: 8.9245 - val_precision_m: 0.9306 - val_recall_m: 0.9024 - val_rmse_m: 0.1757
# Epoch 4/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9176 - f1_m: 0.9165 - loss: 0.5092 - mae_m: 0.0941 - mape_m: 9.4091 - precision_m: 0.9308 - recall_m: 0.9031 - rmse_m: 0.1754
# Epoch 4: val_loss improved from 0.51380 to 0.48030, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9176 - f1_m: 0.9165 - loss: 0.5092 - mae_m: 0.0941 - mape_m: 9.4087 - precision_m: 0.9308 - recall_m: 0.9031 - rmse_m: 0.1754 - val_accuracy: 0.9327 - val_f1_m: 0.9318 - val_loss: 0.4803 - val_mae_m: 0.0795 - val_mape_m: 7.9537 - val_precision_m: 0.9440 - val_recall_m: 0.9204 - val_rmse_m: 0.1580
# Epoch 5/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9280 - f1_m: 0.9275 - loss: 0.4918 - mae_m: 0.0880 - mape_m: 8.8034 - precision_m: 0.9395 - recall_m: 0.9162 - rmse_m: 0.1657
# Epoch 5: val_loss improved from 0.48030 to 0.46342, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9280 - f1_m: 0.9274 - loss: 0.4918 - mae_m: 0.0880 - mape_m: 8.8035 - precision_m: 0.9395 - recall_m: 0.9162 - rmse_m: 0.1657 - val_accuracy: 0.9392 - val_f1_m: 0.9375 - val_loss: 0.4634 - val_mae_m: 0.0780 - val_mape_m: 7.7995 - val_precision_m: 0.9489 - val_recall_m: 0.9268 - val_rmse_m: 0.1510
# Epoch 6/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9345 - f1_m: 0.9332 - loss: 0.4823 - mae_m: 0.0850 - mape_m: 8.4984 - precision_m: 0.9439 - recall_m: 0.9230 - rmse_m: 0.1596
# Epoch 6: val_loss did not improve from 0.46342
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9345 - f1_m: 0.9332 - loss: 0.4823 - mae_m: 0.0850 - mape_m: 8.4985 - precision_m: 0.9439 - recall_m: 0.9230 - rmse_m: 0.1596 - val_accuracy: 0.9340 - val_f1_m: 0.9343 - val_loss: 0.4718 - val_mae_m: 0.0785 - val_mape_m: 7.8458 - val_precision_m: 0.9428 - val_recall_m: 0.9261 - val_rmse_m: 0.1544
# Epoch 7/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9371 - f1_m: 0.9353 - loss: 0.4729 - mae_m: 0.0819 - mape_m: 8.1852 - precision_m: 0.9448 - recall_m: 0.9263 - rmse_m: 0.1548
# Epoch 7: val_loss did not improve from 0.46342
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9371 - f1_m: 0.9353 - loss: 0.4729 - mae_m: 0.0819 - mape_m: 8.1852 - precision_m: 0.9448 - recall_m: 0.9263 - rmse_m: 0.1548 - val_accuracy: 0.9390 - val_f1_m: 0.9383 - val_loss: 0.4662 - val_mae_m: 0.0759 - val_mape_m: 7.5910 - val_precision_m: 0.9463 - val_recall_m: 0.9306 - val_rmse_m: 0.1507
# Epoch 8/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9427 - f1_m: 0.9403 - loss: 0.4657 - mae_m: 0.0789 - mape_m: 7.8898 - precision_m: 0.9504 - recall_m: 0.9307 - rmse_m: 0.1495
# Epoch 8: val_loss improved from 0.46342 to 0.45695, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9427 - f1_m: 0.9403 - loss: 0.4657 - mae_m: 0.0789 - mape_m: 7.8900 - precision_m: 0.9504 - recall_m: 0.9307 - rmse_m: 0.1495 - val_accuracy: 0.9430 - val_f1_m: 0.9429 - val_loss: 0.4569 - val_mae_m: 0.0698 - val_mape_m: 6.9804 - val_precision_m: 0.9510 - val_recall_m: 0.9351 - val_rmse_m: 0.1434
# Epoch 9/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9459 - f1_m: 0.9455 - loss: 0.4588 - mae_m: 0.0764 - mape_m: 7.6380 - precision_m: 0.9544 - recall_m: 0.9371 - rmse_m: 0.1450
# Epoch 9: val_loss improved from 0.45695 to 0.45178, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 14s 18ms/step - accuracy: 0.9459 - f1_m: 0.9455 - loss: 0.4588 - mae_m: 0.0764 - mape_m: 7.6386 - precision_m: 0.9544 - recall_m: 0.9371 - rmse_m: 0.1450 - val_accuracy: 0.9457 - val_f1_m: 0.9472 - val_loss: 0.4518 - val_mae_m: 0.0707 - val_mape_m: 7.0663 - val_precision_m: 0.9538 - val_recall_m: 0.9409 - val_rmse_m: 0.1409
# Epoch 10/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9466 - f1_m: 0.9459 - loss: 0.4574 - mae_m: 0.0761 - mape_m: 7.6071 - precision_m: 0.9539 - recall_m: 0.9383 - rmse_m: 0.1438
# Epoch 10: val_loss did not improve from 0.45178
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 17s 23ms/step - accuracy: 0.9466 - f1_m: 0.9459 - loss: 0.4574 - mae_m: 0.0761 - mape_m: 7.6070 - precision_m: 0.9539 - recall_m: 0.9383 - rmse_m: 0.1438 - val_accuracy: 0.9459 - val_f1_m: 0.9455 - val_loss: 0.4529 - val_mae_m: 0.0702 - val_mape_m: 7.0233 - val_precision_m: 0.9533 - val_recall_m: 0.9380 - val_rmse_m: 0.1417
# Epoch 11/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9520 - f1_m: 0.9511 - loss: 0.4498 - mae_m: 0.0730 - mape_m: 7.3049 - precision_m: 0.9588 - recall_m: 0.9438 - rmse_m: 0.1383
# Epoch 11: val_loss did not improve from 0.45178
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9520 - f1_m: 0.9511 - loss: 0.4498 - mae_m: 0.0731 - mape_m: 7.3051 - precision_m: 0.9588 - recall_m: 0.9438 - rmse_m: 0.1383 - val_accuracy: 0.9421 - val_f1_m: 0.9411 - val_loss: 0.4580 - val_mae_m: 0.0748 - val_mape_m: 7.4821 - val_precision_m: 0.9486 - val_recall_m: 0.9339 - val_rmse_m: 0.1468
# Epoch 12/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9536 - f1_m: 0.9526 - loss: 0.4457 - mae_m: 0.0723 - mape_m: 7.2263 - precision_m: 0.9596 - recall_m: 0.9459 - rmse_m: 0.1359
# Epoch 12: val_loss did not improve from 0.45178
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9536 - f1_m: 0.9526 - loss: 0.4457 - mae_m: 0.0723 - mape_m: 7.2264 - precision_m: 0.9596 - recall_m: 0.9459 - rmse_m: 0.1359 - val_accuracy: 0.9486 - val_f1_m: 0.9479 - val_loss: 0.4541 - val_mae_m: 0.0693 - val_mape_m: 6.9313 - val_precision_m: 0.9540 - val_recall_m: 0.9420 - val_rmse_m: 0.1405
# Epoch 13/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9539 - f1_m: 0.9525 - loss: 0.4422 - mae_m: 0.0710 - mape_m: 7.0991 - precision_m: 0.9595 - recall_m: 0.9458 - rmse_m: 0.1344
# Epoch 13: val_loss did not improve from 0.45178
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9539 - f1_m: 0.9525 - loss: 0.4422 - mae_m: 0.0710 - mape_m: 7.0990 - precision_m: 0.9595 - recall_m: 0.9458 - rmse_m: 0.1344 - val_accuracy: 0.9491 - val_f1_m: 0.9478 - val_loss: 0.4520 - val_mae_m: 0.0680 - val_mape_m: 6.8046 - val_precision_m: 0.9534 - val_recall_m: 0.9424 - val_rmse_m: 0.1396
# Epoch 14/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9580 - f1_m: 0.9578 - loss: 0.4358 - mae_m: 0.0685 - mape_m: 6.8464 - precision_m: 0.9644 - recall_m: 0.9515 - rmse_m: 0.1285
# Epoch 14: val_loss improved from 0.45178 to 0.44976, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.9580 - f1_m: 0.9578 - loss: 0.4358 - mae_m: 0.0685 - mape_m: 6.8465 - precision_m: 0.9644 - recall_m: 0.9515 - rmse_m: 0.1285 - val_accuracy: 0.9495 - val_f1_m: 0.9497 - val_loss: 0.4498 - val_mae_m: 0.0654 - val_mape_m: 6.5440 - val_precision_m: 0.9543 - val_recall_m: 0.9454 - val_rmse_m: 0.1362
# Epoch 15/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9576 - f1_m: 0.9572 - loss: 0.4369 - mae_m: 0.0687 - mape_m: 6.8691 - precision_m: 0.9636 - recall_m: 0.9512 - rmse_m: 0.1292
# Epoch 15: val_loss did not improve from 0.44976
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9576 - f1_m: 0.9573 - loss: 0.4369 - mae_m: 0.0687 - mape_m: 6.8689 - precision_m: 0.9636 - recall_m: 0.9512 - rmse_m: 0.1292 - val_accuracy: 0.9491 - val_f1_m: 0.9485 - val_loss: 0.4554 - val_mae_m: 0.0658 - val_mape_m: 6.5761 - val_precision_m: 0.9531 - val_recall_m: 0.9440 - val_rmse_m: 0.1379
# Epoch 16/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9624 - f1_m: 0.9624 - loss: 0.4287 - mae_m: 0.0656 - mape_m: 6.5638 - precision_m: 0.9673 - recall_m: 0.9576 - rmse_m: 0.1228
# Epoch 16: val_loss did not improve from 0.44976
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9624 - f1_m: 0.9624 - loss: 0.4287 - mae_m: 0.0656 - mape_m: 6.5641 - precision_m: 0.9673 - recall_m: 0.9576 - rmse_m: 0.1228 - val_accuracy: 0.9499 - val_f1_m: 0.9498 - val_loss: 0.4510 - val_mae_m: 0.0660 - val_mape_m: 6.6014 - val_precision_m: 0.9547 - val_recall_m: 0.9451 - val_rmse_m: 0.1366
# Epoch 17/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9639 - f1_m: 0.9638 - loss: 0.4277 - mae_m: 0.0656 - mape_m: 6.5569 - precision_m: 0.9686 - recall_m: 0.9591 - rmse_m: 0.1223
# Epoch 17: val_loss did not improve from 0.44976
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9639 - f1_m: 0.9638 - loss: 0.4277 - mae_m: 0.0656 - mape_m: 6.5570 - precision_m: 0.9686 - recall_m: 0.9591 - rmse_m: 0.1224 - val_accuracy: 0.9396 - val_f1_m: 0.9389 - val_loss: 0.4688 - val_mae_m: 0.0675 - val_mape_m: 6.7452 - val_precision_m: 0.9451 - val_recall_m: 0.9330 - val_rmse_m: 0.1465
# Epoch 18/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9638 - f1_m: 0.9627 - loss: 0.4263 - mae_m: 0.0648 - mape_m: 6.4767 - precision_m: 0.9687 - recall_m: 0.9570 - rmse_m: 0.1208
# Epoch 18: val_loss improved from 0.44976 to 0.44308, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9638 - f1_m: 0.9627 - loss: 0.4263 - mae_m: 0.0648 - mape_m: 6.4767 - precision_m: 0.9687 - recall_m: 0.9570 - rmse_m: 0.1208 - val_accuracy: 0.9523 - val_f1_m: 0.9523 - val_loss: 0.4431 - val_mae_m: 0.0643 - val_mape_m: 6.4347 - val_precision_m: 0.9574 - val_recall_m: 0.9474 - val_rmse_m: 0.1323
# Epoch 19/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9632 - f1_m: 0.9627 - loss: 0.4244 - mae_m: 0.0644 - mape_m: 6.4404 - precision_m: 0.9677 - recall_m: 0.9579 - rmse_m: 0.1195
# Epoch 19: val_loss did not improve from 0.44308
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9632 - f1_m: 0.9627 - loss: 0.4244 - mae_m: 0.0644 - mape_m: 6.4402 - precision_m: 0.9678 - recall_m: 0.9579 - rmse_m: 0.1195 - val_accuracy: 0.9530 - val_f1_m: 0.9536 - val_loss: 0.4439 - val_mae_m: 0.0615 - val_mape_m: 6.1485 - val_precision_m: 0.9578 - val_recall_m: 0.9496 - val_rmse_m: 0.1313
# Epoch 20/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9692 - f1_m: 0.9685 - loss: 0.4182 - mae_m: 0.0618 - mape_m: 6.1806 - precision_m: 0.9730 - recall_m: 0.9642 - rmse_m: 0.1138
# Epoch 20: val_loss improved from 0.44308 to 0.43994, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9692 - f1_m: 0.9685 - loss: 0.4182 - mae_m: 0.0618 - mape_m: 6.1812 - precision_m: 0.9730 - recall_m: 0.9642 - rmse_m: 0.1139 - val_accuracy: 0.9520 - val_f1_m: 0.9514 - val_loss: 0.4399 - val_mae_m: 0.0642 - val_mape_m: 6.4236 - val_precision_m: 0.9561 - val_recall_m: 0.9469 - val_rmse_m: 0.1309
# Epoch 21/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9681 - f1_m: 0.9678 - loss: 0.4183 - mae_m: 0.0620 - mape_m: 6.2041 - precision_m: 0.9724 - recall_m: 0.9635 - rmse_m: 0.1142
# Epoch 21: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9681 - f1_m: 0.9678 - loss: 0.4183 - mae_m: 0.0620 - mape_m: 6.2042 - precision_m: 0.9724 - recall_m: 0.9635 - rmse_m: 0.1142 - val_accuracy: 0.9516 - val_f1_m: 0.9527 - val_loss: 0.4457 - val_mae_m: 0.0600 - val_mape_m: 6.0042 - val_precision_m: 0.9569 - val_recall_m: 0.9488 - val_rmse_m: 0.1301
# Epoch 22/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9736 - f1_m: 0.9727 - loss: 0.4106 - mae_m: 0.0591 - mape_m: 5.9070 - precision_m: 0.9772 - recall_m: 0.9685 - rmse_m: 0.1065
# Epoch 22: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9736 - f1_m: 0.9727 - loss: 0.4106 - mae_m: 0.0591 - mape_m: 5.9076 - precision_m: 0.9771 - recall_m: 0.9685 - rmse_m: 0.1065 - val_accuracy: 0.9516 - val_f1_m: 0.9516 - val_loss: 0.4497 - val_mae_m: 0.0631 - val_mape_m: 6.3139 - val_precision_m: 0.9559 - val_recall_m: 0.9474 - val_rmse_m: 0.1342
# Epoch 23/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9714 - f1_m: 0.9711 - loss: 0.4141 - mae_m: 0.0604 - mape_m: 6.0410 - precision_m: 0.9753 - recall_m: 0.9670 - rmse_m: 0.1101
# Epoch 23: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9714 - f1_m: 0.9711 - loss: 0.4141 - mae_m: 0.0604 - mape_m: 6.0410 - precision_m: 0.9753 - recall_m: 0.9670 - rmse_m: 0.1101 - val_accuracy: 0.9510 - val_f1_m: 0.9506 - val_loss: 0.4464 - val_mae_m: 0.0636 - val_mape_m: 6.3612 - val_precision_m: 0.9549 - val_recall_m: 0.9464 - val_rmse_m: 0.1324
# Epoch 24/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9719 - f1_m: 0.9717 - loss: 0.4132 - mae_m: 0.0602 - mape_m: 6.0234 - precision_m: 0.9761 - recall_m: 0.9675 - rmse_m: 0.1094
# Epoch 24: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9719 - f1_m: 0.9717 - loss: 0.4132 - mae_m: 0.0602 - mape_m: 6.0233 - precision_m: 0.9761 - recall_m: 0.9675 - rmse_m: 0.1094 - val_accuracy: 0.9544 - val_f1_m: 0.9540 - val_loss: 0.4447 - val_mae_m: 0.0637 - val_mape_m: 6.3684 - val_precision_m: 0.9582 - val_recall_m: 0.9500 - val_rmse_m: 0.1305
# Epoch 25/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9731 - f1_m: 0.9721 - loss: 0.4099 - mae_m: 0.0591 - mape_m: 5.9081 - precision_m: 0.9758 - recall_m: 0.9685 - rmse_m: 0.1067
# Epoch 25: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9731 - f1_m: 0.9721 - loss: 0.4099 - mae_m: 0.0591 - mape_m: 5.9081 - precision_m: 0.9758 - recall_m: 0.9685 - rmse_m: 0.1067 - val_accuracy: 0.9526 - val_f1_m: 0.9527 - val_loss: 0.4464 - val_mae_m: 0.0619 - val_mape_m: 6.1880 - val_precision_m: 0.9568 - val_recall_m: 0.9488 - val_rmse_m: 0.1310
# Epoch 26/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9758 - f1_m: 0.9754 - loss: 0.4069 - mae_m: 0.0579 - mape_m: 5.7909 - precision_m: 0.9787 - recall_m: 0.9723 - rmse_m: 0.1037
# Epoch 26: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9758 - f1_m: 0.9754 - loss: 0.4069 - mae_m: 0.0579 - mape_m: 5.7913 - precision_m: 0.9787 - recall_m: 0.9722 - rmse_m: 0.1037 - val_accuracy: 0.9519 - val_f1_m: 0.9511 - val_loss: 0.4497 - val_mae_m: 0.0658 - val_mape_m: 6.5798 - val_precision_m: 0.9548 - val_recall_m: 0.9475 - val_rmse_m: 0.1359
# Epoch 27/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9732 - f1_m: 0.9734 - loss: 0.4081 - mae_m: 0.0586 - mape_m: 5.8628 - precision_m: 0.9770 - recall_m: 0.9699 - rmse_m: 0.1056
# Epoch 27: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9732 - f1_m: 0.9734 - loss: 0.4081 - mae_m: 0.0586 - mape_m: 5.8627 - precision_m: 0.9770 - recall_m: 0.9699 - rmse_m: 0.1056 - val_accuracy: 0.9542 - val_f1_m: 0.9533 - val_loss: 0.4433 - val_mae_m: 0.0601 - val_mape_m: 6.0073 - val_precision_m: 0.9569 - val_recall_m: 0.9499 - val_rmse_m: 0.1284
# Epoch 28/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9791 - f1_m: 0.9786 - loss: 0.3996 - mae_m: 0.0551 - mape_m: 5.5143 - precision_m: 0.9813 - recall_m: 0.9760 - rmse_m: 0.0970
# Epoch 28: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9791 - f1_m: 0.9786 - loss: 0.3996 - mae_m: 0.0551 - mape_m: 5.5146 - precision_m: 0.9813 - recall_m: 0.9760 - rmse_m: 0.0970 - val_accuracy: 0.9513 - val_f1_m: 0.9515 - val_loss: 0.4497 - val_mae_m: 0.0610 - val_mape_m: 6.0954 - val_precision_m: 0.9557 - val_recall_m: 0.9474 - val_rmse_m: 0.1324
# Epoch 29/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9750 - f1_m: 0.9756 - loss: 0.4040 - mae_m: 0.0566 - mape_m: 5.6614 - precision_m: 0.9792 - recall_m: 0.9721 - rmse_m: 0.1009
# Epoch 29: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9750 - f1_m: 0.9756 - loss: 0.4040 - mae_m: 0.0566 - mape_m: 5.6614 - precision_m: 0.9792 - recall_m: 0.9721 - rmse_m: 0.1010 - val_accuracy: 0.9548 - val_f1_m: 0.9530 - val_loss: 0.4485 - val_mae_m: 0.0605 - val_mape_m: 6.0515 - val_precision_m: 0.9564 - val_recall_m: 0.9498 - val_rmse_m: 0.1300
# Epoch 30/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9786 - f1_m: 0.9787 - loss: 0.4001 - mae_m: 0.0553 - mape_m: 5.5306 - precision_m: 0.9817 - recall_m: 0.9758 - rmse_m: 0.0976
# Epoch 30: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9786 - f1_m: 0.9787 - loss: 0.4001 - mae_m: 0.0553 - mape_m: 5.5307 - precision_m: 0.9817 - recall_m: 0.9758 - rmse_m: 0.0976 - val_accuracy: 0.9535 - val_f1_m: 0.9532 - val_loss: 0.4474 - val_mae_m: 0.0596 - val_mape_m: 5.9619 - val_precision_m: 0.9572 - val_recall_m: 0.9494 - val_rmse_m: 0.1291
# Epoch 31/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9808 - f1_m: 0.9799 - loss: 0.3956 - mae_m: 0.0540 - mape_m: 5.3962 - precision_m: 0.9837 - recall_m: 0.9763 - rmse_m: 0.0935
# Epoch 31: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9808 - f1_m: 0.9799 - loss: 0.3956 - mae_m: 0.0540 - mape_m: 5.3967 - precision_m: 0.9837 - recall_m: 0.9763 - rmse_m: 0.0935 - val_accuracy: 0.9538 - val_f1_m: 0.9533 - val_loss: 0.4486 - val_mae_m: 0.0607 - val_mape_m: 6.0711 - val_precision_m: 0.9569 - val_recall_m: 0.9498 - val_rmse_m: 0.1304
# Epoch 32/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9803 - f1_m: 0.9793 - loss: 0.3971 - mae_m: 0.0543 - mape_m: 5.4262 - precision_m: 0.9826 - recall_m: 0.9762 - rmse_m: 0.0949
# Epoch 32: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9803 - f1_m: 0.9793 - loss: 0.3971 - mae_m: 0.0543 - mape_m: 5.4265 - precision_m: 0.9826 - recall_m: 0.9762 - rmse_m: 0.0949 - val_accuracy: 0.9544 - val_f1_m: 0.9541 - val_loss: 0.4455 - val_mae_m: 0.0609 - val_mape_m: 6.0881 - val_precision_m: 0.9585 - val_recall_m: 0.9499 - val_rmse_m: 0.1288
# Epoch 33/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9798 - f1_m: 0.9798 - loss: 0.3977 - mae_m: 0.0545 - mape_m: 5.4473 - precision_m: 0.9828 - recall_m: 0.9770 - rmse_m: 0.0953
# Epoch 33: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9798 - f1_m: 0.9798 - loss: 0.3977 - mae_m: 0.0545 - mape_m: 5.4473 - precision_m: 0.9828 - recall_m: 0.9770 - rmse_m: 0.0953 - val_accuracy: 0.9554 - val_f1_m: 0.9554 - val_loss: 0.4433 - val_mae_m: 0.0600 - val_mape_m: 6.0019 - val_precision_m: 0.9592 - val_recall_m: 0.9517 - val_rmse_m: 0.1282
# Epoch 34/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9809 - f1_m: 0.9797 - loss: 0.3954 - mae_m: 0.0538 - mape_m: 5.3824 - precision_m: 0.9825 - recall_m: 0.9769 - rmse_m: 0.0932
# Epoch 34: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9808 - f1_m: 0.9797 - loss: 0.3954 - mae_m: 0.0538 - mape_m: 5.3825 - precision_m: 0.9825 - recall_m: 0.9769 - rmse_m: 0.0932 - val_accuracy: 0.9579 - val_f1_m: 0.9576 - val_loss: 0.4406 - val_mae_m: 0.0571 - val_mape_m: 5.7110 - val_precision_m: 0.9607 - val_recall_m: 0.9546 - val_rmse_m: 0.1243
# Epoch 35/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9823 - f1_m: 0.9821 - loss: 0.3941 - mae_m: 0.0529 - mape_m: 5.2931 - precision_m: 0.9847 - recall_m: 0.9796 - rmse_m: 0.0910
# Epoch 35: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9823 - f1_m: 0.9821 - loss: 0.3941 - mae_m: 0.0529 - mape_m: 5.2932 - precision_m: 0.9847 - recall_m: 0.9796 - rmse_m: 0.0910 - val_accuracy: 0.9534 - val_f1_m: 0.9532 - val_loss: 0.4494 - val_mae_m: 0.0601 - val_mape_m: 6.0113 - val_precision_m: 0.9571 - val_recall_m: 0.9495 - val_rmse_m: 0.1293
# Epoch 36/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9845 - f1_m: 0.9836 - loss: 0.3909 - mae_m: 0.0520 - mape_m: 5.2009 - precision_m: 0.9863 - recall_m: 0.9811 - rmse_m: 0.0885
# Epoch 36: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9845 - f1_m: 0.9836 - loss: 0.3909 - mae_m: 0.0520 - mape_m: 5.2016 - precision_m: 0.9863 - recall_m: 0.9810 - rmse_m: 0.0885 - val_accuracy: 0.9576 - val_f1_m: 0.9568 - val_loss: 0.4431 - val_mae_m: 0.0611 - val_mape_m: 6.1118 - val_precision_m: 0.9606 - val_recall_m: 0.9531 - val_rmse_m: 0.1269
# Epoch 37/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9804 - f1_m: 0.9802 - loss: 0.3953 - mae_m: 0.0538 - mape_m: 5.3757 - precision_m: 0.9836 - recall_m: 0.9770 - rmse_m: 0.0924
# Epoch 37: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9804 - f1_m: 0.9802 - loss: 0.3953 - mae_m: 0.0538 - mape_m: 5.3757 - precision_m: 0.9836 - recall_m: 0.9770 - rmse_m: 0.0924 - val_accuracy: 0.9560 - val_f1_m: 0.9557 - val_loss: 0.4426 - val_mae_m: 0.0581 - val_mape_m: 5.8058 - val_precision_m: 0.9600 - val_recall_m: 0.9515 - val_rmse_m: 0.1257
# Epoch 38/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9846 - f1_m: 0.9838 - loss: 0.3890 - mae_m: 0.0514 - mape_m: 5.1353 - precision_m: 0.9868 - recall_m: 0.9810 - rmse_m: 0.0868
# Epoch 38: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9846 - f1_m: 0.9838 - loss: 0.3890 - mae_m: 0.0514 - mape_m: 5.1354 - precision_m: 0.9868 - recall_m: 0.9810 - rmse_m: 0.0868 - val_accuracy: 0.9556 - val_f1_m: 0.9555 - val_loss: 0.4433 - val_mae_m: 0.0598 - val_mape_m: 5.9847 - val_precision_m: 0.9587 - val_recall_m: 0.9525 - val_rmse_m: 0.1273
# Epoch 39/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9858 - f1_m: 0.9853 - loss: 0.3884 - mae_m: 0.0511 - mape_m: 5.1091 - precision_m: 0.9877 - recall_m: 0.9831 - rmse_m: 0.0853
# Epoch 39: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9858 - f1_m: 0.9853 - loss: 0.3884 - mae_m: 0.0511 - mape_m: 5.1095 - precision_m: 0.9877 - recall_m: 0.9831 - rmse_m: 0.0853 - val_accuracy: 0.9546 - val_f1_m: 0.9545 - val_loss: 0.4459 - val_mae_m: 0.0598 - val_mape_m: 5.9796 - val_precision_m: 0.9572 - val_recall_m: 0.9520 - val_rmse_m: 0.1280
# Epoch 40/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9842 - f1_m: 0.9839 - loss: 0.3895 - mae_m: 0.0519 - mape_m: 5.1852 - precision_m: 0.9868 - recall_m: 0.9811 - rmse_m: 0.0876
# Epoch 40: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9842 - f1_m: 0.9839 - loss: 0.3895 - mae_m: 0.0519 - mape_m: 5.1852 - precision_m: 0.9868 - recall_m: 0.9811 - rmse_m: 0.0876 - val_accuracy: 0.9526 - val_f1_m: 0.9532 - val_loss: 0.4522 - val_mae_m: 0.0588 - val_mape_m: 5.8803 - val_precision_m: 0.9566 - val_recall_m: 0.9499 - val_rmse_m: 0.1298
# Epoch 41/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9871 - f1_m: 0.9866 - loss: 0.3857 - mae_m: 0.0499 - mape_m: 4.9886 - precision_m: 0.9888 - recall_m: 0.9844 - rmse_m: 0.0822
# Epoch 41: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9871 - f1_m: 0.9866 - loss: 0.3857 - mae_m: 0.0499 - mape_m: 4.9887 - precision_m: 0.9888 - recall_m: 0.9844 - rmse_m: 0.0823 - val_accuracy: 0.9528 - val_f1_m: 0.9530 - val_loss: 0.4491 - val_mae_m: 0.0598 - val_mape_m: 5.9845 - val_precision_m: 0.9559 - val_recall_m: 0.9503 - val_rmse_m: 0.1307
# Epoch 42/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9845 - f1_m: 0.9846 - loss: 0.3884 - mae_m: 0.0512 - mape_m: 5.1196 - precision_m: 0.9869 - recall_m: 0.9823 - rmse_m: 0.0861
# Epoch 42: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9845 - f1_m: 0.9846 - loss: 0.3884 - mae_m: 0.0512 - mape_m: 5.1199 - precision_m: 0.9869 - recall_m: 0.9823 - rmse_m: 0.0861 - val_accuracy: 0.9546 - val_f1_m: 0.9549 - val_loss: 0.4479 - val_mae_m: 0.0604 - val_mape_m: 6.0414 - val_precision_m: 0.9587 - val_recall_m: 0.9513 - val_rmse_m: 0.1294
# Epoch 43/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9857 - f1_m: 0.9851 - loss: 0.3872 - mae_m: 0.0509 - mape_m: 5.0943 - precision_m: 0.9879 - recall_m: 0.9824 - rmse_m: 0.0850
# Epoch 43: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9857 - f1_m: 0.9851 - loss: 0.3872 - mae_m: 0.0509 - mape_m: 5.0946 - precision_m: 0.9879 - recall_m: 0.9824 - rmse_m: 0.0850 - val_accuracy: 0.9572 - val_f1_m: 0.9572 - val_loss: 0.4440 - val_mae_m: 0.0574 - val_mape_m: 5.7359 - val_precision_m: 0.9601 - val_recall_m: 0.9545 - val_rmse_m: 0.1261
# Epoch 44/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9878 - f1_m: 0.9875 - loss: 0.3852 - mae_m: 0.0498 - mape_m: 4.9755 - precision_m: 0.9892 - recall_m: 0.9858 - rmse_m: 0.0819
# Epoch 44: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9878 - f1_m: 0.9875 - loss: 0.3852 - mae_m: 0.0498 - mape_m: 4.9758 - precision_m: 0.9892 - recall_m: 0.9858 - rmse_m: 0.0819 - val_accuracy: 0.9575 - val_f1_m: 0.9578 - val_loss: 0.4442 - val_mae_m: 0.0601 - val_mape_m: 6.0084 - val_precision_m: 0.9609 - val_recall_m: 0.9548 - val_rmse_m: 0.1261
# Epoch 45/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9862 - f1_m: 0.9861 - loss: 0.3862 - mae_m: 0.0505 - mape_m: 5.0516 - precision_m: 0.9882 - recall_m: 0.9841 - rmse_m: 0.0836
# Epoch 45: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9862 - f1_m: 0.9861 - loss: 0.3862 - mae_m: 0.0505 - mape_m: 5.0515 - precision_m: 0.9882 - recall_m: 0.9841 - rmse_m: 0.0836 - val_accuracy: 0.9544 - val_f1_m: 0.9544 - val_loss: 0.4494 - val_mae_m: 0.0591 - val_mape_m: 5.9118 - val_precision_m: 0.9574 - val_recall_m: 0.9515 - val_rmse_m: 0.1290
# Epoch 46/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9888 - f1_m: 0.9887 - loss: 0.3815 - mae_m: 0.0487 - mape_m: 4.8714 - precision_m: 0.9911 - recall_m: 0.9865 - rmse_m: 0.0784
# Epoch 46: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9888 - f1_m: 0.9887 - loss: 0.3815 - mae_m: 0.0487 - mape_m: 4.8719 - precision_m: 0.9911 - recall_m: 0.9865 - rmse_m: 0.0784 - val_accuracy: 0.9576 - val_f1_m: 0.9573 - val_loss: 0.4458 - val_mae_m: 0.0584 - val_mape_m: 5.8448 - val_precision_m: 0.9605 - val_recall_m: 0.9542 - val_rmse_m: 0.1260
# Epoch 47/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9883 - f1_m: 0.9881 - loss: 0.3831 - mae_m: 0.0492 - mape_m: 4.9204 - precision_m: 0.9899 - recall_m: 0.9864 - rmse_m: 0.0792
# Epoch 47: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9883 - f1_m: 0.9881 - loss: 0.3831 - mae_m: 0.0492 - mape_m: 4.9205 - precision_m: 0.9899 - recall_m: 0.9863 - rmse_m: 0.0792 - val_accuracy: 0.9521 - val_f1_m: 0.9517 - val_loss: 0.4558 - val_mae_m: 0.0597 - val_mape_m: 5.9739 - val_precision_m: 0.9546 - val_recall_m: 0.9489 - val_rmse_m: 0.1322
# Epoch 48/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9881 - f1_m: 0.9878 - loss: 0.3838 - mae_m: 0.0492 - mape_m: 4.9240 - precision_m: 0.9896 - recall_m: 0.9860 - rmse_m: 0.0803
# Epoch 48: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9881 - f1_m: 0.9878 - loss: 0.3838 - mae_m: 0.0492 - mape_m: 4.9241 - precision_m: 0.9896 - recall_m: 0.9860 - rmse_m: 0.0803 - val_accuracy: 0.9564 - val_f1_m: 0.9560 - val_loss: 0.4445 - val_mae_m: 0.0593 - val_mape_m: 5.9318 - val_precision_m: 0.9594 - val_recall_m: 0.9528 - val_rmse_m: 0.1268
# Epoch 49/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9883 - f1_m: 0.9877 - loss: 0.3847 - mae_m: 0.0495 - mape_m: 4.9461 - precision_m: 0.9897 - recall_m: 0.9857 - rmse_m: 0.0805
# Epoch 49: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9883 - f1_m: 0.9877 - loss: 0.3847 - mae_m: 0.0495 - mape_m: 4.9462 - precision_m: 0.9897 - recall_m: 0.9857 - rmse_m: 0.0805 - val_accuracy: 0.9545 - val_f1_m: 0.9544 - val_loss: 0.4476 - val_mae_m: 0.0581 - val_mape_m: 5.8069 - val_precision_m: 0.9576 - val_recall_m: 0.9514 - val_rmse_m: 0.1283
# Epoch 50/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9887 - f1_m: 0.9884 - loss: 0.3811 - mae_m: 0.0485 - mape_m: 4.8479 - precision_m: 0.9904 - recall_m: 0.9864 - rmse_m: 0.0782
# Epoch 50: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9887 - f1_m: 0.9884 - loss: 0.3811 - mae_m: 0.0485 - mape_m: 4.8480 - precision_m: 0.9904 - recall_m: 0.9864 - rmse_m: 0.0782 - val_accuracy: 0.9579 - val_f1_m: 0.9575 - val_loss: 0.4450 - val_mae_m: 0.0580 - val_mape_m: 5.8048 - val_precision_m: 0.9606 - val_recall_m: 0.9544 - val_rmse_m: 0.1255
# Epoch 51/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9914 - f1_m: 0.9911 - loss: 0.3785 - mae_m: 0.0474 - mape_m: 4.7430 - precision_m: 0.9925 - recall_m: 0.9898 - rmse_m: 0.0744
# Epoch 51: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9914 - f1_m: 0.9911 - loss: 0.3785 - mae_m: 0.0474 - mape_m: 4.7431 - precision_m: 0.9925 - recall_m: 0.9898 - rmse_m: 0.0744 - val_accuracy: 0.9551 - val_f1_m: 0.9556 - val_loss: 0.4482 - val_mae_m: 0.0595 - val_mape_m: 5.9506 - val_precision_m: 0.9586 - val_recall_m: 0.9526 - val_rmse_m: 0.1283
# Epoch 52/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9892 - f1_m: 0.9888 - loss: 0.3813 - mae_m: 0.0486 - mape_m: 4.8579 - precision_m: 0.9908 - recall_m: 0.9868 - rmse_m: 0.0776
# Epoch 52: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9892 - f1_m: 0.9888 - loss: 0.3813 - mae_m: 0.0486 - mape_m: 4.8579 - precision_m: 0.9908 - recall_m: 0.9868 - rmse_m: 0.0776 - val_accuracy: 0.9554 - val_f1_m: 0.9548 - val_loss: 0.4536 - val_mae_m: 0.0573 - val_mape_m: 5.7297 - val_precision_m: 0.9586 - val_recall_m: 0.9513 - val_rmse_m: 0.1287
# Epoch 53/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9897 - f1_m: 0.9894 - loss: 0.3801 - mae_m: 0.0477 - mape_m: 4.7700 - precision_m: 0.9912 - recall_m: 0.9876 - rmse_m: 0.0760
# Epoch 53: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9897 - f1_m: 0.9894 - loss: 0.3801 - mae_m: 0.0477 - mape_m: 4.7701 - precision_m: 0.9912 - recall_m: 0.9876 - rmse_m: 0.0760 - val_accuracy: 0.9554 - val_f1_m: 0.9561 - val_loss: 0.4475 - val_mae_m: 0.0598 - val_mape_m: 5.9839 - val_precision_m: 0.9591 - val_recall_m: 0.9532 - val_rmse_m: 0.1276
# Epoch 54/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9910 - f1_m: 0.9909 - loss: 0.3793 - mae_m: 0.0477 - mape_m: 4.7699 - precision_m: 0.9923 - recall_m: 0.9896 - rmse_m: 0.0749
# Epoch 54: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9910 - f1_m: 0.9909 - loss: 0.3793 - mae_m: 0.0477 - mape_m: 4.7699 - precision_m: 0.9923 - recall_m: 0.9896 - rmse_m: 0.0749 - val_accuracy: 0.9580 - val_f1_m: 0.9578 - val_loss: 0.4456 - val_mae_m: 0.0574 - val_mape_m: 5.7437 - val_precision_m: 0.9610 - val_recall_m: 0.9548 - val_rmse_m: 0.1241
# Epoch 55/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9895 - f1_m: 0.9894 - loss: 0.3791 - mae_m: 0.0477 - mape_m: 4.7679 - precision_m: 0.9911 - recall_m: 0.9877 - rmse_m: 0.0757
# Epoch 55: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9894 - f1_m: 0.9894 - loss: 0.3791 - mae_m: 0.0477 - mape_m: 4.7682 - precision_m: 0.9911 - recall_m: 0.9877 - rmse_m: 0.0757 - val_accuracy: 0.9548 - val_f1_m: 0.9545 - val_loss: 0.4480 - val_mae_m: 0.0568 - val_mape_m: 5.6810 - val_precision_m: 0.9576 - val_recall_m: 0.9516 - val_rmse_m: 0.1257
# Epoch 56/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9920 - f1_m: 0.9919 - loss: 0.3779 - mae_m: 0.0472 - mape_m: 4.7189 - precision_m: 0.9935 - recall_m: 0.9905 - rmse_m: 0.0738
# Epoch 56: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9920 - f1_m: 0.9919 - loss: 0.3779 - mae_m: 0.0472 - mape_m: 4.7190 - precision_m: 0.9935 - recall_m: 0.9905 - rmse_m: 0.0738 - val_accuracy: 0.9535 - val_f1_m: 0.9533 - val_loss: 0.4549 - val_mae_m: 0.0603 - val_mape_m: 6.0263 - val_precision_m: 0.9567 - val_recall_m: 0.9501 - val_rmse_m: 0.1314
# Epoch 57/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9906 - f1_m: 0.9902 - loss: 0.3782 - mae_m: 0.0475 - mape_m: 4.7481 - precision_m: 0.9921 - recall_m: 0.9883 - rmse_m: 0.0740
# Epoch 57: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9906 - f1_m: 0.9902 - loss: 0.3782 - mae_m: 0.0475 - mape_m: 4.7480 - precision_m: 0.9921 - recall_m: 0.9883 - rmse_m: 0.0740 - val_accuracy: 0.9557 - val_f1_m: 0.9559 - val_loss: 0.4504 - val_mae_m: 0.0574 - val_mape_m: 5.7422 - val_precision_m: 0.9584 - val_recall_m: 0.9535 - val_rmse_m: 0.1271
# Epoch 58/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9916 - f1_m: 0.9913 - loss: 0.3766 - mae_m: 0.0467 - mape_m: 4.6712 - precision_m: 0.9926 - recall_m: 0.9899 - rmse_m: 0.0725
# Epoch 58: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9916 - f1_m: 0.9912 - loss: 0.3766 - mae_m: 0.0467 - mape_m: 4.6714 - precision_m: 0.9926 - recall_m: 0.9899 - rmse_m: 0.0725 - val_accuracy: 0.9572 - val_f1_m: 0.9568 - val_loss: 0.4457 - val_mae_m: 0.0594 - val_mape_m: 5.9367 - val_precision_m: 0.9593 - val_recall_m: 0.9544 - val_rmse_m: 0.1271
# Epoch 59/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9918 - f1_m: 0.9915 - loss: 0.3758 - mae_m: 0.0468 - mape_m: 4.6774 - precision_m: 0.9927 - recall_m: 0.9905 - rmse_m: 0.0722
# Epoch 59: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9918 - f1_m: 0.9915 - loss: 0.3758 - mae_m: 0.0468 - mape_m: 4.6775 - precision_m: 0.9927 - recall_m: 0.9905 - rmse_m: 0.0722 - val_accuracy: 0.9561 - val_f1_m: 0.9561 - val_loss: 0.4509 - val_mae_m: 0.0588 - val_mape_m: 5.8757 - val_precision_m: 0.9587 - val_recall_m: 0.9536 - val_rmse_m: 0.1275
# Epoch 60/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9926 - f1_m: 0.9926 - loss: 0.3748 - mae_m: 0.0462 - mape_m: 4.6229 - precision_m: 0.9939 - recall_m: 0.9912 - rmse_m: 0.0703
# Epoch 60: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9925 - f1_m: 0.9926 - loss: 0.3748 - mae_m: 0.0462 - mape_m: 4.6232 - precision_m: 0.9939 - recall_m: 0.9912 - rmse_m: 0.0704 - val_accuracy: 0.9567 - val_f1_m: 0.9565 - val_loss: 0.4484 - val_mae_m: 0.0590 - val_mape_m: 5.8958 - val_precision_m: 0.9600 - val_recall_m: 0.9531 - val_rmse_m: 0.1265
# Epoch 61/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9914 - f1_m: 0.9912 - loss: 0.3761 - mae_m: 0.0467 - mape_m: 4.6727 - precision_m: 0.9925 - recall_m: 0.9899 - rmse_m: 0.0721
# Epoch 61: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9914 - f1_m: 0.9912 - loss: 0.3761 - mae_m: 0.0467 - mape_m: 4.6727 - precision_m: 0.9925 - recall_m: 0.9899 - rmse_m: 0.0721 - val_accuracy: 0.9554 - val_f1_m: 0.9551 - val_loss: 0.4515 - val_mae_m: 0.0585 - val_mape_m: 5.8541 - val_precision_m: 0.9576 - val_recall_m: 0.9526 - val_rmse_m: 0.1282
# Epoch 62/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9919 - f1_m: 0.9920 - loss: 0.3750 - mae_m: 0.0463 - mape_m: 4.6346 - precision_m: 0.9933 - recall_m: 0.9907 - rmse_m: 0.0708
# Epoch 62: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9919 - f1_m: 0.9920 - loss: 0.3750 - mae_m: 0.0463 - mape_m: 4.6348 - precision_m: 0.9933 - recall_m: 0.9907 - rmse_m: 0.0708 - val_accuracy: 0.9561 - val_f1_m: 0.9562 - val_loss: 0.4499 - val_mae_m: 0.0580 - val_mape_m: 5.7962 - val_precision_m: 0.9587 - val_recall_m: 0.9538 - val_rmse_m: 0.1275
# Epoch 63/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9904 - f1_m: 0.9900 - loss: 0.3785 - mae_m: 0.0473 - mape_m: 4.7321 - precision_m: 0.9919 - recall_m: 0.9882 - rmse_m: 0.0739
# Epoch 63: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9904 - f1_m: 0.9900 - loss: 0.3785 - mae_m: 0.0473 - mape_m: 4.7321 - precision_m: 0.9919 - recall_m: 0.9882 - rmse_m: 0.0739 - val_accuracy: 0.9546 - val_f1_m: 0.9551 - val_loss: 0.4518 - val_mae_m: 0.0596 - val_mape_m: 5.9594 - val_precision_m: 0.9583 - val_recall_m: 0.9520 - val_rmse_m: 0.1292
# Epoch 64/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9915 - f1_m: 0.9911 - loss: 0.3766 - mae_m: 0.0469 - mape_m: 4.6901 - precision_m: 0.9926 - recall_m: 0.9897 - rmse_m: 0.0730
# Epoch 64: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9915 - f1_m: 0.9911 - loss: 0.3766 - mae_m: 0.0469 - mape_m: 4.6899 - precision_m: 0.9926 - recall_m: 0.9897 - rmse_m: 0.0730 - val_accuracy: 0.9546 - val_f1_m: 0.9553 - val_loss: 0.4529 - val_mae_m: 0.0572 - val_mape_m: 5.7158 - val_precision_m: 0.9583 - val_recall_m: 0.9524 - val_rmse_m: 0.1280
# Epoch 65/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9934 - f1_m: 0.9934 - loss: 0.3728 - mae_m: 0.0454 - mape_m: 4.5401 - precision_m: 0.9943 - recall_m: 0.9925 - rmse_m: 0.0680
# Epoch 65: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9934 - f1_m: 0.9934 - loss: 0.3728 - mae_m: 0.0454 - mape_m: 4.5404 - precision_m: 0.9943 - recall_m: 0.9925 - rmse_m: 0.0680 - val_accuracy: 0.9550 - val_f1_m: 0.9549 - val_loss: 0.4565 - val_mae_m: 0.0583 - val_mape_m: 5.8313 - val_precision_m: 0.9575 - val_recall_m: 0.9524 - val_rmse_m: 0.1295
# Epoch 66/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9915 - f1_m: 0.9917 - loss: 0.3752 - mae_m: 0.0462 - mape_m: 4.6225 - precision_m: 0.9934 - recall_m: 0.9900 - rmse_m: 0.0709
# Epoch 66: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9915 - f1_m: 0.9917 - loss: 0.3752 - mae_m: 0.0462 - mape_m: 4.6230 - precision_m: 0.9934 - recall_m: 0.9900 - rmse_m: 0.0709 - val_accuracy: 0.9555 - val_f1_m: 0.9560 - val_loss: 0.4552 - val_mae_m: 0.0576 - val_mape_m: 5.7614 - val_precision_m: 0.9588 - val_recall_m: 0.9532 - val_rmse_m: 0.1280
# Epoch 67/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9915 - f1_m: 0.9914 - loss: 0.3762 - mae_m: 0.0465 - mape_m: 4.6454 - precision_m: 0.9926 - recall_m: 0.9904 - rmse_m: 0.0717
# Epoch 67: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9915 - f1_m: 0.9914 - loss: 0.3762 - mae_m: 0.0465 - mape_m: 4.6454 - precision_m: 0.9926 - recall_m: 0.9904 - rmse_m: 0.0717 - val_accuracy: 0.9532 - val_f1_m: 0.9530 - val_loss: 0.4586 - val_mae_m: 0.0585 - val_mape_m: 5.8467 - val_precision_m: 0.9561 - val_recall_m: 0.9501 - val_rmse_m: 0.1310
# Epoch 68/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9924 - f1_m: 0.9924 - loss: 0.3737 - mae_m: 0.0458 - mape_m: 4.5761 - precision_m: 0.9937 - recall_m: 0.9912 - rmse_m: 0.0695
# Epoch 68: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9924 - f1_m: 0.9924 - loss: 0.3737 - mae_m: 0.0458 - mape_m: 4.5762 - precision_m: 0.9937 - recall_m: 0.9912 - rmse_m: 0.0695 - val_accuracy: 0.9535 - val_f1_m: 0.9535 - val_loss: 0.4568 - val_mae_m: 0.0591 - val_mape_m: 5.9113 - val_precision_m: 0.9563 - val_recall_m: 0.9507 - val_rmse_m: 0.1304
# Epoch 69/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9947 - f1_m: 0.9943 - loss: 0.3707 - mae_m: 0.0447 - mape_m: 4.4716 - precision_m: 0.9955 - recall_m: 0.9930 - rmse_m: 0.0658
# Epoch 69: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9947 - f1_m: 0.9943 - loss: 0.3707 - mae_m: 0.0447 - mape_m: 4.4717 - precision_m: 0.9955 - recall_m: 0.9930 - rmse_m: 0.0658 - val_accuracy: 0.9528 - val_f1_m: 0.9526 - val_loss: 0.4591 - val_mae_m: 0.0596 - val_mape_m: 5.9593 - val_precision_m: 0.9551 - val_recall_m: 0.9501 - val_rmse_m: 0.1322
# Epoch 70/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9921 - f1_m: 0.9921 - loss: 0.3732 - mae_m: 0.0457 - mape_m: 4.5749 - precision_m: 0.9937 - recall_m: 0.9906 - rmse_m: 0.0693
# Epoch 70: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9921 - f1_m: 0.9921 - loss: 0.3732 - mae_m: 0.0458 - mape_m: 4.5750 - precision_m: 0.9937 - recall_m: 0.9906 - rmse_m: 0.0694 - val_accuracy: 0.9523 - val_f1_m: 0.9522 - val_loss: 0.4567 - val_mae_m: 0.0609 - val_mape_m: 6.0941 - val_precision_m: 0.9553 - val_recall_m: 0.9492 - val_rmse_m: 0.1326
# Epoch 71/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9921 - f1_m: 0.9923 - loss: 0.3737 - mae_m: 0.0458 - mape_m: 4.5829 - precision_m: 0.9939 - recall_m: 0.9907 - rmse_m: 0.0696
# Epoch 71: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9921 - f1_m: 0.9923 - loss: 0.3737 - mae_m: 0.0458 - mape_m: 4.5829 - precision_m: 0.9939 - recall_m: 0.9907 - rmse_m: 0.0696 - val_accuracy: 0.9564 - val_f1_m: 0.9569 - val_loss: 0.4508 - val_mae_m: 0.0580 - val_mape_m: 5.7957 - val_precision_m: 0.9604 - val_recall_m: 0.9535 - val_rmse_m: 0.1263
# Epoch 72/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9908 - f1_m: 0.9904 - loss: 0.3763 - mae_m: 0.0467 - mape_m: 4.6661 - precision_m: 0.9918 - recall_m: 0.9890 - rmse_m: 0.0717
# Epoch 72: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9909 - f1_m: 0.9904 - loss: 0.3763 - mae_m: 0.0467 - mape_m: 4.6660 - precision_m: 0.9918 - recall_m: 0.9890 - rmse_m: 0.0717 - val_accuracy: 0.9574 - val_f1_m: 0.9578 - val_loss: 0.4474 - val_mae_m: 0.0566 - val_mape_m: 5.6636 - val_precision_m: 0.9606 - val_recall_m: 0.9551 - val_rmse_m: 0.1245
# Epoch 73/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9929 - f1_m: 0.9931 - loss: 0.3717 - mae_m: 0.0451 - mape_m: 4.5079 - precision_m: 0.9944 - recall_m: 0.9920 - rmse_m: 0.0672
# Epoch 73: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9929 - f1_m: 0.9931 - loss: 0.3717 - mae_m: 0.0451 - mape_m: 4.5079 - precision_m: 0.9944 - recall_m: 0.9920 - rmse_m: 0.0672 - val_accuracy: 0.9560 - val_f1_m: 0.9560 - val_loss: 0.4548 - val_mae_m: 0.0576 - val_mape_m: 5.7596 - val_precision_m: 0.9595 - val_recall_m: 0.9528 - val_rmse_m: 0.1278
# Epoch 74/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9937 - f1_m: 0.9939 - loss: 0.3716 - mae_m: 0.0450 - mape_m: 4.5028 - precision_m: 0.9947 - recall_m: 0.9930 - rmse_m: 0.0671
# Epoch 74: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9937 - f1_m: 0.9939 - loss: 0.3716 - mae_m: 0.0450 - mape_m: 4.5027 - precision_m: 0.9947 - recall_m: 0.9930 - rmse_m: 0.0671 - val_accuracy: 0.9575 - val_f1_m: 0.9575 - val_loss: 0.4510 - val_mae_m: 0.0558 - val_mape_m: 5.5768 - val_precision_m: 0.9613 - val_recall_m: 0.9539 - val_rmse_m: 0.1250
# Epoch 75/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9927 - f1_m: 0.9927 - loss: 0.3730 - mae_m: 0.0452 - mape_m: 4.5248 - precision_m: 0.9936 - recall_m: 0.9918 - rmse_m: 0.0677
# Epoch 75: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9927 - f1_m: 0.9927 - loss: 0.3730 - mae_m: 0.0453 - mape_m: 4.5252 - precision_m: 0.9936 - recall_m: 0.9918 - rmse_m: 0.0677 - val_accuracy: 0.9572 - val_f1_m: 0.9571 - val_loss: 0.4492 - val_mae_m: 0.0570 - val_mape_m: 5.7019 - val_precision_m: 0.9596 - val_recall_m: 0.9546 - val_rmse_m: 0.1257
# Epoch 76/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9917 - f1_m: 0.9916 - loss: 0.3737 - mae_m: 0.0457 - mape_m: 4.5712 - precision_m: 0.9931 - recall_m: 0.9902 - rmse_m: 0.0697
# Epoch 76: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9917 - f1_m: 0.9916 - loss: 0.3737 - mae_m: 0.0457 - mape_m: 4.5712 - precision_m: 0.9931 - recall_m: 0.9902 - rmse_m: 0.0697 - val_accuracy: 0.9555 - val_f1_m: 0.9550 - val_loss: 0.4501 - val_mae_m: 0.0593 - val_mape_m: 5.9335 - val_precision_m: 0.9574 - val_recall_m: 0.9526 - val_rmse_m: 0.1292
# Epoch 77/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9938 - f1_m: 0.9937 - loss: 0.3709 - mae_m: 0.0447 - mape_m: 4.4743 - precision_m: 0.9950 - recall_m: 0.9924 - rmse_m: 0.0659
# Epoch 77: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9938 - f1_m: 0.9937 - loss: 0.3709 - mae_m: 0.0447 - mape_m: 4.4744 - precision_m: 0.9950 - recall_m: 0.9924 - rmse_m: 0.0659 - val_accuracy: 0.9571 - val_f1_m: 0.9567 - val_loss: 0.4517 - val_mae_m: 0.0568 - val_mape_m: 5.6829 - val_precision_m: 0.9596 - val_recall_m: 0.9540 - val_rmse_m: 0.1263
# Epoch 78/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9940 - f1_m: 0.9937 - loss: 0.3704 - mae_m: 0.0444 - mape_m: 4.4440 - precision_m: 0.9948 - recall_m: 0.9927 - rmse_m: 0.0650
# Epoch 78: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9939 - f1_m: 0.9937 - loss: 0.3704 - mae_m: 0.0444 - mape_m: 4.4442 - precision_m: 0.9948 - recall_m: 0.9927 - rmse_m: 0.0650 - val_accuracy: 0.9526 - val_f1_m: 0.9527 - val_loss: 0.4542 - val_mae_m: 0.0595 - val_mape_m: 5.9530 - val_precision_m: 0.9565 - val_recall_m: 0.9490 - val_rmse_m: 0.1304
# Epoch 79/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9939 - f1_m: 0.9940 - loss: 0.3716 - mae_m: 0.0450 - mape_m: 4.5006 - precision_m: 0.9953 - recall_m: 0.9926 - rmse_m: 0.0664
# Epoch 79: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9939 - f1_m: 0.9940 - loss: 0.3716 - mae_m: 0.0450 - mape_m: 4.5006 - precision_m: 0.9953 - recall_m: 0.9926 - rmse_m: 0.0664 - val_accuracy: 0.9532 - val_f1_m: 0.9531 - val_loss: 0.4559 - val_mae_m: 0.0593 - val_mape_m: 5.9345 - val_precision_m: 0.9558 - val_recall_m: 0.9506 - val_rmse_m: 0.1308
# Epoch 80/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9953 - f1_m: 0.9951 - loss: 0.3688 - mae_m: 0.0440 - mape_m: 4.4012 - precision_m: 0.9962 - recall_m: 0.9941 - rmse_m: 0.0635
# Epoch 80: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9953 - f1_m: 0.9951 - loss: 0.3688 - mae_m: 0.0440 - mape_m: 4.4012 - precision_m: 0.9962 - recall_m: 0.9941 - rmse_m: 0.0635 - val_accuracy: 0.9564 - val_f1_m: 0.9562 - val_loss: 0.4532 - val_mae_m: 0.0585 - val_mape_m: 5.8456 - val_precision_m: 0.9593 - val_recall_m: 0.9532 - val_rmse_m: 0.1281
# Epoch 81/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9954 - f1_m: 0.9953 - loss: 0.3683 - mae_m: 0.0437 - mape_m: 4.3719 - precision_m: 0.9960 - recall_m: 0.9946 - rmse_m: 0.0623
# Epoch 81: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9954 - f1_m: 0.9953 - loss: 0.3683 - mae_m: 0.0437 - mape_m: 4.3728 - precision_m: 0.9960 - recall_m: 0.9946 - rmse_m: 0.0623 - val_accuracy: 0.9548 - val_f1_m: 0.9539 - val_loss: 0.4536 - val_mae_m: 0.0596 - val_mape_m: 5.9580 - val_precision_m: 0.9567 - val_recall_m: 0.9513 - val_rmse_m: 0.1299
# Epoch 82/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9946 - f1_m: 0.9942 - loss: 0.3703 - mae_m: 0.0445 - mape_m: 4.4518 - precision_m: 0.9952 - recall_m: 0.9932 - rmse_m: 0.0652
# Epoch 82: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9946 - f1_m: 0.9942 - loss: 0.3703 - mae_m: 0.0445 - mape_m: 4.4519 - precision_m: 0.9952 - recall_m: 0.9931 - rmse_m: 0.0652 - val_accuracy: 0.9546 - val_f1_m: 0.9549 - val_loss: 0.4549 - val_mae_m: 0.0592 - val_mape_m: 5.9243 - val_precision_m: 0.9572 - val_recall_m: 0.9528 - val_rmse_m: 0.1295
# Epoch 83/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9951 - f1_m: 0.9949 - loss: 0.3696 - mae_m: 0.0443 - mape_m: 4.4347 - precision_m: 0.9960 - recall_m: 0.9940 - rmse_m: 0.0645
# Epoch 83: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9951 - f1_m: 0.9949 - loss: 0.3696 - mae_m: 0.0443 - mape_m: 4.4349 - precision_m: 0.9960 - recall_m: 0.9939 - rmse_m: 0.0645 - val_accuracy: 0.9564 - val_f1_m: 0.9559 - val_loss: 0.4508 - val_mae_m: 0.0574 - val_mape_m: 5.7435 - val_precision_m: 0.9587 - val_recall_m: 0.9532 - val_rmse_m: 0.1266
# Epoch 84/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9939 - f1_m: 0.9939 - loss: 0.3697 - mae_m: 0.0444 - mape_m: 4.4429 - precision_m: 0.9948 - recall_m: 0.9932 - rmse_m: 0.0646
# Epoch 84: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9939 - f1_m: 0.9939 - loss: 0.3697 - mae_m: 0.0444 - mape_m: 4.4430 - precision_m: 0.9948 - recall_m: 0.9932 - rmse_m: 0.0646 - val_accuracy: 0.9550 - val_f1_m: 0.9548 - val_loss: 0.4544 - val_mae_m: 0.0580 - val_mape_m: 5.8014 - val_precision_m: 0.9573 - val_recall_m: 0.9524 - val_rmse_m: 0.1280
# Epoch 85/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9934 - f1_m: 0.9934 - loss: 0.3727 - mae_m: 0.0452 - mape_m: 4.5221 - precision_m: 0.9945 - recall_m: 0.9925 - rmse_m: 0.0679
# Epoch 85: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9934 - f1_m: 0.9934 - loss: 0.3727 - mae_m: 0.0452 - mape_m: 4.5220 - precision_m: 0.9945 - recall_m: 0.9925 - rmse_m: 0.0679 - val_accuracy: 0.9559 - val_f1_m: 0.9564 - val_loss: 0.4496 - val_mae_m: 0.0589 - val_mape_m: 5.8924 - val_precision_m: 0.9592 - val_recall_m: 0.9538 - val_rmse_m: 0.1273
# Epoch 86/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9940 - f1_m: 0.9936 - loss: 0.3704 - mae_m: 0.0447 - mape_m: 4.4664 - precision_m: 0.9946 - recall_m: 0.9927 - rmse_m: 0.0654
# Epoch 86: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9940 - f1_m: 0.9936 - loss: 0.3704 - mae_m: 0.0447 - mape_m: 4.4663 - precision_m: 0.9947 - recall_m: 0.9927 - rmse_m: 0.0654 - val_accuracy: 0.9557 - val_f1_m: 0.9554 - val_loss: 0.4508 - val_mae_m: 0.0573 - val_mape_m: 5.7350 - val_precision_m: 0.9581 - val_recall_m: 0.9529 - val_rmse_m: 0.1269
# Epoch 87/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9959 - f1_m: 0.9959 - loss: 0.3672 - mae_m: 0.0434 - mape_m: 4.3406 - precision_m: 0.9967 - recall_m: 0.9952 - rmse_m: 0.0613
# Epoch 87: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9959 - f1_m: 0.9959 - loss: 0.3672 - mae_m: 0.0434 - mape_m: 4.3408 - precision_m: 0.9967 - recall_m: 0.9952 - rmse_m: 0.0613 - val_accuracy: 0.9560 - val_f1_m: 0.9558 - val_loss: 0.4543 - val_mae_m: 0.0569 - val_mape_m: 5.6928 - val_precision_m: 0.9587 - val_recall_m: 0.9530 - val_rmse_m: 0.1278
# Epoch 88/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9947 - f1_m: 0.9948 - loss: 0.3697 - mae_m: 0.0442 - mape_m: 4.4228 - precision_m: 0.9959 - recall_m: 0.9937 - rmse_m: 0.0641
# Epoch 88: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9947 - f1_m: 0.9948 - loss: 0.3697 - mae_m: 0.0442 - mape_m: 4.4233 - precision_m: 0.9959 - recall_m: 0.9937 - rmse_m: 0.0642 - val_accuracy: 0.9550 - val_f1_m: 0.9551 - val_loss: 0.4514 - val_mae_m: 0.0573 - val_mape_m: 5.7271 - val_precision_m: 0.9582 - val_recall_m: 0.9521 - val_rmse_m: 0.1268
# Epoch 89/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9958 - f1_m: 0.9958 - loss: 0.3667 - mae_m: 0.0433 - mape_m: 4.3296 - precision_m: 0.9966 - recall_m: 0.9950 - rmse_m: 0.0611
# Epoch 89: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9958 - f1_m: 0.9958 - loss: 0.3668 - mae_m: 0.0433 - mape_m: 4.3300 - precision_m: 0.9966 - recall_m: 0.9950 - rmse_m: 0.0611 - val_accuracy: 0.9532 - val_f1_m: 0.9534 - val_loss: 0.4558 - val_mae_m: 0.0582 - val_mape_m: 5.8227 - val_precision_m: 0.9556 - val_recall_m: 0.9514 - val_rmse_m: 0.1296
# Epoch 90/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9957 - f1_m: 0.9956 - loss: 0.3678 - mae_m: 0.0437 - mape_m: 4.3661 - precision_m: 0.9963 - recall_m: 0.9949 - rmse_m: 0.0624
# Epoch 90: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9957 - f1_m: 0.9956 - loss: 0.3678 - mae_m: 0.0437 - mape_m: 4.3661 - precision_m: 0.9963 - recall_m: 0.9949 - rmse_m: 0.0624 - val_accuracy: 0.9559 - val_f1_m: 0.9558 - val_loss: 0.4533 - val_mae_m: 0.0573 - val_mape_m: 5.7255 - val_precision_m: 0.9591 - val_recall_m: 0.9526 - val_rmse_m: 0.1268
# Epoch 91/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9941 - f1_m: 0.9940 - loss: 0.3701 - mae_m: 0.0444 - mape_m: 4.4402 - precision_m: 0.9951 - recall_m: 0.9931 - rmse_m: 0.0651
# Epoch 91: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9941 - f1_m: 0.9940 - loss: 0.3701 - mae_m: 0.0444 - mape_m: 4.4406 - precision_m: 0.9951 - recall_m: 0.9931 - rmse_m: 0.0651 - val_accuracy: 0.9546 - val_f1_m: 0.9550 - val_loss: 0.4539 - val_mae_m: 0.0567 - val_mape_m: 5.6670 - val_precision_m: 0.9576 - val_recall_m: 0.9524 - val_rmse_m: 0.1282
# Epoch 92/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9951 - f1_m: 0.9949 - loss: 0.3686 - mae_m: 0.0439 - mape_m: 4.3859 - precision_m: 0.9959 - recall_m: 0.9940 - rmse_m: 0.0634
# Epoch 92: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - accuracy: 0.9951 - f1_m: 0.9949 - loss: 0.3686 - mae_m: 0.0439 - mape_m: 4.3860 - precision_m: 0.9959 - recall_m: 0.9940 - rmse_m: 0.0634 - val_accuracy: 0.9589 - val_f1_m: 0.9586 - val_loss: 0.4502 - val_mae_m: 0.0560 - val_mape_m: 5.5964 - val_precision_m: 0.9607 - val_recall_m: 0.9566 - val_rmse_m: 0.1240
# Epoch 93/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9947 - f1_m: 0.9950 - loss: 0.3694 - mae_m: 0.0441 - mape_m: 4.4050 - precision_m: 0.9959 - recall_m: 0.9941 - rmse_m: 0.0636
# Epoch 93: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9947 - f1_m: 0.9950 - loss: 0.3694 - mae_m: 0.0441 - mape_m: 4.4052 - precision_m: 0.9959 - recall_m: 0.9941 - rmse_m: 0.0636 - val_accuracy: 0.9526 - val_f1_m: 0.9522 - val_loss: 0.4602 - val_mae_m: 0.0592 - val_mape_m: 5.9161 - val_precision_m: 0.9548 - val_recall_m: 0.9498 - val_rmse_m: 0.1328
# Epoch 94/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9933 - f1_m: 0.9931 - loss: 0.3714 - mae_m: 0.0447 - mape_m: 4.4738 - precision_m: 0.9939 - recall_m: 0.9923 - rmse_m: 0.0665
# Epoch 94: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9933 - f1_m: 0.9931 - loss: 0.3714 - mae_m: 0.0447 - mape_m: 4.4736 - precision_m: 0.9939 - recall_m: 0.9923 - rmse_m: 0.0665 - val_accuracy: 0.9556 - val_f1_m: 0.9558 - val_loss: 0.4563 - val_mae_m: 0.0577 - val_mape_m: 5.7688 - val_precision_m: 0.9585 - val_recall_m: 0.9532 - val_rmse_m: 0.1290
# Epoch 95/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9969 - f1_m: 0.9969 - loss: 0.3650 - mae_m: 0.0427 - mape_m: 4.2664 - precision_m: 0.9977 - recall_m: 0.9961 - rmse_m: 0.0586
# Epoch 95: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9968 - f1_m: 0.9969 - loss: 0.3650 - mae_m: 0.0427 - mape_m: 4.2666 - precision_m: 0.9977 - recall_m: 0.9961 - rmse_m: 0.0587 - val_accuracy: 0.9557 - val_f1_m: 0.9561 - val_loss: 0.4526 - val_mae_m: 0.0585 - val_mape_m: 5.8511 - val_precision_m: 0.9583 - val_recall_m: 0.9539 - val_rmse_m: 0.1279
# Epoch 96/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9967 - f1_m: 0.9965 - loss: 0.3651 - mae_m: 0.0428 - mape_m: 4.2776 - precision_m: 0.9974 - recall_m: 0.9956 - rmse_m: 0.0591
# Epoch 96: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - accuracy: 0.9967 - f1_m: 0.9965 - loss: 0.3651 - mae_m: 0.0428 - mape_m: 4.2779 - precision_m: 0.9974 - recall_m: 0.9956 - rmse_m: 0.0591 - val_accuracy: 0.9545 - val_f1_m: 0.9544 - val_loss: 0.4560 - val_mae_m: 0.0573 - val_mape_m: 5.7287 - val_precision_m: 0.9576 - val_recall_m: 0.9514 - val_rmse_m: 0.1285
# Epoch 97/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9932 - f1_m: 0.9930 - loss: 0.3720 - mae_m: 0.0449 - mape_m: 4.4887 - precision_m: 0.9941 - recall_m: 0.9919 - rmse_m: 0.0668
# Epoch 97: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.9932 - f1_m: 0.9930 - loss: 0.3720 - mae_m: 0.0449 - mape_m: 4.4885 - precision_m: 0.9941 - recall_m: 0.9920 - rmse_m: 0.0668 - val_accuracy: 0.9559 - val_f1_m: 0.9552 - val_loss: 0.4585 - val_mae_m: 0.0570 - val_mape_m: 5.6965 - val_precision_m: 0.9581 - val_recall_m: 0.9524 - val_rmse_m: 0.1289
# Epoch 98/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9944 - f1_m: 0.9942 - loss: 0.3691 - mae_m: 0.0440 - mape_m: 4.4029 - precision_m: 0.9952 - recall_m: 0.9933 - rmse_m: 0.0636
# Epoch 98: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9944 - f1_m: 0.9942 - loss: 0.3691 - mae_m: 0.0440 - mape_m: 4.4032 - precision_m: 0.9951 - recall_m: 0.9933 - rmse_m: 0.0636 - val_accuracy: 0.9531 - val_f1_m: 0.9535 - val_loss: 0.4573 - val_mae_m: 0.0573 - val_mape_m: 5.7271 - val_precision_m: 0.9562 - val_recall_m: 0.9509 - val_rmse_m: 0.1305
# Epoch 99/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9956 - f1_m: 0.9950 - loss: 0.3682 - mae_m: 0.0438 - mape_m: 4.3818 - precision_m: 0.9962 - recall_m: 0.9939 - rmse_m: 0.0627
# Epoch 99: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9956 - f1_m: 0.9950 - loss: 0.3682 - mae_m: 0.0438 - mape_m: 4.3819 - precision_m: 0.9962 - recall_m: 0.9939 - rmse_m: 0.0627 - val_accuracy: 0.9549 - val_f1_m: 0.9555 - val_loss: 0.4531 - val_mae_m: 0.0571 - val_mape_m: 5.7130 - val_precision_m: 0.9575 - val_recall_m: 0.9536 - val_rmse_m: 0.1287
# Epoch 100/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9956 - f1_m: 0.9954 - loss: 0.3673 - mae_m: 0.0434 - mape_m: 4.3433 - precision_m: 0.9964 - recall_m: 0.9944 - rmse_m: 0.0616
# Epoch 100: val_loss did not improve from 0.43994
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9956 - f1_m: 0.9954 - loss: 0.3673 - mae_m: 0.0434 - mape_m: 4.3433 - precision_m: 0.9964 - recall_m: 0.9944 - rmse_m: 0.0616 - val_accuracy: 0.9548 - val_f1_m: 0.9541 - val_loss: 0.4563 - val_mae_m: 0.0585 - val_mape_m: 5.8485 - val_precision_m: 0.9571 - val_recall_m: 0.9511 - val_rmse_m: 0.1301

# %%
# Evaluate the model
loss, accuracy, f1_score, precision, recall, mae, mape, rmse = model.evaluate(x_test_lstm, y_test, verbose=0)

# Print results
print(f"Validation Loss: {loss:.4f}")
print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Score: {f1_score:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
# Out:
# Validation Loss: 0.4468
# Accuracy: 0.9584
# F1 Score: 0.9579
# Precision: 0.9601
# Recall: 0.9559
# Mean Absolute Error (MAE): 0.0571
# Mean Absolute Percentage Error (MAPE): 5.7133
# Root Mean Squared Error (RMSE): 0.1254

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_actual_vs_predicted(model, x_test, y_test):
    # Predict
    y_pred_probs = model.predict(x_test, batch_size=64, verbose=1)
    y_pred = np.argmax(y_pred_probs, axis=1)
    y_true = np.argmax(y_test, axis=1)

    # Confirm correct number of samples
    print(f"Number of test samples: {len(y_true)}")
    print(f"Number of predictions: {len(y_pred)}")

    if len(y_true) != len(y_pred):
        print("Mismatch between test samples and predictions!")
        return

    # Classes
    classes = np.unique(y_true)
    print(f"Classes found in test set: {classes}")

    # True and Predicted counts
    true_counts = [np.sum(y_true == cls) for cls in classes]
    pred_counts = [np.sum(y_pred == cls) for cls in classes]

    # Correct predictions per class
    correct_counts = [np.sum((y_true == cls) & (y_pred == cls)) for cls in classes]

    # Per-class accuracy (percentage of correct predictions)
    class_accuracy = [
        (correct_counts[i] / true_counts[i]) * 100 if true_counts[i] != 0 else 0
        for i in range(len(classes))
    ]

    # Total accuracy
    total_correct = np.sum(y_true == y_pred)
    total_samples = len(y_true)
    total_accuracy = (total_correct / total_samples) * 100

    # Print per-class accuracy
    print("\nPer-Class Accuracy (Correct Predictions Percentage):")
    for i, acc in enumerate(class_accuracy):
        print(f"  Class {classes[i]}: {acc:.2f}%")
    print(f"\nTotal Test Accuracy: {total_accuracy:.2f}%")

    # Bar plot Actual vs Predicted
    x = np.arange(len(classes))
    width = 0.35

    fig, ax = plt.subplots(figsize=(10, 7))
    rects1 = ax.bar(x - width/2, true_counts, width, label='Actual Count', color='lightblue')
    rects2 = ax.bar(x + width/2, pred_counts, width, label='Predicted Count', color='salmon')

    ax.set_xlabel('Class Labels')
    ax.set_ylabel('Number of Samples')
    ax.set_title(f'Actual vs Predicted Samples (Total Accuracy: {total_accuracy:.2f}%)')
    ax.set_xticks(x)
    ax.set_xticklabels(classes)
    
    ax.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05),
              ncol=2, fancybox=True, shadow=True)


    # Annotate bar heights
    def autolabel(rects):
        for rect in rects:
            height = rect.get_height()
            ax.annotate(f'{int(height)}',
                        xy=(rect.get_x() + rect.get_width() / 2, height),
                        xytext=(0, 3),
                        textcoords="offset points",
                        ha='center', va='bottom')

    autolabel(rects1)
    autolabel(rects2)

    plt.tight_layout()
    plt.show()

# Example usage
plot_actual_vs_predicted(model, x_test_lstm, y_test)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# Number of test samples: 8000
# Number of predictions: 8000
# Classes found in test set: [0 1 2 3]
#
# Per-Class Accuracy (Correct Predictions Percentage):
#   Class 0: 95.52%
#   Class 1: 96.70%
#   Class 2: 96.36%
#   Class 3: 94.82%
#
# Total Test Accuracy: 95.84%

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, f1_score

def plot_precision_recall_f1(model, x_test, y_test):
    # Predict
    y_pred_probs = model.predict(x_test, batch_size=64, verbose=1)
    y_pred = np.argmax(y_pred_probs, axis=1)
    y_true = np.argmax(y_test, axis=1)

    # Confirm correct number of samples
    print(f"Number of test samples: {len(y_true)}")
    print(f"Number of predictions: {len(y_pred)}")

    if len(y_true) != len(y_pred):
        print("Mismatch between test samples and predictions!")
        return

    # Classes
    classes = np.unique(y_true)
    print(f"Classes found in test set: {classes}")

    # Calculate metrics per class
    precision = precision_score(y_true, y_pred, labels=classes, average=None)
    recall = recall_score(y_true, y_pred, labels=classes, average=None)
    f1 = f1_score(y_true, y_pred, labels=classes, average=None)

    # Print
    print("\nPer-Class Precision, Recall, F1-Score:")
    for idx, cls in enumerate(classes):
        print(f"Class {cls} -> Precision: {precision[idx]:.4f}, Recall: {recall[idx]:.4f}, F1-Score: {f1[idx]:.4f}")

    # Plot
    x = np.arange(len(classes))
    width = 0.25  # bar width

    fig, ax = plt.subplots(figsize=(12, 7))
    rects1 = ax.bar(x - width, precision, width, label='Precision', color='skyblue')
    rects2 = ax.bar(x, recall, width, label='Recall', color='lightgreen')
    rects3 = ax.bar(x + width, f1, width, label='F1-Score', color='salmon')

    ax.set_xlabel('Class Labels')
    ax.set_ylabel('Score')
    ax.set_title('Precision, Recall, F1-Score per Class')
    ax.set_xticks(x)
    ax.set_xticklabels(classes)
    ax.set_ylim(0, 1.05)
    ax.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05),
              ncol=3, fancybox=True, shadow=True)

    # Annotate bar heights
    def autolabel(rects):
        for rect in rects:
            height = rect.get_height()
            ax.annotate(f'{height:.2f}',
                        xy=(rect.get_x() + rect.get_width() / 2, height),
                        xytext=(0, 3),
                        textcoords="offset points",
                        ha='center', va='bottom')

    autolabel(rects1)
    autolabel(rects2)
    autolabel(rects3)

    plt.tight_layout()
    plt.show()

# Example usage
plot_precision_recall_f1(model, x_test_lstm, y_test)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# Number of test samples: 8000
# Number of predictions: 8000
# Classes found in test set: [0 1 2 3]
#
# Per-Class Precision, Recall, F1-Score:
# Class 0 -> Precision: 0.9417, Recall: 0.9552, F1-Score: 0.9484
# Class 1 -> Precision: 0.9680, Recall: 0.9670, F1-Score: 0.9675
# Class 2 -> Precision: 0.9622, Recall: 0.9636, F1-Score: 0.9629
# Class 3 -> Precision: 0.9624, Recall: 0.9482, F1-Score: 0.9552
