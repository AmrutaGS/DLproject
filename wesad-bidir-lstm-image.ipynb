# %%
# !pip install pyts
# Out:
# Collecting pyts
#   Downloading pyts-0.13.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.26.4)
# Requirement already satisfied: scipy>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.15.2)
# Requirement already satisfied: scikit-learn>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.4.2)
# Requirement already satisfied: numba>=0.55.2 in /usr/local/lib/python3.11/dist-packages (from pyts) (0.60.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.55.2->pyts) (0.43.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (2.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.2.0->pyts) (3.6.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.22.4->pyts) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.22.4->pyts) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.22.4->pyts) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.22.4->pyts) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.22.4->pyts) (2024.2.0)
# Downloading pyts-0.13.0-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 24.9 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pyts
# Successfully installed pyts-0.13.0

# %%
import os
import pickle
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from mpl_toolkits.axes_grid1 import ImageGrid
from pyts.image import GramianAngularField
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Conv2D, BatchNormalization, MaxPool2D, Flatten, Dense
from keras import backend as K
class ReadData:
    def __init__(self, path, subject):
        self.keys = ['label', 'subject', 'signal']
        self.signal_keys = ['wrist', 'chest']
        self.chest_sensor_keys = ['ACC', 'ECG', 'EDA', 'EMG', 'Resp', 'Temp']
        
        os.chdir(path)
        os.chdir(subject)
        with open(subject + '.pkl', 'rb') as file:
            data = pickle.load(file, encoding='latin1')
        self.data = data
        
    def get_labels(self):
        return self.data[self.keys[0]]
    def get_chest_data(self):
        return self.data[self.keys[2]][self.signal_keys[1]]

# %%
data_path = '/kaggle/input/tiles-05-05/WESAD'
subject = 'S17'
data_target = {subject: ReadData(data_path, subject)}
chest_data_dict = data_target[subject].get_chest_data()

acc_x = chest_data_dict['ACC'][:, 0]
acc_y = chest_data_dict['ACC'][:, 1]
acc_z = chest_data_dict['ACC'][:, 2]
emg_x = chest_data_dict['EMG'][:, 0]
eda_x = chest_data_dict['EDA'][:, 0]
ecg_x = chest_data_dict['ECG'][:, 0]
temp_x = chest_data_dict['Temp'][:, 0]
resp_x = chest_data_dict['Resp'][:, 0]
w_labels = data_target[subject].data['label']

# %%
def quantile_normalize(df):
    df_sorted = pd.DataFrame(np.sort(df.values, axis=0), index=df.index, columns=df.columns)
    df_mean = df_sorted.mean(axis=1)
    df_mean.index = np.arange(1, len(df_mean) + 1)
    df_qn = df.rank(method='min').stack().astype(int).map(df_mean).unstack()
    return df_qn
    
df_chest = pd.DataFrame({
    'ACC_X': acc_x,
    'ACC_Y': acc_y,
    'ACC_Z': acc_z,
    'EMG': emg_x,
    'EDA': eda_x,
    'ECG': ecg_x,
    'Temp': temp_x,
    'Resp': resp_x
})

df_chest['w_labels'] = w_labels  
if 'w_labels' in df_chest.columns:
    baseline_0 = df_chest[df_chest['w_labels'] == 0]  
    baseline = df_chest[df_chest['w_labels'] == 1]    
    stress = df_chest[df_chest['w_labels'] == 2]      
    amusement = df_chest[df_chest['w_labels'] == 3]   
else:
    raise KeyError("'w_labels' column not found in df_chest")

df_0 = baseline_0.tail(10000)
df_1 = baseline.tail(10000)
df_2 = stress.tail(10000)
df_3 = amusement.tail(10000)

df_chest = pd.concat([df_3, df_1, df_2, df_0], ignore_index=True)
print("before",df_chest.shape)
print("Before Normalization:")
print(df_chest.describe())

labels_wesad = df_chest.pop('w_labels').to_numpy()
df_chest = quantile_normalize(df_chest)
print("after",df_chest.shape)
print("After Normalization:")
print(df_chest.describe())
# Out:
# before (40000, 9)
# Before Normalization:
#               ACC_X         ACC_Y         ACC_Z           EMG           EDA  \
# count  40000.000000  40000.000000  40000.000000  40000.000000  40000.000000
# mean       0.693697     -0.003684     -0.516699     -0.004170      6.546550
# std        0.214727      0.052481      0.293308      0.016550      0.778822
# min        0.354600     -0.148600     -0.914400     -0.183975      5.482864
# 25%        0.523450     -0.047800     -0.810000     -0.012497      5.839729
# 50%        0.682000      0.006200     -0.519100     -0.003937      6.629562
# 75%        0.893000      0.043850     -0.210350      0.004257      7.321930
# max        1.257400      0.153400      0.082600      0.152618      7.411575
#
#                 ECG          Temp          Resp      w_labels
# count  40000.000000  40000.000000  40000.000000  40000.000000
# mean       0.000935     33.891136      0.004522      1.500000
# std        0.304003      0.409040      5.204628      1.118048
# min       -0.549454     33.435608    -17.668152      0.000000
# 25%       -0.116867     33.574677     -2.363586      0.750000
# 50%       -0.045273     33.764084     -0.367737      1.500000
# 75%        0.024582     34.114494      3.382874      2.250000
# max        1.499222     34.695465     12.091064      3.000000
# after (40000, 8)
# After Normalization:
#               ACC_X         ACC_Y         ACC_Z           EMG           EDA  \
# count  40000.000000  40000.000000  40000.000000  40000.000000  40000.000000
# mean       5.069479      5.070116      5.071703      5.074770      5.067471
# std        0.872955      0.868172      0.873510      0.867254      0.873757
# min        2.476061      2.476061      2.476061      2.476061      2.476061
# 25%        4.573369      4.521347      4.573388      4.516100      4.573388
# 50%        5.018225      4.916174      5.018225      4.919940      5.018225
# 75%        5.677986      5.694778      5.695512      5.678207      5.681315
# max        7.167918      7.167918      7.167918      7.167918      7.167918
#
#                 ECG          Temp          Resp
# count  40000.000000  40000.000000  40000.000000
# mean       5.076337      5.064553      5.076474
# std        0.867256      0.866327      0.867271
# min        2.476061      2.476061      2.476061
# 25%        4.525111      4.523536      4.522551
# 50%        4.922862      5.018090      4.924158
# 75%        5.679911      5.696830      5.680890
# max        7.141439      7.167918      7.167918

# %%
import tensorflow as tf
from tensorflow.keras import backend as K

def f1_m(y_true, y_pred):
    y_true = K.cast(y_true, dtype='float32')  
    y_pred = K.cast(y_pred, dtype='float32')  
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

def precision_m(y_true, y_pred):
    y_true = K.cast(y_true, dtype='float32')  
    y_pred = K.cast(y_pred, dtype='float32')  
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    return true_positives / (predicted_positives + K.epsilon())

def recall_m(y_true, y_pred):
    y_true = K.cast(y_true, dtype='float32')  
    y_pred = K.cast(y_pred, dtype='float32')  
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from pyts.image import GramianAngularField

gasf = GramianAngularField(method='summation')

X_train = df_chest.to_numpy()
X_train = gasf.fit_transform(X_train)

Y_train = labels_wesad.reshape(len(labels_wesad), 1)
X_train = X_train.reshape(X_train.shape[0], 8, 8, 1).astype('float32')
X_train /= np.amax(X_train)

Y_train = tf.keras.utils.to_categorical(Y_train, num_classes=4)

x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size=0.4, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, test_size=0.5, random_state=42)

print(f"x_train shape: {x_train.shape}, y_train shape: {y_train.shape}")
print(f"x_val shape: {x_val.shape}, y_val shape: {y_val.shape}")
print(f"x_test shape: {x_test.shape}, y_test shape: {y_test.shape}")

plt.imshow(x_train[0, :, :, 0], cmap='gray') 
plt.title(f"Class: {np.argmax(y_train[0])}")
plt.show()
# Out:
# x_train shape: (24000, 8, 8, 1), y_train shape: (24000, 4)
# x_val shape: (8000, 8, 8, 1), y_val shape: (8000, 4)
# x_test shape: (8000, 8, 8, 1), y_test shape: (8000, 4)

# %%
x_train_lstm = x_train.reshape(-1, 8, 8)
x_val_lstm = x_val.reshape(-1, 8, 8)
x_test_lstm = x_test.reshape(-1, 8, 8)

# %%
import tensorflow as tf
from tensorflow.keras import layers, regularizers, callbacks
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, BatchNormalization, Dense, Bidirectional
from tensorflow.keras.optimizers import Adam

def model_BiLSTM():
    model = Sequential()
    model.add(Bidirectional(LSTM(64, return_sequences=True, activation='tanh'), input_shape=(8,8)))
    model.add(BatchNormalization())
    model.add(Bidirectional(LSTM(64, return_sequences=True, activation='tanh')))
    model.add(BatchNormalization())
    model.add(Bidirectional(LSTM(64, activation='tanh')))
    model.add(BatchNormalization())
    model.add(Dense(6)) 
    model.add(Dense(4, activation='softmax'))  
    model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy', f1_m, precision_m, recall_m])
    return model

# %%
model=model_BiLSTM()
loss = tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1)

optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)

model.compile(
    optimizer=optimizer,
    loss=loss,
    metrics=['accuracy', f1_m, precision_m, recall_m] 
)
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ bidirectional_6 (Bidirectional)      │ (None, 8, 128)              │          37,376 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 8, 128)              │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_7 (Bidirectional)      │ (None, 8, 128)              │          98,816 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_7                │ (None, 8, 128)              │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_8 (Bidirectional)      │ (None, 128)                 │          98,816 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_8                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 6)                   │             774 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 4)                   │              28 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 237,346 (927.13 KB)
#  Trainable params: 236,578 (924.13 KB)
#  Non-trainable params: 768 (3.00 KB)

# %%
model_checkpoint = callbacks.ModelCheckpoint("/kaggle/working/best_model.keras", save_best_only=True, monitor='val_loss', verbose=1)
history = model.fit(x_train_lstm, y_train, batch_size=32, epochs=100, validation_data=(x_val_lstm, y_val),callbacks=[model_checkpoint])
# Out:
# Epoch 1/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7716 - f1_m: 0.7621 - loss: 0.8000 - precision_m: 0.8094 - recall_m: 0.7223
# Epoch 1: val_loss improved from inf to 0.56527, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.7718 - f1_m: 0.7624 - loss: 0.7995 - precision_m: 0.8097 - recall_m: 0.7226 - val_accuracy: 0.8875 - val_f1_m: 0.8836 - val_loss: 0.5653 - val_precision_m: 0.9052 - val_recall_m: 0.8636
# Epoch 2/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8963 - f1_m: 0.8938 - loss: 0.5549 - precision_m: 0.9170 - recall_m: 0.8725
# Epoch 2: val_loss improved from 0.56527 to 0.49964, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.8963 - f1_m: 0.8938 - loss: 0.5549 - precision_m: 0.9170 - recall_m: 0.8725 - val_accuracy: 0.9236 - val_f1_m: 0.9208 - val_loss: 0.4996 - val_precision_m: 0.9371 - val_recall_m: 0.9056
# Epoch 3/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9171 - f1_m: 0.9140 - loss: 0.5152 - precision_m: 0.9312 - recall_m: 0.8979
# Epoch 3: val_loss did not improve from 0.49964
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - accuracy: 0.9171 - f1_m: 0.9140 - loss: 0.5152 - precision_m: 0.9312 - recall_m: 0.8979 - val_accuracy: 0.9164 - val_f1_m: 0.9153 - val_loss: 0.5011 - val_precision_m: 0.9277 - val_recall_m: 0.9036
# Epoch 4/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9259 - f1_m: 0.9246 - loss: 0.4951 - precision_m: 0.9380 - recall_m: 0.9120
# Epoch 4: val_loss improved from 0.49964 to 0.47980, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9259 - f1_m: 0.9246 - loss: 0.4951 - precision_m: 0.9380 - recall_m: 0.9120 - val_accuracy: 0.9305 - val_f1_m: 0.9282 - val_loss: 0.4798 - val_precision_m: 0.9367 - val_recall_m: 0.9200
# Epoch 5/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9301 - f1_m: 0.9287 - loss: 0.4891 - precision_m: 0.9413 - recall_m: 0.9168
# Epoch 5: val_loss improved from 0.47980 to 0.47337, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9301 - f1_m: 0.9287 - loss: 0.4891 - precision_m: 0.9413 - recall_m: 0.9168 - val_accuracy: 0.9355 - val_f1_m: 0.9346 - val_loss: 0.4734 - val_precision_m: 0.9448 - val_recall_m: 0.9250
# Epoch 6/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9336 - f1_m: 0.9322 - loss: 0.4782 - precision_m: 0.9442 - recall_m: 0.9209
# Epoch 6: val_loss improved from 0.47337 to 0.47323, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - accuracy: 0.9336 - f1_m: 0.9322 - loss: 0.4782 - precision_m: 0.9442 - recall_m: 0.9209 - val_accuracy: 0.9359 - val_f1_m: 0.9352 - val_loss: 0.4732 - val_precision_m: 0.9435 - val_recall_m: 0.9274
# Epoch 7/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9404 - f1_m: 0.9394 - loss: 0.4666 - precision_m: 0.9493 - recall_m: 0.9299
# Epoch 7: val_loss improved from 0.47323 to 0.45895, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9404 - f1_m: 0.9394 - loss: 0.4666 - precision_m: 0.9493 - recall_m: 0.9299 - val_accuracy: 0.9425 - val_f1_m: 0.9422 - val_loss: 0.4590 - val_precision_m: 0.9506 - val_recall_m: 0.9341
# Epoch 8/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9491 - f1_m: 0.9480 - loss: 0.4558 - precision_m: 0.9564 - recall_m: 0.9400
# Epoch 8: val_loss did not improve from 0.45895
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9491 - f1_m: 0.9480 - loss: 0.4558 - precision_m: 0.9564 - recall_m: 0.9399 - val_accuracy: 0.9419 - val_f1_m: 0.9420 - val_loss: 0.4647 - val_precision_m: 0.9501 - val_recall_m: 0.9342
# Epoch 9/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9514 - f1_m: 0.9509 - loss: 0.4496 - precision_m: 0.9591 - recall_m: 0.9432
# Epoch 9: val_loss did not improve from 0.45895
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9514 - f1_m: 0.9509 - loss: 0.4496 - precision_m: 0.9591 - recall_m: 0.9432 - val_accuracy: 0.9410 - val_f1_m: 0.9407 - val_loss: 0.4596 - val_precision_m: 0.9462 - val_recall_m: 0.9354
# Epoch 10/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9530 - f1_m: 0.9526 - loss: 0.4474 - precision_m: 0.9600 - recall_m: 0.9455
# Epoch 10: val_loss improved from 0.45895 to 0.45554, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9530 - f1_m: 0.9526 - loss: 0.4474 - precision_m: 0.9600 - recall_m: 0.9455 - val_accuracy: 0.9441 - val_f1_m: 0.9444 - val_loss: 0.4555 - val_precision_m: 0.9506 - val_recall_m: 0.9385
# Epoch 11/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9573 - f1_m: 0.9563 - loss: 0.4407 - precision_m: 0.9633 - recall_m: 0.9495
# Epoch 11: val_loss improved from 0.45554 to 0.44553, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9573 - f1_m: 0.9563 - loss: 0.4407 - precision_m: 0.9633 - recall_m: 0.9495 - val_accuracy: 0.9516 - val_f1_m: 0.9507 - val_loss: 0.4455 - val_precision_m: 0.9576 - val_recall_m: 0.9441
# Epoch 12/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9596 - f1_m: 0.9594 - loss: 0.4339 - precision_m: 0.9652 - recall_m: 0.9538
# Epoch 12: val_loss did not improve from 0.44553
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9596 - f1_m: 0.9594 - loss: 0.4339 - precision_m: 0.9652 - recall_m: 0.9538 - val_accuracy: 0.9466 - val_f1_m: 0.9446 - val_loss: 0.4632 - val_precision_m: 0.9502 - val_recall_m: 0.9392
# Epoch 13/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9627 - f1_m: 0.9623 - loss: 0.4311 - precision_m: 0.9687 - recall_m: 0.9561
# Epoch 13: val_loss did not improve from 0.44553
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9627 - f1_m: 0.9623 - loss: 0.4311 - precision_m: 0.9687 - recall_m: 0.9561 - val_accuracy: 0.9499 - val_f1_m: 0.9498 - val_loss: 0.4466 - val_precision_m: 0.9560 - val_recall_m: 0.9439
# Epoch 14/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9656 - f1_m: 0.9660 - loss: 0.4247 - precision_m: 0.9714 - recall_m: 0.9608
# Epoch 14: val_loss did not improve from 0.44553
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9656 - f1_m: 0.9660 - loss: 0.4247 - precision_m: 0.9714 - recall_m: 0.9607 - val_accuracy: 0.9500 - val_f1_m: 0.9490 - val_loss: 0.4502 - val_precision_m: 0.9539 - val_recall_m: 0.9444
# Epoch 15/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9636 - f1_m: 0.9631 - loss: 0.4256 - precision_m: 0.9687 - recall_m: 0.9577
# Epoch 15: val_loss did not improve from 0.44553
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9636 - f1_m: 0.9631 - loss: 0.4256 - precision_m: 0.9687 - recall_m: 0.9577 - val_accuracy: 0.9521 - val_f1_m: 0.9533 - val_loss: 0.4461 - val_precision_m: 0.9592 - val_recall_m: 0.9476
# Epoch 16/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9688 - f1_m: 0.9685 - loss: 0.4200 - precision_m: 0.9732 - recall_m: 0.9640
# Epoch 16: val_loss improved from 0.44553 to 0.44245, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - accuracy: 0.9688 - f1_m: 0.9685 - loss: 0.4200 - precision_m: 0.9732 - recall_m: 0.9640 - val_accuracy: 0.9530 - val_f1_m: 0.9530 - val_loss: 0.4425 - val_precision_m: 0.9585 - val_recall_m: 0.9476
# Epoch 17/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9699 - f1_m: 0.9694 - loss: 0.4178 - precision_m: 0.9751 - recall_m: 0.9641
# Epoch 17: val_loss improved from 0.44245 to 0.44190, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9699 - f1_m: 0.9694 - loss: 0.4178 - precision_m: 0.9751 - recall_m: 0.9641 - val_accuracy: 0.9549 - val_f1_m: 0.9544 - val_loss: 0.4419 - val_precision_m: 0.9589 - val_recall_m: 0.9501
# Epoch 18/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9727 - f1_m: 0.9720 - loss: 0.4123 - precision_m: 0.9767 - recall_m: 0.9676
# Epoch 18: val_loss did not improve from 0.44190
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - accuracy: 0.9727 - f1_m: 0.9720 - loss: 0.4123 - precision_m: 0.9767 - recall_m: 0.9676 - val_accuracy: 0.9535 - val_f1_m: 0.9535 - val_loss: 0.4435 - val_precision_m: 0.9580 - val_recall_m: 0.9492
# Epoch 19/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9698 - f1_m: 0.9691 - loss: 0.4140 - precision_m: 0.9737 - recall_m: 0.9646
# Epoch 19: val_loss did not improve from 0.44190
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9698 - f1_m: 0.9691 - loss: 0.4140 - precision_m: 0.9737 - recall_m: 0.9646 - val_accuracy: 0.9545 - val_f1_m: 0.9544 - val_loss: 0.4430 - val_precision_m: 0.9594 - val_recall_m: 0.9496
# Epoch 20/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9761 - f1_m: 0.9759 - loss: 0.4067 - precision_m: 0.9803 - recall_m: 0.9717
# Epoch 20: val_loss did not improve from 0.44190
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - accuracy: 0.9761 - f1_m: 0.9759 - loss: 0.4068 - precision_m: 0.9803 - recall_m: 0.9717 - val_accuracy: 0.9544 - val_f1_m: 0.9534 - val_loss: 0.4461 - val_precision_m: 0.9591 - val_recall_m: 0.9479
# Epoch 21/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9772 - f1_m: 0.9764 - loss: 0.4050 - precision_m: 0.9802 - recall_m: 0.9728
# Epoch 21: val_loss did not improve from 0.44190
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - accuracy: 0.9772 - f1_m: 0.9764 - loss: 0.4050 - precision_m: 0.9802 - recall_m: 0.9728 - val_accuracy: 0.9535 - val_f1_m: 0.9536 - val_loss: 0.4446 - val_precision_m: 0.9592 - val_recall_m: 0.9482
# Epoch 22/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9870 - f1_m: 0.9865 - loss: 0.3872 - precision_m: 0.9894 - recall_m: 0.9836
# Epoch 31: val_loss did not improve from 0.43913
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9870 - f1_m: 0.9864 - loss: 0.3872 - precision_m: 0.9894 - recall_m: 0.9836 - val_accuracy: 0.9541 - val_f1_m: 0.9534 - val_loss: 0.4451 - val_precision_m: 0.9572 - val_recall_m: 0.9498
# Epoch 32/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9863 - f1_m: 0.9855 - loss: 0.3889 - precision_m: 0.9876 - recall_m: 0.9836
# Epoch 32: val_loss did not improve from 0.43913
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9863 - f1_m: 0.9855 - loss: 0.3889 - precision_m: 0.9876 - recall_m: 0.9836 - val_accuracy: 0.9585 - val_f1_m: 0.9578 - val_loss: 0.4422 - val_precision_m: 0.9620 - val_recall_m: 0.9538
# Epoch 33/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9865 - f1_m: 0.9863 - loss: 0.3866 - precision_m: 0.9884 - recall_m: 0.9843
# Epoch 33: val_loss did not improve from 0.43913
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9865 - f1_m: 0.9863 - loss: 0.3866 - precision_m: 0.9884 - recall_m: 0.9843 - val_accuracy: 0.9554 - val_f1_m: 0.9545 - val_loss: 0.4476 - val_precision_m: 0.9584 - val_recall_m: 0.9506
# Epoch 34/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9863 - f1_m: 0.9858 - loss: 0.3874 - precision_m: 0.9888 - recall_m: 0.9829
# Epoch 34: val_loss did not improve from 0.43913
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9863 - f1_m: 0.9858 - loss: 0.3874 - precision_m: 0.9888 - recall_m: 0.9829 - val_accuracy: 0.9576 - val_f1_m: 0.9566 - val_loss: 0.4397 - val_precision_m: 0.9601 - val_recall_m: 0.9532
# Epoch 35/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9900 - f1_m: 0.9898 - loss: 0.3820 - precision_m: 0.9920 - recall_m: 0.9877
# Epoch 35: val_loss did not improve from 0.43913
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9900 - f1_m: 0.9898 - loss: 0.3821 - precision_m: 0.9920 - recall_m: 0.9877 - val_accuracy: 0.9565 - val_f1_m: 0.9570 - val_loss: 0.4428 - val_precision_m: 0.9611 - val_recall_m: 0.9530
# Epoch 36/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9885 - f1_m: 0.9882 - loss: 0.3830 - precision_m: 0.9904 - recall_m: 0.9861
# Epoch 36: val_loss did not improve from 0.43913
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - accuracy: 0.9885 - f1_m: 0.9882 - loss: 0.3830 - precision_m: 0.9904 - recall_m: 0.9861 - val_accuracy: 0.9581 - val_f1_m: 0.9585 - val_loss: 0.4441 - val_precision_m: 0.9613 - val_recall_m: 0.9559
# Epoch 37/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9890 - f1_m: 0.9888 - loss: 0.3811 - precision_m: 0.9908 - recall_m: 0.9869
# Epoch 37: val_loss did not improve from 0.43913
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9890 - f1_m: 0.9888 - loss: 0.3811 - precision_m: 0.9908 - recall_m: 0.9869 - val_accuracy: 0.9575 - val_f1_m: 0.9574 - val_loss: 0.4432 - val_precision_m: 0.9617 - val_recall_m: 0.9532
# Epoch 38/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9907 - f1_m: 0.9905 - loss: 0.3797 - precision_m: 0.9925 - recall_m: 0.9885
# Epoch 38: val_loss did not improve from 0.43913
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9907 - f1_m: 0.9905 - loss: 0.3797 - precision_m: 0.9925 - recall_m: 0.9885 - val_accuracy: 0.9555 - val_f1_m: 0.9560 - val_loss: 0.4426 - val_precision_m: 0.9598 - val_recall_m: 0.9524
# Epoch 39/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9905 - f1_m: 0.9902 - loss: 0.3812 - precision_m: 0.9922 - recall_m: 0.9882
# Epoch 39: val_loss did not improve from 0.43913
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9905 - f1_m: 0.9902 - loss: 0.3812 - precision_m: 0.9922 - recall_m: 0.9882 - val_accuracy: 0.9566 - val_f1_m: 0.9566 - val_loss: 0.4420 - val_precision_m: 0.9606 - val_recall_m: 0.9529
# Epoch 40/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9898 - f1_m: 0.9898 - loss: 0.3818 - precision_m: 0.9917 - recall_m: 0.9880
# Epoch 40: val_loss did not improve from 0.43913
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - accuracy: 0.9898 - f1_m: 0.9898 - loss: 0.3818 - precision_m: 0.9917 - recall_m: 0.9880 - val_accuracy: 0.9589 - val_f1_m: 0.9585 - val_loss: 0.4434 - val_precision_m: 0.9622 - val_recall_m: 0.9549
# Epoch 41/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9910 - f1_m: 0.9908 - loss: 0.3790 - precision_m: 0.9924 - recall_m: 0.9892
# Epoch 41: val_loss did not improve from 0.43913
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9910 - f1_m: 0.9908 - loss: 0.3790 - precision_m: 0.9924 - recall_m: 0.9892 - val_accuracy: 0.9585 - val_f1_m: 0.9593 - val_loss: 0.4405 - val_precision_m: 0.9633 - val_recall_m: 0.9554
# Epoch 42/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9918 - f1_m: 0.9913 - loss: 0.3781 - precision_m: 0.9928 - recall_m: 0.9899
# Epoch 42: val_loss did not improve from 0.43913
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - accuracy: 0.9918 - f1_m: 0.9913 - loss: 0.3781 - precision_m: 0.9928 - recall_m: 0.9899 - val_accuracy: 0.9565 - val_f1_m: 0.9565 - val_loss: 0.4401 - val_precision_m: 0.9612 - val_recall_m: 0.9521
# Epoch 43/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9913 - f1_m: 0.9904 - loss: 0.3792 - precision_m: 0.9924 - recall_m: 0.9884
# Epoch 43: val_loss did not improve from 0.43913
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9913 - f1_m: 0.9904 - loss: 0.3792 - precision_m: 0.9924 - recall_m: 0.9884 - val_accuracy: 0.9551 - val_f1_m: 0.9554 - val_loss: 0.4465 - val_precision_m: 0.9581 - val_recall_m: 0.9528
# Epoch 44/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9931 - f1_m: 0.9930 - loss: 0.3749 - precision_m: 0.9947 - recall_m: 0.9913
# Epoch 44: val_loss did not improve from 0.43913
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - accuracy: 0.9931 - f1_m: 0.9930 - loss: 0.3749 - precision_m: 0.9947 - recall_m: 0.9913 - val_accuracy: 0.9571 - val_f1_m: 0.9566 - val_loss: 0.4454 - val_precision_m: 0.9605 - val_recall_m: 0.9530
# Epoch 45/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9918 - f1_m: 0.9918 - loss: 0.3777 - precision_m: 0.9933 - recall_m: 0.9903
# Epoch 45: val_loss did not improve from 0.43913
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9918 - f1_m: 0.9918 - loss: 0.3777 - precision_m: 0.9933 - recall_m: 0.9903 - val_accuracy: 0.9571 - val_f1_m: 0.9564 - val_loss: 0.4468 - val_precision_m: 0.9605 - val_recall_m: 0.9525
# Epoch 46/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9930 - f1_m: 0.9927 - loss: 0.3756 - precision_m: 0.9942 - recall_m: 0.9912
# Epoch 46: val_loss did not improve from 0.43913
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - accuracy: 0.9930 - f1_m: 0.9927 - loss: 0.3757 - precision_m: 0.9942 - recall_m: 0.9912 - val_accuracy: 0.9530 - val_f1_m: 0.9540 - val_loss: 0.4510 - val_precision_m: 0.9584 - val_recall_m: 0.9498
# Epoch 47/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9922 - f1_m: 0.9926 - loss: 0.3767 - precision_m: 0.9941 - recall_m: 0.9911
# Epoch 47: val_loss did not improve from 0.43913
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9922 - f1_m: 0.9926 - loss: 0.3767 - precision_m: 0.9941 - recall_m: 0.9911 - val_accuracy: 0.9553 - val_f1_m: 0.9546 - val_loss: 0.4479 - val_precision_m: 0.9586 - val_recall_m: 0.9507
# Epoch 48/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9945 - f1_m: 0.9941 - loss: 0.3713 - precision_m: 0.9951 - recall_m: 0.9931
# Epoch 54: val_loss did not improve from 0.43913
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9945 - f1_m: 0.9941 - loss: 0.3713 - precision_m: 0.9951 - recall_m: 0.9931 - val_accuracy: 0.9560 - val_f1_m: 0.9561 - val_loss: 0.4453 - val_precision_m: 0.9598 - val_recall_m: 0.9525
# Epoch 55/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9948 - f1_m: 0.9944 - loss: 0.3707 - precision_m: 0.9957 - recall_m: 0.9931
# Epoch 55: val_loss did not improve from 0.43913
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9948 - f1_m: 0.9944 - loss: 0.3707 - precision_m: 0.9957 - recall_m: 0.9931 - val_accuracy: 0.9557 - val_f1_m: 0.9557 - val_loss: 0.4496 - val_precision_m: 0.9595 - val_recall_m: 0.9521
# Epoch 56/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9959 - f1_m: 0.9958 - loss: 0.3695 - precision_m: 0.9968 - recall_m: 0.9948
# Epoch 56: val_loss did not improve from 0.43913
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9959 - f1_m: 0.9958 - loss: 0.3695 - precision_m: 0.9968 - recall_m: 0.9948 - val_accuracy: 0.9591 - val_f1_m: 0.9590 - val_loss: 0.4447 - val_precision_m: 0.9623 - val_recall_m: 0.9557
# Epoch 57/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9953 - f1_m: 0.9953 - loss: 0.3702 - precision_m: 0.9963 - recall_m: 0.9943
# Epoch 57: val_loss did not improve from 0.43913
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9953 - f1_m: 0.9953 - loss: 0.3702 - precision_m: 0.9963 - recall_m: 0.9943 - val_accuracy: 0.9594 - val_f1_m: 0.9593 - val_loss: 0.4399 - val_precision_m: 0.9631 - val_recall_m: 0.9557
# Epoch 58/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9952 - f1_m: 0.9952 - loss: 0.3701 - precision_m: 0.9961 - recall_m: 0.9944
# Epoch 64: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9952 - f1_m: 0.9952 - loss: 0.3701 - precision_m: 0.9961 - recall_m: 0.9944 - val_accuracy: 0.9595 - val_f1_m: 0.9599 - val_loss: 0.4413 - val_precision_m: 0.9631 - val_recall_m: 0.9569
# Epoch 65/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9949 - f1_m: 0.9946 - loss: 0.3702 - precision_m: 0.9958 - recall_m: 0.9934
# Epoch 65: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9949 - f1_m: 0.9946 - loss: 0.3702 - precision_m: 0.9958 - recall_m: 0.9934 - val_accuracy: 0.9561 - val_f1_m: 0.9561 - val_loss: 0.4469 - val_precision_m: 0.9595 - val_recall_m: 0.9529
# Epoch 66/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9968 - f1_m: 0.9967 - loss: 0.3670 - precision_m: 0.9973 - recall_m: 0.9962
# Epoch 66: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9968 - f1_m: 0.9967 - loss: 0.3670 - precision_m: 0.9973 - recall_m: 0.9962 - val_accuracy: 0.9606 - val_f1_m: 0.9607 - val_loss: 0.4418 - val_precision_m: 0.9641 - val_recall_m: 0.9574
# Epoch 67/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9954 - f1_m: 0.9955 - loss: 0.3695 - precision_m: 0.9963 - recall_m: 0.9946
# Epoch 67: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9954 - f1_m: 0.9955 - loss: 0.3695 - precision_m: 0.9963 - recall_m: 0.9946 - val_accuracy: 0.9601 - val_f1_m: 0.9596 - val_loss: 0.4420 - val_precision_m: 0.9629 - val_recall_m: 0.9564
# Epoch 68/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9976 - f1_m: 0.9975 - loss: 0.3646 - precision_m: 0.9982 - recall_m: 0.9967
# Epoch 68: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9976 - f1_m: 0.9975 - loss: 0.3646 - precision_m: 0.9982 - recall_m: 0.9967 - val_accuracy: 0.9584 - val_f1_m: 0.9587 - val_loss: 0.4453 - val_precision_m: 0.9621 - val_recall_m: 0.9555
# Epoch 69/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9970 - f1_m: 0.9967 - loss: 0.3663 - precision_m: 0.9978 - recall_m: 0.9957
# Epoch 69: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 19ms/step - accuracy: 0.9970 - f1_m: 0.9967 - loss: 0.3663 - precision_m: 0.9978 - recall_m: 0.9956 - val_accuracy: 0.9575 - val_f1_m: 0.9577 - val_loss: 0.4458 - val_precision_m: 0.9611 - val_recall_m: 0.9545
# Epoch 70/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9948 - f1_m: 0.9949 - loss: 0.3690 - precision_m: 0.9958 - recall_m: 0.9940
# Epoch 70: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9948 - f1_m: 0.9949 - loss: 0.3690 - precision_m: 0.9958 - recall_m: 0.9940 - val_accuracy: 0.9586 - val_f1_m: 0.9588 - val_loss: 0.4448 - val_precision_m: 0.9616 - val_recall_m: 0.9560
# Epoch 71/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9961 - f1_m: 0.9959 - loss: 0.3680 - precision_m: 0.9968 - recall_m: 0.9950
# Epoch 71: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9961 - f1_m: 0.9959 - loss: 0.3680 - precision_m: 0.9968 - recall_m: 0.9950 - val_accuracy: 0.9571 - val_f1_m: 0.9569 - val_loss: 0.4429 - val_precision_m: 0.9599 - val_recall_m: 0.9540
# Epoch 72/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9972 - f1_m: 0.9968 - loss: 0.3655 - precision_m: 0.9978 - recall_m: 0.9959
# Epoch 72: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9972 - f1_m: 0.9968 - loss: 0.3655 - precision_m: 0.9978 - recall_m: 0.9959 - val_accuracy: 0.9576 - val_f1_m: 0.9574 - val_loss: 0.4486 - val_precision_m: 0.9602 - val_recall_m: 0.9548
# Epoch 73/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9975 - f1_m: 0.9971 - loss: 0.3648 - precision_m: 0.9979 - recall_m: 0.9964
# Epoch 73: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9975 - f1_m: 0.9971 - loss: 0.3648 - precision_m: 0.9978 - recall_m: 0.9964 - val_accuracy: 0.9564 - val_f1_m: 0.9562 - val_loss: 0.4487 - val_precision_m: 0.9596 - val_recall_m: 0.9529
# Epoch 74/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9959 - f1_m: 0.9956 - loss: 0.3682 - precision_m: 0.9967 - recall_m: 0.9945
# Epoch 74: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9959 - f1_m: 0.9956 - loss: 0.3682 - precision_m: 0.9967 - recall_m: 0.9945 - val_accuracy: 0.9616 - val_f1_m: 0.9605 - val_loss: 0.4405 - val_precision_m: 0.9635 - val_recall_m: 0.9576
# Epoch 75/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9962 - f1_m: 0.9961 - loss: 0.3670 - precision_m: 0.9968 - recall_m: 0.9955
# Epoch 75: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9962 - f1_m: 0.9961 - loss: 0.3670 - precision_m: 0.9968 - recall_m: 0.9955 - val_accuracy: 0.9605 - val_f1_m: 0.9603 - val_loss: 0.4401 - val_precision_m: 0.9641 - val_recall_m: 0.9566
# Epoch 76/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9961 - f1_m: 0.9961 - loss: 0.3662 - precision_m: 0.9971 - recall_m: 0.9951
# Epoch 76: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9961 - f1_m: 0.9961 - loss: 0.3662 - precision_m: 0.9971 - recall_m: 0.9951 - val_accuracy: 0.9600 - val_f1_m: 0.9590 - val_loss: 0.4420 - val_precision_m: 0.9620 - val_recall_m: 0.9561
# Epoch 77/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9970 - f1_m: 0.9968 - loss: 0.3656 - precision_m: 0.9974 - recall_m: 0.9963
# Epoch 77: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9970 - f1_m: 0.9968 - loss: 0.3656 - precision_m: 0.9974 - recall_m: 0.9963 - val_accuracy: 0.9563 - val_f1_m: 0.9569 - val_loss: 0.4479 - val_precision_m: 0.9600 - val_recall_m: 0.9539
# Epoch 78/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9967 - f1_m: 0.9967 - loss: 0.3664 - precision_m: 0.9975 - recall_m: 0.9960
# Epoch 78: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9967 - f1_m: 0.9967 - loss: 0.3664 - precision_m: 0.9975 - recall_m: 0.9960 - val_accuracy: 0.9553 - val_f1_m: 0.9550 - val_loss: 0.4504 - val_precision_m: 0.9580 - val_recall_m: 0.9521
# Epoch 79/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9974 - f1_m: 0.9975 - loss: 0.3651 - precision_m: 0.9980 - recall_m: 0.9970
# Epoch 79: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9974 - f1_m: 0.9975 - loss: 0.3651 - precision_m: 0.9980 - recall_m: 0.9970 - val_accuracy: 0.9580 - val_f1_m: 0.9576 - val_loss: 0.4461 - val_precision_m: 0.9599 - val_recall_m: 0.9554
# Epoch 80/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9972 - f1_m: 0.9970 - loss: 0.3650 - precision_m: 0.9975 - recall_m: 0.9964
# Epoch 80: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9972 - f1_m: 0.9970 - loss: 0.3650 - precision_m: 0.9975 - recall_m: 0.9964 - val_accuracy: 0.9576 - val_f1_m: 0.9586 - val_loss: 0.4438 - val_precision_m: 0.9613 - val_recall_m: 0.9559
# Epoch 81/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9972 - f1_m: 0.9971 - loss: 0.3659 - precision_m: 0.9979 - recall_m: 0.9963
# Epoch 81: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9972 - f1_m: 0.9971 - loss: 0.3659 - precision_m: 0.9979 - recall_m: 0.9963 - val_accuracy: 0.9554 - val_f1_m: 0.9557 - val_loss: 0.4507 - val_precision_m: 0.9597 - val_recall_m: 0.9519
# Epoch 82/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9979 - f1_m: 0.9977 - loss: 0.3646 - precision_m: 0.9984 - recall_m: 0.9971
# Epoch 82: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9979 - f1_m: 0.9977 - loss: 0.3646 - precision_m: 0.9984 - recall_m: 0.9971 - val_accuracy: 0.9597 - val_f1_m: 0.9594 - val_loss: 0.4430 - val_precision_m: 0.9624 - val_recall_m: 0.9566
# Epoch 83/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9965 - f1_m: 0.9962 - loss: 0.3666 - precision_m: 0.9971 - recall_m: 0.9953
# Epoch 83: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9965 - f1_m: 0.9962 - loss: 0.3666 - precision_m: 0.9971 - recall_m: 0.9953 - val_accuracy: 0.9566 - val_f1_m: 0.9565 - val_loss: 0.4479 - val_precision_m: 0.9591 - val_recall_m: 0.9540
# Epoch 84/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9966 - f1_m: 0.9966 - loss: 0.3660 - precision_m: 0.9978 - recall_m: 0.9954
# Epoch 84: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9966 - f1_m: 0.9966 - loss: 0.3660 - precision_m: 0.9978 - recall_m: 0.9954 - val_accuracy: 0.9564 - val_f1_m: 0.9565 - val_loss: 0.4455 - val_precision_m: 0.9598 - val_recall_m: 0.9534
# Epoch 85/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9969 - f1_m: 0.9966 - loss: 0.3655 - precision_m: 0.9972 - recall_m: 0.9960
# Epoch 85: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9969 - f1_m: 0.9966 - loss: 0.3655 - precision_m: 0.9972 - recall_m: 0.9960 - val_accuracy: 0.9580 - val_f1_m: 0.9572 - val_loss: 0.4446 - val_precision_m: 0.9604 - val_recall_m: 0.9542
# Epoch 86/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9969 - f1_m: 0.9967 - loss: 0.3654 - precision_m: 0.9971 - recall_m: 0.9963
# Epoch 86: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9969 - f1_m: 0.9967 - loss: 0.3654 - precision_m: 0.9971 - recall_m: 0.9963 - val_accuracy: 0.9594 - val_f1_m: 0.9598 - val_loss: 0.4404 - val_precision_m: 0.9630 - val_recall_m: 0.9567
# Epoch 87/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9979 - f1_m: 0.9978 - loss: 0.3635 - precision_m: 0.9984 - recall_m: 0.9973
# Epoch 87: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9979 - f1_m: 0.9978 - loss: 0.3635 - precision_m: 0.9984 - recall_m: 0.9973 - val_accuracy: 0.9584 - val_f1_m: 0.9579 - val_loss: 0.4464 - val_precision_m: 0.9611 - val_recall_m: 0.9549
# Epoch 88/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9976 - f1_m: 0.9974 - loss: 0.3642 - precision_m: 0.9979 - recall_m: 0.9969
# Epoch 88: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9976 - f1_m: 0.9974 - loss: 0.3642 - precision_m: 0.9979 - recall_m: 0.9969 - val_accuracy: 0.9575 - val_f1_m: 0.9566 - val_loss: 0.4470 - val_precision_m: 0.9594 - val_recall_m: 0.9539
# Epoch 89/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9976 - f1_m: 0.9978 - loss: 0.3638 - precision_m: 0.9984 - recall_m: 0.9973
# Epoch 89: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9976 - f1_m: 0.9978 - loss: 0.3638 - precision_m: 0.9983 - recall_m: 0.9973 - val_accuracy: 0.9584 - val_f1_m: 0.9578 - val_loss: 0.4461 - val_precision_m: 0.9608 - val_recall_m: 0.9549
# Epoch 90/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9977 - f1_m: 0.9976 - loss: 0.3640 - precision_m: 0.9978 - recall_m: 0.9973
# Epoch 90: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9977 - f1_m: 0.9976 - loss: 0.3640 - precision_m: 0.9978 - recall_m: 0.9973 - val_accuracy: 0.9600 - val_f1_m: 0.9594 - val_loss: 0.4435 - val_precision_m: 0.9624 - val_recall_m: 0.9565
# Epoch 91/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9979 - f1_m: 0.9978 - loss: 0.3636 - precision_m: 0.9983 - recall_m: 0.9974
# Epoch 91: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9979 - f1_m: 0.9978 - loss: 0.3636 - precision_m: 0.9983 - recall_m: 0.9974 - val_accuracy: 0.9588 - val_f1_m: 0.9590 - val_loss: 0.4400 - val_precision_m: 0.9621 - val_recall_m: 0.9560
# Epoch 92/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9971 - f1_m: 0.9971 - loss: 0.3644 - precision_m: 0.9977 - recall_m: 0.9966
# Epoch 92: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9971 - f1_m: 0.9971 - loss: 0.3644 - precision_m: 0.9977 - recall_m: 0.9966 - val_accuracy: 0.9576 - val_f1_m: 0.9570 - val_loss: 0.4462 - val_precision_m: 0.9607 - val_recall_m: 0.9534
# Epoch 93/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9983 - f1_m: 0.9981 - loss: 0.3628 - precision_m: 0.9988 - recall_m: 0.9974
# Epoch 93: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9983 - f1_m: 0.9981 - loss: 0.3628 - precision_m: 0.9988 - recall_m: 0.9974 - val_accuracy: 0.9582 - val_f1_m: 0.9576 - val_loss: 0.4477 - val_precision_m: 0.9605 - val_recall_m: 0.9549
# Epoch 94/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9975 - f1_m: 0.9973 - loss: 0.3644 - precision_m: 0.9979 - recall_m: 0.9968
# Epoch 94: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9975 - f1_m: 0.9973 - loss: 0.3644 - precision_m: 0.9979 - recall_m: 0.9968 - val_accuracy: 0.9565 - val_f1_m: 0.9561 - val_loss: 0.4498 - val_precision_m: 0.9594 - val_recall_m: 0.9529
# Epoch 95/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9984 - f1_m: 0.9983 - loss: 0.3631 - precision_m: 0.9989 - recall_m: 0.9978
# Epoch 95: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9984 - f1_m: 0.9983 - loss: 0.3631 - precision_m: 0.9989 - recall_m: 0.9978 - val_accuracy: 0.9560 - val_f1_m: 0.9559 - val_loss: 0.4524 - val_precision_m: 0.9592 - val_recall_m: 0.9528
# Epoch 96/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9968 - f1_m: 0.9965 - loss: 0.3650 - precision_m: 0.9972 - recall_m: 0.9958
# Epoch 96: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - accuracy: 0.9968 - f1_m: 0.9965 - loss: 0.3650 - precision_m: 0.9972 - recall_m: 0.9958 - val_accuracy: 0.9564 - val_f1_m: 0.9566 - val_loss: 0.4508 - val_precision_m: 0.9595 - val_recall_m: 0.9538
# Epoch 97/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9971 - f1_m: 0.9972 - loss: 0.3639 - precision_m: 0.9978 - recall_m: 0.9966
# Epoch 97: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9971 - f1_m: 0.9972 - loss: 0.3639 - precision_m: 0.9978 - recall_m: 0.9966 - val_accuracy: 0.9589 - val_f1_m: 0.9586 - val_loss: 0.4453 - val_precision_m: 0.9620 - val_recall_m: 0.9554
# Epoch 98/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9983 - f1_m: 0.9984 - loss: 0.3619 - precision_m: 0.9987 - recall_m: 0.9982
# Epoch 98: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9983 - f1_m: 0.9984 - loss: 0.3619 - precision_m: 0.9987 - recall_m: 0.9982 - val_accuracy: 0.9548 - val_f1_m: 0.9553 - val_loss: 0.4515 - val_precision_m: 0.9591 - val_recall_m: 0.9516
# Epoch 99/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9968 - f1_m: 0.9965 - loss: 0.3664 - precision_m: 0.9975 - recall_m: 0.9955
# Epoch 99: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9968 - f1_m: 0.9965 - loss: 0.3664 - precision_m: 0.9975 - recall_m: 0.9955 - val_accuracy: 0.9572 - val_f1_m: 0.9578 - val_loss: 0.4486 - val_precision_m: 0.9608 - val_recall_m: 0.9549
# Epoch 100/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9974 - f1_m: 0.9975 - loss: 0.3633 - precision_m: 0.9981 - recall_m: 0.9970
# Epoch 100: val_loss did not improve from 0.43892
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9974 - f1_m: 0.9975 - loss: 0.3633 - precision_m: 0.9981 - recall_m: 0.9970 - val_accuracy: 0.9571 - val_f1_m: 0.9573 - val_loss: 0.4467 - val_precision_m: 0.9611 - val_recall_m: 0.9538

# %%
loss, accuracy, f1_score, precision, recall = model.evaluate(x_test_lstm, y_test, verbose=0)
print(f"Validation Loss: {loss}")
print(f"Accuracy: {accuracy}")
print(f"F1 Score: {f1_score}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
# Out:
# Validation Loss: 0.44826769828796387
# Accuracy: 0.9589999914169312
# F1 Score: 0.959255039691925
# Precision: 0.9625145792961121
# Recall: 0.956125020980835

# %% [markdown]
# **Visualizations**

# %%
import matplotlib.pyplot as plt

def plot_accuracy_loss(history):
    fig, axs = plt.subplots(1, 2, figsize=(12, 4))

    axs[0].plot(history.history['accuracy'], label='Train Accuracy')
    axs[0].plot(history.history['val_accuracy'], label='Validation Accuracy')
    axs[0].set_title('Model Accuracy')
    axs[0].set_xlabel('Epochs')
    axs[0].set_ylabel('Accuracy')
    axs[0].legend()

    axs[1].plot(history.history['loss'], label='Train Loss')
    axs[1].plot(history.history['val_loss'], label='Validation Loss')
    axs[1].set_title('Model Loss')
    axs[1].set_xlabel('Epochs')
    axs[1].set_ylabel('Loss')
    axs[1].legend()

    plt.show()

plot_accuracy_loss(history)

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
import numpy as np

def plot_confusion_matrix(model, x_test, y_test):
    y_pred = np.argmax(model.predict(x_test), axis=1)
    y_true = np.argmax(y_test, axis=1)

    cm = confusion_matrix(y_true, y_pred)
    class_names = [f'Class {i}' for i in range(y_test.shape[1])]
    
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names,
                yticklabels=class_names)
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.show()

plot_confusion_matrix(model, x_test_lstm, y_test)
# Out:
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step

# %%
from sklearn.metrics import roc_curve, auc, roc_auc_score
from itertools import cycle
import matplotlib.pyplot as plt

def plot_roc_curve(model, x_test, y_test):
    y_pred = model.predict(x_test)
    n_classes = y_test.shape[1]

    fpr, tpr, roc_auc = {}, {}, {}
    plt.figure(figsize=(8, 6))
    colors = cycle(['blue', 'red', 'green', 'purple', 'orange'])

    for i, color in zip(range(n_classes), colors):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
        plt.plot(fpr[i], tpr[i], color=color, lw=2,
                 label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

    fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_pred.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
    plt.plot(fpr["micro"], tpr["micro"],
             label=f'Micro-average ROC (AUC = {roc_auc["micro"]:.2f})',
             color='black', linestyle='--', linewidth=2)

    plt.plot([0, 1], [0, 1], 'k--', lw=1)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Multi-class ROC Curve')
    plt.legend(loc="lower right")
    plt.tight_layout()
    plt.show()
plot_roc_curve(model, x_test_lstm, y_test)
# Out:
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
def permutation_importance_gaf_lstm(model, X, y_true, feature_names, base_score_fn=accuracy_score):
    """
    Computes permutation importance for GAF input of shape (N, 8, 8) — for LSTM input.
    Each original feature is encoded as a GAF image row/column.
    """
    base_preds = np.argmax(model.predict(X), axis=1)
    if len(y_true.shape) > 1:
        y_true = np.argmax(y_true, axis=1)

    base_score = base_score_fn(y_true, base_preds)
    feature_importance = []

    for i in range(8):  # Loop through each feature (i-th row and column)
        X_permuted = np.copy(X)

        for j in range(X.shape[0]):
            row_perm = np.random.permutation(8)
            col_perm = np.random.permutation(8)

            # Permute only the i-th row and column
            X_permuted[j, i, :] = X[j, i, col_perm]  # Shuffle row i
            X_permuted[j, :, i] = X[j, row_perm, i]  # Shuffle column i

        preds = np.argmax(model.predict(X_permuted), axis=1)
        score = base_score_fn(y_true, preds)
        importance = base_score - score
        feature_importance.append(importance)

    return feature_importance
feature_names = ["ACC_X", "ACC_Y", "ACC_Z", "EMG", "EDA", "ECG", "Temp", "Resp"]
importances = permutation_importance_gaf_lstm(model, x_test_lstm, y_test, feature_names)

# Normalize and plot
importances = np.array(importances)
importances /= importances.max()

plt.figure(figsize=(10, 5))
plt.bar(range(8), importances, color='teal')
plt.xticks(range(8), feature_names, rotation=45)
plt.ylabel("Feature Importance")
plt.title("Permutation Feature Importance (LSTM Input: GAF)")
plt.tight_layout()
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()
# Out:
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
