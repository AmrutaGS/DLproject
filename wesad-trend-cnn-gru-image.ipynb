# %%
# !pip install pyts
# Out:
# Collecting pyts
#   Downloading pyts-0.13.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.26.4)
# Requirement already satisfied: scipy>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.15.2)
# Requirement already satisfied: scikit-learn>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.4.2)
# Requirement already satisfied: numba>=0.55.2 in /usr/local/lib/python3.11/dist-packages (from pyts) (0.60.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.55.2->pyts) (0.43.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (2.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.2.0->pyts) (3.6.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.22.4->pyts) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.22.4->pyts) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.22.4->pyts) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.22.4->pyts) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.22.4->pyts) (2024.2.0)
# Downloading pyts-0.13.0-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 46.1 MB/s eta 0:00:0000:01
# Installing collected packages: pyts
# Successfully installed pyts-0.13.0

# %%
import os
import pickle
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from mpl_toolkits.axes_grid1 import ImageGrid
from pyts.image import GramianAngularField
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Conv2D, BatchNormalization, MaxPool2D, Flatten, Dense
from keras import backend as K

class ReadData:
    def __init__(self, path, subject): 
        self.keys = ['label', 'subject', 'signal']
        self.signal_keys = ['wrist', 'chest']
        self.chest_sensor_keys = ['ACC', 'ECG', 'EDA', 'EMG', 'Resp', 'Temp']
        
        os.chdir(path) 
        os.chdir(subject)  
        
        with open(subject + '.pkl', 'rb') as file:
            data = pickle.load(file, encoding='latin1') 
            
        self.data = data 
            
    def get_labels(self):
        return self.data[self.keys[0]] 
    
    def get_chest_data(self):
        return self.data[self.keys[2]][self.signal_keys[1]] 

data_path = '/kaggle/input/tiles-05-05/WESAD'
subject = 'S17'
data_target = {subject: ReadData(data_path, subject)}
chest_data_dict = data_target[subject].get_chest_data()

# Extract chest sensor signals
acc_x = chest_data_dict['ACC'][:, 0]
acc_y = chest_data_dict['ACC'][:, 1]
acc_z = chest_data_dict['ACC'][:, 2]
emg_x = chest_data_dict['EMG'][:, 0]
eda_x = chest_data_dict['EDA'][:, 0]
ecg_x = chest_data_dict['ECG'][:, 0]
temp_x = chest_data_dict['Temp'][:, 0]
resp_x = chest_data_dict['Resp'][:, 0]
w_labels = data_target[subject].data['label']

# %%
def quantile_normalize(df):
    df_sorted = pd.DataFrame(np.sort(df.values, axis=0), index=df.index, columns=df.columns)
    df_mean = df_sorted.mean(axis=1)
    df_mean.index = np.arange(1, len(df_mean) + 1)
    df_qn = df.rank(method='min').stack().astype(int).map(df_mean).unstack()
    return df_qn
    
df_chest = pd.DataFrame({
    'ACC_X': acc_x,
    'ACC_Y': acc_y,
    'ACC_Z': acc_z,
    'EMG': emg_x,
    'EDA': eda_x,
    'ECG': ecg_x,
    'Temp': temp_x,
    'Resp': resp_x
})
df_chest['w_labels'] = w_labels 

if 'w_labels' in df_chest.columns:
    baseline_0 = df_chest[df_chest['w_labels'] == 0]  
    baseline = df_chest[df_chest['w_labels'] == 1]    
    stress = df_chest[df_chest['w_labels'] == 2]      
    amusement = df_chest[df_chest['w_labels'] == 3]   
else:
    raise KeyError("'w_labels' column not found in df_chest")
df_0 = baseline_0.tail(10000)
df_1 = baseline.tail(10000)
df_2 = stress.tail(10000)
df_3 = amusement.tail(10000)


df_chest = pd.concat([df_3, df_1, df_2, df_0], ignore_index=True)
print("before",df_chest.shape)
print("Before Normalization:")
print(df_chest.describe())

labels_wesad = df_chest.pop('w_labels').to_numpy()
df_chest = quantile_normalize(df_chest)
print("after",df_chest.shape)
print("After Normalization:")
print(df_chest.describe())
# Out:
# before (40000, 9)
# Before Normalization:
#               ACC_X         ACC_Y         ACC_Z           EMG           EDA  \
# count  40000.000000  40000.000000  40000.000000  40000.000000  40000.000000
# mean       0.693697     -0.003684     -0.516699     -0.004170      6.546550
# std        0.214727      0.052481      0.293308      0.016550      0.778822
# min        0.354600     -0.148600     -0.914400     -0.183975      5.482864
# 25%        0.523450     -0.047800     -0.810000     -0.012497      5.839729
# 50%        0.682000      0.006200     -0.519100     -0.003937      6.629562
# 75%        0.893000      0.043850     -0.210350      0.004257      7.321930
# max        1.257400      0.153400      0.082600      0.152618      7.411575
#
#                 ECG          Temp          Resp      w_labels
# count  40000.000000  40000.000000  40000.000000  40000.000000
# mean       0.000935     33.891136      0.004522      1.500000
# std        0.304003      0.409040      5.204628      1.118048
# min       -0.549454     33.435608    -17.668152      0.000000
# 25%       -0.116867     33.574677     -2.363586      0.750000
# 50%       -0.045273     33.764084     -0.367737      1.500000
# 75%        0.024582     34.114494      3.382874      2.250000
# max        1.499222     34.695465     12.091064      3.000000
# after (40000, 8)
# After Normalization:
#               ACC_X         ACC_Y         ACC_Z           EMG           EDA  \
# count  40000.000000  40000.000000  40000.000000  40000.000000  40000.000000
# mean       5.069479      5.070116      5.071703      5.074770      5.067471
# std        0.872955      0.868172      0.873510      0.867254      0.873757
# min        2.476061      2.476061      2.476061      2.476061      2.476061
# 25%        4.573369      4.521347      4.573388      4.516100      4.573388
# 50%        5.018225      4.916174      5.018225      4.919940      5.018225
# 75%        5.677986      5.694778      5.695512      5.678207      5.681315
# max        7.167918      7.167918      7.167918      7.167918      7.167918
#
#                 ECG          Temp          Resp
# count  40000.000000  40000.000000  40000.000000
# mean       5.076337      5.064553      5.076474
# std        0.867256      0.866327      0.867271
# min        2.476061      2.476061      2.476061
# 25%        4.525111      4.523536      4.522551
# 50%        4.922862      5.018090      4.924158
# 75%        5.679911      5.696830      5.680890
# max        7.141439      7.167918      7.167918

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from pyts.image import GramianAngularField

gasf = GramianAngularField(method='summation')

X_train = df_chest.to_numpy()
X_train = gasf.fit_transform(X_train)

Y_train = labels_wesad.reshape(len(labels_wesad), 1)
X_train = X_train.reshape(X_train.shape[0], 8, 8, 1).astype('float32')
X_train /= np.amax(X_train)

Y_train = tf.keras.utils.to_categorical(Y_train, num_classes=4)

x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size=0.4, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, test_size=0.5, random_state=42)

print(f"x_train shape: {x_train.shape}, y_train shape: {y_train.shape}")
print(f"x_val shape: {x_val.shape}, y_val shape: {y_val.shape}")
print(f"x_test shape: {x_test.shape}, y_test shape: {y_test.shape}")
# Out:
# x_train shape: (24000, 8, 8, 1), y_train shape: (24000, 4)
# x_val shape: (8000, 8, 8, 1), y_val shape: (8000, 4)
# x_test shape: (8000, 8, 8, 1), y_test shape: (8000, 4)

# %%
import tensorflow as tf
from tensorflow.keras import backend as K

# Mean Absolute Error (MAE)
def mae_m(y_true, y_pred):
    y_true = K.cast(y_true, dtype='float32')  
    y_pred = K.cast(y_pred, dtype='float32')  
    return K.mean(K.abs(y_true - y_pred))

def mape_m(y_true, y_pred):
    y_true = K.cast(y_true, dtype='float32')
    y_pred = K.cast(y_pred, dtype='float32')
    diff = K.abs(y_true - y_pred)
    denom = K.maximum(K.abs(y_true), 1.0)  # Use 1.0 instead of tiny epsilon
    return 100.0 * K.mean(diff / denom)

# Root Mean Squared Error (RMSE)
def rmse_m(y_true, y_pred):
    y_true = K.cast(y_true, dtype='float32')
    y_pred = K.cast(y_pred, dtype='float32')
    return K.sqrt(K.mean(K.square(y_true - y_pred)))

# %%
import tensorflow as tf
from tensorflow.keras import backend as K
# Define custom metrics
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    return true_positives / (predicted_positives + K.epsilon())

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Conv2D, BatchNormalization, MaxPooling2D, Flatten,
                                     Dense, Dropout, Reshape, GRU, GlobalAveragePooling2D)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

def cnn_gru_for_gaf():
    input_layer = Input(shape=(8, 8, 1)) 
    
    # CNN Block
    x = Conv2D(32, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001))(input_layer)
    x = BatchNormalization()(x)
    
    x = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    
    x = MaxPooling2D(pool_size=(2, 2))(x)  # Output: (4, 4, 64)
    x = Reshape((4, 4 * 64))(x)  
    
    # GRU Block
    x = GRU(64, return_sequences=False)(x)
    x = Dropout(0.3)(x)

    # Dense Layers
    x = Dense(64, activation='relu')(x)
    x = Dropout(0.2)(x)
    
    output = Dense(4, activation='softmax')(x)
    model = Model(inputs=input_layer, outputs=output)
    
    model.compile(optimizer=Adam(learning_rate=0.0005),
                  loss='categorical_crossentropy',
                  metrics=['accuracy', f1_m, precision_m, recall_m,mae_m, mape_m, rmse_m])
    
    return model

model_cnn_gru = cnn_gru_for_gaf()
model_cnn_gru.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)           │ (None, 8, 8, 1)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 8, 8, 32)            │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 8, 8, 32)            │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 8, 8, 64)            │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 8, 8, 64)            │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 4, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape_2 (Reshape)                  │ (None, 4, 256)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru_2 (GRU)                          │ (None, 64)                  │          61,824 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 4)                   │             260 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 85,444 (333.77 KB)
#  Trainable params: 85,252 (333.02 KB)
#  Non-trainable params: 192 (768.00 B)

# %%
from tensorflow.keras import callbacks
reduce_lr = callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=3, min_lr=1e-5, verbose=1
)

checkpoint = callbacks.ModelCheckpoint(
    "/kaggle/working/wesad_best_model.keras", save_best_only=True,
    monitor='val_loss', verbose=1
)
history = model_cnn_gru.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    epochs=100,
    batch_size=32,
    shuffle=True,
    callbacks=[checkpoint, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7401 - f1_m: 0.6952 - loss: 0.6906 - mae_m: 0.1849 - mape_m: 18.4899 - precision_m: 0.7921 - recall_m: 0.6461 - rmse_m: 0.2876
# Epoch 1: val_loss improved from inf to 0.29730, saving model to /kaggle/working/wesad_best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - accuracy: 0.7405 - f1_m: 0.6958 - loss: 0.6895 - mae_m: 0.1846 - mape_m: 18.4601 - precision_m: 0.7925 - recall_m: 0.6468 - rmse_m: 0.2874 - val_accuracy: 0.9021 - val_f1_m: 0.9007 - val_loss: 0.2973 - val_mae_m: 0.0755 - val_mape_m: 7.5540 - val_precision_m: 0.9123 - val_recall_m: 0.8898 - val_rmse_m: 0.1849 - learning_rate: 5.0000e-04
# Epoch 2/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8973 - f1_m: 0.8966 - loss: 0.3214 - mae_m: 0.0775 - mape_m: 7.7478 - precision_m: 0.9065 - recall_m: 0.8872 - rmse_m: 0.1910
# Epoch 2: val_loss improved from 0.29730 to 0.26285, saving model to /kaggle/working/wesad_best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.8973 - f1_m: 0.8966 - loss: 0.3214 - mae_m: 0.0775 - mape_m: 7.7474 - precision_m: 0.9065 - recall_m: 0.8872 - rmse_m: 0.1910 - val_accuracy: 0.9115 - val_f1_m: 0.9105 - val_loss: 0.2629 - val_mae_m: 0.0635 - val_mape_m: 6.3529 - val_precision_m: 0.9172 - val_recall_m: 0.9040 - val_rmse_m: 0.1728 - learning_rate: 5.0000e-04
# Epoch 3/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9126 - f1_m: 0.9126 - loss: 0.2723 - mae_m: 0.0641 - mape_m: 6.4059 - precision_m: 0.9201 - recall_m: 0.9054 - rmse_m: 0.1732
# Epoch 3: val_loss did not improve from 0.26285
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9126 - f1_m: 0.9126 - loss: 0.2723 - mae_m: 0.0641 - mape_m: 6.4057 - precision_m: 0.9201 - recall_m: 0.9054 - rmse_m: 0.1732 - val_accuracy: 0.9137 - val_f1_m: 0.9141 - val_loss: 0.2735 - val_mae_m: 0.0580 - val_mape_m: 5.8014 - val_precision_m: 0.9192 - val_recall_m: 0.9091 - val_rmse_m: 0.1736 - learning_rate: 5.0000e-04
# Epoch 4/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9189 - f1_m: 0.9182 - loss: 0.2469 - mae_m: 0.0575 - mape_m: 5.7461 - precision_m: 0.9235 - recall_m: 0.9131 - rmse_m: 0.1650
# Epoch 4: val_loss improved from 0.26285 to 0.21522, saving model to /kaggle/working/wesad_best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.
val_loss did not improve from 0.17402
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9843 - f1_m: 0.9842 - loss: 0.0668 - mae_m: 0.0127 - mape_m: 1.2686 - precision_m: 0.9845 - recall_m: 0.9839 - rmse_m: 0.0633 - val_accuracy: 0.9519 - val_f1_m: 0.9520 - val_loss: 0.1959 - val_mae_m: 0.0272 - val_mape_m: 2.7183 - val_precision_m: 0.9523 - val_recall_m: 0.9516 - val_rmse_m: 0.1261 - learning_rate: 1.0000e-05
# Epoch 75/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9837 - f1_m: 0.9838 - loss: 0.0648 - mae_m: 0.0125 - mape_m: 1.2501 - precision_m: 0.9841 - recall_m: 0.9836 - rmse_m: 0.0627
# Epoch 75: val_loss did not improve from 0.17402
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9837 - f1_m: 0.9838 - loss: 0.0648 - mae_m: 0.0125 - mape_m: 1.2501 - precision_m: 0.9841 - recall_m: 0.9836 - rmse_m: 0.0627 - val_accuracy: 0.9521 - val_f1_m: 0.9522 - val_loss: 0.1975 - val_mae_m: 0.0272 - val_mape_m: 2.7186 - val_precision_m: 0.9528 - val_recall_m: 0.9516 - val_rmse_m: 0.1263 - learning_rate: 1.0000e-05
# Epoch 76/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9851 - f1_m: 0.9850 - loss: 0.0645 - mae_m: 0.0123 - mape_m: 1.2329 - precision_m: 0.9853 - recall_m: 0.9848 - rmse_m: 0.0628
# Epoch 76: val_loss did not improve from 0.17402
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9851 - f1_m: 0.9850 - loss: 0.0645 - mae_m: 0.0123 - mape_m: 1.2330 - precision_m: 0.9853 - recall_m: 0.9848 - rmse_m: 0.0628 - val_accuracy: 0.9515 - val_f1_m: 0.9515 - val_loss: 0.1978 - val_mae_m: 0.0272 - val_mape_m: 2.7169 - val_precision_m: 0.9520 - val_recall_m: 0.9510 - val_rmse_m: 0.1264 - learning_rate: 1.0000e-05
# Epoch 77/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9851 - f1_m: 0.9851 - loss: 0.0641 - mae_m: 0.0122 - mape_m: 1.2198 - precision_m: 0.9853 - recall_m: 0.9848 - rmse_m: 0.0607
# Epoch 77: val_loss did not improve from 0.17402
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9851 - f1_m: 0.9851 - loss: 0.0641 - mae_m: 0.0122 - mape_m: 1.2200 - precision_m: 0.9853 - recall_m: 0.9848 - rmse_m: 0.0607 - val_accuracy: 0.9513 - val_f1_m: 0.9515 - val_loss: 0.1985 - val_mae_m: 0.0271 - val_mape_m: 2.7066 - val_precision_m: 0.9520 - val_recall_m: 0.9510 - val_rmse_m: 0.1263 - learning_rate: 1.0000e-05
# Epoch 78/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9856 - f1_m: 0.9856 - loss: 0.0634 - mae_m: 0.0120 - mape_m: 1.2014 - precision_m: 0.9858 - recall_m: 0.9853 - rmse_m: 0.0599
# Epoch 78: val_loss did not improve from 0.17402
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 12s 15ms/step - accuracy: 0.9856 - f1_m: 0.9856 - loss: 0.0634 - mae_m: 0.0120 - mape_m: 1.2015 - precision_m: 0.9858 - recall_m: 0.9853 - rmse_m: 0.0599 - val_accuracy: 0.9510 - val_f1_m: 0.9513 - val_loss: 0.1991 - val_mae_m: 0.0271 - val_mape_m: 2.7091 - val_precision_m: 0.9518 - val_recall_m: 0.9509 - val_rmse_m: 0.1266 - learning_rate: 1.0000e-05
# Epoch 79/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9855 - f1_m: 0.9855 - loss: 0.0633 - mae_m: 0.0121 - mape_m: 1.2080 - precision_m: 0.9856 - recall_m: 0.9854 - rmse_m: 0.0619
# Epoch 79: val_loss did not improve from 0.17402
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.
100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9864 - f1_m: 0.9865 - loss: 0.0619 - mae_m: 0.0117 - mape_m: 1.1660 - precision_m: 0.9867 - recall_m: 0.9863 - rmse_m: 0.0602
# Epoch 84: val_loss did not improve from 0.17402
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9864 - f1_m: 0.9865 - loss: 0.0619 - mae_m: 0.0117 - mape_m: 1.1662 - precision_m: 0.9867 - recall_m: 0.9863 - rmse_m: 0.0602 - val_accuracy: 0.9511 - val_f1_m: 0.9514 - val_loss: 0.2013 - val_mae_m: 0.0270 - val_mape_m: 2.7046 - val_precision_m: 0.9519 - val_recall_m: 0.9509 - val_rmse_m: 0.1268 - learning_rate: 1.0000e-05
# Epoch 85/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9864 - f1_m: 0.9863 - loss: 0.0602 - mae_m: 0.0116 - mape_m: 1.1550 - precision_m: 0.9866 - recall_m: 0.9860 - rmse_m: 0.0574
# Epoch 85: val_loss did not improve from 0.17402
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9864 - f1_m: 0.9863 - loss: 0.0602 - mae_m: 0.0116 - mape_m: 1.1551 - precision_m: 0.9866 - recall_m: 0.9860 - rmse_m: 0.0574 - val_accuracy: 0.9520 - val_f1_m: 0.9520 - val_loss: 0.2013 - val_mae_m: 0.0270 - val_mape_m: 2.7015 - val_precision_m: 0.9523 - val_recall_m: 0.9516 - val_rmse_m: 0.1265 - learning_rate: 1.0000e-05
# Epoch 86/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9849 - f1_m: 0.9849 - loss: 0.0639 - mae_m: 0.0122 - mape_m: 1.2221 - precision_m: 0.9852 - recall_m: 0.9846 - rmse_m: 0.0612
# Epoch 86: val_loss did not improve from 0.17402
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9849 - f1_m: 0.9849 - loss: 0.0639 - mae_m: 0.0122 - mape_m: 1.2221 - precision_m: 0.9852 - recall_m: 0.9846 - rmse_m: 0.0612 - val_accuracy: 0.9507 - val_f1_m: 0.9511 - val_loss: 0.2040 - val_mae_m: 0.0270 - val_mape_m: 2.7014 - val_precision_m: 0.9516 - val_recall_m: 0.9506 - val_rmse_m: 0.1272 - learning_rate: 1.0000e-05
# Epoch 87/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9859 - f1_m: 0.9859 - loss: 0.0615 - mae_m: 0.0116 - mape_m: 1.1559 - precision_m: 0.9861 - recall_m: 0.9858 - rmse_m: 0.0593
# Epoch 87: val_loss did not improve from 0.17402
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9859 - f1_m: 0.9859 - loss: 0.0615 - mae_m: 0.0116 - mape_m: 1.1560 - precision_m: 0.9861 - recall_m: 0.9858 - rmse_m: 0.0593 - val_accuracy: 0.9520 - val_f1_m: 0.9521 - val_loss: 0.2016 - val_mae_m: 0.0269 - val_mape_m: 2.6897 - val_precision_m: 0.9526 - val_recall_m: 0.9516 - val_rmse_m: 0.1263 - learning_rate: 1.0000e-05
# Epoch 88/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9850 - f1_m: 0.9851 - loss: 0.0614 - mae_m: 0.0116 - mape_m: 1.1580 - precision_m: 0.9854 - recall_m: 0.9848 - rmse_m: 0.0598
# Epoch 88: val_loss did not improve from 0.17402
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9850 - f1_m: 0.9851 - loss: 0.0614 - mae_m: 0.0116 - mape_m: 1.1580 - precision_m: 0.9854 - recall_m: 0.9848 - rmse_m: 0.0598 - val_accuracy: 0.9509 - val_f1_m: 0.9510 - val_loss: 0.2029 - val_mae_m: 0.0269 - val_mape_m: 2.6860 - val_precision_m: 0.9515 - val_recall_m: 0.9506 - val_rmse_m: 0.1266 - learning_rate: 1.0000e-05
# Epoch 89/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9849 - f1_m: 0.9849 - loss: 0.0609 - mae_m: 0.0118 - mape_m: 1.1773 - precision_m: 0.9852 - recall_m: 0.9846 - rmse_m: 0.0594
# Epoch 89: val_loss did not improve from 0.17402
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9849 - f1_m: 0.9849 - loss: 0.0609 - mae_m: 0.0118 - mape_m: 1.1773 - precision_m: 0.9852 - recall_m: 0.9846 - rmse_m: 0.0594 - val_accuracy: 0.9519 - val_f1_m: 0.9520 - val_loss: 0.2032 - val_mae_m: 0.0268 - val_mape_m: 2.6804 - val_precision_m: 0.9526 - val_recall_m: 0.9515 - val_rmse_m: 0.1265 - learning_rate: 1.0000e-05
# Epoch 90/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9857 - f1_m: 0.9857 - loss: 0.0615 - mae_m: 0.0117 - mape_m: 1.1715 - precision_m: 0.9859 - recall_m: 0.9855 - rmse_m: 0.0597
# Epoch 90: val_loss did not improve from 0.17402
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9857 - f1_m: 0.9857 - loss: 0.0615 - mae_m: 0.0117 - mape_m: 1.1716 - precision_m: 0.9859 - recall_m: 0.9855 - rmse_m: 0.0597 - val_accuracy: 0.9509 - val_f1_m: 0.9509 - val_loss: 0.2064 - val_mae_m: 0.0267 - val_mape_m: 2.6719 - val_precision_m: 0.9513 - val_recall_m: 0.9505 - val_rmse_m: 0.1266 - learning_rate: 1.0000e-05
# Epoch 91/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9846 - f1_m: 0.9847 - loss: 0.0623 - mae_m: 0.0117 - mape_m: 1.1732 - precision_m: 0.9849 - recall_m: 0.9844 - rmse_m: 0.0604
# Epoch 91: val_loss did not improve from 0.17402
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9846 - f1_m: 0.9847 - loss: 0.0623 - mae_m: 0.0117 - mape_m: 1.1732 - precision_m: 0.9849 - recall_m: 0.9844 - rmse_m: 0.0604 - val_accuracy: 0.9514 - val_f1_m: 0.9514 - val_loss: 0.2043 - val_mae_m: 0.0268 - val_mape_m: 2.6756 - val_precision_m: 0.9516 - val_recall_m: 0.9513 - val_rmse_m: 0.1266 - learning_rate: 1.0000e-05
# Epoch 92/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9844 - f1_m: 0.9844 - loss: 0.0642 - mae_m: 0.0119 - mape_m: 1.1943 - precision_m: 0.9845 - recall_m: 0.9843 - rmse_m: 0.0612
# Epoch 92: val_loss did not improve from 0.17402
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9844 - f1_m: 0.9844 - loss: 0.0642 - mae_m: 0.0119 - mape_m: 1.1943 - precision_m: 0.9845 - recall_m: 0.9843 - rmse_m: 0.0612 - val_accuracy: 0.9514 - val_f1_m: 0.9515 - val_loss: 0.2058 - val_mae_m: 0.0268 - val_mape_m: 2.6818 - val_precision_m: 0.9517 - val_recall_m: 0.9513 - val_rmse_m: 0.1268 - learning_rate: 1.0000e-05
# Epoch 93/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9849 - f1_m: 0.9849 - loss: 0.0607 - mae_m: 0.0113 - mape_m: 1.1275 - precision_m: 0.9850 - recall_m: 0.9847 - rmse_m: 0.0588
# Epoch 93: val_loss did not improve from 0.17402
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9849 - f1_m: 0.9849 - loss: 0.0607 - mae_m: 0.0113 - mape_m: 1.1278 - precision_m: 0.9850 - recall_m: 0.9847 - rmse_m: 0.0589 - val_accuracy: 0.9509 - val_f1_m: 0.9510 - val_loss: 0.2060 - val_mae_m: 0.0270 - val_mape_m: 2.6983 - val_precision_m: 0.9513 - val_recall_m: 0.9506 - val_rmse_m: 0.1274 - learning_rate: 1.0000e-05
# Epoch 94/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9849 - f1_m: 0.9849 - loss: 0.0616 - mae_m: 0.0116 - mape_m: 1.1603 - precision_m: 0.9852 - recall_m: 0.9847 - rmse_m: 0.0595
# Epoch 94: val_loss did not improve from 0.17402
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9849 - f1_m: 0.9849 - loss: 0.0617 - mae_m: 0.0116 - mape_m: 1.1603 - precision_m: 0.9852 - recall_m: 0.9847 - rmse_m: 0.0595 - val_accuracy: 0.9516 - val_f1_m: 0.9517 - val_loss: 0.2053 - val_mae_m: 0.0270 - val_mape_m: 2.6980 - val_precision_m: 0.9521 - val_recall_m: 0.9514 - val_rmse_m: 0.1274 - learning_rate: 1.0000e-05
# Epoch 95/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9871 - f1_m: 0.9872 - loss: 0.0593 - mae_m: 0.0110 - mape_m: 1.1002 - precision_m: 0.9874 - recall_m: 0.9869 - rmse_m: 0.0564
# Epoch 95: val_loss did not improve from 0.17402
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9871 - f1_m: 0.9872 - loss: 0.0593 - mae_m: 0.0110 - mape_m: 1.1002 - precision_m: 0.9874 - recall_m: 0.9869 - rmse_m: 0.0564 - val_accuracy: 0.9509 - val_f1_m: 0.9508 - val_loss: 0.2077 - val_mae_m: 0.0267 - val_mape_m: 2.6665 - val_precision_m: 0.9513 - val_recall_m: 0.9504 - val_rmse_m: 0.1269 - learning_rate: 1.0000e-05
# Epoch 96/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9862 - f1_m: 0.9862 - loss: 0.0611 - mae_m: 0.0112 - mape_m: 1.1242 - precision_m: 0.9865 - recall_m: 0.9860 - rmse_m: 0.0578
# Epoch 96: val_loss did not improve from 0.17402
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - accuracy: 0.9862 - f1_m: 0.9862 - loss: 0.0611 - mae_m: 0.0112 - mape_m: 1.1243 - precision_m: 0.9865 - recall_m: 0.9860 - rmse_m: 0.0578 - val_accuracy: 0.9517 - val_f1_m: 0.9520 - val_loss: 0.2062 - val_mae_m: 0.0267 - val_mape_m: 2.6676 - val_precision_m: 0.9524 - val_recall_m: 0.9515 - val_rmse_m: 0.1265 - learning_rate: 1.0000e-05
# Epoch 97/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9873 - f1_m: 0.9872 - loss: 0.0585 - mae_m: 0.0111 - mape_m: 1.1096 - precision_m: 0.9875 - recall_m: 0.9869 - rmse_m: 0.0568
# Epoch 97: val_loss did not improve from 0.17402
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9873 - f1_m: 0.9872 - loss: 0.0585 - mae_m: 0.0111 - mape_m: 1.1097 - precision_m: 0.9875 - recall_m: 0.9869 - rmse_m: 0.0568 - val_accuracy: 0.9514 - val_f1_m: 0.9514 - val_loss: 0.2068 - val_mae_m: 0.0267 - val_mape_m: 2.6729 - val_precision_m: 0.9517 - val_recall_m: 0.9511 - val_rmse_m: 0.1268 - learning_rate: 1.0000e-05
# Epoch 98/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9866 - f1_m: 0.9867 - loss: 0.0583 - mae_m: 0.0108 - mape_m: 1.0844 - precision_m: 0.9868 - recall_m: 0.9865 - rmse_m: 0.0575
# Epoch 98: val_loss did not improve from 0.17402
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9866 - f1_m: 0.9867 - loss: 0.0583 - mae_m: 0.0108 - mape_m: 1.0846 - precision_m: 0.9868 - recall_m: 0.9865 - rmse_m: 0.0575 - val_accuracy: 0.9509 - val_f1_m: 0.9507 - val_loss: 0.2076 - val_mae_m: 0.0267 - val_mape_m: 2.6654 - val_precision_m: 0.9511 - val_recall_m: 0.9503 - val_rmse_m: 0.1267 - learning_rate: 1.0000e-05
# Epoch 99/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9864 - f1_m: 0.9866 - loss: 0.0574 - mae_m: 0.0108 - mape_m: 1.0756 - precision_m: 0.9869 - recall_m: 0.9863 - rmse_m: 0.0560
# Epoch 99: val_loss did not improve from 0.17402
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - accuracy: 0.9864 - f1_m: 0.9866 - loss: 0.0574 - mae_m: 0.0108 - mape_m: 1.0757 - precision_m: 0.9869 - recall_m: 0.9863 - rmse_m: 0.0560 - val_accuracy: 0.9513 - val_f1_m: 0.9514 - val_loss: 0.2088 - val_mae_m: 0.0265 - val_mape_m: 2.6512 - val_precision_m: 0.9518 - val_recall_m: 0.9510 - val_rmse_m: 0.1262 - learning_rate: 1.0000e-05
# Epoch 100/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9873 - f1_m: 0.9873 - loss: 0.0580 - mae_m: 0.0105 - mape_m: 1.0464 - precision_m: 0.9875 - recall_m: 0.9871 - rmse_m: 0.0548
# Epoch 100: val_loss did not improve from 0.17402
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - accuracy: 0.9873 - f1_m: 0.9873 - loss: 0.0580 - mae_m: 0.0105 - mape_m: 1.0465 - precision_m: 0.9875 - recall_m: 0.9871 - rmse_m: 0.0548 - val_accuracy: 0.9505 - val_f1_m: 0.9506 - val_loss: 0.2077 - val_mae_m: 0.0267 - val_mape_m: 2.6652 - val_precision_m: 0.9509 - val_recall_m: 0.9504 - val_rmse_m: 0.1265 - learning_rate: 1.0000e-05

# %%
loss, accuracy, f1_score, precision, recall, mae, mape, rmse = model_cnn_gru.evaluate(x_test, y_test, verbose=0)

# Print results
print(f"Validation Loss: {loss:.4f}")
print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Score: {f1_score:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
# Out:
# Validation Loss: 0.1895
# Accuracy: 0.9545
# F1 Score: 0.9548
# Precision: 0.9553
# Recall: 0.9542
# Mean Absolute Error (MAE): 0.0249
# Mean Absolute Percentage Error (MAPE): 2.4921
# Root Mean Squared Error (RMSE): 0.1206

# %% [markdown]
# **Visualizations**

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_actual_vs_predicted(model, x_test, y_test):
    # Predict
    y_pred_probs = model.predict(x_test, batch_size=64, verbose=1)
    y_pred = np.argmax(y_pred_probs, axis=1)
    y_true = np.argmax(y_test, axis=1)

    # Confirm correct number of samples
    print(f"Number of test samples: {len(y_true)}")
    print(f"Number of predictions: {len(y_pred)}")

    if len(y_true) != len(y_pred):
        print("Mismatch between test samples and predictions!")
        return

    # Classes
    classes = np.unique(y_true)
    print(f"Classes found in test set: {classes}")

    # True and Predicted counts
    true_counts = [np.sum(y_true == cls) for cls in classes]
    pred_counts = [np.sum(y_pred == cls) for cls in classes]

    # Correct predictions per class
    correct_counts = [np.sum((y_true == cls) & (y_pred == cls)) for cls in classes]

    # Per-class accuracy (percentage of correct predictions)
    class_accuracy = [
        (correct_counts[i] / true_counts[i]) * 100 if true_counts[i] != 0 else 0
        for i in range(len(classes))]
    # Total accuracy
    total_correct = np.sum(y_true == y_pred)
    total_samples = len(y_true)
    total_accuracy = (total_correct / total_samples) * 100

    # Print per-class accuracy
    print("\nPer-Class Accuracy (Correct Predictions Percentage):")
    for i, acc in enumerate(class_accuracy):
        print(f"  Class {classes[i]}: {acc:.2f}%")
    print(f"\nTotal Test Accuracy: {total_accuracy:.2f}%")

    # Bar plot Actual vs Predicted
    x = np.arange(len(classes))
    width = 0.35

    fig, ax = plt.subplots(figsize=(10, 7))
    rects1 = ax.bar(x - width/2, true_counts, width, label='Actual Count', color='lightblue')
    rects2 = ax.bar(x + width/2, pred_counts, width, label='Predicted Count', color='salmon')

    ax.set_xlabel('Class Labels')
    ax.set_ylabel('Number of Samples')
    ax.set_title(f'Actual vs Predicted Samples (Total Accuracy: {total_accuracy:.2f}%)')
    ax.set_xticks(x)
    ax.set_xticklabels(classes)
    
    ax.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05),
              ncol=2, fancybox=True, shadow=True)
    # Annotate bar heights
    def autolabel(rects):
        for rect in rects:
            height = rect.get_height()
            ax.annotate(f'{int(height)}',
                        xy=(rect.get_x() + rect.get_width() / 2, height),
                        xytext=(0, 3),
                        textcoords="offset points",
                        ha='center', va='bottom')

    autolabel(rects1)
    autolabel(rects2)

    plt.tight_layout()
    plt.show()

# Example usage
plot_actual_vs_predicted(model_cnn_gru,x_test, y_test)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# Number of test samples: 8000
# Number of predictions: 8000
# Classes found in test set: [0 1 2 3]
#
# Per-Class Accuracy (Correct Predictions Percentage):
#   Class 0: 95.08%
#   Class 1: 96.23%
#   Class 2: 96.06%
#   Class 3: 94.47%
#
# Total Test Accuracy: 95.45%

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, f1_score

def plot_precision_recall_f1(model, x_test, y_test):
    # Predict
    y_pred_probs = model.predict(x_test, batch_size=64, verbose=1)
    y_pred = np.argmax(y_pred_probs, axis=1)
    y_true = np.argmax(y_test, axis=1)

    # Confirm correct number of samples
    print(f"Number of test samples: {len(y_true)}")
    print(f"Number of predictions: {len(y_pred)}")

    if len(y_true) != len(y_pred):
        print("Mismatch between test samples and predictions!")
        return

    # Classes
    classes = np.unique(y_true)
    print(f"Classes found in test set: {classes}")

    # Calculate metrics per class
    precision = precision_score(y_true, y_pred, labels=classes, average=None)
    recall = recall_score(y_true, y_pred, labels=classes, average=None)
    f1 = f1_score(y_true, y_pred, labels=classes, average=None)    # Print
    print("\nPer-Class Precision, Recall, F1-Score:")
    for idx, cls in enumerate(classes):
        print(f"Class {cls} -> Precision: {precision[idx]:.4f}, Recall: {recall[idx]:.4f}, F1-Score: {f1[idx]:.4f}")
    # Plot
    x = np.arange(len(classes))
    width = 0.25  # bar width

    fig, ax = plt.subplots(figsize=(12, 7))
    rects1 = ax.bar(x - width, precision, width, label='Precision', color='skyblue')
    rects2 = ax.bar(x, recall, width, label='Recall', color='lightgreen')
    rects3 = ax.bar(x + width, f1, width, label='F1-Score', color='salmon')

    ax.set_xlabel('Class Labels')
    ax.set_ylabel('Score')
    ax.set_title('Precision, Recall, F1-Score per Class')
    ax.set_xticks(x)
    ax.set_xticklabels(classes)
    ax.set_ylim(0, 1.05)
    ax.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05),
              ncol=3, fancybox=True, shadow=True)    # Annotate bar heights
    def autolabel(rects):
        for rect in rects:
            height = rect.get_height()
            ax.annotate(f'{height:.2f}',
                        xy=(rect.get_x() + rect.get_width() / 2, height),
                        xytext=(0, 3),
                        textcoords="offset points",
                        ha='center', va='bottom')
    autolabel(rects1)
    autolabel(rects2)
    autolabel(rects3)

    plt.tight_layout()
    plt.show()

# Example usage
plot_precision_recall_f1(model_cnn_gru,x_test,y_test)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# Number of test samples: 8000
# Number of predictions: 8000
# Classes found in test set: [0 1 2 3]
#
# Per-Class Precision, Recall, F1-Score:
# Class 0 -> Precision: 0.9392, Recall: 0.9508, F1-Score: 0.9449
# Class 1 -> Precision: 0.9698, Recall: 0.9623, F1-Score: 0.9661
# Class 2 -> Precision: 0.9578, Recall: 0.9606, F1-Score: 0.9592
# Class 3 -> Precision: 0.9522, Recall: 0.9447, F1-Score: 0.9485
