# %%
# !pip install pyts
# Out:
# Collecting pyts
#   Downloading pyts-0.13.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.26.4)
# Requirement already satisfied: scipy>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.15.2)
# Requirement already satisfied: scikit-learn>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.4.2)
# Requirement already satisfied: numba>=0.55.2 in /usr/local/lib/python3.11/dist-packages (from pyts) (0.60.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.55.2->pyts) (0.43.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (2.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.2.0->pyts) (3.6.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.22.4->pyts) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.22.4->pyts) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.22.4->pyts) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.22.4->pyts) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.22.4->pyts) (2024.2.0)
# Downloading pyts-0.13.0-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 44.1 MB/s eta 0:00:0000:01
# Installing collected packages: pyts
# Successfully installed pyts-0.13.0

# %%
import os
import pickle
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from mpl_toolkits.axes_grid1 import ImageGrid
from pyts.image import GramianAngularField
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from keras.models import Sequential
from keras.layers import Conv2D, BatchNormalization, MaxPool2D, Flatten, Dense
from keras import backend as K
class ReadData:
    def __init__(self, path, subject):
        self.keys = ['label', 'subject', 'signal']
        self.signal_keys = ['wrist', 'chest']
        self.chest_sensor_keys = ['ACC', 'ECG', 'EDA', 'EMG', 'Resp', 'Temp']
        
        os.chdir(path)
        os.chdir(subject)
        with open(subject + '.pkl', 'rb') as file:
            data = pickle.load(file, encoding='latin1')
        self.data = data
        
    def get_labels(self):
        return self.data[self.keys[0]]
    def get_chest_data(self):
        return self.data[self.keys[2]][self.signal_keys[1]]

# %%
data_path = '/kaggle/input/tiles-05-05/WESAD'
subject = 'S17'
data_target = {subject: ReadData(data_path, subject)}
chest_data_dict = data_target[subject].get_chest_data()

acc_x = chest_data_dict['ACC'][:, 0]
acc_y = chest_data_dict['ACC'][:, 1]
acc_z = chest_data_dict['ACC'][:, 2]
emg_x = chest_data_dict['EMG'][:, 0]
eda_x = chest_data_dict['EDA'][:, 0]
ecg_x = chest_data_dict['ECG'][:, 0]
temp_x = chest_data_dict['Temp'][:, 0]
resp_x = chest_data_dict['Resp'][:, 0]
w_labels = data_target[subject].data['label']

# %%
def quantile_normalize(df):
    df_sorted = pd.DataFrame(np.sort(df.values, axis=0), index=df.index, columns=df.columns)
    df_mean = df_sorted.mean(axis=1)
    df_mean.index = np.arange(1, len(df_mean) + 1)
    df_qn = df.rank(method='min').stack().astype(int).map(df_mean).unstack()
    return df_qn
    
df_chest = pd.DataFrame({
    'ACC_X': acc_x,
    'ACC_Y': acc_y,
    'ACC_Z': acc_z,
    'EMG': emg_x,
    'EDA': eda_x,
    'ECG': ecg_x,
    'Temp': temp_x,
    'Resp': resp_x
})
df_chest['w_labels'] = w_labels  

if 'w_labels' in df_chest.columns:
    baseline_0 = df_chest[df_chest['w_labels'] == 0]  
    baseline = df_chest[df_chest['w_labels'] == 1]    
    stress = df_chest[df_chest['w_labels'] == 2]      
    amusement = df_chest[df_chest['w_labels'] == 3]   
else:
    raise KeyError("'w_labels' column not found in df_chest")

df_0 = baseline_0.tail(10000)
df_1 = baseline.tail(10000)
df_2 = stress.tail(10000)
df_3 = amusement.tail(10000)

df_chest = pd.concat([df_3, df_1, df_2, df_0], ignore_index=True)
print("before",df_chest.shape)
print("Before Normalization:")
print(df_chest.describe())

labels_wesad = df_chest.pop('w_labels').to_numpy()
df_chest = quantile_normalize(df_chest)
print("after",df_chest.shape)
print("After Normalization:")
print(df_chest.describe())
# Out:
# before (40000, 9)
# Before Normalization:
#               ACC_X         ACC_Y         ACC_Z           EMG           EDA  \
# count  40000.000000  40000.000000  40000.000000  40000.000000  40000.000000
# mean       0.693697     -0.003684     -0.516699     -0.004170      6.546550
# std        0.214727      0.052481      0.293308      0.016550      0.778822
# min        0.354600     -0.148600     -0.914400     -0.183975      5.482864
# 25%        0.523450     -0.047800     -0.810000     -0.012497      5.839729
# 50%        0.682000      0.006200     -0.519100     -0.003937      6.629562
# 75%        0.893000      0.043850     -0.210350      0.004257      7.321930
# max        1.257400      0.153400      0.082600      0.152618      7.411575
#
#                 ECG          Temp          Resp      w_labels
# count  40000.000000  40000.000000  40000.000000  40000.000000
# mean       0.000935     33.891136      0.004522      1.500000
# std        0.304003      0.409040      5.204628      1.118048
# min       -0.549454     33.435608    -17.668152      0.000000
# 25%       -0.116867     33.574677     -2.363586      0.750000
# 50%       -0.045273     33.764084     -0.367737      1.500000
# 75%        0.024582     34.114494      3.382874      2.250000
# max        1.499222     34.695465     12.091064      3.000000
# after (40000, 8)
# After Normalization:
#               ACC_X         ACC_Y         ACC_Z           EMG           EDA  \
# count  40000.000000  40000.000000  40000.000000  40000.000000  40000.000000
# mean       5.069479      5.070116      5.071703      5.074770      5.067471
# std        0.872955      0.868172      0.873510      0.867254      0.873757
# min        2.476061      2.476061      2.476061      2.476061      2.476061
# 25%        4.573369      4.521347      4.573388      4.516100      4.573388
# 50%        5.018225      4.916174      5.018225      4.919940      5.018225
# 75%        5.677986      5.694778      5.695512      5.678207      5.681315
# max        7.167918      7.167918      7.167918      7.167918      7.167918
#
#                 ECG          Temp          Resp
# count  40000.000000  40000.000000  40000.000000
# mean       5.076337      5.064553      5.076474
# std        0.867256      0.866327      0.867271
# min        2.476061      2.476061      2.476061
# 25%        4.525111      4.523536      4.522551
# 50%        4.922862      5.018090      4.924158
# 75%        5.679911      5.696830      5.680890
# max        7.141439      7.167918      7.167918

# %%
import tensorflow as tf
from tensorflow.keras import backend as K

# Mean Absolute Error (MAE)
def mae_m(y_true, y_pred):
    y_true = K.cast(y_true, dtype='float32')  
    y_pred = K.cast(y_pred, dtype='float32')  
    return K.mean(K.abs(y_true - y_pred))

def mape_m(y_true, y_pred):
    y_true = K.cast(y_true, dtype='float32')
    y_pred = K.cast(y_pred, dtype='float32')
    diff = K.abs(y_true - y_pred)
    denom = K.maximum(K.abs(y_true), 1.0)  # Use 1.0 instead of tiny epsilon
    return 100.0 * K.mean(diff / denom)

# Root Mean Squared Error (RMSE)
def rmse_m(y_true, y_pred):
    y_true = K.cast(y_true, dtype='float32')
    y_pred = K.cast(y_pred, dtype='float32')
    return K.sqrt(K.mean(K.square(y_true - y_pred)))

# %%
import tensorflow as tf
from tensorflow.keras import backend as K

def f1_m(y_true, y_pred):
    y_true = K.cast(y_true, dtype='float32')  
    y_pred = K.cast(y_pred, dtype='float32')  
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2 * ((precision * recall) / (precision + recall + K.epsilon()))

def precision_m(y_true, y_pred):
    y_true = K.cast(y_true, dtype='float32')  
    y_pred = K.cast(y_pred, dtype='float32')  
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    return true_positives / (predicted_positives + K.epsilon())

def recall_m(y_true, y_pred):
    y_true = K.cast(y_true, dtype='float32')  
    y_pred = K.cast(y_pred, dtype='float32')  
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from pyts.image import GramianAngularField

gasf = GramianAngularField(method='summation')

X_train = df_chest.to_numpy()
X_train = gasf.fit_transform(X_train)

Y_train = labels_wesad.reshape(len(labels_wesad), 1)
X_train = X_train.reshape(X_train.shape[0], 8, 8, 1).astype('float32')
X_train /= np.amax(X_train)

Y_train = tf.keras.utils.to_categorical(Y_train, num_classes=4)

x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size=0.4, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, test_size=0.5, random_state=42)

print(f"x_train shape: {x_train.shape}, y_train shape: {y_train.shape}")
print(f"x_val shape: {x_val.shape}, y_val shape: {y_val.shape}")
print(f"x_test shape: {x_test.shape}, y_test shape: {y_test.shape}")

plt.imshow(x_train[0, :, :, 0], cmap='gray') 
plt.title(f"Class: {np.argmax(y_train[0])}")
plt.show()
# Out:
# x_train shape: (24000, 8, 8, 1), y_train shape: (24000, 4)
# x_val shape: (8000, 8, 8, 1), y_val shape: (8000, 4)
# x_test shape: (8000, 8, 8, 1), y_test shape: (8000, 4)

# %%
import tensorflow as tf
from tensorflow.keras import layers, regularizers, callbacks

# Define the Model with Swish Activation
model_CNN = tf.keras.Sequential([
    layers.Conv2D(32, (3,3), padding="same", kernel_regularizer=regularizers.l2(1e-6), input_shape=(8, 8, 1)),
    layers.BatchNormalization(),
    layers.Activation('swish'),  
    layers.MaxPooling2D(2, 2),

    layers.Conv2D(64, (3,3), padding="same", kernel_regularizer=regularizers.l2(1e-6)),
    layers.BatchNormalization(),
    layers.Activation('swish'),  
    layers.MaxPooling2D(2, 2),

    layers.Conv2D(128, (3,3), padding="same", kernel_regularizer=regularizers.l2(1e-6)),  
    layers.BatchNormalization(),
    layers.Activation('swish'),  
    layers.MaxPooling2D(2, 2),

    layers.Flatten(),
    layers.Dense(64, activation='swish', kernel_regularizer=regularizers.l2(1e-6)), 
    layers.BatchNormalization(),

    layers.Dense(4, activation='softmax')
])
loss = tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1)

optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)

model_CNN.compile(optimizer=optimizer, 
                  loss=loss, 
                  metrics=[f1_m,'accuracy', precision_m, recall_m, mae_m, mape_m, rmse_m])
model_CNN.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)                    │ (None, 8, 8, 32)            │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 8, 8, 32)            │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_3 (Activation)            │ (None, 8, 8, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 4, 4, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 4, 4, 64)            │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 4, 4, 64)            │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_4 (Activation)            │ (None, 4, 4, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 2, 2, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 2, 2, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 2, 2, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_5 (Activation)            │ (None, 2, 2, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 1, 1, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_7                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 4)                   │             260 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 102,340 (399.77 KB)
#  Trainable params: 101,764 (397.52 KB)
#  Non-trainable params: 576 (2.25 KB)

# %%
model_checkpoint = callbacks.ModelCheckpoint("/kaggle/working/best_model.keras", save_best_only=True, monitor='val_loss', verbose=1)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1)

history = model_CNN.fit(
    x_train, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(x_val, y_val),
    callbacks=[ model_checkpoint, reduce_lr]
)
# Out:
# Epoch 1/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8100 - f1_m: 0.8015 - loss: 0.7303 - mae_m: 0.1546 - mape_m: 15.4587 - precision_m: 0.8482 - recall_m: 0.7619 - rmse_m: 0.2573
# Epoch 1: val_loss improved from inf to 0.61286, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - accuracy: 0.8103 - f1_m: 0.8019 - loss: 0.7297 - mae_m: 0.1544 - mape_m: 15.4438 - precision_m: 0.8485 - recall_m: 0.7623 - rmse_m: 0.2571 - val_accuracy: 0.8742 - val_f1_m: 0.8690 - val_loss: 0.6129 - val_mae_m: 0.1233 - val_mape_m: 12.3320 - val_precision_m: 0.8992 - val_recall_m: 0.8418 - val_rmse_m: 0.2187 - learning_rate: 0.0010
# Epoch 2/100
# 745/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9016 - f1_m: 0.8988 - loss: 0.5499 - mae_m: 0.1072 - mape_m: 10.7250 - precision_m: 0.9258 - recall_m: 0.8741 - rmse_m: 0.1936
# Epoch 2: val_loss improved from 0.61286 to 0.55303, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9016 - f1_m: 0.8988 - loss: 0.5499 - mae_m: 0.1072 - mape_m: 10.7237 - precision_m: 0.9257 - recall_m: 0.8741 - rmse_m: 0.1935 - val_accuracy: 0.9014 - val_f1_m: 0.8980 - val_loss: 0.5530 - val_mae_m: 0.1120 - val_mape_m: 11.2044 - val_precision_m: 0.9185 - val_recall_m: 0.8790 - val_rmse_m: 0.1972 - learning_rate: 0.0010
# Epoch 3/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9158 - f1_m: 0.9142 - loss: 0.5224 - mae_m: 0.0978 - mape_m: 9.7799 - precision_m: 0.9340 - recall_m: 0.8957 - rmse_m: 0.1799
# Epoch 3: val_loss improved from 0.55303 to 0.54037, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9158 - f1_m: 0.9142 - loss: 0.5224 - mae_m: 0.0978 - mape_m: 9.7799 - precision_m: 0.9340 - recall_m: 0.8958 - rmse_m: 0.1799 - val_accuracy: 0.9066 - val_f1_m: 0.9037 - val_loss: 0.5404 - val_mae_m: 0.1043 - val_mape_m: 10.4346 - val_precision_m: 0.9266 - val_recall_m: 0.8826 - val_rmse_m: 0.1886 - learning_rate: 0.0010
# Epoch 4/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9224 - f1_m: 0.9198 - loss: 0.5105 - mae_m: 0.0939 - mape_m: 9.3899 - precision_m: 0.9354 - recall_m: 0.9052 - rmse_m: 0.1742
# Epoch 4: val_loss improved from 0.54037 to 0.49946, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9224 - f1_m: 0.9198 - loss: 0.5105 - mae_m: 0.0939 - mape_m: 9.3895 - precision_m: 0.9354 - recall_m: 0.9052 - rmse_m: 0.1742 - val_accuracy: 0.9266 - val_f1_m: 0.9234 - val_loss: 0.4995 - val_mae_m: 0.0884 - val_mape_m: 8.8365 - val_precision_m: 0.9396 - val_recall_m: 0.9082 - val_rmse_m: 0.1682 - learning_rate: 0.0010
# Epoch 5/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9298 - f1_m: 0.9269 - loss: 0.4973 - mae_m: 0.0898 - mape_m: 8.9769 - precision_m: 0.9418 - recall_m: 0.9129 - rmse_m: 0.1672
# Epoch 5: val_loss did not improve from 0.49946
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9298 - f1_m: 0.9269 - loss: 0.4973 - mae_m: 0.0898 - mape_m: 8.9767 - precision_m: 0.9418 - recall_m: 0.9129 - rmse_m: 0.1672 - val_accuracy: 0.9160 - val_f1_m: 0.9155 - val_loss: 0.5137 - val_mae_m: 0.0856 - val_mape_m: 8.5583 - val_precision_m: 0.9256 - val_recall_m: 0.9060 - val_rmse_m: 0.1731 - learning_rate: 0.0010
# Epoch 6/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9367 - f1_m: 0.9360 - loss: 0.4835 - mae_m: 0.0850 - mape_m: 8.4983 - precision_m: 0.9480 - recall_m: 0.9248 - rmse_m: 0.1589
# Epoch 6: val_loss improved from 0.49946 to 0.49332, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9367 - f1_m: 0.9360 - loss: 0.4835 - mae_m: 0.0850 - mape_m: 8.4983 - precision_m: 0.9480 - recall_m: 0.9247 - rmse_m: 0.1589 - val_accuracy: 0.9285 - val_f1_m: 0.9277 - val_loss: 0.4933 - val_mae_m: 0.0862 - val_mape_m: 8.6224 - val_precision_m: 0.9398 - val_recall_m: 0.9162 - val_rmse_m: 0.1645 - learning_rate: 0.0010
# Epoch 7/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9376 - f1_m: 0.9354 - loss: 0.4797 - mae_m: 0.0837 - mape_m: 8.3682 - precision_m: 0.9466 - recall_m: 0.9249 - rmse_m: 0.1564
# Epoch 7: val_loss did not improve from 0.49332
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9376 - f1_m: 0.9354 - loss: 0.4797 - mae_m: 0.0837 - mape_m: 8.3683 - precision_m: 0.9466 - recall_m: 0.9249 - rmse_m: 0.1564 - val_accuracy: 0.9243 - val_f1_m: 0.9235 - val_loss: 0.5030 - val_mae_m: 0.0811 - val_mape_m: 8.1118 - val_precision_m: 0.9332 - val_recall_m: 0.9144 - val_rmse_m: 0.1666 - learning_rate: 0.0010
# Epoch 8/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9402 - f1_m: 0.9384 - loss: 0.4770 - mae_m: 0.0822 - mape_m: 8.2246 - precision_m: 0.9494 - recall_m: 0.9279 - rmse_m: 0.1544
# Epoch 8: val_loss improved from 0.49332 to 0.47859, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9402 - f1_m: 0.9384 - loss: 0.4770 - mae_m: 0.0822 - mape_m: 8.2244 - precision_m: 0.9494 - recall_m: 0.9279 - rmse_m: 0.1544 - val_accuracy: 0.9333 - val_f1_m: 0.9326 - val_loss: 0.4786 - val_mae_m: 0.0789 - val_mape_m: 7.8850 - val_precision_m: 0.9421 - val_recall_m: 0.9236 - val_rmse_m: 0.1568 - learning_rate: 0.0010
# Epoch 9/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9441 - f1_m: 0.9432 - loss: 0.4645 - mae_m: 0.0785 - mape_m: 7.8541 - precision_m: 0.9537 - recall_m: 0.9333 - rmse_m: 0.1472
# Epoch 9: val_loss improved from 0.47859 to 0.47389, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9440 - f1_m: 0.9432 - loss: 0.4645 - mae_m: 0.0785 - mape_m: 7.8542 - precision_m: 0.9537 - recall_m: 0.9332 - rmse_m: 0.1472 - val_accuracy: 0.9361 - val_f1_m: 0.9354 - val_loss: 0.4739 - val_mae_m: 0.0789 - val_mape_m: 7.8854 - val_precision_m: 0.9468 - val_recall_m: 0.9246 - val_rmse_m: 0.1543 - learning_rate: 0.0010
# Epoch 10/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9462 - f1_m: 0.9461 - loss: 0.4597 - mae_m: 0.0766 - mape_m: 7.6599 - precision_m: 0.9549 - recall_m: 0.9377 - rmse_m: 0.1437
# Epoch 10: val_loss did not improve from 0.47389
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9462 - f1_m: 0.9461 - loss: 0.4598 - mae_m: 0.0766 - mape_m: 7.6600 - precision_m: 0.9549 - recall_m: 0.9377 - rmse_m: 0.1437 - val_accuracy: 0.9285 - val_f1_m: 0.9273 - val_loss: 0.4917 - val_mae_m: 0.0765 - val_mape_m: 7.6524 - val_precision_m: 0.9351 - val_recall_m: 0.9197 - val_rmse_m: 0.1611 - learning_rate: 0.0010
# Epoch 11/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9505 - f1_m: 0.9497 - loss: 0.4549 - mae_m: 0.0750 - mape_m: 7.4956 - precision_m: 0.9598 - recall_m: 0.9401 - rmse_m: 0.1410
# Epoch 11: val_loss did not improve from 0.47389
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9505 - f1_m: 0.9497 - loss: 0.4549 - mae_m: 0.0750 - mape_m: 7.4959 - precision_m: 0.9598 - recall_m: 0.9400 - rmse_m: 0.1410 - val_accuracy: 0.9290 - val_f1_m: 0.9281 - val_loss: 0.4866 - val_mae_m: 0.0752 - val_mape_m: 7.5218 - val_precision_m: 0.9367 - val_recall_m: 0.9199 - val_rmse_m: 0.1588 - learning_rate: 0.0010
# Epoch 12/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9511 - f1_m: 0.9493 - loss: 0.4544 - mae_m: 0.0746 - mape_m: 7.4564 - precision_m: 0.9590 - recall_m: 0.9401 - rmse_m: 0.1403
# Epoch 12: val_loss did not improve from 0.47389
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9511 - f1_m: 0.9493 - loss: 0.4544 - mae_m: 0.0746 - mape_m: 7.4559 - precision_m: 0.9590 - recall_m: 0.9401 - rmse_m: 0.1403 - val_accuracy: 0.9374 - val_f1_m: 0.9362 - val_loss: 0.4800 - val_mae_m: 0.0742 - val_mape_m: 7.4189 - val_precision_m: 0.9442 - val_recall_m: 0.9286 - val_rmse_m: 0.1531 - learning_rate: 0.0010
# Epoch 13/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9602 - f1_m: 0.9595 - loss: 0.4360 - mae_m: 0.0679 - mape_m: 6.7923 - precision_m: 0.9657 - recall_m: 0.9535 - rmse_m: 0.1270
# Epoch 13: val_loss improved from 0.47389 to 0.45615, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9602 - f1_m: 0.9595 - loss: 0.4360 - mae_m: 0.0679 - mape_m: 6.7923 - precision_m: 0.9657 - recall_m: 0.9535 - rmse_m: 0.1270 - val_accuracy: 0.9467 - val_f1_m: 0.9454 - val_loss: 0.4562 - val_mae_m: 0.0634 - val_mape_m: 6.3447 - val_precision_m: 0.9517 - val_recall_m: 0.9394 - val_rmse_m: 0.1374 - learning_rate: 5.0000e-04
# Epoch 14/100
# 745/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9652 - f1_m: 0.9647 - loss: 0.4274 - mae_m: 0.0651 - mape_m: 6.5098 - precision_m: 0.9706 - recall_m: 0.9591 - rmse_m: 0.1201
# Epoch 14: val_loss did not improve from 0.45615
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9652 - f1_m: 0.9647 - loss: 0.4274 - mae_m: 0.0651 - mape_m: 6.5102 - precision_m: 0.9706 - recall_m: 0.9591 - rmse_m: 0.1201 - val_accuracy: 0.9449 - val_f1_m: 0.9437 - val_loss: 0.4627 - val_mae_m: 0.0668 - val_mape_m: 6.6775 - val_precision_m: 0.9495 - val_recall_m: 0.9381 - val_rmse_m: 0.1427 - learning_rate: 5.0000e-04
# Epoch 15/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9658 - f1_m: 0.9647 - loss: 0.4248 - mae_m: 0.0644 - mape_m: 6.4353 - precision_m: 0.9710 - recall_m: 0.9586 - rmse_m: 0.1192
# Epoch 15: val_loss did not improve from 0.45615
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9658 - f1_m: 0.9647 - loss: 0.4248 - mae_m: 0.0644 - mape_m: 6.4355 - precision_m: 0.9710 - recall_m: 0.9586 - rmse_m: 0.1192 - val_accuracy: 0.9425 - val_f1_m: 0.9436 - val_loss: 0.4594 - val_mae_m: 0.0693 - val_mape_m: 6.9311 - val_precision_m: 0.9505 - val_recall_m: 0.9370 - val_rmse_m: 0.1415 - learning_rate: 5.0000e-04
# Epoch 16/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9662 - f1_m: 0.9653 - loss: 0.4237 - mae_m: 0.0641 - mape_m: 6.4095 - precision_m: 0.9712 - recall_m: 0.9595 - rmse_m: 0.1176
# Epoch 16: val_loss did not improve from 0.45615
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9662 - f1_m: 0.9653 - loss: 0.4237 - mae_m: 0.0641 - mape_m: 6.4094 - precision_m: 0.9712 - recall_m: 0.9595 - rmse_m: 0.1176 - val_accuracy: 0.9461 - val_f1_m: 0.9452 - val_loss: 0.4573 - val_mae_m: 0.0710 - val_mape_m: 7.0998 - val_precision_m: 0.9515 - val_recall_m: 0.9392 - val_rmse_m: 0.1419 - learning_rate: 5.0000e-04
# Epoch 17/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9775 - f1_m: 0.9770 - loss: 0.4084 - mae_m: 0.0592 - mape_m: 5.9216 - precision_m: 0.9820 - recall_m: 0.9723 - rmse_m: 0.1044
# Epoch 17: val_loss improved from 0.45615 to 0.45501, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9775 - f1_m: 0.9770 - loss: 0.4084 - mae_m: 0.0592 - mape_m: 5.9218 - precision_m: 0.9820 - recall_m: 0.9723 - rmse_m: 0.1045 - val_accuracy: 0.9488 - val_f1_m: 0.9486 - val_loss: 0.4550 - val_mae_m: 0.0656 - val_mape_m: 6.5553 - val_precision_m: 0.9539 - val_recall_m: 0.9436 - val_rmse_m: 0.1372 - learning_rate: 2.5000e-04
# Epoch 18/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9771 - f1_m: 0.9761 - loss: 0.4080 - mae_m: 0.0584 - mape_m: 5.8412 - precision_m: 0.9807 - recall_m: 0.9717 - rmse_m: 0.1038
# Epoch 18: val_loss improved from 0.45501 to 0.44679, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9771 - f1_m: 0.9761 - loss: 0.4080 - mae_m: 0.0584 - mape_m: 5.8416 - precision_m: 0.9807 - recall_m: 0.9717 - rmse_m: 0.1038 - val_accuracy: 0.9507 - val_f1_m: 0.9508 - val_loss: 0.4468 - val_mae_m: 0.0624 - val_mape_m: 6.2354 - val_precision_m: 0.9560 - val_recall_m: 0.9459 - val_rmse_m: 0.1316 - learning_rate: 2.5000e-04
# Epoch 19/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9768 - f1_m: 0.9760 - loss: 0.4066 - mae_m: 0.0577 - mape_m: 5.7665 - precision_m: 0.9808 - recall_m: 0.9714 - rmse_m: 0.1022
# Epoch 19: val_loss did not improve from 0.44679
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9768 - f1_m: 0.9760 - loss: 0.4066 - mae_m: 0.0577 - mape_m: 5.7668 - precision_m: 0.9808 - recall_m: 0.9714 - rmse_m: 0.1022 - val_accuracy: 0.9505 - val_f1_m: 0.9507 - val_loss: 0.4473 - val_mae_m: 0.0643 - val_mape_m: 6.4275 - val_precision_m: 0.9553 - val_recall_m: 0.9463 - val_rmse_m: 0.1334 - learning_rate: 2.5000e-04
# Epoch 20/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9805 - f1_m: 0.9796 - loss: 0.4035 - mae_m: 0.0567 - mape_m: 5.6738 - precision_m: 0.9842 - recall_m: 0.9752 - rmse_m: 0.0997
# Epoch 20: val_loss improved from 0.44679 to 0.44628, saving model to /kaggle/working/best_model.keras
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9805 - f1_m: 0.9796 - loss: 0.4035 - mae_m: 0.0567 - mape_m: 5.6740 - precision_m: 0.9842 - recall_m: 0.9752 - rmse_m: 0.0997 - val_accuracy: 0.9520 - val_f1_m: 0.9515 - val_loss: 0.4463 - val_mae_m: 0.0671 - val_mape_m: 6.7064 - val_precision_m: 0.9570 - val_recall_m: 0.9463 - val_rmse_m: 0.1338 - learning_rate: 2.5000e-04
# Epoch 21/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9792 - f1_m: 0.9787 - loss: 0.4024 - mae_m: 0.0564 - mape_m: 5.6433 - precision_m: 0.9825 - recall_m: 0.9750 - rmse_m: 0.0989
# Epoch 21: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9792 - f1_m: 0.9787 - loss: 0.4024 - mae_m: 0.0564 - mape_m: 5.6435 - precision_m: 0.9825 - recall_m: 0.9750 - rmse_m: 0.0989 - val_accuracy: 0.9507 - val_f1_m: 0.9494 - val_loss: 0.4497 - val_mae_m: 0.0641 - val_mape_m: 6.4124 - val_precision_m: 0.9555 - val_recall_m: 0.9435 - val_rmse_m: 0.1335 - learning_rate: 2.5000e-04
# Epoch 22/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9811 - f1_m: 0.9801 - loss: 0.3994 - mae_m: 0.0551 - mape_m: 5.5116 - precision_m: 0.9839 - recall_m: 0.9765 - rmse_m: 0.0959
# Epoch 22: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9811 - f1_m: 0.9801 - loss: 0.3994 - mae_m: 0.0551 - mape_m: 5.5117 - precision_m: 0.9839 - recall_m: 0.9765 - rmse_m: 0.0959 - val_accuracy: 0.9501 - val_f1_m: 0.9496 - val_loss: 0.4517 - val_mae_m: 0.0640 - val_mape_m: 6.4023 - val_precision_m: 0.9555 - val_recall_m: 0.9439 - val_rmse_m: 0.1343 - learning_rate: 2.5000e-04
# Epoch 23/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9826 - f1_m: 0.9827 - loss: 0.3972 - mae_m: 0.0546 - mape_m: 5.4628 - precision_m: 0.9863 - recall_m: 0.9791 - rmse_m: 0.0937
# Epoch 23: val_loss did not improve from 0.44628
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9826 - f1_m: 0.9826 - loss: 0.3972 - mae_m: 0.0546 - mape_m: 5.4633 - precision_m: 0.9863 - recall_m: 0.9791 - rmse_m: 0.0937 - val_accuracy: 0.9515 - val_f1_m: 0.9501 - val_loss: 0.4526 - val_mae_m: 0.0650 - val_mape_m: 6.5001 - val_precision_m: 0.9559 - val_recall_m: 0.9446 - val_rmse_m: 0.1342 - learning_rate: 2.5000e-04
# Epoch 24/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9841 - f1_m: 0.9839 - loss: 0.3941 - mae_m: 0.0536 - mape_m: 5.3632 - precision_m: 0.9872 - recall_m: 0.9807 - rmse_m: 0.0906
# Epoch 24: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9841 - f1_m: 0.9839 - loss: 0.3941 - mae_m: 0.0536 - mape_m: 5.3632 - precision_m: 0.9872 - recall_m: 0.9807 - rmse_m: 0.0906 - val_accuracy: 0.9511 - val_f1_m: 0.9510 - val_loss: 0.4480 - val_mae_m: 0.0631 - val_mape_m: 6.3096 - val_precision_m: 0.9564 - val_recall_m: 0.9459 - val_rmse_m: 0.1316 - learning_rate: 1.2500e-04
# Epoch 25/100
# 745/750 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9853 - f1_m: 0.9850 - loss: 0.3914 - mae_m: 0.0523 - mape_m: 5.2349 - precision_m: 0.9882 - recall_m: 0.9819 - rmse_m: 0.0873
# Epoch 25: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9853 - f1_m: 0.9850 - loss: 0.3914 - mae_m: 0.0524 - mape_m: 5.2351 - precision_m: 0.9882 - recall_m: 0.9819 - rmse_m: 0.0873 - val_accuracy: 0.9511 - val_f1_m: 0.9518 - val_loss: 0.4476 - val_mae_m: 0.0625 - val_mape_m: 6.2515 - val_precision_m: 0.9573 - val_recall_m: 0.9465 - val_rmse_m: 0.1310 - learning_rate: 1.2500e-04
# Epoch 26/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9858 - f1_m: 0.9850 - loss: 0.3919 - mae_m: 0.0524 - mape_m: 5.2362 - precision_m: 0.9880 - recall_m: 0.9821 - rmse_m: 0.0876
# Epoch 26: val_loss did not improve from 0.44628
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - accuracy: 0.9858 - f1_m: 0.9850 - loss: 0.3919 - mae_m: 0.0524 - mape_m: 5.2363 - precision_m: 0.9880 - recall_m: 0.9821 - rmse_m: 0.0876 - val_accuracy: 0.9507 - val_f1_m: 0.9510 - val_loss: 0.4489 - val_mae_m: 0.0635 - val_mape_m: 6.3542 - val_precision_m: 0.9563 - val_recall_m: 0.9460 - val_rmse_m: 0.1322 - learning_rate: 1.2500e-04
# Epoch 27/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9884 - f1_m: 0.9878 - loss: 0.3892 - mae_m: 0.0517 - mape_m: 5.1723 - precision_m: 0.9907 - recall_m: 0.9850 - rmse_m: 0.0852
# Epoch 27: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9884 - f1_m: 0.9878 - loss: 0.3892 - mae_m: 0.0517 - mape_m: 5.1722 - precision_m: 0.9907 - recall_m: 0.9850 - rmse_m: 0.0851 - val_accuracy: 0.9519 - val_f1_m: 0.9517 - val_loss: 0.4481 - val_mae_m: 0.0613 - val_mape_m: 6.1288 - val_precision_m: 0.9582 - val_recall_m: 0.9454 - val_rmse_m: 0.1304 - learning_rate: 6.2500e-05
# Epoch 28/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9881 - f1_m: 0.9878 - loss: 0.3882 - mae_m: 0.0512 - mape_m: 5.1211 - precision_m: 0.9899 - recall_m: 0.9858 - rmse_m: 0.0842
# Epoch 28: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9881 - f1_m: 0.9878 - loss: 0.3882 - mae_m: 0.0512 - mape_m: 5.1209 - precision_m: 0.9899 - recall_m: 0.9858 - rmse_m: 0.0842 - val_accuracy: 0.9505 - val_f1_m: 0.9506 - val_loss: 0.4492 - val_mae_m: 0.0612 - val_mape_m: 6.1248 - val_precision_m: 0.9561 - val_recall_m: 0.9454 - val_rmse_m: 0.1306 - learning_rate: 6.2500e-05
# Epoch 29/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9877 - f1_m: 0.9882 - loss: 0.3871 - mae_m: 0.0506 - mape_m: 5.0569 - precision_m: 0.9904 - recall_m: 0.9861 - rmse_m: 0.0821
# Epoch 29: val_loss did not improve from 0.44628
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9877 - f1_m: 0.9882 - loss: 0.3871 - mae_m: 0.0506 - mape_m: 5.0569 - precision_m: 0.9904 - recall_m: 0.9861 - rmse_m: 0.0821 - val_accuracy: 0.9538 - val_f1_m: 0.9529 - val_loss: 0.4499 - val_mae_m: 0.0601 - val_mape_m: 6.0145 - val_precision_m: 0.9580 - val_recall_m: 0.9480 - val_rmse_m: 0.1295 - learning_rate: 6.2500e-05
# Epoch 30/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9899 - f1_m: 0.9893 - loss: 0.3837 - mae_m: 0.0493 - mape_m: 4.9291 - precision_m: 0.9917 - recall_m: 0.9870 - rmse_m: 0.0788
# Epoch 30: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9899 - f1_m: 0.9893 - loss: 0.3837 - mae_m: 0.0493 - mape_m: 4.9295 - precision_m: 0.9917 - recall_m: 0.9870 - rmse_m: 0.0788 - val_accuracy: 0.9526 - val_f1_m: 0.9526 - val_loss: 0.4500 - val_mae_m: 0.0607 - val_mape_m: 6.0745 - val_precision_m: 0.9573 - val_recall_m: 0.9480 - val_rmse_m: 0.1302 - learning_rate: 3.1250e-05
# Epoch 31/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9893 - f1_m: 0.9886 - loss: 0.3861 - mae_m: 0.0504 - mape_m: 5.0388 - precision_m: 0.9912 - recall_m: 0.9861 - rmse_m: 0.0814
# Epoch 31: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9893 - f1_m: 0.9886 - loss: 0.3861 - mae_m: 0.0504 - mape_m: 5.0387 - precision_m: 0.9912 - recall_m: 0.9861 - rmse_m: 0.0814 - val_accuracy: 0.9521 - val_f1_m: 0.9523 - val_loss: 0.4496 - val_mae_m: 0.0612 - val_mape_m: 6.1176 - val_precision_m: 0.9584 - val_recall_m: 0.9464 - val_rmse_m: 0.1303 - learning_rate: 3.1250e-05
# Epoch 32/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9904 - f1_m: 0.9902 - loss: 0.3849 - mae_m: 0.0498 - mape_m: 4.9821 - precision_m: 0.9924 - recall_m: 0.9880 - rmse_m: 0.0800
# Epoch 32: val_loss did not improve from 0.44628
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9904 - f1_m: 0.9902 - loss: 0.3849 - mae_m: 0.0498 - mape_m: 4.9821 - precision_m: 0.9924 - recall_m: 0.9880 - rmse_m: 0.0800 - val_accuracy: 0.9517 - val_f1_m: 0.9520 - val_loss: 0.4502 - val_mae_m: 0.0601 - val_mape_m: 6.0132 - val_precision_m: 0.9576 - val_recall_m: 0.9466 - val_rmse_m: 0.1301 - learning_rate: 3.1250e-05
# Epoch 33/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9895 - f1_m: 0.9895 - loss: 0.3852 - mae_m: 0.0499 - mape_m: 4.9919 - precision_m: 0.9917 - recall_m: 0.9873 - rmse_m: 0.0807
# Epoch 33: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9895 - f1_m: 0.9895 - loss: 0.3852 - mae_m: 0.0499 - mape_m: 4.9919 - precision_m: 0.9917 - recall_m: 0.9873 - rmse_m: 0.0807 - val_accuracy: 0.9526 - val_f1_m: 0.9520 - val_loss: 0.4495 - val_mae_m: 0.0606 - val_mape_m: 6.0594 - val_precision_m: 0.9581 - val_recall_m: 0.9461 - val_rmse_m: 0.1300 - learning_rate: 1.5625e-05
# Epoch 34/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9925 - f1_m: 0.9920 - loss: 0.3829 - mae_m: 0.0494 - mape_m: 4.9427 - precision_m: 0.9940 - recall_m: 0.9901 - rmse_m: 0.0777
# Epoch 34: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9925 - f1_m: 0.9920 - loss: 0.3829 - mae_m: 0.0494 - mape_m: 4.9428 - precision_m: 0.9940 - recall_m: 0.9901 - rmse_m: 0.0777 - val_accuracy: 0.9531 - val_f1_m: 0.9523 - val_loss: 0.4494 - val_mae_m: 0.0608 - val_mape_m: 6.0813 - val_precision_m: 0.9573 - val_recall_m: 0.9475 - val_rmse_m: 0.1301 - learning_rate: 1.5625e-05
# Epoch 35/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9912 - f1_m: 0.9907 - loss: 0.3840 - mae_m: 0.0495 - mape_m: 4.9453 - precision_m: 0.9926 - recall_m: 0.9889 - rmse_m: 0.0788
# Epoch 35: val_loss did not improve from 0.44628
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9912 - f1_m: 0.9907 - loss: 0.3840 - mae_m: 0.0495 - mape_m: 4.9454 - precision_m: 0.9926 - recall_m: 0.9889 - rmse_m: 0.0788 - val_accuracy: 0.9534 - val_f1_m: 0.9522 - val_loss: 0.4504 - val_mae_m: 0.0602 - val_mape_m: 6.0170 - val_precision_m: 0.9572 - val_recall_m: 0.9475 - val_rmse_m: 0.1300 - learning_rate: 1.5625e-05
# Epoch 36/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9898 - f1_m: 0.9893 - loss: 0.3856 - mae_m: 0.0500 - mape_m: 4.9994 - precision_m: 0.9918 - recall_m: 0.9870 - rmse_m: 0.0806
# Epoch 36: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9898 - f1_m: 0.9893 - loss: 0.3856 - mae_m: 0.0500 - mape_m: 4.9991 - precision_m: 0.9918 - recall_m: 0.9870 - rmse_m: 0.0806 - val_accuracy: 0.9534 - val_f1_m: 0.9527 - val_loss: 0.4500 - val_mae_m: 0.0605 - val_mape_m: 6.0496 - val_precision_m: 0.9580 - val_recall_m: 0.9475 - val_rmse_m: 0.1300 - learning_rate: 7.8125e-06
# Epoch 37/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9900 - f1_m: 0.9902 - loss: 0.3838 - mae_m: 0.0497 - mape_m: 4.9651 - precision_m: 0.9925 - recall_m: 0.9880 - rmse_m: 0.0791
# Epoch 37: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9900 - f1_m: 0.9902 - loss: 0.3838 - mae_m: 0.0496 - mape_m: 4.9649 - precision_m: 0.9925 - recall_m: 0.9880 - rmse_m: 0.0791 - val_accuracy: 0.9536 - val_f1_m: 0.9526 - val_loss: 0.4497 - val_mae_m: 0.0606 - val_mape_m: 6.0611 - val_precision_m: 0.9583 - val_recall_m: 0.9471 - val_rmse_m: 0.1299 - learning_rate: 7.8125e-06
# Epoch 38/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9908 - f1_m: 0.9909 - loss: 0.3829 - mae_m: 0.0491 - mape_m: 4.9065 - precision_m: 0.9936 - recall_m: 0.9884 - rmse_m: 0.0775
# Epoch 38: val_loss did not improve from 0.44628
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9908 - f1_m: 0.9909 - loss: 0.3829 - mae_m: 0.0491 - mape_m: 4.9067 - precision_m: 0.9936 - recall_m: 0.9884 - rmse_m: 0.0775 - val_accuracy: 0.9535 - val_f1_m: 0.9524 - val_loss: 0.4498 - val_mae_m: 0.0607 - val_mape_m: 6.0652 - val_precision_m: 0.9576 - val_recall_m: 0.9475 - val_rmse_m: 0.1301 - learning_rate: 7.8125e-06
# Epoch 39/100
# 745/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9914 - f1_m: 0.9907 - loss: 0.3832 - mae_m: 0.0492 - mape_m: 4.9215 - precision_m: 0.9925 - recall_m: 0.9889 - rmse_m: 0.0782
# Epoch 39: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9914 - f1_m: 0.9907 - loss: 0.3832 - mae_m: 0.0492 - mape_m: 4.9215 - precision_m: 0.9925 - recall_m: 0.9889 - rmse_m: 0.0782 - val_accuracy: 0.9530 - val_f1_m: 0.9524 - val_loss: 0.4498 - val_mae_m: 0.0604 - val_mape_m: 6.0368 - val_precision_m: 0.9579 - val_recall_m: 0.9471 - val_rmse_m: 0.1300 - learning_rate: 3.9063e-06
# Epoch 40/100
# 745/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9917 - f1_m: 0.9914 - loss: 0.3830 - mae_m: 0.0491 - mape_m: 4.9065 - precision_m: 0.9934 - recall_m: 0.9894 - rmse_m: 0.0782
# Epoch 40: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9917 - f1_m: 0.9914 - loss: 0.3830 - mae_m: 0.0491 - mape_m: 4.9065 - precision_m: 0.9934 - recall_m: 0.9894 - rmse_m: 0.0782 - val_accuracy: 0.9535 - val_f1_m: 0.9525 - val_loss: 0.4501 - val_mae_m: 0.0606 - val_mape_m: 6.0625 - val_precision_m: 0.9580 - val_recall_m: 0.9473 - val_rmse_m: 0.1301 - learning_rate: 3.9063e-06
# Epoch 41/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9915 - f1_m: 0.9912 - loss: 0.3822 - mae_m: 0.0487 - mape_m: 4.8694 - precision_m: 0.9932 - recall_m: 0.9893 - rmse_m: 0.0766
# Epoch 41: val_loss did not improve from 0.44628
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9915 - f1_m: 0.9912 - loss: 0.3822 - mae_m: 0.0487 - mape_m: 4.8695 - precision_m: 0.9932 - recall_m: 0.9893 - rmse_m: 0.0766 - val_accuracy: 0.9521 - val_f1_m: 0.9526 - val_loss: 0.4498 - val_mae_m: 0.0607 - val_mape_m: 6.0657 - val_precision_m: 0.9580 - val_recall_m: 0.9474 - val_rmse_m: 0.1301 - learning_rate: 3.9063e-06
# Epoch 42/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9914 - f1_m: 0.9910 - loss: 0.3833 - mae_m: 0.0492 - mape_m: 4.9224 - precision_m: 0.9926 - recall_m: 0.9895 - rmse_m: 0.0781
# Epoch 42: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9914 - f1_m: 0.9910 - loss: 0.3833 - mae_m: 0.0492 - mape_m: 4.9223 - precision_m: 0.9926 - recall_m: 0.9895 - rmse_m: 0.0781 - val_accuracy: 0.9535 - val_f1_m: 0.9525 - val_loss: 0.4504 - val_mae_m: 0.0607 - val_mape_m: 6.0689 - val_precision_m: 0.9579 - val_recall_m: 0.9474 - val_rmse_m: 0.1302 - learning_rate: 1.9531e-06
# Epoch 43/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9917 - f1_m: 0.9913 - loss: 0.3819 - mae_m: 0.0486 - mape_m: 4.8610 - precision_m: 0.9934 - recall_m: 0.9893 - rmse_m: 0.0767
# Epoch 43: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9917 - f1_m: 0.9913 - loss: 0.3819 - mae_m: 0.0486 - mape_m: 4.8612 - precision_m: 0.9934 - recall_m: 0.9893 - rmse_m: 0.0767 - val_accuracy: 0.9532 - val_f1_m: 0.9525 - val_loss: 0.4503 - val_mae_m: 0.0606 - val_mape_m: 6.0586 - val_precision_m: 0.9582 - val_recall_m: 0.9470 - val_rmse_m: 0.1301 - learning_rate: 1.9531e-06
# Epoch 44/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9922 - f1_m: 0.9915 - loss: 0.3827 - mae_m: 0.0491 - mape_m: 4.9122 - precision_m: 0.9939 - recall_m: 0.9892 - rmse_m: 0.0775
# Epoch 44: val_loss did not improve from 0.44628
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1e-06.
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9922 - f1_m: 0.9915 - loss: 0.3827 - mae_m: 0.0491 - mape_m: 4.9122 - precision_m: 0.9939 - recall_m: 0.9892 - rmse_m: 0.0775 - val_accuracy: 0.9529 - val_f1_m: 0.9522 - val_loss: 0.4502 - val_mae_m: 0.0605 - val_mape_m: 6.0528 - val_precision_m: 0.9579 - val_recall_m: 0.9467 - val_rmse_m: 0.1301 - learning_rate: 1.9531e-06
# Epoch 45/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9919 - f1_m: 0.9916 - loss: 0.3817 - mae_m: 0.0487 - mape_m: 4.8708 - precision_m: 0.9931 - recall_m: 0.9900 - rmse_m: 0.0764
# Epoch 45: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9919 - f1_m: 0.9915 - loss: 0.3818 - mae_m: 0.0487 - mape_m: 4.8710 - precision_m: 0.9931 - recall_m: 0.9900 - rmse_m: 0.0764 - val_accuracy: 0.9531 - val_f1_m: 0.9522 - val_loss: 0.4504 - val_mae_m: 0.0603 - val_mape_m: 6.0309 - val_precision_m: 0.9580 - val_recall_m: 0.9467 - val_rmse_m: 0.1300 - learning_rate: 1.0000e-06
# Epoch 46/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9911 - f1_m: 0.9911 - loss: 0.3831 - mae_m: 0.0494 - mape_m: 4.9366 - precision_m: 0.9930 - recall_m: 0.9893 - rmse_m: 0.0781
# Epoch 46: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9911 - f1_m: 0.9911 - loss: 0.3831 - mae_m: 0.0494 - mape_m: 4.9364 - precision_m: 0.9930 - recall_m: 0.9893 - rmse_m: 0.0781 - val_accuracy: 0.9531 - val_f1_m: 0.9523 - val_loss: 0.4502 - val_mae_m: 0.0607 - val_mape_m: 6.0701 - val_precision_m: 0.9580 - val_recall_m: 0.9469 - val_rmse_m: 0.1302 - learning_rate: 1.0000e-06
# Epoch 47/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9909 - f1_m: 0.9907 - loss: 0.3836 - mae_m: 0.0494 - mape_m: 4.9384 - precision_m: 0.9925 - recall_m: 0.9889 - rmse_m: 0.0783
# Epoch 47: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9909 - f1_m: 0.9907 - loss: 0.3836 - mae_m: 0.0494 - mape_m: 4.9384 - precision_m: 0.9925 - recall_m: 0.9889 - rmse_m: 0.0783 - val_accuracy: 0.9535 - val_f1_m: 0.9526 - val_loss: 0.4502 - val_mae_m: 0.0606 - val_mape_m: 6.0600 - val_precision_m: 0.9581 - val_recall_m: 0.9473 - val_rmse_m: 0.1301 - learning_rate: 1.0000e-06
# Epoch 48/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9928 - f1_m: 0.9919 - loss: 0.3819 - mae_m: 0.0488 - mape_m: 4.8786 - precision_m: 0.9937 - recall_m: 0.9902 - rmse_m: 0.0765
# Epoch 48: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9928 - f1_m: 0.9919 - loss: 0.3819 - mae_m: 0.0488 - mape_m: 4.8787 - precision_m: 0.9937 - recall_m: 0.9902 - rmse_m: 0.0765 - val_accuracy: 0.9531 - val_f1_m: 0.9525 - val_loss: 0.4501 - val_mae_m: 0.0609 - val_mape_m: 6.0945 - val_precision_m: 0.9578 - val_recall_m: 0.9474 - val_rmse_m: 0.1304 - learning_rate: 1.0000e-06
# Epoch 49/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9928 - f1_m: 0.9920 - loss: 0.3819 - mae_m: 0.0491 - mape_m: 4.9146 - precision_m: 0.9944 - recall_m: 0.9897 - rmse_m: 0.0770
# Epoch 49: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9928 - f1_m: 0.9920 - loss: 0.3819 - mae_m: 0.0491 - mape_m: 4.9146 - precision_m: 0.9944 - recall_m: 0.9897 - rmse_m: 0.0770 - val_accuracy: 0.9529 - val_f1_m: 0.9526 - val_loss: 0.4503 - val_mae_m: 0.0603 - val_mape_m: 6.0327 - val_precision_m: 0.9581 - val_recall_m: 0.9474 - val_rmse_m: 0.1300 - learning_rate: 1.0000e-06
# Epoch 50/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9918 - f1_m: 0.9915 - loss: 0.3814 - mae_m: 0.0487 - mape_m: 4.8707 - precision_m: 0.9940 - recall_m: 0.9890 - rmse_m: 0.0766
# Epoch 50: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9918 - f1_m: 0.9914 - loss: 0.3814 - mae_m: 0.0487 - mape_m: 4.8710 - precision_m: 0.9940 - recall_m: 0.9890 - rmse_m: 0.0766 - val_accuracy: 0.9529 - val_f1_m: 0.9525 - val_loss: 0.4504 - val_mae_m: 0.0604 - val_mape_m: 6.0420 - val_precision_m: 0.9579 - val_recall_m: 0.9474 - val_rmse_m: 0.1301 - learning_rate: 1.0000e-06
# Epoch 51/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9921 - f1_m: 0.9917 - loss: 0.3827 - mae_m: 0.0492 - mape_m: 4.9243 - precision_m: 0.9938 - recall_m: 0.9896 - rmse_m: 0.0773
# Epoch 51: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9921 - f1_m: 0.9917 - loss: 0.3827 - mae_m: 0.0492 - mape_m: 4.9243 - precision_m: 0.9938 - recall_m: 0.9896 - rmse_m: 0.0773 - val_accuracy: 0.9530 - val_f1_m: 0.9527 - val_loss: 0.4501 - val_mae_m: 0.0608 - val_mape_m: 6.0806 - val_precision_m: 0.9579 - val_recall_m: 0.9476 - val_rmse_m: 0.1302 - learning_rate: 1.0000e-06
# Epoch 52/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9914 - f1_m: 0.9909 - loss: 0.3829 - mae_m: 0.0492 - mape_m: 4.9210 - precision_m: 0.9935 - recall_m: 0.9885 - rmse_m: 0.0778
# Epoch 52: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9914 - f1_m: 0.9909 - loss: 0.3829 - mae_m: 0.0492 - mape_m: 4.9210 - precision_m: 0.9935 - recall_m: 0.9885 - rmse_m: 0.0778 - val_accuracy: 0.9529 - val_f1_m: 0.9524 - val_loss: 0.4500 - val_mae_m: 0.0608 - val_mape_m: 6.0796 - val_precision_m: 0.9579 - val_recall_m: 0.9471 - val_rmse_m: 0.1302 - learning_rate: 1.0000e-06
# Epoch 53/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9916 - f1_m: 0.9915 - loss: 0.3830 - mae_m: 0.0494 - mape_m: 4.9421 - precision_m: 0.9934 - recall_m: 0.9896 - rmse_m: 0.0773
# Epoch 53: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9916 - f1_m: 0.9915 - loss: 0.3830 - mae_m: 0.0494 - mape_m: 4.9420 - precision_m: 0.9934 - recall_m: 0.9896 - rmse_m: 0.0773 - val_accuracy: 0.9528 - val_f1_m: 0.9524 - val_loss: 0.4504 - val_mae_m: 0.0605 - val_mape_m: 6.0482 - val_precision_m: 0.9580 - val_recall_m: 0.9471 - val_rmse_m: 0.1301 - learning_rate: 1.0000e-06
# Epoch 54/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9920 - f1_m: 0.9920 - loss: 0.3809 - mae_m: 0.0484 - mape_m: 4.8449 - precision_m: 0.9939 - recall_m: 0.9901 - rmse_m: 0.0753
# Epoch 54: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9920 - f1_m: 0.9920 - loss: 0.3809 - mae_m: 0.0484 - mape_m: 4.8449 - precision_m: 0.9939 - recall_m: 0.9901 - rmse_m: 0.0753 - val_accuracy: 0.9528 - val_f1_m: 0.9525 - val_loss: 0.4502 - val_mae_m: 0.0605 - val_mape_m: 6.0455 - val_precision_m: 0.9580 - val_recall_m: 0.9473 - val_rmse_m: 0.1301 - learning_rate: 1.0000e-06
# Epoch 55/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9912 - f1_m: 0.9910 - loss: 0.3833 - mae_m: 0.0492 - mape_m: 4.9222 - precision_m: 0.9926 - recall_m: 0.9894 - rmse_m: 0.0780
# Epoch 55: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9912 - f1_m: 0.9910 - loss: 0.3833 - mae_m: 0.0492 - mape_m: 4.9222 - precision_m: 0.9926 - recall_m: 0.9894 - rmse_m: 0.0780 - val_accuracy: 0.9532 - val_f1_m: 0.9525 - val_loss: 0.4502 - val_mae_m: 0.0609 - val_mape_m: 6.0866 - val_precision_m: 0.9580 - val_recall_m: 0.9473 - val_rmse_m: 0.1302 - learning_rate: 1.0000e-06
# Epoch 56/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9918 - f1_m: 0.9915 - loss: 0.3836 - mae_m: 0.0495 - mape_m: 4.9450 - precision_m: 0.9937 - recall_m: 0.9895 - rmse_m: 0.0784
# Epoch 56: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9918 - f1_m: 0.9915 - loss: 0.3836 - mae_m: 0.0494 - mape_m: 4.9448 - precision_m: 0.9937 - recall_m: 0.9895 - rmse_m: 0.0784 - val_accuracy: 0.9530 - val_f1_m: 0.9524 - val_loss: 0.4505 - val_mae_m: 0.0603 - val_mape_m: 6.0286 - val_precision_m: 0.9580 - val_recall_m: 0.9471 - val_rmse_m: 0.1300 - learning_rate: 1.0000e-06
# Epoch 57/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9927 - f1_m: 0.9926 - loss: 0.3809 - mae_m: 0.0484 - mape_m: 4.8412 - precision_m: 0.9944 - recall_m: 0.9908 - rmse_m: 0.0754
# Epoch 57: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9927 - f1_m: 0.9926 - loss: 0.3809 - mae_m: 0.0484 - mape_m: 4.8416 - precision_m: 0.9944 - recall_m: 0.9908 - rmse_m: 0.0754 - val_accuracy: 0.9530 - val_f1_m: 0.9524 - val_loss: 0.4501 - val_mae_m: 0.0605 - val_mape_m: 6.0519 - val_precision_m: 0.9581 - val_recall_m: 0.9470 - val_rmse_m: 0.1301 - learning_rate: 1.0000e-06
# Epoch 58/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9916 - f1_m: 0.9913 - loss: 0.3822 - mae_m: 0.0489 - mape_m: 4.8940 - precision_m: 0.9929 - recall_m: 0.9898 - rmse_m: 0.0769
# Epoch 58: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9916 - f1_m: 0.9913 - loss: 0.3822 - mae_m: 0.0489 - mape_m: 4.8941 - precision_m: 0.9929 - recall_m: 0.9898 - rmse_m: 0.0769 - val_accuracy: 0.9535 - val_f1_m: 0.9523 - val_loss: 0.4506 - val_mae_m: 0.0606 - val_mape_m: 6.0579 - val_precision_m: 0.9578 - val_recall_m: 0.9470 - val_rmse_m: 0.1302 - learning_rate: 1.0000e-06
# Epoch 59/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9920 - f1_m: 0.9920 - loss: 0.3815 - mae_m: 0.0485 - mape_m: 4.8535 - precision_m: 0.9939 - recall_m: 0.9901 - rmse_m: 0.0763
# Epoch 59: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9920 - f1_m: 0.9920 - loss: 0.3815 - mae_m: 0.0485 - mape_m: 4.8536 - precision_m: 0.9939 - recall_m: 0.9901 - rmse_m: 0.0763 - val_accuracy: 0.9528 - val_f1_m: 0.9525 - val_loss: 0.4503 - val_mae_m: 0.0605 - val_mape_m: 6.0545 - val_precision_m: 0.9581 - val_recall_m: 0.9471 - val_rmse_m: 0.1301 - learning_rate: 1.0000e-06
# Epoch 60/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9906 - f1_m: 0.9905 - loss: 0.3826 - mae_m: 0.0488 - mape_m: 4.8782 - precision_m: 0.9926 - recall_m: 0.9885 - rmse_m: 0.0774
# Epoch 60: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9906 - f1_m: 0.9905 - loss: 0.3826 - mae_m: 0.0488 - mape_m: 4.8782 - precision_m: 0.9926 - recall_m: 0.9885 - rmse_m: 0.0774 - val_accuracy: 0.9529 - val_f1_m: 0.9525 - val_loss: 0.4505 - val_mae_m: 0.0606 - val_mape_m: 6.0581 - val_precision_m: 0.9579 - val_recall_m: 0.9473 - val_rmse_m: 0.1302 - learning_rate: 1.0000e-06
# Epoch 61/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9917 - f1_m: 0.9916 - loss: 0.3819 - mae_m: 0.0486 - mape_m: 4.8627 - precision_m: 0.9932 - recall_m: 0.9900 - rmse_m: 0.0764
# Epoch 61: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9917 - f1_m: 0.9916 - loss: 0.3819 - mae_m: 0.0486 - mape_m: 4.8628 - precision_m: 0.9932 - recall_m: 0.9900 - rmse_m: 0.0764 - val_accuracy: 0.9528 - val_f1_m: 0.9526 - val_loss: 0.4506 - val_mae_m: 0.0605 - val_mape_m: 6.0528 - val_precision_m: 0.9581 - val_recall_m: 0.9473 - val_rmse_m: 0.1302 - learning_rate: 1.0000e-06
# Epoch 62/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9916 - f1_m: 0.9909 - loss: 0.3821 - mae_m: 0.0489 - mape_m: 4.8887 - precision_m: 0.9927 - recall_m: 0.9892 - rmse_m: 0.0771
# Epoch 62: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9916 - f1_m: 0.9909 - loss: 0.3821 - mae_m: 0.0489 - mape_m: 4.8887 - precision_m: 0.9927 - recall_m: 0.9892 - rmse_m: 0.0771 - val_accuracy: 0.9532 - val_f1_m: 0.9526 - val_loss: 0.4501 - val_mae_m: 0.0607 - val_mape_m: 6.0746 - val_precision_m: 0.9585 - val_recall_m: 0.9469 - val_rmse_m: 0.1302 - learning_rate: 1.0000e-06
# Epoch 63/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9912 - f1_m: 0.9908 - loss: 0.3828 - mae_m: 0.0492 - mape_m: 4.9160 - precision_m: 0.9929 - recall_m: 0.9888 - rmse_m: 0.0776
# Epoch 63: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9912 - f1_m: 0.9908 - loss: 0.3828 - mae_m: 0.0492 - mape_m: 4.9160 - precision_m: 0.9929 - recall_m: 0.9888 - rmse_m: 0.0776 - val_accuracy: 0.9528 - val_f1_m: 0.9524 - val_loss: 0.4502 - val_mae_m: 0.0606 - val_mape_m: 6.0632 - val_precision_m: 0.9580 - val_recall_m: 0.9470 - val_rmse_m: 0.1301 - learning_rate: 1.0000e-06
# Epoch 64/100
# 745/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9910 - f1_m: 0.9907 - loss: 0.3838 - mae_m: 0.0494 - mape_m: 4.9439 - precision_m: 0.9928 - recall_m: 0.9886 - rmse_m: 0.0792
# Epoch 64: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9910 - f1_m: 0.9907 - loss: 0.3838 - mae_m: 0.0494 - mape_m: 4.9438 - precision_m: 0.9928 - recall_m: 0.9886 - rmse_m: 0.0792 - val_accuracy: 0.9525 - val_f1_m: 0.9525 - val_loss: 0.4500 - val_mae_m: 0.0607 - val_mape_m: 6.0746 - val_precision_m: 0.9580 - val_recall_m: 0.9473 - val_rmse_m: 0.1302 - learning_rate: 1.0000e-06
# Epoch 65/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9914 - f1_m: 0.9913 - loss: 0.3822 - mae_m: 0.0490 - mape_m: 4.9046 - precision_m: 0.9931 - recall_m: 0.9894 - rmse_m: 0.0772
# Epoch 65: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 11ms/step - accuracy: 0.9914 - f1_m: 0.9913 - loss: 0.3822 - mae_m: 0.0490 - mape_m: 4.9048 - precision_m: 0.9931 - recall_m: 0.9894 - rmse_m: 0.0773 - val_accuracy: 0.9529 - val_f1_m: 0.9524 - val_loss: 0.4502 - val_mae_m: 0.0607 - val_mape_m: 6.0690 - val_precision_m: 0.9580 - val_recall_m: 0.9470 - val_rmse_m: 0.1302 - learning_rate: 1.0000e-06
# Epoch 66/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9914 - f1_m: 0.9912 - loss: 0.3828 - mae_m: 0.0492 - mape_m: 4.9221 - precision_m: 0.9932 - recall_m: 0.9893 - rmse_m: 0.0773
# Epoch 66: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9914 - f1_m: 0.9912 - loss: 0.3828 - mae_m: 0.0492 - mape_m: 4.9221 - precision_m: 0.9932 - recall_m: 0.9893 - rmse_m: 0.0773 - val_accuracy: 0.9530 - val_f1_m: 0.9524 - val_loss: 0.4503 - val_mae_m: 0.0606 - val_mape_m: 6.0564 - val_precision_m: 0.9580 - val_recall_m: 0.9470 - val_rmse_m: 0.1302 - learning_rate: 1.0000e-06
# Epoch 67/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9914 - f1_m: 0.9908 - loss: 0.3822 - mae_m: 0.0488 - mape_m: 4.8829 - precision_m: 0.9928 - recall_m: 0.9889 - rmse_m: 0.0770
# Epoch 67: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9914 - f1_m: 0.9908 - loss: 0.3822 - mae_m: 0.0488 - mape_m: 4.8829 - precision_m: 0.9928 - recall_m: 0.9889 - rmse_m: 0.0770 - val_accuracy: 0.9530 - val_f1_m: 0.9523 - val_loss: 0.4504 - val_mae_m: 0.0606 - val_mape_m: 6.0571 - val_precision_m: 0.9577 - val_recall_m: 0.9470 - val_rmse_m: 0.1302 - learning_rate: 1.0000e-06
# Epoch 68/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9917 - f1_m: 0.9910 - loss: 0.3823 - mae_m: 0.0489 - mape_m: 4.8895 - precision_m: 0.9933 - recall_m: 0.9887 - rmse_m: 0.0773
# Epoch 68: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9917 - f1_m: 0.9910 - loss: 0.3823 - mae_m: 0.0489 - mape_m: 4.8897 - precision_m: 0.9933 - recall_m: 0.9887 - rmse_m: 0.0773 - val_accuracy: 0.9531 - val_f1_m: 0.9527 - val_loss: 0.4504 - val_mae_m: 0.0607 - val_mape_m: 6.0679 - val_precision_m: 0.9579 - val_recall_m: 0.9476 - val_rmse_m: 0.1302 - learning_rate: 1.0000e-06
# Epoch 69/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9909 - f1_m: 0.9905 - loss: 0.3833 - mae_m: 0.0492 - mape_m: 4.9224 - precision_m: 0.9924 - recall_m: 0.9886 - rmse_m: 0.0780
# Epoch 69: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9909 - f1_m: 0.9905 - loss: 0.3833 - mae_m: 0.0492 - mape_m: 4.9224 - precision_m: 0.9924 - recall_m: 0.9886 - rmse_m: 0.0780 - val_accuracy: 0.9529 - val_f1_m: 0.9526 - val_loss: 0.4507 - val_mae_m: 0.0606 - val_mape_m: 6.0638 - val_precision_m: 0.9580 - val_recall_m: 0.9474 - val_rmse_m: 0.1302 - learning_rate: 1.0000e-06
# Epoch 70/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9909 - f1_m: 0.9909 - loss: 0.3830 - mae_m: 0.0492 - mape_m: 4.9235 - precision_m: 0.9929 - recall_m: 0.9889 - rmse_m: 0.0778
# Epoch 70: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9909 - f1_m: 0.9909 - loss: 0.3830 - mae_m: 0.0492 - mape_m: 4.9234 - precision_m: 0.9929 - recall_m: 0.9889 - rmse_m: 0.0778 - val_accuracy: 0.9526 - val_f1_m: 0.9523 - val_loss: 0.4502 - val_mae_m: 0.0605 - val_mape_m: 6.0529 - val_precision_m: 0.9579 - val_recall_m: 0.9469 - val_rmse_m: 0.1301 - learning_rate: 1.0000e-06
# Epoch 71/100
# 745/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9914 - f1_m: 0.9911 - loss: 0.3823 - mae_m: 0.0488 - mape_m: 4.8786 - precision_m: 0.9930 - recall_m: 0.9893 - rmse_m: 0.0770
# Epoch 71: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9914 - f1_m: 0.9911 - loss: 0.3823 - mae_m: 0.0488 - mape_m: 4.8788 - precision_m: 0.9930 - recall_m: 0.9893 - rmse_m: 0.0770 - val_accuracy: 0.9524 - val_f1_m: 0.9526 - val_loss: 0.4505 - val_mae_m: 0.0604 - val_mape_m: 6.0365 - val_precision_m: 0.9581 - val_recall_m: 0.9473 - val_rmse_m: 0.1301 - learning_rate: 1.0000e-06
# Epoch 72/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9913 - f1_m: 0.9909 - loss: 0.3833 - mae_m: 0.0493 - mape_m: 4.9276 - precision_m: 0.9927 - recall_m: 0.9893 - rmse_m: 0.0781
# Epoch 72: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9913 - f1_m: 0.9909 - loss: 0.3833 - mae_m: 0.0493 - mape_m: 4.9275 - precision_m: 0.9927 - recall_m: 0.9893 - rmse_m: 0.0781 - val_accuracy: 0.9526 - val_f1_m: 0.9526 - val_loss: 0.4505 - val_mae_m: 0.0605 - val_mape_m: 6.0496 - val_precision_m: 0.9584 - val_recall_m: 0.9471 - val_rmse_m: 0.1301 - learning_rate: 1.0000e-06
# Epoch 73/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9922 - f1_m: 0.9922 - loss: 0.3823 - mae_m: 0.0491 - mape_m: 4.9073 - precision_m: 0.9940 - recall_m: 0.9904 - rmse_m: 0.0769
# Epoch 73: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9922 - f1_m: 0.9922 - loss: 0.3823 - mae_m: 0.0491 - mape_m: 4.9073 - precision_m: 0.9940 - recall_m: 0.9904 - rmse_m: 0.0769 - val_accuracy: 0.9528 - val_f1_m: 0.9525 - val_loss: 0.4506 - val_mae_m: 0.0605 - val_mape_m: 6.0465 - val_precision_m: 0.9579 - val_recall_m: 0.9474 - val_rmse_m: 0.1302 - learning_rate: 1.0000e-06
# Epoch 74/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9909 - f1_m: 0.9906 - loss: 0.3838 - mae_m: 0.0495 - mape_m: 4.9481 - precision_m: 0.9928 - recall_m: 0.9885 - rmse_m: 0.0784
# Epoch 74: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9909 - f1_m: 0.9906 - loss: 0.3838 - mae_m: 0.0495 - mape_m: 4.9480 - precision_m: 0.9928 - recall_m: 0.9885 - rmse_m: 0.0784 - val_accuracy: 0.9528 - val_f1_m: 0.9524 - val_loss: 0.4505 - val_mae_m: 0.0604 - val_mape_m: 6.0427 - val_precision_m: 0.9581 - val_recall_m: 0.9470 - val_rmse_m: 0.1301 - learning_rate: 1.0000e-06
# Epoch 75/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9914 - f1_m: 0.9908 - loss: 0.3826 - mae_m: 0.0489 - mape_m: 4.8935 - precision_m: 0.9929 - recall_m: 0.9889 - rmse_m: 0.0777
# Epoch 75: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9914 - f1_m: 0.9908 - loss: 0.3826 - mae_m: 0.0489 - mape_m: 4.8936 - precision_m: 0.9929 - recall_m: 0.9889 - rmse_m: 0.0777 - val_accuracy: 0.9530 - val_f1_m: 0.9526 - val_loss: 0.4507 - val_mae_m: 0.0604 - val_mape_m: 6.0427 - val_precision_m: 0.9580 - val_recall_m: 0.9474 - val_rmse_m: 0.1302 - learning_rate: 1.0000e-06
# Epoch 76/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9913 - f1_m: 0.9914 - loss: 0.3832 - mae_m: 0.0491 - mape_m: 4.9118 - precision_m: 0.9936 - recall_m: 0.9892 - rmse_m: 0.0776
# Epoch 76: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9913 - f1_m: 0.9914 - loss: 0.3832 - mae_m: 0.0491 - mape_m: 4.9118 - precision_m: 0.9936 - recall_m: 0.9892 - rmse_m: 0.0776 - val_accuracy: 0.9532 - val_f1_m: 0.9525 - val_loss: 0.4507 - val_mae_m: 0.0605 - val_mape_m: 6.0476 - val_precision_m: 0.9583 - val_recall_m: 0.9470 - val_rmse_m: 0.1302 - learning_rate: 1.0000e-06
# Epoch 77/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9917 - f1_m: 0.9920 - loss: 0.3816 - mae_m: 0.0486 - mape_m: 4.8622 - precision_m: 0.9938 - recall_m: 0.9902 - rmse_m: 0.0761
# Epoch 77: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9917 - f1_m: 0.9920 - loss: 0.3816 - mae_m: 0.0486 - mape_m: 4.8625 - precision_m: 0.9938 - recall_m: 0.9902 - rmse_m: 0.0761 - val_accuracy: 0.9529 - val_f1_m: 0.9523 - val_loss: 0.4505 - val_mae_m: 0.0606 - val_mape_m: 6.0555 - val_precision_m: 0.9579 - val_recall_m: 0.9469 - val_rmse_m: 0.1302 - learning_rate: 1.0000e-06
# Epoch 78/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9911 - f1_m: 0.9907 - loss: 0.3843 - mae_m: 0.0497 - mape_m: 4.9659 - precision_m: 0.9926 - recall_m: 0.9889 - rmse_m: 0.0788
# Epoch 78: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9911 - f1_m: 0.9907 - loss: 0.3843 - mae_m: 0.0497 - mape_m: 4.9657 - precision_m: 0.9926 - recall_m: 0.9889 - rmse_m: 0.0788 - val_accuracy: 0.9530 - val_f1_m: 0.9524 - val_loss: 0.4500 - val_mae_m: 0.0606 - val_mape_m: 6.0601 - val_precision_m: 0.9581 - val_recall_m: 0.9470 - val_rmse_m: 0.1301 - learning_rate: 1.0000e-06
# Epoch 79/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9905 - f1_m: 0.9902 - loss: 0.3832 - mae_m: 0.0489 - mape_m: 4.8901 - precision_m: 0.9927 - recall_m: 0.9878 - rmse_m: 0.0780
# Epoch 79: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9905 - f1_m: 0.9902 - loss: 0.3832 - mae_m: 0.0489 - mape_m: 4.8901 - precision_m: 0.9927 - recall_m: 0.9879 - rmse_m: 0.0780 - val_accuracy: 0.9530 - val_f1_m: 0.9524 - val_loss: 0.4503 - val_mae_m: 0.0606 - val_mape_m: 6.0638 - val_precision_m: 0.9581 - val_recall_m: 0.9470 - val_rmse_m: 0.1302 - learning_rate: 1.0000e-06
# Epoch 80/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9917 - f1_m: 0.9912 - loss: 0.3830 - mae_m: 0.0490 - mape_m: 4.8961 - precision_m: 0.9931 - recall_m: 0.9894 - rmse_m: 0.0772
# Epoch 80: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9917 - f1_m: 0.9912 - loss: 0.3830 - mae_m: 0.0490 - mape_m: 4.8961 - precision_m: 0.9931 - recall_m: 0.9894 - rmse_m: 0.0772 - val_accuracy: 0.9532 - val_f1_m: 0.9525 - val_loss: 0.4507 - val_mae_m: 0.0603 - val_mape_m: 6.0330 - val_precision_m: 0.9580 - val_recall_m: 0.9473 - val_rmse_m: 0.1301 - learning_rate: 1.0000e-06
# Epoch 81/100
# 745/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9914 - f1_m: 0.9914 - loss: 0.3827 - mae_m: 0.0493 - mape_m: 4.9287 - precision_m: 0.9932 - recall_m: 0.9897 - rmse_m: 0.0774
# Epoch 81: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9914 - f1_m: 0.9914 - loss: 0.3827 - mae_m: 0.0493 - mape_m: 4.9286 - precision_m: 0.9932 - recall_m: 0.9897 - rmse_m: 0.0774 - val_accuracy: 0.9530 - val_f1_m: 0.9523 - val_loss: 0.4507 - val_mae_m: 0.0604 - val_mape_m: 6.0368 - val_precision_m: 0.9580 - val_recall_m: 0.9469 - val_rmse_m: 0.1301 - learning_rate: 1.0000e-06
# Epoch 82/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9913 - f1_m: 0.9910 - loss: 0.3821 - mae_m: 0.0489 - mape_m: 4.8903 - precision_m: 0.9935 - recall_m: 0.9885 - rmse_m: 0.0769
# Epoch 82: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9913 - f1_m: 0.9910 - loss: 0.3821 - mae_m: 0.0489 - mape_m: 4.8903 - precision_m: 0.9935 - recall_m: 0.9885 - rmse_m: 0.0769 - val_accuracy: 0.9531 - val_f1_m: 0.9525 - val_loss: 0.4508 - val_mae_m: 0.0604 - val_mape_m: 6.0417 - val_precision_m: 0.9582 - val_recall_m: 0.9470 - val_rmse_m: 0.1302 - learning_rate: 1.0000e-06
# Epoch 83/100
# 746/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9920 - f1_m: 0.9921 - loss: 0.3831 - mae_m: 0.0491 - mape_m: 4.9086 - precision_m: 0.9940 - recall_m: 0.9902 - rmse_m: 0.0773
# Epoch 83: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9920 - f1_m: 0.9921 - loss: 0.3831 - mae_m: 0.0491 - mape_m: 4.9084 - precision_m: 0.9940 - recall_m: 0.9902 - rmse_m: 0.0773 - val_accuracy: 0.9534 - val_f1_m: 0.9523 - val_loss: 0.4508 - val_mae_m: 0.0605 - val_mape_m: 6.0546 - val_precision_m: 0.9580 - val_recall_m: 0.9467 - val_rmse_m: 0.1303 - learning_rate: 1.0000e-06
# Epoch 84/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9924 - f1_m: 0.9917 - loss: 0.3822 - mae_m: 0.0488 - mape_m: 4.8805 - precision_m: 0.9935 - recall_m: 0.9899 - rmse_m: 0.0764
# Epoch 84: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9924 - f1_m: 0.9917 - loss: 0.3822 - mae_m: 0.0488 - mape_m: 4.8806 - precision_m: 0.9935 - recall_m: 0.9899 - rmse_m: 0.0764 - val_accuracy: 0.9534 - val_f1_m: 0.9526 - val_loss: 0.4506 - val_mae_m: 0.0607 - val_mape_m: 6.0714 - val_precision_m: 0.9582 - val_recall_m: 0.9471 - val_rmse_m: 0.1303 - learning_rate: 1.0000e-06
# Epoch 85/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9923 - f1_m: 0.9916 - loss: 0.3829 - mae_m: 0.0491 - mape_m: 4.9126 - precision_m: 0.9937 - recall_m: 0.9894 - rmse_m: 0.0776
# Epoch 85: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9923 - f1_m: 0.9916 - loss: 0.3829 - mae_m: 0.0491 - mape_m: 4.9125 - precision_m: 0.9937 - recall_m: 0.9894 - rmse_m: 0.0776 - val_accuracy: 0.9529 - val_f1_m: 0.9524 - val_loss: 0.4508 - val_mae_m: 0.0603 - val_mape_m: 6.0303 - val_precision_m: 0.9581 - val_recall_m: 0.9470 - val_rmse_m: 0.1301 - learning_rate: 1.0000e-06
# Epoch 86/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9908 - f1_m: 0.9902 - loss: 0.3838 - mae_m: 0.0497 - mape_m: 4.9657 - precision_m: 0.9925 - recall_m: 0.9881 - rmse_m: 0.0787
# Epoch 86: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9908 - f1_m: 0.9902 - loss: 0.3838 - mae_m: 0.0497 - mape_m: 4.9656 - precision_m: 0.9925 - recall_m: 0.9881 - rmse_m: 0.0787 - val_accuracy: 0.9531 - val_f1_m: 0.9522 - val_loss: 0.4504 - val_mae_m: 0.0607 - val_mape_m: 6.0673 - val_precision_m: 0.9581 - val_recall_m: 0.9466 - val_rmse_m: 0.1303 - learning_rate: 1.0000e-06
# Epoch 87/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9906 - f1_m: 0.9905 - loss: 0.3837 - mae_m: 0.0493 - mape_m: 4.9258 - precision_m: 0.9927 - recall_m: 0.9884 - rmse_m: 0.0780
# Epoch 87: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9906 - f1_m: 0.9905 - loss: 0.3837 - mae_m: 0.0493 - mape_m: 4.9256 - precision_m: 0.9927 - recall_m: 0.9884 - rmse_m: 0.0780 - val_accuracy: 0.9534 - val_f1_m: 0.9523 - val_loss: 0.4506 - val_mae_m: 0.0606 - val_mape_m: 6.0631 - val_precision_m: 0.9580 - val_recall_m: 0.9469 - val_rmse_m: 0.1303 - learning_rate: 1.0000e-06
# Epoch 88/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9914 - f1_m: 0.9913 - loss: 0.3833 - mae_m: 0.0492 - mape_m: 4.9157 - precision_m: 0.9937 - recall_m: 0.9891 - rmse_m: 0.0779
# Epoch 88: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9914 - f1_m: 0.9913 - loss: 0.3833 - mae_m: 0.0492 - mape_m: 4.9156 - precision_m: 0.9937 - recall_m: 0.9891 - rmse_m: 0.0779 - val_accuracy: 0.9530 - val_f1_m: 0.9522 - val_loss: 0.4504 - val_mae_m: 0.0607 - val_mape_m: 6.0651 - val_precision_m: 0.9582 - val_recall_m: 0.9465 - val_rmse_m: 0.1302 - learning_rate: 1.0000e-06
# Epoch 89/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9912 - f1_m: 0.9910 - loss: 0.3814 - mae_m: 0.0482 - mape_m: 4.8249 - precision_m: 0.9928 - recall_m: 0.9894 - rmse_m: 0.0759
# Epoch 89: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9912 - f1_m: 0.9910 - loss: 0.3815 - mae_m: 0.0483 - mape_m: 4.8251 - precision_m: 0.9928 - recall_m: 0.9894 - rmse_m: 0.0759 - val_accuracy: 0.9530 - val_f1_m: 0.9523 - val_loss: 0.4505 - val_mae_m: 0.0607 - val_mape_m: 6.0740 - val_precision_m: 0.9581 - val_recall_m: 0.9467 - val_rmse_m: 0.1303 - learning_rate: 1.0000e-06
# Epoch 90/100
# 745/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9905 - f1_m: 0.9899 - loss: 0.3835 - mae_m: 0.0494 - mape_m: 4.9420 - precision_m: 0.9918 - recall_m: 0.9881 - rmse_m: 0.0786
# Epoch 90: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9905 - f1_m: 0.9899 - loss: 0.3835 - mae_m: 0.0494 - mape_m: 4.9417 - precision_m: 0.9918 - recall_m: 0.9881 - rmse_m: 0.0786 - val_accuracy: 0.9532 - val_f1_m: 0.9521 - val_loss: 0.4502 - val_mae_m: 0.0605 - val_mape_m: 6.0525 - val_precision_m: 0.9578 - val_recall_m: 0.9466 - val_rmse_m: 0.1302 - learning_rate: 1.0000e-06
# Epoch 91/100
# 749/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9917 - f1_m: 0.9907 - loss: 0.3819 - mae_m: 0.0486 - mape_m: 4.8611 - precision_m: 0.9932 - recall_m: 0.9883 - rmse_m: 0.0769
# Epoch 91: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9917 - f1_m: 0.9907 - loss: 0.3819 - mae_m: 0.0486 - mape_m: 4.8611 - precision_m: 0.9932 - recall_m: 0.9883 - rmse_m: 0.0769 - val_accuracy: 0.9529 - val_f1_m: 0.9522 - val_loss: 0.4506 - val_mae_m: 0.0604 - val_mape_m: 6.0425 - val_precision_m: 0.9580 - val_recall_m: 0.9467 - val_rmse_m: 0.1302 - learning_rate: 1.0000e-06
# Epoch 92/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9914 - f1_m: 0.9912 - loss: 0.3830 - mae_m: 0.0491 - mape_m: 4.9111 - precision_m: 0.9930 - recall_m: 0.9895 - rmse_m: 0.0774
# Epoch 92: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9914 - f1_m: 0.9912 - loss: 0.3830 - mae_m: 0.0491 - mape_m: 4.9111 - precision_m: 0.9930 - recall_m: 0.9895 - rmse_m: 0.0774 - val_accuracy: 0.9528 - val_f1_m: 0.9521 - val_loss: 0.4503 - val_mae_m: 0.0605 - val_mape_m: 6.0548 - val_precision_m: 0.9577 - val_recall_m: 0.9466 - val_rmse_m: 0.1302 - learning_rate: 1.0000e-06
# Epoch 93/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9914 - f1_m: 0.9912 - loss: 0.3839 - mae_m: 0.0495 - mape_m: 4.9455 - precision_m: 0.9933 - recall_m: 0.9892 - rmse_m: 0.0782
# Epoch 93: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9914 - f1_m: 0.9912 - loss: 0.3839 - mae_m: 0.0495 - mape_m: 4.9455 - precision_m: 0.9933 - recall_m: 0.9892 - rmse_m: 0.0782 - val_accuracy: 0.9530 - val_f1_m: 0.9521 - val_loss: 0.4507 - val_mae_m: 0.0604 - val_mape_m: 6.0384 - val_precision_m: 0.9578 - val_recall_m: 0.9466 - val_rmse_m: 0.1302 - learning_rate: 1.0000e-06
# Epoch 94/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9917 - f1_m: 0.9914 - loss: 0.3816 - mae_m: 0.0486 - mape_m: 4.8608 - precision_m: 0.9933 - recall_m: 0.9895 - rmse_m: 0.0763
# Epoch 94: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9917 - f1_m: 0.9914 - loss: 0.3816 - mae_m: 0.0486 - mape_m: 4.8609 - precision_m: 0.9933 - recall_m: 0.9895 - rmse_m: 0.0763 - val_accuracy: 0.9530 - val_f1_m: 0.9523 - val_loss: 0.4506 - val_mae_m: 0.0605 - val_mape_m: 6.0545 - val_precision_m: 0.9580 - val_recall_m: 0.9469 - val_rmse_m: 0.1302 - learning_rate: 1.0000e-06
# Epoch 95/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9922 - f1_m: 0.9917 - loss: 0.3817 - mae_m: 0.0488 - mape_m: 4.8806 - precision_m: 0.9938 - recall_m: 0.9896 - rmse_m: 0.0766
# Epoch 95: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9922 - f1_m: 0.9917 - loss: 0.3817 - mae_m: 0.0488 - mape_m: 4.8806 - precision_m: 0.9938 - recall_m: 0.9896 - rmse_m: 0.0766 - val_accuracy: 0.9528 - val_f1_m: 0.9524 - val_loss: 0.4505 - val_mae_m: 0.0607 - val_mape_m: 6.0677 - val_precision_m: 0.9580 - val_recall_m: 0.9470 - val_rmse_m: 0.1303 - learning_rate: 1.0000e-06
# Epoch 96/100
# 747/750 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9909 - f1_m: 0.9906 - loss: 0.3825 - mae_m: 0.0486 - mape_m: 4.8647 - precision_m: 0.9927 - recall_m: 0.9885 - rmse_m: 0.0773
# Epoch 96: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9909 - f1_m: 0.9906 - loss: 0.3825 - mae_m: 0.0486 - mape_m: 4.8648 - precision_m: 0.9927 - recall_m: 0.9885 - rmse_m: 0.0773 - val_accuracy: 0.9525 - val_f1_m: 0.9522 - val_loss: 0.4506 - val_mae_m: 0.0607 - val_mape_m: 6.0670 - val_precision_m: 0.9579 - val_recall_m: 0.9467 - val_rmse_m: 0.1303 - learning_rate: 1.0000e-06
# Epoch 97/100
# 748/750 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9918 - f1_m: 0.9918 - loss: 0.3812 - mae_m: 0.0481 - mape_m: 4.8099 - precision_m: 0.9939 - recall_m: 0.9898 - rmse_m: 0.0753
# Epoch 97: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9918 - f1_m: 0.9918 - loss: 0.3812 - mae_m: 0.0481 - mape_m: 4.8102 - precision_m: 0.9939 - recall_m: 0.9898 - rmse_m: 0.0753 - val_accuracy: 0.9529 - val_f1_m: 0.9523 - val_loss: 0.4507 - val_mae_m: 0.0608 - val_mape_m: 6.0786 - val_precision_m: 0.9577 - val_recall_m: 0.9473 - val_rmse_m: 0.1304 - learning_rate: 1.0000e-06
# Epoch 98/100
# 745/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9918 - f1_m: 0.9915 - loss: 0.3818 - mae_m: 0.0488 - mape_m: 4.8803 - precision_m: 0.9934 - recall_m: 0.9896 - rmse_m: 0.0766
# Epoch 98: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9918 - f1_m: 0.9915 - loss: 0.3818 - mae_m: 0.0488 - mape_m: 4.8803 - precision_m: 0.9934 - recall_m: 0.9896 - rmse_m: 0.0766 - val_accuracy: 0.9529 - val_f1_m: 0.9525 - val_loss: 0.4508 - val_mae_m: 0.0606 - val_mape_m: 6.0585 - val_precision_m: 0.9581 - val_recall_m: 0.9471 - val_rmse_m: 0.1303 - learning_rate: 1.0000e-06
# Epoch 99/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9937 - f1_m: 0.9929 - loss: 0.3801 - mae_m: 0.0483 - mape_m: 4.8315 - precision_m: 0.9949 - recall_m: 0.9910 - rmse_m: 0.0749
# Epoch 99: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9937 - f1_m: 0.9929 - loss: 0.3801 - mae_m: 0.0483 - mape_m: 4.8316 - precision_m: 0.9949 - recall_m: 0.9910 - rmse_m: 0.0749 - val_accuracy: 0.9531 - val_f1_m: 0.9526 - val_loss: 0.4507 - val_mae_m: 0.0606 - val_mape_m: 6.0575 - val_precision_m: 0.9582 - val_recall_m: 0.9471 - val_rmse_m: 0.1302 - learning_rate: 1.0000e-06
# Epoch 100/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9906 - f1_m: 0.9906 - loss: 0.3832 - mae_m: 0.0491 - mape_m: 4.9087 - precision_m: 0.9923 - recall_m: 0.9890 - rmse_m: 0.0779
# Epoch 100: val_loss did not improve from 0.44628
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - accuracy: 0.9906 - f1_m: 0.9906 - loss: 0.3832 - mae_m: 0.0491 - mape_m: 4.9087 - precision_m: 0.9923 - recall_m: 0.9890 - rmse_m: 0.0779 - val_accuracy: 0.9530 - val_f1_m: 0.9526 - val_loss: 0.4508 - val_mae_m: 0.0604 - val_mape_m: 6.0412 - val_precision_m: 0.9581 - val_recall_m: 0.9473 - val_rmse_m: 0.1302 - learning_rate: 1.0000e-06

# %%
loss, accuracy, f1_score, precision, recall, mae, mape, rmse = model_CNN.evaluate(x_test, y_test, verbose=0)
print(f"Validation Loss: {loss:.4f}")
print(f"Accuracy: {accuracy:.4f}")
print(f"F1 Score: {f1_score:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.4f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
# Out:
# Validation Loss: 0.4455
# Accuracy: 0.9545
# F1 Score: 0.9542
# Precision: 0.9593
# Recall: 0.9500
# Mean Absolute Error (MAE): 0.0598
# Mean Absolute Percentage Error (MAPE): 5.9788
# Root Mean Squared Error (RMSE): 0.1279

# %% [markdown]
# **Visualizations**

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_actual_vs_predicted(model, x_test, y_test):
    # Predict
    y_pred_probs = model.predict(x_test, batch_size=64, verbose=1)
    y_pred = np.argmax(y_pred_probs, axis=1)
    y_true = np.argmax(y_test, axis=1)

    # Confirm correct number of samples
    print(f"Number of test samples: {len(y_true)}")
    print(f"Number of predictions: {len(y_pred)}")

    if len(y_true) != len(y_pred):
        print("Mismatch between test samples and predictions!")
        return

    # Classes
    classes = np.unique(y_true)
    print(f"Classes found in test set: {classes}")

    # True and Predicted counts
    true_counts = [np.sum(y_true == cls) for cls in classes]
    pred_counts = [np.sum(y_pred == cls) for cls in classes]

    # Correct predictions per class
    correct_counts = [np.sum((y_true == cls) & (y_pred == cls)) for cls in classes]

    # Per-class accuracy (percentage of correct predictions)
    class_accuracy = [
        (correct_counts[i] / true_counts[i]) * 100 if true_counts[i] != 0 else 0
        for i in range(len(classes))
    ]

    # Total accuracy
    total_correct = np.sum(y_true == y_pred)
    total_samples = len(y_true)
    total_accuracy = (total_correct / total_samples) * 100

    # Print per-class accuracy
    print("\nPer-Class Accuracy (Correct Predictions Percentage):")
    for i, acc in enumerate(class_accuracy):
        print(f"  Class {classes[i]}: {acc:.2f}%")
    print(f"\nTotal Test Accuracy: {total_accuracy:.2f}%")

    # Bar plot Actual vs Predicted
    x = np.arange(len(classes))
    width = 0.35

    fig, ax = plt.subplots(figsize=(10, 7))
    rects1 = ax.bar(x - width/2, true_counts, width, label='Actual Count', color='lightblue')
    rects2 = ax.bar(x + width/2, pred_counts, width, label='Predicted Count', color='salmon')

    ax.set_xlabel('Class Labels')
    ax.set_ylabel('Number of Samples')
    ax.set_title(f'Actual vs Predicted Samples (Total Accuracy: {total_accuracy:.2f}%)')
    ax.set_xticks(x)
    ax.set_xticklabels(classes)
    
    ax.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05),
              ncol=2, fancybox=True, shadow=True)


    # Annotate bar heights
    def autolabel(rects):
        for rect in rects:
            height = rect.get_height()
            ax.annotate(f'{int(height)}',
                        xy=(rect.get_x() + rect.get_width() / 2, height),
                        xytext=(0, 3),
                        textcoords="offset points",
                        ha='center', va='bottom')

    autolabel(rects1)
    autolabel(rects2)

    plt.tight_layout()
    plt.show()

# Example usage
plot_actual_vs_predicted(model_CNN, x_test, y_test)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Number of test samples: 8000
# Number of predictions: 8000
# Classes found in test set: [0 1 2 3]
#
# Per-Class Accuracy (Correct Predictions Percentage):
#   Class 0: 94.83%
#   Class 1: 95.82%
#   Class 2: 96.26%
#   Class 3: 94.82%
#
# Total Test Accuracy: 95.43%

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import precision_score, recall_score, f1_score

def plot_precision_recall_f1(model, x_test, y_test):
    # Predict
    y_pred_probs = model.predict(x_test, batch_size=64, verbose=1)
    y_pred = np.argmax(y_pred_probs, axis=1)
    y_true = np.argmax(y_test, axis=1)

    # Confirm correct number of samples
    print(f"Number of test samples: {len(y_true)}")
    print(f"Number of predictions: {len(y_pred)}")

    if len(y_true) != len(y_pred):
        print("Mismatch between test samples and predictions!")
        return

    # Classes
    classes = np.unique(y_true)
    print(f"Classes found in test set: {classes}")

    # Calculate metrics per class
    precision = precision_score(y_true, y_pred, labels=classes, average=None)
    recall = recall_score(y_true, y_pred, labels=classes, average=None)
    f1 = f1_score(y_true, y_pred, labels=classes, average=None)
       # Print
    print("\nPer-Class Precision, Recall, F1-Score:")
    for idx, cls in enumerate(classes):
        print(f"Class {cls} -> Precision: {precision[idx]:.4f}, Recall: {recall[idx]:.4f}, F1-Score: {f1[idx]:.4f}")

    # Plot
    x = np.arange(len(classes))
    width = 0.25  # bar width

    fig, ax = plt.subplots(figsize=(12, 7))
    rects1 = ax.bar(x - width, precision, width, label='Precision', color='skyblue')
    rects2 = ax.bar(x, recall, width, label='Recall', color='lightgreen')
    rects3 = ax.bar(x + width, f1, width, label='F1-Score', color='salmon')

    ax.set_xlabel('Class Labels')
    ax.set_ylabel('Score')
    ax.set_title('Precision, Recall, F1-Score per Class')
    ax.set_xticks(x)
    ax.set_xticklabels(classes)
    ax.set_ylim(0, 1.05)
    ax.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05),
              ncol=3, fancybox=True, shadow=True)
        # Annotate bar heights
    def autolabel(rects):
        for rect in rects:
            height = rect.get_height()
            ax.annotate(f'{height:.2f}',
                        xy=(rect.get_x() + rect.get_width() / 2, height),
                        xytext=(0, 3),
                        textcoords="offset points",
                        ha='center', va='bottom')

    autolabel(rects1)
    autolabel(rects2)
    autolabel(rects3)

    plt.tight_layout()
    plt.show()

# Example usage
plot_precision_recall_f1(model_CNN, x_test, y_test)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Number of test samples: 8000
# Number of predictions: 8000
# Classes found in test set: [0 1 2 3]
#
# Per-Class Precision, Recall, F1-Score:
# Class 0 -> Precision: 0.9359, Recall: 0.9483, F1-Score: 0.9420
# Class 1 -> Precision: 0.9652, Recall: 0.9582, F1-Score: 0.9617
# Class 2 -> Precision: 0.9626, Recall: 0.9626, F1-Score: 0.9626
# Class 3 -> Precision: 0.9543, Recall: 0.9482, F1-Score: 0.9512
