# %%
# !pip install pyts
# Out:
# Collecting pyts
#   Downloading pyts-0.13.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.26.4)
# Requirement already satisfied: scipy>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.15.2)
# Requirement already satisfied: scikit-learn>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from pyts) (1.4.2)
# Requirement already satisfied: numba>=0.55.2 in /usr/local/lib/python3.11/dist-packages (from pyts) (0.60.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.55.2->pyts) (0.43.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.22.4->pyts) (2.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.2.0->pyts) (3.6.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.22.4->pyts) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.22.4->pyts) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.22.4->pyts) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.22.4->pyts) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.22.4->pyts) (2024.2.0)
# Downloading pyts-0.13.0-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 26.3 MB/s eta 0:00:0000:010:01
# Installing collected packages: pyts
# Successfully installed pyts-0.13.0

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt

from mpl_toolkits.axes_grid1 import ImageGrid
from pyts.image import GramianAngularField
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

def root_directory():
    """Returns the root directory of the project."""
    return "/kaggle/input/swell-heart-rate-variability-hrv/hrv dataset"
def data_directory():
    """Returns the data directory path."""
    return os.path.join(root_directory(), "data")
def load_train_set():
    """Loads training dataset as a Pandas DataFrame."""
    train_file = os.path.join(data_directory(), "final", "train.csv")
    return pd.read_csv(train_file)
def load_test_set():
    """Loads test dataset as a Pandas DataFrame."""
    test_file = os.path.join(data_directory(), "final", "test.csv")
    return pd.read_csv(test_file)
train = load_train_set()
test = load_test_set()
target = "condition"
hrv_features = [col for col in train.columns if col != target]
label_map = {"no stress": 0, "interruption": 1, "time pressure": 2}
train[target] = train[target].map(label_map)
test[target] = test[target].map(label_map)

def sample_data(df, label_col, n_samples):
    """Safely sample n_samples per class without errors."""
    sampled_df = []
    for label in df[label_col].unique():
        class_data = df[df[label_col] == label]
        sample_size = min(n_samples, len(class_data))  
        sampled_df.append(class_data.sample(n=sample_size, random_state=42))
    return pd.concat(sampled_df).reset_index(drop=True)

train_balanced = sample_data(train, target, 10000)
test_balanced = sample_data(test, target, 3000) 

X_train = train_balanced[hrv_features]
y_train = train_balanced[target]
if "datasetId" in X_train.columns:
    X_train = X_train.drop(columns="datasetId")

X_test = test_balanced[hrv_features]
y_test = test_balanced[target]

if "datasetId" in X_test.columns:
    X_test = X_test.drop(columns="datasetId")

print(f"Train Set Shape: {X_train.shape}, Labels Shape: {y_train.shape}")
print(f"Test Set Shape: {X_test.shape}, Labels Shape: {y_test.shape}")

display(X_train.head())
display(y_train.head())
# Out:
# Train Set Shape: (30000, 34), Labels Shape: (30000,)
# Test Set Shape: (9000, 34), Labels Shape: (9000,)
#       MEAN_RR   MEDIAN_RR        SDRR      RMSSD       SDSD  SDRR_RMSSD  \
# 0  896.720876  880.459590  106.101117  13.924951  13.924949    7.619497
# 1  903.325242  905.495460   72.285411  12.387407  12.386563    5.835395
# 2  934.870026  916.307545  128.556268  16.728592  16.728579    7.684823
# 3  726.048217  726.396200   58.167902   9.760850   9.760850    5.959307
# 4  903.212333  918.237180  108.998652  16.905228  16.905228    6.447630
#
#           HR      pNN25     pNN50        SD1  ...     LF_PCT      LF_NU  \
# 0  67.818401   7.733333  0.466667   9.849712  ...  28.035932  98.809256
# 1  66.855229   4.466667  0.133333   8.761546  ...  23.244445  99.726832
# 2  65.364253  13.200000  1.066667  11.832839  ...  28.280122  99.507931
# 3  83.181060   1.400000  0.000000   6.904267  ...  22.022647  93.990424
# 4  67.479959  12.400000  1.333333  11.957790  ...  23.825552  98.769012
#
#           HF    HF_PCT     HF_NU           TP       LF_HF     HF_LF    sampen  \
# 0   9.922258  0.337859  1.190744  2936.803667   82.981135  0.012051  2.127076
# 1   1.783522  0.063670  0.273168  2801.178306  365.074431  0.002739  2.192351
# 2   6.164162  0.139846  0.492069  4407.828115  202.223606  0.004945  2.160318
# 3  26.015607  1.408088  6.009576  1847.584044   15.640109  0.063938  2.157452
# 4  13.625402  0.296945  1.230988  4588.526989   80.235569  0.012463  2.179244
#
#      higuci
# 0  1.134921
# 1  1.069071
# 2  1.126186
# 3  1.152640
# 4  1.177820
#
# [5 rows x 34 columns]
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: condition, dtype: int64

# %%
def quantile_normalize(df):
    """Applies quantile normalization to the DataFrame."""
    df_sorted = pd.DataFrame(np.sort(df.values, axis=0), index=df.index, columns=df.columns)
    df_mean = df_sorted.mean(axis=1)
    df_mean.index = np.arange(1, len(df_mean) + 1)
    df_qn = df.rank(method="min").stack().astype(int).map(df_mean).unstack()
    return df_qn

x_train_swell = quantile_normalize(X_train)
x_test_swell = quantile_normalize(X_test)

display(x_train_swell.head())
display(x_test_swell.head())
print(x_train_swell.describe())
print(x_test_swell.describe())
# Out:
#       MEAN_RR   MEDIAN_RR        SDRR       RMSSD        SDSD  SDRR_RMSSD  \
# 0  276.697101  261.548330  281.634094  201.939225  201.948873  306.099269
# 1  283.060633  290.437894  183.073989  167.021640  166.952993  215.238532
# 2  312.856441  298.311570  333.659979  277.912510  277.935225  309.649467
# 3  118.124366  124.548167  136.809099  117.415260  117.430190  221.768654
# 4  282.869530  300.263695  289.169845  283.041251  283.046942  248.500700
#
#            HR       pNN25       pNN50         SD1  ...      LF_PCT  \
# 0  186.792253  220.098299  219.751609  201.948873  ...  209.281585
# 1  178.099179  165.854182  166.058400  166.952993  ...  175.512435
# 2  167.908511  315.431057  277.893149  277.935225  ...  211.163474
# 3  463.050505  112.676927   57.594885  117.430190  ...  165.622387
# 4  183.634928  300.234227  309.342415  283.046942  ...  179.713401
#
#         LF_NU          HF      HF_PCT       HF_NU          TP       LF_HF  \
# 0  309.383929  166.989622  170.844721  172.502720  229.176610  309.383929
# 1  527.319177  104.591577  111.702021  111.394438  220.181001  527.319177
# 2  434.164037  141.753598  139.078646  129.723889  339.437487  434.164037
# 3  158.516499  250.212396  280.129440  339.707893  158.679659  158.516499
# 4  305.818680  184.847490  165.565337  174.383861  355.878824  305.818680
#
#         HF_LF      sampen      higuci
# 0  172.502720  220.280335  160.774105
# 1  111.394438  390.664047   91.473882
# 2  129.723889  264.643133  147.015168
# 3  339.707893  259.802904  193.893174
# 4  174.383861  315.449174  240.393451
#
# [5 rows x 34 columns]
#       MEAN_RR   MEDIAN_RR        SDRR       RMSSD        SDSD  SDRR_RMSSD  \
# 0  154.981903  130.948799  357.917964  218.603896  218.603896  399.488499
# 1  206.332670  212.064032  158.559158  158.894224  158.894224  188.846044
# 2  108.774609  110.761248  174.510012  123.887169  123.887169  272.919928
# 3  184.635339  206.397936  343.041840  204.879360  204.879360  387.853716
# 4  173.729083  170.568761  115.378578  158.499353  158.499353  143.334814
#
#            HR       pNN25       pNN50         SD1  ...      LF_PCT  \
# 0  376.844594  226.243094  239.203434  218.603896  ...  181.232421
# 1  240.684831  152.445046   58.596835  158.894224  ...  190.435567
# 2  513.057777  134.679136   58.596835  123.887169  ...  207.303791
# 3  305.771471  206.484818  278.290686  204.879360  ...  166.258531
# 4  289.746416  143.353928   58.596835  158.499353  ...  522.481666
#
#         LF_NU          HF      HF_PCT       HF_NU          TP       LF_HF  \
# 0  142.039242  396.002894  311.944479  386.663115  242.885987  142.039242
# 1  171.716120  259.323638  280.144485  306.319210  163.331167  171.716120
# 2  223.802244  209.252014  228.533895  232.983896  175.664416  223.802244
# 3  211.404028  272.407888  219.344145  244.743676  281.113670  211.404028
# 4  276.389324  196.987243  244.559104  188.324377  140.363456  276.389324
#
#         HF_LF      sampen      higuci
# 0  386.663115   94.875043  272.298257
# 1  306.319210  250.749993  301.416603
# 2  232.983896  297.822034  161.413623
# 3  244.743676  194.813778  174.500443
# 4  188.324377  267.048739  166.388660
#
# [5 rows x 34 columns]
#             MEAN_RR     MEDIAN_RR          SDRR         RMSSD          SDSD  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean     272.534334    272.434753    272.534334    272.534334    272.534334
# std      161.064480    160.681748    161.064480    161.064480    161.064480
# min       57.594885     57.594885     57.594885     57.594885     57.594885
# 25%      161.769849    161.769849    161.769849    161.769849    161.769849
# 50%      229.496375    229.489324    229.496375    229.496375    229.496375
# 75%      332.274137    332.242212    332.274137    332.274137    332.274137
# max     1242.394745   1144.375092   1242.394745   1242.394745   1242.394745
#
#          SDRR_RMSSD            HR         pNN25         pNN50           SD1  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean     272.534334    272.534334    271.779447    253.502644    272.534334
# std      161.064480    161.064480    160.934737    173.991796    161.064480
# min       57.594885     57.594885     57.594885     57.594885     57.594885
# 25%      161.769849    161.769849    161.525190    157.635702    161.769849
# 50%      229.496375    229.496375    228.712355    224.236676    229.496375
# 75%      332.274137    332.274137    331.051105    332.262775    332.274137
# max     1242.394745   1242.394745   1242.394745   1242.394745   1242.394745
#
#        ...        LF_PCT         LF_NU            HF        HF_PCT  \
# count  ...  30000.000000  30000.000000  30000.000000  30000.000000
# mean   ...    272.534334    272.534334    272.534334    272.534334
# std    ...    161.064480    161.064480    161.064480    161.064480
# min    ...     57.594885     57.594885     57.594885     57.594885
# 25%    ...    161.769849    161.769849    161.769849    161.769849
# 50%    ...    229.496375    229.496375    229.496375    229.496375
# 75%    ...    332.274137    332.274137    332.274137    332.274137
# max    ...   1242.394745   1242.394745   1242.394745   1242.394745
#
#               HF_NU            TP         LF_HF         HF_LF        sampen  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean     272.534334    272.534334    272.534334    272.534334    272.518826
# std      161.064480    161.064480    161.064480    161.064480    161.039607
# min       57.594885     57.594885     57.594885     57.594885     57.594885
# 25%      161.769849    161.769849    161.769849    161.769849    161.768069
# 50%      229.496375    229.496375    229.496375    229.496375    229.496375
# 75%      332.274137    332.274137    332.274137    332.274137    332.262775
# max     1242.394745   1242.394745   1242.394745   1242.394745   1242.394745
#
#              higuci
# count  30000.000000
# mean     272.534334
# std      161.064480
# min       57.594885
# 25%      161.769849
# 50%      229.496375
# 75%      332.274137
# max     1242.394745
#
# [8 rows x 34 columns]
#            MEAN_RR    MEDIAN_RR         SDRR        RMSSD         SDSD  \
# count  9000.000000  9000.000000  9000.000000  9000.000000  9000.000000
# mean    270.802541   270.717383   270.802541   270.802541   270.802541
# std     160.659658   160.343754   160.659658   160.659658   160.659658
# min      58.596835    58.596835    58.596835    58.596835    58.596835
# 25%     160.556477   160.556477   160.556477   160.556477   160.556477
# 50%     228.452560   228.452560   228.452560   228.452560   228.452560
# 75%     330.168948   330.168948   330.168948   330.168948   330.168948
# max    1234.324066  1167.337049  1234.324066  1234.324066  1234.324066
#
#         SDRR_RMSSD           HR        pNN25        pNN50          SD1  ...  \
# count  9000.000000  9000.000000  9000.000000  9000.000000  9000.000000  ...
# mean    270.802541   270.802541   270.047725   252.342726   270.802541  ...
# std     160.659658   160.659658   160.541381   173.061263   160.659658  ...
# min      58.596835    58.596835    58.596835    58.596835    58.596835  ...
# 25%     160.556477   160.556477   160.241940   156.411510   160.556477  ...
# 50%     228.452560   228.452560   227.704178   223.068524   228.452560  ...
# 75%     330.168948   330.168948   329.177168   327.284772   330.168948  ...
# max    1234.324066  1234.324066  1234.324066  1234.324066  1234.324066  ...
#
#             LF_PCT        LF_NU           HF       HF_PCT        HF_NU  \
# count  9000.000000  9000.000000  9000.000000  9000.000000  9000.000000
# mean    270.802541   270.802541   270.802541   270.802541   270.802541
# std     160.659658   160.659658   160.659658   160.659658   160.659658
# min      58.596835    58.596835    58.596835    58.596835    58.596835
# 25%     160.556477   160.556477   160.556477   160.556477   160.556477
# 50%     228.452560   228.452560   228.452560   228.452560   228.452560
# 75%     330.168948   330.168948   330.168948   330.168948   330.168948
# max    1234.324066  1234.324066  1234.324066  1234.324066  1234.324066
#
#                 TP        LF_HF        HF_LF       sampen       higuci
# count  9000.000000  9000.000000  9000.000000  9000.000000  9000.000000
# mean    270.802541   270.802541   270.802541   270.783826   270.802541
# std     160.659658   160.659658   160.659658   160.619619   160.659658
# min      58.596835    58.596835    58.596835    58.596835    58.596835
# 25%     160.556477   160.556477   160.556477   160.535503   160.556477
# 50%     228.452560   228.452560   228.452560   228.452560   228.452560
# 75%     330.168948   330.168948   330.168948   330.120840   330.168948
# max    1234.324066  1234.324066  1234.324066  1234.324066  1234.324066
#
# [8 rows x 34 columns]

# %%
gaf = GramianAngularField()

X_train_gaf = gaf.fit_transform(X_train.to_numpy())
X_test_gaf = gaf.fit_transform(X_test.to_numpy())

X_train_gaf = X_train_gaf.reshape(X_train_gaf.shape[0], 34, 34, 1)
X_test_gaf = X_test_gaf.reshape(X_test_gaf.shape[0], 34, 34, 1)

X_train_gaf /= np.max(X_train_gaf, axis=(1, 2, 3), keepdims=True)
X_test_gaf /= np.max(X_test_gaf, axis=(1, 2, 3), keepdims=True)

y_train = tf.keras.utils.to_categorical(y_train, num_classes=3)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=3)
print(X_train_gaf.shape)
print(X_test_gaf.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (30000, 34, 34, 1)
# (9000, 34, 34, 1)
# (30000, 3)
# (9000, 3)

# %%
# Custom Metrics
def recall_m(y_true, y_pred):
    true_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_true * y_pred, 0, 1)))
    possible_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + tf.keras.backend.epsilon())

def precision_m(y_true, y_pred):
    true_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_true * y_pred, 0, 1)))
    predicted_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_pred, 0, 1)))
    return true_positives / (predicted_positives + tf.keras.backend.epsilon())

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2 * ((precision * recall) / (precision + recall + tf.keras.backend.epsilon()))

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Conv2D, BatchNormalization, MaxPooling2D,
                                     Reshape, GRU, Dense, Dropout)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

def cnn_gru_for_swell():
    input_layer = Input(shape=(34, 34, 1))  # GAF image shape for SWELL
    
    # CNN Block
    x = Conv2D(32, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001))(input_layer)
    x = BatchNormalization()(x)
    
    x = Conv2D(64, (3, 3), activation='relu', padding='same', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)

    x = MaxPooling2D(pool_size=(2, 2))(x)  # Output: (17, 17, 64)

    # Reshape for GRU: Flatten spatial dims and treat as a sequence
    x = Reshape((17, 17 * 64))(x)  # Sequence length = 17, features = 1088
    
    # GRU Block
    x = GRU(64, return_sequences=False)(x)
    x = Dropout(0.3)(x)

    # Dense Layers
    x = Dense(64, activation='relu')(x)
    x = Dropout(0.2)(x)
    
    output = Dense(3, activation='softmax')(x)  # 3-class output for SWELL

    model = Model(inputs=input_layer, outputs=output)
    
    model.compile(optimizer=Adam(learning_rate=0.0005),
                  loss='categorical_crossentropy',
                  metrics=['accuracy', f1_m, precision_m, recall_m])

    return model

model_cnn_gru_swell = cnn_gru_for_swell()
model_cnn_gru_swell.summary()
# Out:
# 2025-04-15 08:38:25.500927: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 34, 34, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 34, 34, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 34, 34, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 34, 34, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 34, 34, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 17, 17, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ reshape (Reshape)                    │ (None, 17, 1088)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru (GRU)                            │ (None, 64)                  │         221,568 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3)                   │             195 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 245,123 (957.51 KB)
#  Trainable params: 244,931 (956.76 KB)
#  Non-trainable params: 192 (768.00 B)

# %%
from tensorflow.keras import callbacks
# --- Callbacks ---
reduce_lr = callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-5,
    verbose=1
)
model_checkpoint = callbacks.ModelCheckpoint("/kaggle/working/best_model.keras", save_best_only=True, monitor='val_loss', verbose=1)

# --- Train ---
history = model_cnn_gru_swell.fit(
    X_train_gaf, y_train,
    validation_data=(X_test_gaf, y_test),
    epochs=100,
    batch_size=64,
    shuffle=True,
    callbacks=[model_checkpoint, reduce_lr]
)
# Out:
# Epoch 1/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.4480 - f1_m: 0.2607 - loss: 1.0783 - precision_m: 0.5744 - recall_m: 0.1732
# Epoch 1: val_loss improved from inf to 0.98621, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 221ms/step - accuracy: 0.4480 - f1_m: 0.2608 - loss: 1.0782 - precision_m: 0.5744 - recall_m: 0.1733 - val_accuracy: 0.5232 - val_f1_m: 0.3458 - val_loss: 0.9862 - val_precision_m: 0.5951 - val_recall_m: 0.2475 - learning_rate: 5.0000e-04
# Epoch 2/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.5369 - f1_m: 0.4179 - loss: 0.9772 - precision_m: 0.6618 - recall_m: 0.3092
# Epoch 2: val_loss improved from 0.98621 to 0.88855, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 220ms/step - accuracy: 0.5369 - f1_m: 0.4179 - loss: 0.9771 - precision_m: 0.6619 - recall_m: 0.3093 - val_accuracy: 0.5801 - val_f1_m: 0.4811 - val_loss: 0.8885 - val_precision_m: 0.7070 - val_recall_m: 0.3702 - learning_rate: 5.0000e-04
# Epoch 3/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.5855 - f1_m: 0.5180 - loss: 0.9005 - precision_m: 0.6882 - recall_m: 0.4173
# Epoch 3: val_loss improved from 0.88855 to 0.80412, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 104s 222ms/step - accuracy: 0.5855 - f1_m: 0.5181 - loss: 0.9004 - precision_m: 0.6883 - recall_m: 0.4174 - val_accuracy: 0.6382 - val_f1_m: 0.5601 - val_loss: 0.8041 - val_precision_m: 0.7403 - val_recall_m: 0.4524 - learning_rate: 5.0000e-04
# Epoch 4/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.6226 - f1_m: 0.5672 - loss: 0.8355 - precision_m: 0.7063 - recall_m: 0.4762
# Epoch 4: val_loss improved from 0.80412 to 0.72460, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 220ms/step - accuracy: 0.6226 - f1_m: 0.5673 - loss: 0.8354 - precision_m: 0.7063 - recall_m: 0.4762 - val_accuracy: 0.6999 - val_f1_m: 0.6487 - val_loss: 0.7246 - val_precision_m: 0.7772 - val_recall_m: 0.5579 - learning_rate: 5.0000e-04
# Epoch 5/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.6636 - f1_m: 0.6297 - loss: 0.7696 - precision_m: 0.7271 - recall_m: 0.5568
# Epoch 5: val_loss improved from 0.72460 to 0.67004, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 107s 228ms/step - accuracy: 0.6636 - f1_m: 0.6297 - loss: 0.7695 - precision_m: 0.7271 - recall_m: 0.5569 - val_accuracy: 0.7322 - val_f1_m: 0.6975 - val_loss: 0.6700 - val_precision_m: 0.7741 - val_recall_m: 0.6357 - learning_rate: 5.0000e-04
# Epoch 6/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.7029 - f1_m: 0.6847 - loss: 0.7030 - precision_m: 0.7522 - recall_m: 0.6294
# Epoch 6: val_loss improved from 0.67004 to 0.60122, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 220ms/step - accuracy: 0.7029 - f1_m: 0.6847 - loss: 0.7030 - precision_m: 0.7522 - recall_m: 0.6294 - val_accuracy: 0.7606 - val_f1_m: 0.7408 - val_loss: 0.6012 - val_precision_m: 0.8079 - val_recall_m: 0.6854 - learning_rate: 5.0000e-04
# Epoch 7/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.7313 - f1_m: 0.7201 - loss: 0.6513 - precision_m: 0.7683 - recall_m: 0.6784
# Epoch 7: val_loss improved from 0.60122 to 0.55644, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 108s 229ms/step - accuracy: 0.7314 - f1_m: 0.7201 - loss: 0.6513 - precision_m: 0.7683 - recall_m: 0.6784 - val_accuracy: 0.7799 - val_f1_m: 0.7732 - val_loss: 0.5564 - val_precision_m: 0.8191 - val_recall_m: 0.7330 - learning_rate: 5.0000e-04
# Epoch 8/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.7642 - f1_m: 0.7575 - loss: 0.5995 - precision_m: 0.7925 - recall_m: 0.7259
# Epoch 8: val_loss improved from 0.55644 to 0.48418, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 219ms/step - accuracy: 0.7642 - f1_m: 0.7575 - loss: 0.5994 - precision_m: 0.7925 - recall_m: 0.7259 - val_accuracy: 0.8246 - val_f1_m: 0.8204 - val_loss: 0.4842 - val_precision_m: 0.8479 - val_recall_m: 0.7952 - learning_rate: 5.0000e-04
# Epoch 9/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.7890 - f1_m: 0.7845 - loss: 0.5450 - precision_m: 0.8121 - recall_m: 0.7591
# Epoch 9: val_loss improved from 0.48418 to 0.44567, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 107s 227ms/step - accuracy: 0.7890 - f1_m: 0.7845 - loss: 0.5450 - precision_m: 0.8121 - recall_m: 0.7591 - val_accuracy: 0.8348 - val_f1_m: 0.8351 - val_loss: 0.4457 - val_precision_m: 0.8574 - val_recall_m: 0.8143 - learning_rate: 5.0000e-04
# Epoch 10/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.7992 - f1_m: 0.7974 - loss: 0.5232 - precision_m: 0.8223 - recall_m: 0.7743
# Epoch 10: val_loss did not improve from 0.44567
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 219ms/step - accuracy: 0.7992 - f1_m: 0.7974 - loss: 0.5232 - precision_m: 0.8223 - recall_m: 0.7743 - val_accuracy: 0.8144 - val_f1_m: 0.8130 - val_loss: 0.4754 - val_precision_m: 0.8285 - val_recall_m: 0.7984 - learning_rate: 5.0000e-04
# Epoch 11/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.8208 - f1_m: 0.8188 - loss: 0.4757 - precision_m: 0.8383 - recall_m: 0.8006
# Epoch 11: val_loss improved from 0.44567 to 0.40885, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 102s 218ms/step - accuracy: 0.8208 - f1_m: 0.8188 - loss: 0.4757 - precision_m: 0.8383 - recall_m: 0.8006 - val_accuracy: 0.8500 - val_f1_m: 0.8468 - val_loss: 0.4089 - val_precision_m: 0.8690 - val_recall_m: 0.8259 - learning_rate: 5.0000e-04
# Epoch 12/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.8271 - f1_m: 0.8251 - loss: 0.4603 - precision_m: 0.8444 - recall_m: 0.8069
# Epoch 12: val_loss improved from 0.40885 to 0.37466, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 104s 222ms/step - accuracy: 0.8271 - f1_m: 0.8251 - loss: 0.4603 - precision_m: 0.8445 - recall_m: 0.8069 - val_accuracy: 0.8592 - val_f1_m: 0.8585 - val_loss: 0.3747 - val_precision_m: 0.8748 - val_recall_m: 0.8430 - learning_rate: 5.0000e-04
# Epoch 13/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.8420 - f1_m: 0.8406 - loss: 0.4217 - precision_m: 0.8569 - recall_m: 0.8252
# Epoch 13: val_loss did not improve from 0.37466
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 104s 221ms/step - accuracy: 0.8420 - f1_m: 0.8406 - loss: 0.4217 - precision_m: 0.8569 - recall_m: 0.8252 - val_accuracy: 0.8386 - val_f1_m: 0.8356 - val_loss: 0.4110 - val_precision_m: 0.8536 - val_recall_m: 0.8187 - learning_rate: 5.0000e-04
# Epoch 14/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.8485 - f1_m: 0.8479 - loss: 0.4115 - precision_m: 0.8630 - recall_m: 0.8335
# Epoch 14: val_loss improved from 0.37466 to 0.34743, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 142s 220ms/step - accuracy: 0.8486 - f1_m: 0.8479 - loss: 0.4115 - precision_m: 0.8630 - recall_m: 0.8336 - val_accuracy: 0.8781 - val_f1_m: 0.8781 - val_loss: 0.3474 - val_precision_m: 0.8929 - val_recall_m: 0.8642 - learning_rate: 5.0000e-04
# Epoch 15/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.8600 - f1_m: 0.8594 - loss: 0.3809 - precision_m: 0.8724 - recall_m: 0.8471
# Epoch 15: val_loss improved from 0.34743 to 0.31514, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 111s 236ms/step - accuracy: 0.8600 - f1_m: 0.8594 - loss: 0.3809 - precision_m: 0.8724 - recall_m: 0.8471 - val_accuracy: 0.8898 - val_f1_m: 0.8888 - val_loss: 0.3151 - val_precision_m: 0.8997 - val_recall_m: 0.8784 - learning_rate: 5.0000e-04
# Epoch 16/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.8635 - f1_m: 0.8630 - loss: 0.3753 - precision_m: 0.8754 - recall_m: 0.8511
# Epoch 16: val_loss improved from 0.31514 to 0.30690, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 109s 233ms/step - accuracy: 0.8635 - f1_m: 0.8630 - loss: 0.3752 - precision_m: 0.8754 - recall_m: 0.8511 - val_accuracy: 0.8942 - val_f1_m: 0.8929 - val_loss: 0.3069 - val_precision_m: 0.9106 - val_recall_m: 0.8761 - learning_rate: 5.0000e-04
# Epoch 17/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.8727 - f1_m: 0.8710 - loss: 0.3520 - precision_m: 0.8837 - recall_m: 0.8589
# Epoch 17: val_loss improved from 0.30690 to 0.29016, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 106s 226ms/step - accuracy: 0.8727 - f1_m: 0.8710 - loss: 0.3520 - precision_m: 0.8837 - recall_m: 0.8589 - val_accuracy: 0.8934 - val_f1_m: 0.8941 - val_loss: 0.2902 - val_precision_m: 0.9069 - val_recall_m: 0.8819 - learning_rate: 5.0000e-04
# Epoch 18/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.8752 - f1_m: 0.8761 - loss: 0.3417 - precision_m: 0.8868 - recall_m: 0.8658
# Epoch 18: val_loss did not improve from 0.29016
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 220ms/step - accuracy: 0.8752 - f1_m: 0.8761 - loss: 0.3417 - precision_m: 0.8868 - recall_m: 0.8658 - val_accuracy: 0.8933 - val_f1_m: 0.8921 - val_loss: 0.2973 - val_precision_m: 0.9029 - val_recall_m: 0.8818 - learning_rate: 5.0000e-04
# Epoch 19/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.8844 - f1_m: 0.8838 - loss: 0.3263 - precision_m: 0.8936 - recall_m: 0.8744
# Epoch 19: val_loss improved from 0.29016 to 0.27368, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 219ms/step - accuracy: 0.8844 - f1_m: 0.8838 - loss: 0.3263 - precision_m: 0.8936 - recall_m: 0.8744 - val_accuracy: 0.9024 - val_f1_m: 0.9011 - val_loss: 0.2737 - val_precision_m: 0.9111 - val_recall_m: 0.8915 - learning_rate: 5.0000e-04
# Epoch 20/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.8936 - f1_m: 0.8929 - loss: 0.3057 - precision_m: 0.9015 - recall_m: 0.8847
# Epoch 20: val_loss improved from 0.27368 to 0.24564, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 102s 217ms/step - accuracy: 0.8936 - f1_m: 0.8929 - loss: 0.3057 - precision_m: 0.9015 - recall_m: 0.8846 - val_accuracy: 0.9168 - val_f1_m: 0.9152 - val_loss: 0.2456 - val_precision_m: 0.9238 - val_recall_m: 0.9068 - learning_rate: 5.0000e-04
# Epoch 21/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9030 - f1_m: 0.9027 - loss: 0.2816 - precision_m: 0.9102 - recall_m: 0.8955
# Epoch 21: val_loss did not improve from 0.24564
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 220ms/step - accuracy: 0.9030 - f1_m: 0.9027 - loss: 0.2817 - precision_m: 0.9102 - recall_m: 0.8954 - val_accuracy: 0.9156 - val_f1_m: 0.9156 - val_loss: 0.2458 - val_precision_m: 0.9213 - val_recall_m: 0.9100 - learning_rate: 5.0000e-04
# Epoch 22/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9077 - f1_m: 0.9074 - loss: 0.2787 - precision_m: 0.9144 - recall_m: 0.9006
# Epoch 22: val_loss improved from 0.24564 to 0.22784, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 220ms/step - accuracy: 0.9077 - f1_m: 0.9074 - loss: 0.2787 - precision_m: 0.9144 - recall_m: 0.9006 - val_accuracy: 0.9228 - val_f1_m: 0.9215 - val_loss: 0.2278 - val_precision_m: 0.9276 - val_recall_m: 0.9155 - learning_rate: 5.0000e-04
# Epoch 23/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9057 - f1_m: 0.9055 - loss: 0.2788 - precision_m: 0.9115 - recall_m: 0.8996
# Epoch 23: val_loss did not improve from 0.22784
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 102s 217ms/step - accuracy: 0.9057 - f1_m: 0.9055 - loss: 0.2787 - precision_m: 0.9115 - recall_m: 0.8996 - val_accuracy: 0.9201 - val_f1_m: 0.9205 - val_loss: 0.2310 - val_precision_m: 0.9247 - val_recall_m: 0.9164 - learning_rate: 5.0000e-04
# Epoch 24/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9102 - f1_m: 0.9099 - loss: 0.2628 - precision_m: 0.9161 - recall_m: 0.9038
# Epoch 24: val_loss improved from 0.22784 to 0.20965, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 107s 228ms/step - accuracy: 0.9102 - f1_m: 0.9099 - loss: 0.2628 - precision_m: 0.9161 - recall_m: 0.9038 - val_accuracy: 0.9309 - val_f1_m: 0.9305 - val_loss: 0.2097 - val_precision_m: 0.9357 - val_recall_m: 0.9254 - learning_rate: 5.0000e-04
# Epoch 25/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9146 - f1_m: 0.9143 - loss: 0.2558 - precision_m: 0.9208 - recall_m: 0.9080
# Epoch 25: val_loss improved from 0.20965 to 0.20660, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 102s 217ms/step - accuracy: 0.9146 - f1_m: 0.9143 - loss: 0.2558 - precision_m: 0.9208 - recall_m: 0.9080 - val_accuracy: 0.9289 - val_f1_m: 0.9281 - val_loss: 0.2066 - val_precision_m: 0.9322 - val_recall_m: 0.9241 - learning_rate: 5.0000e-04
# Epoch 26/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9200 - f1_m: 0.9197 - loss: 0.2418 - precision_m: 0.9240 - recall_m: 0.9155
# Epoch 26: val_loss improved from 0.20660 to 0.19256, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 101s 215ms/step - accuracy: 0.9200 - f1_m: 0.9197 - loss: 0.2418 - precision_m: 0.9240 - recall_m: 0.9155 - val_accuracy: 0.9382 - val_f1_m: 0.9381 - val_loss: 0.1926 - val_precision_m: 0.9428 - val_recall_m: 0.9335 - learning_rate: 5.0000e-04
# Epoch 27/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9244 - f1_m: 0.9243 - loss: 0.2315 - precision_m: 0.9289 - recall_m: 0.9199
# Epoch 27: val_loss did not improve from 0.19256
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 100s 214ms/step - accuracy: 0.9244 - f1_m: 0.9243 - loss: 0.2315 - precision_m: 0.9289 - recall_m: 0.9199 - val_accuracy: 0.9343 - val_f1_m: 0.9337 - val_loss: 0.2100 - val_precision_m: 0.9395 - val_recall_m: 0.9280 - learning_rate: 5.0000e-04
# Epoch 28/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9231 - f1_m: 0.9233 - loss: 0.2385 - precision_m: 0.9274 - recall_m: 0.9193
# Epoch 28: val_loss did not improve from 0.19256
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 101s 216ms/step - accuracy: 0.9231 - f1_m: 0.9233 - loss: 0.2385 - precision_m: 0.9274 - recall_m: 0.9193 - val_accuracy: 0.9217 - val_f1_m: 0.9214 - val_loss: 0.2273 - val_precision_m: 0.9236 - val_recall_m: 0.9192 - learning_rate: 5.0000e-04
# Epoch 29/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9269 - f1_m: 0.9271 - loss: 0.2268 - precision_m: 0.9318 - recall_m: 0.9225
# Epoch 29: val_loss did not improve from 0.19256
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 102s 217ms/step - accuracy: 0.9269 - f1_m: 0.9271 - loss: 0.2268 - precision_m: 0.9318 - recall_m: 0.9225 - val_accuracy: 0.9347 - val_f1_m: 0.9353 - val_loss: 0.1970 - val_precision_m: 0.9402 - val_recall_m: 0.9306 - learning_rate: 5.0000e-04
# Epoch 30/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9520 - f1_m: 0.9516 - loss: 0.1680 - precision_m: 0.9545 - recall_m: 0.9487
# Epoch 30: val_loss improved from 0.19256 to 0.15570, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 220ms/step - accuracy: 0.9520 - f1_m: 0.9516 - loss: 0.1680 - precision_m: 0.9545 - recall_m: 0.9487 - val_accuracy: 0.9527 - val_f1_m: 0.9522 - val_loss: 0.1557 - val_precision_m: 0.9538 - val_recall_m: 0.9506 - learning_rate: 2.5000e-04
# Epoch 31/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9553 - f1_m: 0.9555 - loss: 0.1545 - precision_m: 0.9572 - recall_m: 0.9537
# Epoch 31: val_loss improved from 0.15570 to 0.12209, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 106s 226ms/step - accuracy: 0.9553 - f1_m: 0.9555 - loss: 0.1545 - precision_m: 0.9572 - recall_m: 0.9537 - val_accuracy: 0.9661 - val_f1_m: 0.9659 - val_loss: 0.1221 - val_precision_m: 0.9670 - val_recall_m: 0.9648 - learning_rate: 2.5000e-04
# Epoch 32/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9572 - f1_m: 0.9574 - loss: 0.1452 - precision_m: 0.9597 - recall_m: 0.9552
# Epoch 32: val_loss improved from 0.12209 to 0.12062, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 102s 218ms/step - accuracy: 0.9572 - f1_m: 0.9574 - loss: 0.1452 - precision_m: 0.9597 - recall_m: 0.9552 - val_accuracy: 0.9689 - val_f1_m: 0.9687 - val_loss: 0.1206 - val_precision_m: 0.9694 - val_recall_m: 0.9680 - learning_rate: 2.5000e-04
# Epoch 33/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9610 - f1_m: 0.9609 - loss: 0.1363 - precision_m: 0.9625 - recall_m: 0.9593
# Epoch 33: val_loss improved from 0.12062 to 0.11844, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 219ms/step - accuracy: 0.9610 - f1_m: 0.9609 - loss: 0.1363 - precision_m: 0.9625 - recall_m: 0.9593 - val_accuracy: 0.9663 - val_f1_m: 0.9660 - val_loss: 0.1184 - val_precision_m: 0.9670 - val_recall_m: 0.9650 - learning_rate: 2.5000e-04
# Epoch 34/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9632 - f1_m: 0.9636 - loss: 0.1310 - precision_m: 0.9646 - recall_m: 0.9626
# Epoch 34: val_loss improved from 0.11844 to 0.10963, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 106s 225ms/step - accuracy: 0.9632 - f1_m: 0.9635 - loss: 0.1310 - precision_m: 0.9646 - recall_m: 0.9626 - val_accuracy: 0.9708 - val_f1_m: 0.9707 - val_loss: 0.1096 - val_precision_m: 0.9713 - val_recall_m: 0.9701 - learning_rate: 2.5000e-04
# Epoch 35/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9647 - f1_m: 0.9644 - loss: 0.1344 - precision_m: 0.9656 - recall_m: 0.9632
# Epoch 35: val_loss did not improve from 0.10963
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 105s 225ms/step - accuracy: 0.9647 - f1_m: 0.9644 - loss: 0.1344 - precision_m: 0.9656 - recall_m: 0.9632 - val_accuracy: 0.9694 - val_f1_m: 0.9697 - val_loss: 0.1150 - val_precision_m: 0.9703 - val_recall_m: 0.9691 - learning_rate: 2.5000e-04
# Epoch 36/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9636 - f1_m: 0.9635 - loss: 0.1336 - precision_m: 0.9643 - recall_m: 0.9628
# Epoch 36: val_loss improved from 0.10963 to 0.10737, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 106s 226ms/step - accuracy: 0.9636 - f1_m: 0.9635 - loss: 0.1336 - precision_m: 0.9643 - recall_m: 0.9628 - val_accuracy: 0.9720 - val_f1_m: 0.9718 - val_loss: 0.1074 - val_precision_m: 0.9723 - val_recall_m: 0.9713 - learning_rate: 2.5000e-04
# Epoch 37/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9686 - f1_m: 0.9686 - loss: 0.1180 - precision_m: 0.9698 - recall_m: 0.9674
# Epoch 37: val_loss did not improve from 0.10737
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 102s 218ms/step - accuracy: 0.9686 - f1_m: 0.9686 - loss: 0.1180 - precision_m: 0.9698 - recall_m: 0.9674 - val_accuracy: 0.9706 - val_f1_m: 0.9708 - val_loss: 0.1121 - val_precision_m: 0.9716 - val_recall_m: 0.9700 - learning_rate: 2.5000e-04
# Epoch 38/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9648 - f1_m: 0.9651 - loss: 0.1234 - precision_m: 0.9659 - recall_m: 0.9643
# Epoch 38: val_loss improved from 0.10737 to 0.09959, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 102s 217ms/step - accuracy: 0.9648 - f1_m: 0.9651 - loss: 0.1234 - precision_m: 0.9659 - recall_m: 0.9643 - val_accuracy: 0.9741 - val_f1_m: 0.9739 - val_loss: 0.0996 - val_precision_m: 0.9744 - val_recall_m: 0.9733 - learning_rate: 2.5000e-04
# Epoch 39/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9705 - f1_m: 0.9706 - loss: 0.1110 - precision_m: 0.9713 - recall_m: 0.9699
# Epoch 39: val_loss improved from 0.09959 to 0.09938, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 105s 225ms/step - accuracy: 0.9705 - f1_m: 0.9706 - loss: 0.1110 - precision_m: 0.9713 - recall_m: 0.9699 - val_accuracy: 0.9740 - val_f1_m: 0.9740 - val_loss: 0.0994 - val_precision_m: 0.9743 - val_recall_m: 0.9736 - learning_rate: 2.5000e-04
# Epoch 40/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9664 - f1_m: 0.9666 - loss: 0.1222 - precision_m: 0.9674 - recall_m: 0.9659
# Epoch 40: val_loss did not improve from 0.09938
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 104s 221ms/step - accuracy: 0.9664 - f1_m: 0.9666 - loss: 0.1222 - precision_m: 0.9674 - recall_m: 0.9659 - val_accuracy: 0.9651 - val_f1_m: 0.9649 - val_loss: 0.1192 - val_precision_m: 0.9656 - val_recall_m: 0.9643 - learning_rate: 2.5000e-04
# Epoch 41/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9695 - f1_m: 0.9693 - loss: 0.1161 - precision_m: 0.9699 - recall_m: 0.9687
# Epoch 41: val_loss improved from 0.09938 to 0.09085, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 105s 224ms/step - accuracy: 0.9695 - f1_m: 0.9693 - loss: 0.1161 - precision_m: 0.9699 - recall_m: 0.9687 - val_accuracy: 0.9768 - val_f1_m: 0.9768 - val_loss: 0.0908 - val_precision_m: 0.9770 - val_recall_m: 0.9766 - learning_rate: 2.5000e-04
# Epoch 42/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9703 - f1_m: 0.9703 - loss: 0.1128 - precision_m: 0.9710 - recall_m: 0.9696
# Epoch 42: val_loss did not improve from 0.09085
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 102s 217ms/step - accuracy: 0.9703 - f1_m: 0.9703 - loss: 0.1128 - precision_m: 0.9710 - recall_m: 0.9696 - val_accuracy: 0.9618 - val_f1_m: 0.9618 - val_loss: 0.1339 - val_precision_m: 0.9619 - val_recall_m: 0.9617 - learning_rate: 2.5000e-04
# Epoch 43/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9692 - f1_m: 0.9693 - loss: 0.1142 - precision_m: 0.9698 - recall_m: 0.9687
# Epoch 43: val_loss did not improve from 0.09085
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 142s 216ms/step - accuracy: 0.9692 - f1_m: 0.9693 - loss: 0.1142 - precision_m: 0.9698 - recall_m: 0.9687 - val_accuracy: 0.9740 - val_f1_m: 0.9739 - val_loss: 0.0985 - val_precision_m: 0.9745 - val_recall_m: 0.9734 - learning_rate: 2.5000e-04
# Epoch 44/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9725 - f1_m: 0.9726 - loss: 0.1050 - precision_m: 0.9730 - recall_m: 0.9721
# Epoch 44: val_loss improved from 0.09085 to 0.08985, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 102s 218ms/step - accuracy: 0.9725 - f1_m: 0.9726 - loss: 0.1050 - precision_m: 0.9730 - recall_m: 0.9721 - val_accuracy: 0.9782 - val_f1_m: 0.9783 - val_loss: 0.0898 - val_precision_m: 0.9788 - val_recall_m: 0.9779 - learning_rate: 2.5000e-04
# Epoch 45/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9741 - f1_m: 0.9742 - loss: 0.1009 - precision_m: 0.9747 - recall_m: 0.9737
# Epoch 45: val_loss did not improve from 0.08985
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 101s 215ms/step - accuracy: 0.9741 - f1_m: 0.9742 - loss: 0.1009 - precision_m: 0.9747 - recall_m: 0.9737 - val_accuracy: 0.9730 - val_f1_m: 0.9729 - val_loss: 0.1077 - val_precision_m: 0.9731 - val_recall_m: 0.9727 - learning_rate: 2.5000e-04
# Epoch 46/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9729 - f1_m: 0.9731 - loss: 0.1068 - precision_m: 0.9736 - recall_m: 0.9727
# Epoch 46: val_loss improved from 0.08985 to 0.08975, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 102s 217ms/step - accuracy: 0.9730 - f1_m: 0.9731 - loss: 0.1068 - precision_m: 0.9736 - recall_m: 0.9727 - val_accuracy: 0.9773 - val_f1_m: 0.9772 - val_loss: 0.0898 - val_precision_m: 0.9775 - val_recall_m: 0.9768 - learning_rate: 2.5000e-04
# Epoch 47/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9758 - f1_m: 0.9758 - loss: 0.0984 - precision_m: 0.9761 - recall_m: 0.9755
# Epoch 47: val_loss did not improve from 0.08975
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 220ms/step - accuracy: 0.9758 - f1_m: 0.9758 - loss: 0.0984 - precision_m: 0.9761 - recall_m: 0.9755 - val_accuracy: 0.9638 - val_f1_m: 0.9639 - val_loss: 0.1215 - val_precision_m: 0.9645 - val_recall_m: 0.9633 - learning_rate: 2.5000e-04
# Epoch 48/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9836 - f1_m: 0.9837 - loss: 0.0773 - precision_m: 0.9838 - recall_m: 0.9835
# Epoch 48: val_loss improved from 0.08975 to 0.06646, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 104s 221ms/step - accuracy: 0.9836 - f1_m: 0.9837 - loss: 0.0772 - precision_m: 0.9838 - recall_m: 0.9835 - val_accuracy: 0.9869 - val_f1_m: 0.9868 - val_loss: 0.0665 - val_precision_m: 0.9869 - val_recall_m: 0.9868 - learning_rate: 1.2500e-04
# Epoch 49/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9857 - f1_m: 0.9855 - loss: 0.0683 - precision_m: 0.9858 - recall_m: 0.9851
# Epoch 49: val_loss did not improve from 0.06646
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 108s 229ms/step - accuracy: 0.9857 - f1_m: 0.9855 - loss: 0.0682 - precision_m: 0.9858 - recall_m: 0.9851 - val_accuracy: 0.9868 - val_f1_m: 0.9866 - val_loss: 0.0667 - val_precision_m: 0.9867 - val_recall_m: 0.9864 - learning_rate: 1.2500e-04
# Epoch 50/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9860 - f1_m: 0.9859 - loss: 0.0666 - precision_m: 0.9861 - recall_m: 0.9858
# Epoch 50: val_loss improved from 0.06646 to 0.06518, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 220ms/step - accuracy: 0.9860 - f1_m: 0.9859 - loss: 0.0666 - precision_m: 0.9861 - recall_m: 0.9858 - val_accuracy: 0.9854 - val_f1_m: 0.9854 - val_loss: 0.0652 - val_precision_m: 0.9855 - val_recall_m: 0.9853 - learning_rate: 1.2500e-04
# Epoch 51/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9871 - f1_m: 0.9870 - loss: 0.0652 - precision_m: 0.9871 - recall_m: 0.9869
# Epoch 51: val_loss did not improve from 0.06518
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 220ms/step - accuracy: 0.9871 - f1_m: 0.9870 - loss: 0.0653 - precision_m: 0.9871 - recall_m: 0.9869 - val_accuracy: 0.9870 - val_f1_m: 0.9869 - val_loss: 0.0695 - val_precision_m: 0.9869 - val_recall_m: 0.9869 - learning_rate: 1.2500e-04
# Epoch 52/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9863 - f1_m: 0.9864 - loss: 0.0647 - precision_m: 0.9866 - recall_m: 0.9862
# Epoch 52: val_loss did not improve from 0.06518
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 106s 227ms/step - accuracy: 0.9863 - f1_m: 0.9864 - loss: 0.0647 - precision_m: 0.9866 - recall_m: 0.9862 - val_accuracy: 0.9871 - val_f1_m: 0.9871 - val_loss: 0.0687 - val_precision_m: 0.9871 - val_recall_m: 0.9870 - learning_rate: 1.2500e-04
# Epoch 53/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9858 - f1_m: 0.9858 - loss: 0.0659 - precision_m: 0.9859 - recall_m: 0.9856
# Epoch 53: val_loss did not improve from 0.06518
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 102s 217ms/step - accuracy: 0.9858 - f1_m: 0.9858 - loss: 0.0659 - precision_m: 0.9859 - recall_m: 0.9856 - val_accuracy: 0.9862 - val_f1_m: 0.9863 - val_loss: 0.0709 - val_precision_m: 0.9865 - val_recall_m: 0.9861 - learning_rate: 1.2500e-04
# Epoch 54/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9916 - f1_m: 0.9917 - loss: 0.0521 - precision_m: 0.9918 - recall_m: 0.9916
# Epoch 54: val_loss improved from 0.06518 to 0.05260, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 220ms/step - accuracy: 0.9916 - f1_m: 0.9917 - loss: 0.0521 - precision_m: 0.9918 - recall_m: 0.9916 - val_accuracy: 0.9908 - val_f1_m: 0.9907 - val_loss: 0.0526 - val_precision_m: 0.9908 - val_recall_m: 0.9906 - learning_rate: 6.2500e-05
# Epoch 55/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9919 - f1_m: 0.9918 - loss: 0.0512 - precision_m: 0.9919 - recall_m: 0.9918
# Epoch 55: val_loss did not improve from 0.05260
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 104s 222ms/step - accuracy: 0.9919 - f1_m: 0.9918 - loss: 0.0512 - precision_m: 0.9919 - recall_m: 0.9918 - val_accuracy: 0.9898 - val_f1_m: 0.9895 - val_loss: 0.0573 - val_precision_m: 0.9896 - val_recall_m: 0.9895 - learning_rate: 6.2500e-05
# Epoch 56/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9907 - f1_m: 0.9908 - loss: 0.0510 - precision_m: 0.9909 - recall_m: 0.9907
# Epoch 56: val_loss improved from 0.05260 to 0.05023, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 102s 218ms/step - accuracy: 0.9907 - f1_m: 0.9908 - loss: 0.0510 - precision_m: 0.9909 - recall_m: 0.9907 - val_accuracy: 0.9926 - val_f1_m: 0.9925 - val_loss: 0.0502 - val_precision_m: 0.9925 - val_recall_m: 0.9925 - learning_rate: 6.2500e-05
# Epoch 57/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9926 - f1_m: 0.9927 - loss: 0.0485 - precision_m: 0.9928 - recall_m: 0.9926
# Epoch 57: val_loss did not improve from 0.05023
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 219ms/step - accuracy: 0.9926 - f1_m: 0.9927 - loss: 0.0485 - precision_m: 0.9928 - recall_m: 0.9926 - val_accuracy: 0.9906 - val_f1_m: 0.9906 - val_loss: 0.0556 - val_precision_m: 0.9907 - val_recall_m: 0.9906 - learning_rate: 6.2500e-05
# Epoch 58/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9916 - f1_m: 0.9917 - loss: 0.0486 - precision_m: 0.9919 - recall_m: 0.9915
# Epoch 58: val_loss improved from 0.05023 to 0.04582, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 220ms/step - accuracy: 0.9916 - f1_m: 0.9917 - loss: 0.0486 - precision_m: 0.9919 - recall_m: 0.9915 - val_accuracy: 0.9948 - val_f1_m: 0.9948 - val_loss: 0.0458 - val_precision_m: 0.9949 - val_recall_m: 0.9947 - learning_rate: 6.2500e-05
# Epoch 59/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9924 - f1_m: 0.9924 - loss: 0.0488 - precision_m: 0.9925 - recall_m: 0.9922
# Epoch 59: val_loss did not improve from 0.04582
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 101s 215ms/step - accuracy: 0.9924 - f1_m: 0.9924 - loss: 0.0488 - precision_m: 0.9925 - recall_m: 0.9922 - val_accuracy: 0.9920 - val_f1_m: 0.9919 - val_loss: 0.0518 - val_precision_m: 0.9921 - val_recall_m: 0.9918 - learning_rate: 6.2500e-05
# Epoch 60/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9931 - f1_m: 0.9931 - loss: 0.0462 - precision_m: 0.9932 - recall_m: 0.9931
# Epoch 60: val_loss did not improve from 0.04582
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 101s 216ms/step - accuracy: 0.9931 - f1_m: 0.9931 - loss: 0.0462 - precision_m: 0.9932 - recall_m: 0.9931 - val_accuracy: 0.9921 - val_f1_m: 0.9921 - val_loss: 0.0515 - val_precision_m: 0.9921 - val_recall_m: 0.9920 - learning_rate: 6.2500e-05
# Epoch 61/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9930 - f1_m: 0.9929 - loss: 0.0472 - precision_m: 0.9930 - recall_m: 0.9928
# Epoch 61: val_loss did not improve from 0.04582
#
# Epoch 61: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 101s 216ms/step - accuracy: 0.9930 - f1_m: 0.9929 - loss: 0.0472 - precision_m: 0.9930 - recall_m: 0.9928 - val_accuracy: 0.9911 - val_f1_m: 0.9911 - val_loss: 0.0489 - val_precision_m: 0.9911 - val_recall_m: 0.9911 - learning_rate: 6.2500e-05
# Epoch 62/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9954 - f1_m: 0.9953 - loss: 0.0402 - precision_m: 0.9954 - recall_m: 0.9953
# Epoch 62: val_loss improved from 0.04582 to 0.04286, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 100s 214ms/step - accuracy: 0.9954 - f1_m: 0.9953 - loss: 0.0402 - precision_m: 0.9954 - recall_m: 0.9953 - val_accuracy: 0.9951 - val_f1_m: 0.9951 - val_loss: 0.0429 - val_precision_m: 0.9952 - val_recall_m: 0.9951 - learning_rate: 3.1250e-05
# Epoch 63/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9955 - f1_m: 0.9955 - loss: 0.0403 - precision_m: 0.9956 - recall_m: 0.9955
# Epoch 63: val_loss did not improve from 0.04286
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 101s 215ms/step - accuracy: 0.9955 - f1_m: 0.9955 - loss: 0.0403 - precision_m: 0.9956 - recall_m: 0.9955 - val_accuracy: 0.9948 - val_f1_m: 0.9947 - val_loss: 0.0447 - val_precision_m: 0.9947 - val_recall_m: 0.9947 - learning_rate: 3.1250e-05
# Epoch 64/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9946 - f1_m: 0.9945 - loss: 0.0405 - precision_m: 0.9946 - recall_m: 0.9945
# Epoch 64: val_loss did not improve from 0.04286
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 101s 215ms/step - accuracy: 0.9946 - f1_m: 0.9945 - loss: 0.0405 - precision_m: 0.9946 - recall_m: 0.9945 - val_accuracy: 0.9944 - val_f1_m: 0.9943 - val_loss: 0.0443 - val_precision_m: 0.9944 - val_recall_m: 0.9942 - learning_rate: 3.1250e-05
# Epoch 65/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9947 - f1_m: 0.9946 - loss: 0.0403 - precision_m: 0.9947 - recall_m: 0.9945
# Epoch 65: val_loss did not improve from 0.04286
#
# Epoch 65: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 104s 222ms/step - accuracy: 0.9947 - f1_m: 0.9946 - loss: 0.0403 - precision_m: 0.9947 - recall_m: 0.9945 - val_accuracy: 0.9943 - val_f1_m: 0.9942 - val_loss: 0.0445 - val_precision_m: 0.9943 - val_recall_m: 0.9942 - learning_rate: 3.1250e-05
# Epoch 66/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9971 - f1_m: 0.9971 - loss: 0.0357 - precision_m: 0.9971 - recall_m: 0.9970
# Epoch 66: val_loss improved from 0.04286 to 0.04189, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 102s 216ms/step - accuracy: 0.9971 - f1_m: 0.9971 - loss: 0.0357 - precision_m: 0.9971 - recall_m: 0.9970 - val_accuracy: 0.9947 - val_f1_m: 0.9946 - val_loss: 0.0419 - val_precision_m: 0.9946 - val_recall_m: 0.9945 - learning_rate: 1.5625e-05
# Epoch 67/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9964 - f1_m: 0.9964 - loss: 0.0358 - precision_m: 0.9964 - recall_m: 0.9964
# Epoch 67: val_loss improved from 0.04189 to 0.04189, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 102s 218ms/step - accuracy: 0.9964 - f1_m: 0.9964 - loss: 0.0359 - precision_m: 0.9964 - recall_m: 0.9964 - val_accuracy: 0.9951 - val_f1_m: 0.9951 - val_loss: 0.0419 - val_precision_m: 0.9951 - val_recall_m: 0.9951 - learning_rate: 1.5625e-05
# Epoch 68/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9957 - f1_m: 0.9956 - loss: 0.0377 - precision_m: 0.9957 - recall_m: 0.9956
# Epoch 68: val_loss did not improve from 0.04189
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 104s 221ms/step - accuracy: 0.9957 - f1_m: 0.9956 - loss: 0.0377 - precision_m: 0.9957 - recall_m: 0.9956 - val_accuracy: 0.9949 - val_f1_m: 0.9948 - val_loss: 0.0428 - val_precision_m: 0.9948 - val_recall_m: 0.9947 - learning_rate: 1.5625e-05
# Epoch 69/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9962 - f1_m: 0.9962 - loss: 0.0364 - precision_m: 0.9963 - recall_m: 0.9962
# Epoch 69: val_loss improved from 0.04189 to 0.04176, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 220ms/step - accuracy: 0.9962 - f1_m: 0.9962 - loss: 0.0364 - precision_m: 0.9963 - recall_m: 0.9962 - val_accuracy: 0.9949 - val_f1_m: 0.9950 - val_loss: 0.0418 - val_precision_m: 0.9950 - val_recall_m: 0.9949 - learning_rate: 1.5625e-05
# Epoch 70/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9960 - f1_m: 0.9960 - loss: 0.0362 - precision_m: 0.9960 - recall_m: 0.9960
# Epoch 70: val_loss improved from 0.04176 to 0.04130, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 107s 228ms/step - accuracy: 0.9960 - f1_m: 0.9960 - loss: 0.0362 - precision_m: 0.9960 - recall_m: 0.9960 - val_accuracy: 0.9959 - val_f1_m: 0.9959 - val_loss: 0.0413 - val_precision_m: 0.9959 - val_recall_m: 0.9959 - learning_rate: 1.5625e-05
# Epoch 71/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9964 - f1_m: 0.9965 - loss: 0.0352 - precision_m: 0.9965 - recall_m: 0.9964
# Epoch 71: val_loss improved from 0.04130 to 0.04129, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 104s 221ms/step - accuracy: 0.9964 - f1_m: 0.9965 - loss: 0.0352 - precision_m: 0.9965 - recall_m: 0.9964 - val_accuracy: 0.9952 - val_f1_m: 0.9952 - val_loss: 0.0413 - val_precision_m: 0.9953 - val_recall_m: 0.9952 - learning_rate: 1.5625e-05
# Epoch 72/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9960 - f1_m: 0.9959 - loss: 0.0359 - precision_m: 0.9962 - recall_m: 0.9957
# Epoch 72: val_loss improved from 0.04129 to 0.04073, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 220ms/step - accuracy: 0.9960 - f1_m: 0.9959 - loss: 0.0359 - precision_m: 0.9962 - recall_m: 0.9957 - val_accuracy: 0.9951 - val_f1_m: 0.9951 - val_loss: 0.0407 - val_precision_m: 0.9951 - val_recall_m: 0.9951 - learning_rate: 1.5625e-05
# Epoch 73/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9961 - f1_m: 0.9962 - loss: 0.0365 - precision_m: 0.9962 - recall_m: 0.9961
# Epoch 73: val_loss improved from 0.04073 to 0.04041, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 102s 218ms/step - accuracy: 0.9961 - f1_m: 0.9962 - loss: 0.0365 - precision_m: 0.9962 - recall_m: 0.9961 - val_accuracy: 0.9954 - val_f1_m: 0.9953 - val_loss: 0.0404 - val_precision_m: 0.9954 - val_recall_m: 0.9953 - learning_rate: 1.5625e-05
# Epoch 74/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9963 - f1_m: 0.9963 - loss: 0.0361 - precision_m: 0.9963 - recall_m: 0.9962
# Epoch 74: val_loss improved from 0.04041 to 0.03920, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 142s 218ms/step - accuracy: 0.9963 - f1_m: 0.9963 - loss: 0.0361 - precision_m: 0.9963 - recall_m: 0.9962 - val_accuracy: 0.9962 - val_f1_m: 0.9962 - val_loss: 0.0392 - val_precision_m: 0.9962 - val_recall_m: 0.9962 - learning_rate: 1.5625e-05
# Epoch 75/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9968 - f1_m: 0.9968 - loss: 0.0351 - precision_m: 0.9968 - recall_m: 0.9968
# Epoch 75: val_loss did not improve from 0.03920
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 102s 218ms/step - accuracy: 0.9968 - f1_m: 0.9968 - loss: 0.0351 - precision_m: 0.9968 - recall_m: 0.9968 - val_accuracy: 0.9953 - val_f1_m: 0.9954 - val_loss: 0.0414 - val_precision_m: 0.9955 - val_recall_m: 0.9953 - learning_rate: 1.5625e-05
# Epoch 76/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9965 - f1_m: 0.9965 - loss: 0.0352 - precision_m: 0.9965 - recall_m: 0.9965
# Epoch 76: val_loss did not improve from 0.03920
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 219ms/step - accuracy: 0.9965 - f1_m: 0.9965 - loss: 0.0352 - precision_m: 0.9965 - recall_m: 0.9965 - val_accuracy: 0.9954 - val_f1_m: 0.9954 - val_loss: 0.0413 - val_precision_m: 0.9954 - val_recall_m: 0.9954 - learning_rate: 1.5625e-05
# Epoch 77/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9967 - f1_m: 0.9967 - loss: 0.0341 - precision_m: 0.9967 - recall_m: 0.9967
# Epoch 77: val_loss did not improve from 0.03920
#
# Epoch 77: ReduceLROnPlateau reducing learning rate to 1e-05.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 102s 217ms/step - accuracy: 0.9967 - f1_m: 0.9967 - loss: 0.0341 - precision_m: 0.9967 - recall_m: 0.9967 - val_accuracy: 0.9957 - val_f1_m: 0.9957 - val_loss: 0.0419 - val_precision_m: 0.9957 - val_recall_m: 0.9957 - learning_rate: 1.5625e-05
# Epoch 78/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9966 - f1_m: 0.9967 - loss: 0.0339 - precision_m: 0.9967 - recall_m: 0.9966
# Epoch 78: val_loss did not improve from 0.03920
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 102s 217ms/step - accuracy: 0.9966 - f1_m: 0.9967 - loss: 0.0339 - precision_m: 0.9967 - recall_m: 0.9966 - val_accuracy: 0.9962 - val_f1_m: 0.9962 - val_loss: 0.0400 - val_precision_m: 0.9962 - val_recall_m: 0.9962 - learning_rate: 1.0000e-05
# Epoch 79/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9969 - f1_m: 0.9969 - loss: 0.0344 - precision_m: 0.9970 - recall_m: 0.9969
# Epoch 79: val_loss did not improve from 0.03920
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 142s 218ms/step - accuracy: 0.9969 - f1_m: 0.9969 - loss: 0.0344 - precision_m: 0.9970 - recall_m: 0.9969 - val_accuracy: 0.9957 - val_f1_m: 0.9957 - val_loss: 0.0407 - val_precision_m: 0.9957 - val_recall_m: 0.9957 - learning_rate: 1.0000e-05
# Epoch 80/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9969 - f1_m: 0.9969 - loss: 0.0340 - precision_m: 0.9969 - recall_m: 0.9969
# Epoch 80: val_loss did not improve from 0.03920
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 102s 218ms/step - accuracy: 0.9969 - f1_m: 0.9969 - loss: 0.0340 - precision_m: 0.9969 - recall_m: 0.9969 - val_accuracy: 0.9959 - val_f1_m: 0.9960 - val_loss: 0.0400 - val_precision_m: 0.9960 - val_recall_m: 0.9959 - learning_rate: 1.0000e-05
# Epoch 81/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9967 - f1_m: 0.9967 - loss: 0.0351 - precision_m: 0.9967 - recall_m: 0.9966
# Epoch 81: val_loss did not improve from 0.03920
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 142s 220ms/step - accuracy: 0.9967 - f1_m: 0.9967 - loss: 0.0351 - precision_m: 0.9967 - recall_m: 0.9966 - val_accuracy: 0.9956 - val_f1_m: 0.9956 - val_loss: 0.0409 - val_precision_m: 0.9957 - val_recall_m: 0.9956 - learning_rate: 1.0000e-05
# Epoch 82/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9970 - f1_m: 0.9970 - loss: 0.0332 - precision_m: 0.9970 - recall_m: 0.9970
# Epoch 82: val_loss did not improve from 0.03920
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 142s 220ms/step - accuracy: 0.9970 - f1_m: 0.9970 - loss: 0.0332 - precision_m: 0.9970 - recall_m: 0.9970 - val_accuracy: 0.9954 - val_f1_m: 0.9954 - val_loss: 0.0402 - val_precision_m: 0.9954 - val_recall_m: 0.9954 - learning_rate: 1.0000e-05
# Epoch 83/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9974 - f1_m: 0.9974 - loss: 0.0325 - precision_m: 0.9974 - recall_m: 0.9974
# Epoch 83: val_loss improved from 0.03920 to 0.03911, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 102s 218ms/step - accuracy: 0.9974 - f1_m: 0.9974 - loss: 0.0325 - precision_m: 0.9974 - recall_m: 0.9974 - val_accuracy: 0.9956 - val_f1_m: 0.9956 - val_loss: 0.0391 - val_precision_m: 0.9956 - val_recall_m: 0.9955 - learning_rate: 1.0000e-05
# Epoch 84/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9964 - f1_m: 0.9964 - loss: 0.0354 - precision_m: 0.9964 - recall_m: 0.9964
# Epoch 84: val_loss did not improve from 0.03911
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 104s 222ms/step - accuracy: 0.9964 - f1_m: 0.9964 - loss: 0.0354 - precision_m: 0.9964 - recall_m: 0.9964 - val_accuracy: 0.9957 - val_f1_m: 0.9957 - val_loss: 0.0400 - val_precision_m: 0.9957 - val_recall_m: 0.9957 - learning_rate: 1.0000e-05
# Epoch 85/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9970 - f1_m: 0.9970 - loss: 0.0340 - precision_m: 0.9970 - recall_m: 0.9970
# Epoch 85: val_loss did not improve from 0.03911
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 220ms/step - accuracy: 0.9970 - f1_m: 0.9970 - loss: 0.0340 - precision_m: 0.9970 - recall_m: 0.9970 - val_accuracy: 0.9952 - val_f1_m: 0.9952 - val_loss: 0.0410 - val_precision_m: 0.9952 - val_recall_m: 0.9952 - learning_rate: 1.0000e-05
# Epoch 86/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9972 - f1_m: 0.9972 - loss: 0.0338 - precision_m: 0.9973 - recall_m: 0.9972
# Epoch 86: val_loss did not improve from 0.03911
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 102s 218ms/step - accuracy: 0.9972 - f1_m: 0.9972 - loss: 0.0338 - precision_m: 0.9973 - recall_m: 0.9972 - val_accuracy: 0.9954 - val_f1_m: 0.9954 - val_loss: 0.0406 - val_precision_m: 0.9955 - val_recall_m: 0.9954 - learning_rate: 1.0000e-05
# Epoch 87/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9980 - f1_m: 0.9980 - loss: 0.0314 - precision_m: 0.9980 - recall_m: 0.9980
# Epoch 87: val_loss did not improve from 0.03911
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 105s 223ms/step - accuracy: 0.9980 - f1_m: 0.9980 - loss: 0.0314 - precision_m: 0.9980 - recall_m: 0.9980 - val_accuracy: 0.9960 - val_f1_m: 0.9959 - val_loss: 0.0397 - val_precision_m: 0.9959 - val_recall_m: 0.9958 - learning_rate: 1.0000e-05
# Epoch 88/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9971 - f1_m: 0.9971 - loss: 0.0326 - precision_m: 0.9971 - recall_m: 0.9971
# Epoch 88: val_loss improved from 0.03911 to 0.03876, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 219ms/step - accuracy: 0.9971 - f1_m: 0.9971 - loss: 0.0326 - precision_m: 0.9971 - recall_m: 0.9971 - val_accuracy: 0.9962 - val_f1_m: 0.9962 - val_loss: 0.0388 - val_precision_m: 0.9962 - val_recall_m: 0.9962 - learning_rate: 1.0000e-05
# Epoch 89/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9962 - f1_m: 0.9962 - loss: 0.0339 - precision_m: 0.9962 - recall_m: 0.9962
# Epoch 89: val_loss did not improve from 0.03876
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 104s 222ms/step - accuracy: 0.9962 - f1_m: 0.9962 - loss: 0.0339 - precision_m: 0.9962 - recall_m: 0.9962 - val_accuracy: 0.9960 - val_f1_m: 0.9959 - val_loss: 0.0389 - val_precision_m: 0.9959 - val_recall_m: 0.9959 - learning_rate: 1.0000e-05
# Epoch 90/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9971 - f1_m: 0.9971 - loss: 0.0330 - precision_m: 0.9971 - recall_m: 0.9971
# Epoch 90: val_loss did not improve from 0.03876
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 102s 217ms/step - accuracy: 0.9971 - f1_m: 0.9971 - loss: 0.0330 - precision_m: 0.9971 - recall_m: 0.9971 - val_accuracy: 0.9954 - val_f1_m: 0.9954 - val_loss: 0.0406 - val_precision_m: 0.9954 - val_recall_m: 0.9954 - learning_rate: 1.0000e-05
# Epoch 91/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9973 - f1_m: 0.9973 - loss: 0.0325 - precision_m: 0.9973 - recall_m: 0.9973
# Epoch 91: val_loss did not improve from 0.03876
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 220ms/step - accuracy: 0.9973 - f1_m: 0.9973 - loss: 0.0325 - precision_m: 0.9973 - recall_m: 0.9973 - val_accuracy: 0.9959 - val_f1_m: 0.9959 - val_loss: 0.0388 - val_precision_m: 0.9959 - val_recall_m: 0.9959 - learning_rate: 1.0000e-05
# Epoch 92/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9969 - f1_m: 0.9969 - loss: 0.0327 - precision_m: 0.9969 - recall_m: 0.9968
# Epoch 92: val_loss did not improve from 0.03876
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 220ms/step - accuracy: 0.9969 - f1_m: 0.9969 - loss: 0.0327 - precision_m: 0.9969 - recall_m: 0.9968 - val_accuracy: 0.9960 - val_f1_m: 0.9959 - val_loss: 0.0407 - val_precision_m: 0.9959 - val_recall_m: 0.9959 - learning_rate: 1.0000e-05
# Epoch 93/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9974 - f1_m: 0.9974 - loss: 0.0327 - precision_m: 0.9974 - recall_m: 0.9974
# Epoch 93: val_loss did not improve from 0.03876
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 219ms/step - accuracy: 0.9974 - f1_m: 0.9974 - loss: 0.0327 - precision_m: 0.9974 - recall_m: 0.9974 - val_accuracy: 0.9952 - val_f1_m: 0.9953 - val_loss: 0.0402 - val_precision_m: 0.9953 - val_recall_m: 0.9952 - learning_rate: 1.0000e-05
# Epoch 94/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9979 - f1_m: 0.9979 - loss: 0.0315 - precision_m: 0.9979 - recall_m: 0.9979
# Epoch 94: val_loss did not improve from 0.03876
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 102s 218ms/step - accuracy: 0.9979 - f1_m: 0.9979 - loss: 0.0315 - precision_m: 0.9979 - recall_m: 0.9979 - val_accuracy: 0.9956 - val_f1_m: 0.9955 - val_loss: 0.0405 - val_precision_m: 0.9955 - val_recall_m: 0.9955 - learning_rate: 1.0000e-05
# Epoch 95/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9965 - f1_m: 0.9965 - loss: 0.0333 - precision_m: 0.9965 - recall_m: 0.9965
# Epoch 95: val_loss did not improve from 0.03876
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 102s 218ms/step - accuracy: 0.9965 - f1_m: 0.9965 - loss: 0.0333 - precision_m: 0.9965 - recall_m: 0.9965 - val_accuracy: 0.9953 - val_f1_m: 0.9953 - val_loss: 0.0420 - val_precision_m: 0.9953 - val_recall_m: 0.9953 - learning_rate: 1.0000e-05
# Epoch 96/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.9971 - f1_m: 0.9971 - loss: 0.0319 - precision_m: 0.9971 - recall_m: 0.9971
# Epoch 96: val_loss did not improve from 0.03876
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 103s 219ms/step - accuracy: 0.9971 - f1_m: 0.9971 - loss: 0.0319 - precision_m: 0.9971 - recall_m: 0.9971 - val_accuracy: 0.9952 - val_f1_m: 0.9953 - val_loss: 0.0398 - val_precision_m: 0.9953 - val_recall_m: 0.9952 - learning_rate: 1.0000e-05
# Epoch 97/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.9969 - f1_m: 0.9968 - loss: 0.0327 - precision_m: 0.9969 - recall_m: 0.9967
# Epoch 97: val_loss improved from 0.03876 to 0.03846, saving model to /kaggle/working/best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 106s 226ms/step - accuracy: 0.9969 - f1_m: 0.9968 - loss: 0.0327 - precision_m: 0.9969 - recall_m: 0.9967 - val_accuracy: 0.9964 - val_f1_m: 0.9965 - val_loss: 0.0385 - val_precision_m: 0.9966 - val_recall_m: 0.9963 - learning_rate: 1.0000e-05
# Epoch 98/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9975 - f1_m: 0.9975 - loss: 0.0318 - precision_m: 0.9975 - recall_m: 0.9975
# Epoch 98: val_loss did not improve from 0.03846
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 102s 217ms/step - accuracy: 0.9975 - f1_m: 0.9975 - loss: 0.0318 - precision_m: 0.9975 - recall_m: 0.9975 - val_accuracy: 0.9959 - val_f1_m: 0.9959 - val_loss: 0.0391 - val_precision_m: 0.9959 - val_recall_m: 0.9959 - learning_rate: 1.0000e-05
# Epoch 99/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9977 - f1_m: 0.9977 - loss: 0.0311 - precision_m: 0.9977 - recall_m: 0.9977
# Epoch 99: val_loss did not improve from 0.03846
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 104s 221ms/step - accuracy: 0.9977 - f1_m: 0.9977 - loss: 0.0311 - precision_m: 0.9977 - recall_m: 0.9977 - val_accuracy: 0.9957 - val_f1_m: 0.9956 - val_loss: 0.0395 - val_precision_m: 0.9957 - val_recall_m: 0.9956 - learning_rate: 1.0000e-05
# Epoch 100/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9979 - f1_m: 0.9979 - loss: 0.0308 - precision_m: 0.9980 - recall_m: 0.9979
# Epoch 100: val_loss did not improve from 0.03846
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 107s 228ms/step - accuracy: 0.9979 - f1_m: 0.9979 - loss: 0.0308 - precision_m: 0.9980 - recall_m: 0.9979 - val_accuracy: 0.9962 - val_f1_m: 0.9963 - val_loss: 0.0387 - val_precision_m: 0.9963 - val_recall_m: 0.9962 - learning_rate: 1.0000e-05

# %%
loss, accuracy, f1_score, precision, recall = model_cnn_gru_swell.evaluate(X_test_gaf, y_test, verbose=0)
print(f"Validation Loss: {loss}")
print(f"Accuracy: {accuracy}")
print(f"F1 Score: {f1_score}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
# Out:
# Validation Loss: 0.038728926330804825
# Accuracy: 0.996222198009491
# F1 Score: 0.9962868094444275
# Precision: 0.9963430762290955
# Recall: 0.996232271194458

# %% [markdown]
# **Visualizations**

# %%
import numpy as np
import matplotlib.pyplot as plt

num_samples = 5
sample_images = X_test_gaf[:num_samples]
sample_labels = y_test[:num_samples]

pred_probs = model_cnn_gru_swell.predict(sample_images)
pred_classes = np.argmax(pred_probs, axis=1)
true_classes = np.argmax(sample_labels, axis=1)

for i in range(num_samples):
    plt.imshow(sample_images[i].reshape(sample_images[i].shape[0], sample_images[i].shape[1]), cmap='jet')
    plt.title(f"Actual: {true_classes[i]} | Predicted: {pred_classes[i]}")
    plt.axis('off')
    plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step

# %%
import matplotlib.pyplot as plt

def plot_accuracy_loss(history):
    fig, axs = plt.subplots(1, 2, figsize=(12, 4))

    # Plot Accuracy
    axs[0].plot(history.history['accuracy'], label='Train Accuracy')
    axs[0].plot(history.history['val_accuracy'], label='Validation Accuracy')
    axs[0].set_title('Model Accuracy')
    axs[0].set_xlabel('Epochs')
    axs[0].set_ylabel('Accuracy')
    axs[0].legend()

    # Plot Loss
    axs[1].plot(history.history['loss'], label='Train Loss')
    axs[1].plot(history.history['val_loss'], label='Validation Loss')
    axs[1].set_title('Model Loss')
    axs[1].set_xlabel('Epochs')
    axs[1].set_ylabel('Loss')
    axs[1].legend()

    plt.show()

plot_accuracy_loss(history)

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
import numpy as np

def plot_confusion_matrix(model, x_test, y_test):
    y_pred = np.argmax(model.predict(x_test), axis=1)
    y_true = np.argmax(y_test, axis=1)

    cm = confusion_matrix(y_true, y_pred)
    class_names = [f'Class {i}' for i in range(y_test.shape[1])]
    
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names,
                yticklabels=class_names)
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.show()

plot_confusion_matrix(model_cnn_gru_swell, X_test_gaf, y_test)
# Out:
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step

# %%
from sklearn.metrics import roc_curve, auc, roc_auc_score
from itertools import cycle
import matplotlib.pyplot as plt

def plot_roc_curve(model, x_test, y_test):
    y_pred = model.predict(x_test)
    n_classes = y_test.shape[1]

    fpr, tpr, roc_auc = {}, {}, {}
    plt.figure(figsize=(8, 6))
    colors = cycle(['blue', 'red', 'green', 'purple', 'orange'])

    for i, color in zip(range(n_classes), colors):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
        plt.plot(fpr[i], tpr[i], color=color, lw=2,
                 label=f'Class {i} (AUC = {roc_auc[i]:.2f})')

    fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_pred.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
    plt.plot(fpr["micro"], tpr["micro"],
             label=f'Micro-average ROC (AUC = {roc_auc["micro"]:.2f})',
             color='black', linestyle='--', linewidth=2)

    plt.plot([0, 1], [0, 1], 'k--', lw=1)

    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Multi-class ROC Curve')
    plt.legend(loc="lower right")
    plt.tight_layout()
    plt.show()
    
plot_roc_curve(model_cnn_gru_swell, X_test_gaf, y_test)
# Out:
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
def permutation_importance_gaf(model, X, y_true, base_score_fn=accuracy_score):
    """
    Computes permutation importance for GAF input of shape (N, 34, 34).
    Permutes both row and column i for each of the 34 original features.
    """
    base_preds = np.argmax(model.predict(X), axis=1)
    if len(y_true.shape) > 1:
        y_true = np.argmax(y_true, axis=1)

    base_score = base_score_fn(y_true, base_preds)
    feature_importance = []

    for i in range(34):  
        X_permuted = np.copy(X)

        for j in range(X.shape[0]):  
            perm = np.random.permutation(X.shape[1])
            X_permuted[j, i, :] = X_permuted[j, i, perm]  
            X_permuted[j, :, i] = X_permuted[j, perm, i]  

        preds = np.argmax(model.predict(X_permuted), axis=1)
        score = base_score_fn(y_true, preds)
        importance = base_score - score
        feature_importance.append(importance)

    return feature_importance               
feature_names = [
    "MEAN_RR", "MEDIAN_RR", "SDRR", "RMSSD", "SDSD", "SDRR_RMSSD", "HR", 
    "pNN25", "pNN50", "SD1", "SD2", "SD2_SD1", "KURT", "SKEW", "IQR", 
    "HF_PEAK", "HF_MEAN", "HF_MED", "HF_VAR", "LF", "LF_PEAK", "LF_MEAN", 
    "LF_MED", "LF_VAR", "LF_PCT", "LF_NU", "HF", "HF_PCT", "HF_NU", "TP", 
    "LF_HF", "HF_LF", "sampen", "higuci"
]

importance_per_feature = permutation_importance_gaf(model_cnn_gru_swell, X_test_gaf, y_test)
importance_per_feature = np.array(importance_per_feature)
importance_per_feature /= importance_per_feature.max()

plt.figure(figsize=(16, 6))
plt.bar(range(34), importance_per_feature, color='skyblue')
plt.xticks(range(34), feature_names, rotation=90)
plt.ylabel("Feature Importance")
plt.title("Permutation Feature Importance per Original Feature")
plt.grid(True, linestyle="--", alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 24ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step
# 282/282 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step
